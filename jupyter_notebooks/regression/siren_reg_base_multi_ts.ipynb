# %%
# !pip install tensorflow_addons
# !pip install keras-tuner --upgrade

# clone siren repository, refresh folder to see the siren repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Siren/
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5
# Cloning into 'Siren'...
# remote: Enumerating objects: 351, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 351 (delta 26), reused 48 (delta 22), pack-reused 297
# Receiving objects: 100% (351/351), 188.93 MiB | 23.77 MiB/s, done.
# Resolving deltas: 100% (98/98), done.
# Updating files: 100% (236/236), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"]="3"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_spec = 9
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_spec = (img_rows, img_cols, in_channel_spec)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_ts"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_tool.h5"
model_spec_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_spec.h5"

# dataset
csv_path = "/content/Siren/dataset/labels_reg_sample.csv"
tool_path = "/content/Siren/dataset/tool"
spec_path = "/content/Siren/dataset/spec"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                        tool  \
# 14   /content/Siren/dataset/tool/T8R3B4.jpg
# 10   /content/Siren/dataset/tool/T6R9B3.jpg
# 0    /content/Siren/dataset/tool/T1R2B1.jpg
# 3   /content/Siren/dataset/tool/T2R13B4.jpg
# 1    /content/Siren/dataset/tool/T1R7B4.jpg
#
#                                        spec_x  \
# 14   /content/Siren/dataset/spec/x/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/x/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/x/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/x/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/x/T1R7B4.jpg
#
#                                        spec_y  \
# 14   /content/Siren/dataset/spec/y/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/y/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/y/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/y/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/y/T1R7B4.jpg
#
#                                        spec_z
# 14   /content/Siren/dataset/spec/z/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/z/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/z/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/z/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/z/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                        tool  \
# 16   /content/Siren/dataset/tool/T9R7B4.jpg
# 18  /content/Siren/dataset/tool/T10R3B4.jpg
# 9   /content/Siren/dataset/tool/T5R12B1.jpg
#
#                                        spec_x  \
# 16   /content/Siren/dataset/spec/x/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/x/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/x/T5R12B1.jpg
#
#                                        spec_y  \
# 16   /content/Siren/dataset/spec/y/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/y/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/y/T5R12B1.jpg
#
#                                        spec_z
# 16   /content/Siren/dataset/spec/z/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/z/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/z/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                        tool  \
# 5   /content/Siren/dataset/tool/T3R10B1.jpg
# 13  /content/Siren/dataset/tool/T7R14B3.jpg
# 12   /content/Siren/dataset/tool/T7R8B3.jpg
#
#                                        spec_x  \
# 5   /content/Siren/dataset/spec/x/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/x/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/x/T7R8B3.jpg
#
#                                        spec_y  \
# 5   /content/Siren/dataset/spec/y/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/y/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/y/T7R8B3.jpg
#
#                                        spec_z
# 5   /content/Siren/dataset/spec/z/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/z/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/z/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images


def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []
    for i in range(file_paths_x.size):
        img = []
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_x)

        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_y)

        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_z)
        img = np.concatenate(img, axis=2)
        images.append(img)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / 255.0

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Split the last dimension into 3 separate spectrograms
spectrogram1 = x_train_spec[0, :, :, 0:3]  # First spectrogram (channels 0-2)
spectrogram2 = x_train_spec[0, :, :, 3:6]  # Second spectrogram (channels 3-5)
spectrogram3 = x_train_spec[0, :, :, 6:9]  # Third spectrogram (channels 6-8)
# Convert arrays to images
pil_img1 = tf.keras.utils.array_to_img(spectrogram1)
pil_img2 = tf.keras.utils.array_to_img(spectrogram2)
pil_img3 = tf.keras.utils.array_to_img(spectrogram3)
# Display the images
fig, ax = plt.subplots(1,3, figsize=(10,30))
ax[0].imshow(pil_img1)
ax[1].imshow(pil_img2)
ax[2].imshow(pil_img3)
plt.plot()
# Out:
# []

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
# ============================== augment 1/2 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)

# %%
# ============================== augment 2/2 ==============================
data_augmentation_spec = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_spec",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_spec = data_augmentation_spec(x_train_spec)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_spec": x_train_spec,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_spec": x_test_spec,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_spec": x_val_spec,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs2 = k.Input(input_shape_spec)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_spec': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
model_tool = k.models.load_model(model_tool_path, compile=False)
model_spec = k.models.load_model(model_spec_path, compile=False)

model_tool.trainable = False
model_spec.trainable = False


def load_siren(model_tool, model_spec):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs2 = model_spec.input
    inputs2._name = "input_spec"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_spec = k.Model(
        inputs=model_spec.input, outputs=model_spec.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_spec.output,
        ]
    )
    output = layers.Dense(num_classes, activation="linear", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs2], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_spec.layers:
    layer._name = layer.name + str("_spec")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren(model_tool, model_spec)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1_tool (InputLayer)   [(None, 256, 256, 3)]        0         []
#
#  input_1_spec (InputLayer)   [(None, 256, 256, 9)]        0         []
#
#  conv2d_tool (Conv2D)        (None, 16, 16, 256)          196864    ['input_1_tool[0][0]']
#
#  conv2d_spec (Conv2D)        (None, 16, 16, 256)          590080    ['input_1_spec[0][0]']
#
#  activation_tool (Activatio  (None, 16, 16, 256)          0         ['conv2d_tool[0][0]']
#  n)
#
#  activation_spec (Activatio  (None, 16, 16, 256)          0         ['conv2d_spec[0][0]']
#  n)
#
#  batch_normalization_tool (  (None, 16, 16, 256)          1024      ['activation_tool[0][0]']
#  BatchNormalization)
#
#  batch_normalization_spec (  (None, 16, 16, 256)          1024      ['activation_spec[0][0]']
#  BatchNormalization)
#
#  depthwise_conv2d_tool (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_tool[0][
#  thwiseConv2D)                                                      0]']
#
#  depthwise_conv2d_spec (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_spec[0][
#  thwiseConv2D)                                                      0]']
#
#  activation_1_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_tool[0][0]'
#  ion)                                                               ]
#
#  activation_1_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_spec[0][0]'
#  ion)                                                               ]
#
#  batch_normalization_1_tool  (None, 16, 16, 256)          1024      ['activation_1_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_1_spec  (None, 16, 16, 256)          1024      ['activation_1_spec[0][0]']
#   (BatchNormalization)
#
#  add_tool (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_spec (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  conv2d_1_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_tool[0][0]']
#
#  conv2d_1_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_spec[0][0]']
#
#  activation_2_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_1_tool[0][0]']
#  ion)
#
#  activation_2_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_1_spec[0][0]']
#  ion)
#
#  batch_normalization_2_tool  (None, 16, 16, 256)          1024      ['activation_2_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_2_spec  (None, 16, 16, 256)          1024      ['activation_2_spec[0][0]']
#   (BatchNormalization)
#
#  depthwise_conv2d_1_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  depthwise_conv2d_1_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_3_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_tool[0][0
#  ion)                                                               ]']
#
#  activation_3_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_spec[0][0
#  ion)                                                               ]']
#
#  batch_normalization_3_tool  (None, 16, 16, 256)          1024      ['activation_3_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_3_spec  (None, 16, 16, 256)          1024      ['activation_3_spec[0][0]']
#   (BatchNormalization)
#
#  add_1_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_tool[0
#                                                                     ][0]']
#
#  add_1_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_spec[0
#                                                                     ][0]']
#
#  conv2d_2_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_tool[0][0]']
#
#  conv2d_2_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_spec[0][0]']
#
#  activation_4_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_2_tool[0][0]']
#  ion)
#
#  activation_4_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_2_spec[0][0]']
#  ion)
#
#  batch_normalization_4_tool  (None, 16, 16, 256)          1024      ['activation_4_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_4_spec  (None, 16, 16, 256)          1024      ['activation_4_spec[0][0]']
#   (BatchNormalization)
#
#  add_4_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_4_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  depthwise_conv2d_4_tool (D  (None, 16, 16, 256)          6656      ['add_4_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_4_spec (D  (None, 16, 16, 256)          6656      ['add_4_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_2_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_tool[0][0
#  ion)                                                               ]']
#
#  depthwise_conv2d_2_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_spec[0][0
#  ion)                                                               ]']
#
#  activation_5_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_tool[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_tool  (None, 16, 16, 256)          1024      ['activation_9_tool[0][0]']
#   (BatchNormalization)
#
#  activation_5_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_spec[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_spec  (None, 16, 16, 256)          1024      ['activation_9_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_5_tool  (None, 16, 16, 256)          1024      ['activation_5_tool[0][0]']
#   (BatchNormalization)
#
#  add_5_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_tool[0
#                                                                     ][0]',
#                                                                      'add_4_tool[0][0]']
#
#  batch_normalization_5_spec  (None, 16, 16, 256)          1024      ['activation_5_spec[0][0]']
#   (BatchNormalization)
#
#  add_5_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_spec[0
#                                                                     ][0]',
#                                                                      'add_4_spec[0][0]']
#
#  add_2_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_tool[0
#                                                                     ][0]']
#
#  conv2d_5_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_tool[0][0]']
#
#  add_2_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_spec[0
#                                                                     ][0]']
#
#  conv2d_5_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_spec[0][0]']
#
#  conv2d_3_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_tool[0][0]']
#
#  activation_10_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_5_tool[0][0]']
#  tion)
#
#  conv2d_3_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_spec[0][0]']
#
#  activation_10_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_5_spec[0][0]']
#  tion)
#
#  activation_6_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_3_tool[0][0]']
#  ion)
#
#  batch_normalization_10_too  (None, 16, 16, 256)          1024      ['activation_10_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_6_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_3_spec[0][0]']
#  ion)
#
#  batch_normalization_10_spe  (None, 16, 16, 256)          1024      ['activation_10_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_6_tool  (None, 16, 16, 256)          1024      ['activation_6_tool[0][0]']
#   (BatchNormalization)
#
#  add_6_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_tool[
#                                                                     0][0]']
#
#  batch_normalization_6_spec  (None, 16, 16, 256)          1024      ['activation_6_spec[0][0]']
#   (BatchNormalization)
#
#  add_6_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_spec[
#                                                                     0][0]']
#
#  add_7_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_tool[0
#                                                                     ][0]',
#                                                                      'add_6_tool[0][0]']
#
#  add_7_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_spec[0
#                                                                     ][0]',
#                                                                      'add_6_spec[0][0]']
#
#  depthwise_conv2d_5_tool (D  (None, 16, 16, 256)          6656      ['add_7_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_5_spec (D  (None, 16, 16, 256)          6656      ['add_7_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_3_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_tool[0][0
#  tion)                                                              ]']
#
#  depthwise_conv2d_3_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_spec[0][0
#  tion)                                                              ]']
#
#  activation_7_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_tool[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_too  (None, 16, 16, 256)          1024      ['activation_11_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_7_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_spec[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_spe  (None, 16, 16, 256)          1024      ['activation_11_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_7_tool  (None, 16, 16, 256)          1024      ['activation_7_tool[0][0]']
#   (BatchNormalization)
#
#  add_8_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_tool[
#                                                                     0][0]',
#                                                                      'add_7_tool[0][0]']
#
#  batch_normalization_7_spec  (None, 16, 16, 256)          1024      ['activation_7_spec[0][0]']
#   (BatchNormalization)
#
#  add_8_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_spec[
#                                                                     0][0]',
#                                                                      'add_7_spec[0][0]']
#
#  add_3_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_tool[0
#                                                                     ][0]']
#
#  conv2d_6_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_tool[0][0]']
#
#  add_3_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_spec[0
#                                                                     ][0]']
#
#  conv2d_6_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_spec[0][0]']
#
#  conv2d_4_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_tool[0][0]']
#
#  activation_12_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_6_tool[0][0]']
#  tion)
#
#  conv2d_4_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_spec[0][0]']
#
#  activation_12_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_6_spec[0][0]']
#  tion)
#
#  activation_8_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_4_tool[0][0]']
#  ion)
#
#  batch_normalization_12_too  (None, 16, 16, 256)          1024      ['activation_12_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_8_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_4_spec[0][0]']
#  ion)
#
#  batch_normalization_12_spe  (None, 16, 16, 256)          1024      ['activation_12_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_8_tool  (None, 16, 16, 256)          1024      ['activation_8_tool[0][0]']
#   (BatchNormalization)
#
#  add_9_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_tool[
#                                                                     0][0]']
#
#  batch_normalization_8_spec  (None, 16, 16, 256)          1024      ['activation_8_spec[0][0]']
#   (BatchNormalization)
#
#  add_9_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_spec[
#                                                                     0][0]']
#
#  add_10_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_8_tool[0
#                                                                     ][0]',
#                                                                      'add_9_tool[0][0]']
#
#  add_15_tool (Add)           (None, 16, 16, 256)          0         ['add_9_tool[0][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_10_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_8_spec[0
#                                                                     ][0]',
#                                                                      'add_9_spec[0][0]']
#
#  add_15_spec (Add)           (None, 16, 16, 256)          0         ['add_9_spec[0][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  depthwise_conv2d_6_tool (D  (None, 16, 16, 256)          6656      ['add_10_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_8_tool (D  (None, 16, 16, 256)          6656      ['add_15_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_6_spec (D  (None, 16, 16, 256)          6656      ['add_10_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_8_spec (D  (None, 16, 16, 256)          6656      ['add_15_spec[0][0]']
#  epthwiseConv2D)
#
#  activation_13_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_6_tool[0][0
#  tion)                                                              ]']
#
#  activation_17_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_8_tool[0][0
#  tion)                                                              ]']
#
#  activation_13_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_6_spec[0][0
#  tion)                                                              ]']
#
#  activation_17_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_8_spec[0][0
#  tion)                                                              ]']
#
#  batch_normalization_13_too  (None, 16, 16, 256)          1024      ['activation_13_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_17_too  (None, 16, 16, 256)          1024      ['activation_17_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_13_spe  (None, 16, 16, 256)          1024      ['activation_13_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_17_spe  (None, 16, 16, 256)          1024      ['activation_17_spec[0][0]']
#  c (BatchNormalization)
#
#  add_11_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_13_tool[
#                                                                     0][0]',
#                                                                      'add_10_tool[0][0]']
#
#  add_16_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_17_tool[
#                                                                     0][0]',
#                                                                      'add_15_tool[0][0]']
#
#  add_11_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_13_spec[
#                                                                     0][0]',
#                                                                      'add_10_spec[0][0]']
#
#  add_16_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_17_spec[
#                                                                     0][0]',
#                                                                      'add_15_spec[0][0]']
#
#  conv2d_7_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_11_tool[0][0]']
#
#  conv2d_9_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_16_tool[0][0]']
#
#  conv2d_7_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_11_spec[0][0]']
#
#  conv2d_9_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_16_spec[0][0]']
#
#  activation_14_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_7_tool[0][0]']
#  tion)
#
#  activation_18_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_9_tool[0][0]']
#  tion)
#
#  activation_14_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_7_spec[0][0]']
#  tion)
#
#  activation_18_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_9_spec[0][0]']
#  tion)
#
#  batch_normalization_14_too  (None, 16, 16, 256)          1024      ['activation_14_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_18_too  (None, 16, 16, 256)          1024      ['activation_18_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_14_spe  (None, 16, 16, 256)          1024      ['activation_14_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_18_spe  (None, 16, 16, 256)          1024      ['activation_18_spec[0][0]']
#  c (BatchNormalization)
#
#  add_12_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_6_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_14_tool[
#                                                                     0][0]']
#
#  add_17_tool (Add)           (None, 16, 16, 256)          0         ['add_6_tool[0][0]',
#                                                                      'batch_normalization_18_tool[
#                                                                     0][0]']
#
#  add_12_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_6_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_14_spec[
#                                                                     0][0]']
#
#  add_17_spec (Add)           (None, 16, 16, 256)          0         ['add_6_spec[0][0]',
#                                                                      'batch_normalization_18_spec[
#                                                                     0][0]']
#
#  add_18_tool (Add)           (None, 16, 16, 256)          0         ['add_12_tool[0][0]',
#                                                                      'add_17_tool[0][0]']
#
#  add_18_spec (Add)           (None, 16, 16, 256)          0         ['add_12_spec[0][0]',
#                                                                      'add_17_spec[0][0]']
#
#  depthwise_conv2d_7_tool (D  (None, 16, 16, 256)          6656      ['add_12_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_9_tool (D  (None, 16, 16, 256)          6656      ['add_18_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_7_spec (D  (None, 16, 16, 256)          6656      ['add_12_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_9_spec (D  (None, 16, 16, 256)          6656      ['add_18_spec[0][0]']
#  epthwiseConv2D)
#
#  activation_15_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_7_tool[0][0
#  tion)                                                              ]']
#
#  activation_19_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_9_tool[0][0
#  tion)                                                              ]']
#
#  activation_15_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_7_spec[0][0
#  tion)                                                              ]']
#
#  activation_19_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_9_spec[0][0
#  tion)                                                              ]']
#
#  batch_normalization_15_too  (None, 16, 16, 256)          1024      ['activation_15_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_19_too  (None, 16, 16, 256)          1024      ['activation_19_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_15_spe  (None, 16, 16, 256)          1024      ['activation_15_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_19_spe  (None, 16, 16, 256)          1024      ['activation_19_spec[0][0]']
#  c (BatchNormalization)
#
#  add_13_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_15_tool[
#                                                                     0][0]',
#                                                                      'add_12_tool[0][0]']
# ...
#  activation_28_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_14_tool[0][0]']
#  tion)
#
#  activation_24_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_12_spec[0][0]']
#  tion)
#
#  activation_28_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_14_spec[0][0]']
#  tion)
#
#  batch_normalization_24_too  (None, 16, 16, 256)          1024      ['activation_24_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_28_too  (None, 16, 16, 256)          1024      ['activation_28_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_24_spe  (None, 16, 16, 256)          1024      ['activation_24_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_28_spe  (None, 16, 16, 256)          1024      ['activation_28_spec[0][0]']
#  c (BatchNormalization)
#
#  add_25_tool (Add)           (None, 16, 16, 256)          0         ['add_14_tool[0][0]',
#                                                                      'batch_normalization_24_tool[
#                                                                     0][0]']
#
#  add_31_tool (Add)           (None, 16, 16, 256)          0         ['add_20_tool[0][0]',
#                                                                      'batch_normalization_28_tool[
#                                                                     0][0]']
#
#  add_25_spec (Add)           (None, 16, 16, 256)          0         ['add_14_spec[0][0]',
#                                                                      'batch_normalization_24_spec[
#                                                                     0][0]']
#
#  add_31_spec (Add)           (None, 16, 16, 256)          0         ['add_20_spec[0][0]',
#                                                                      'batch_normalization_28_spec[
#                                                                     0][0]']
#
#  add_32_tool (Add)           (None, 16, 16, 256)          0         ['add_25_tool[0][0]',
#                                                                      'add_31_tool[0][0]']
#
#  add_32_spec (Add)           (None, 16, 16, 256)          0         ['add_25_spec[0][0]',
#                                                                      'add_31_spec[0][0]']
#
#  depthwise_conv2d_14_tool (  (None, 16, 16, 256)          6656      ['add_32_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_14_spec (  (None, 16, 16, 256)          6656      ['add_32_spec[0][0]']
#  DepthwiseConv2D)
#
#  activation_29_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_14_tool[0][
#  tion)                                                              0]']
#
#  activation_29_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_14_spec[0][
#  tion)                                                              0]']
#
#  batch_normalization_29_too  (None, 16, 16, 256)          1024      ['activation_29_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_29_spe  (None, 16, 16, 256)          1024      ['activation_29_spec[0][0]']
#  c (BatchNormalization)
#
#  add_33_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_tool[
#                                                                     0][0]',
#                                                                      'add_32_tool[0][0]']
#
#  add_33_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_spec[
#                                                                     0][0]',
#                                                                      'add_32_spec[0][0]']
#
#  conv2d_15_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_tool[0][0]']
#
#  conv2d_15_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_spec[0][0]']
#
#  activation_30_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_15_tool[0][0]']
#  tion)
#
#  activation_30_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_15_spec[0][0]']
#  tion)
#
#  batch_normalization_30_too  (None, 16, 16, 256)          1024      ['activation_30_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_30_spe  (None, 16, 16, 256)          1024      ['activation_30_spec[0][0]']
#  c (BatchNormalization)
#
#  add_34_tool (Add)           (None, 16, 16, 256)          0         ['add_23_tool[0][0]',
#                                                                      'batch_normalization_30_tool[
#                                                                     0][0]']
#
#  add_34_spec (Add)           (None, 16, 16, 256)          0         ['add_23_spec[0][0]',
#                                                                      'batch_normalization_30_spec[
#                                                                     0][0]']
#
#  depthwise_conv2d_15_tool (  (None, 16, 16, 256)          6656      ['add_34_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_15_spec (  (None, 16, 16, 256)          6656      ['add_34_spec[0][0]']
#  DepthwiseConv2D)
#
#  activation_31_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_tool[0][
#  tion)                                                              0]']
#
#  activation_31_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_spec[0][
#  tion)                                                              0]']
#
#  batch_normalization_31_too  (None, 16, 16, 256)          1024      ['activation_31_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_31_spe  (None, 16, 16, 256)          1024      ['activation_31_spec[0][0]']
#  c (BatchNormalization)
#
#  add_35_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_tool[
#                                                                     0][0]',
#                                                                      'add_34_tool[0][0]']
#
#  add_35_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_spec[
#                                                                     0][0]',
#                                                                      'add_34_spec[0][0]']
#
#  conv2d_16_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_tool[0][0]']
#
#  conv2d_16_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_spec[0][0]']
#
#  activation_32_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_16_tool[0][0]']
#  tion)
#
#  activation_32_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_16_spec[0][0]']
#  tion)
#
#  batch_normalization_32_too  (None, 16, 16, 256)          1024      ['activation_32_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_32_spe  (None, 16, 16, 256)          1024      ['activation_32_spec[0][0]']
#  c (BatchNormalization)
#
#  add_36_tool (Add)           (None, 16, 16, 256)          0         ['add_25_tool[0][0]',
#                                                                      'batch_normalization_32_tool[
#                                                                     0][0]']
#
#  add_36_spec (Add)           (None, 16, 16, 256)          0         ['add_25_spec[0][0]',
#                                                                      'batch_normalization_32_spec[
#                                                                     0][0]']
#
#  global_average_pooling2d_t  (None, 256)                  0         ['add_36_tool[0][0]']
#  ool (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_s  (None, 256)                  0         ['add_36_spec[0][0]']
#  pec (GlobalAveragePooling2
#  D)
#
#  concatenate (Concatenate)   (None, 512)                  0         ['global_average_pooling2d_too
#                                                                     l[0][0]',
#                                                                      'global_average_pooling2d_spe
#                                                                     c[0][0]']
#
#  output_mult (Dense)         (None, 3)                    1539      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3174403 (12.11 MB)
# Trainable params: 1539 (6.01 KB)
# Non-trainable params: 3172864 (12.10 MB)
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 27s 3s/step - loss: 3982.8967 - mean_squared_error: 3982.8967 - val_loss: 4912.5669 - val_mean_squared_error: 4912.5669
# Epoch 2/100
# 2/2 [==============================] - 1s 672ms/step - loss: 3867.8376 - mean_squared_error: 3867.8376 - val_loss: 4775.4966 - val_mean_squared_error: 4775.4966
# Epoch 3/100
# 2/2 [==============================] - 1s 675ms/step - loss: 3756.3159 - mean_squared_error: 3756.3159 - val_loss: 4642.3135 - val_mean_squared_error: 4642.3135
# Epoch 4/100
# 2/2 [==============================] - 1s 566ms/step - loss: 3648.2078 - mean_squared_error: 3648.2078 - val_loss: 4512.9478 - val_mean_squared_error: 4512.9478
# Epoch 5/100
# 2/2 [==============================] - 1s 553ms/step - loss: 3546.4917 - mean_squared_error: 3546.4917 - val_loss: 4386.8228 - val_mean_squared_error: 4386.8228
# Epoch 6/100
# 2/2 [==============================] - 1s 588ms/step - loss: 3443.9744 - mean_squared_error: 3443.9744 - val_loss: 4265.2812 - val_mean_squared_error: 4265.2812
# Epoch 7/100
# 2/2 [==============================] - 2s 932ms/step - loss: 3352.2251 - mean_squared_error: 3352.2249 - val_loss: 4147.1709 - val_mean_squared_error: 4147.1709
# Epoch 8/100
# 2/2 [==============================] - 1s 540ms/step - loss: 3269.2690 - mean_squared_error: 3269.2690 - val_loss: 4032.9075 - val_mean_squared_error: 4032.9075
# Epoch 9/100
# 2/2 [==============================] - 1s 550ms/step - loss: 3174.4045 - mean_squared_error: 3174.4045 - val_loss: 3923.0227 - val_mean_squared_error: 3923.0227
# Epoch 10/100
# 2/2 [==============================] - 1s 686ms/step - loss: 3090.7109 - mean_squared_error: 3090.7109 - val_loss: 3816.6680 - val_mean_squared_error: 3816.6680
# Epoch 11/100
# 2/2 [==============================] - 1s 691ms/step - loss: 3014.3503 - mean_squared_error: 3014.3503 - val_loss: 3713.9443 - val_mean_squared_error: 3713.9443
# Epoch 12/100
# 2/2 [==============================] - 1s 533ms/step - loss: 2939.4709 - mean_squared_error: 2939.4709 - val_loss: 3614.3718 - val_mean_squared_error: 3614.3718
# Epoch 13/100
# 2/2 [==============================] - 1s 533ms/step - loss: 2865.9402 - mean_squared_error: 2865.9402 - val_loss: 3518.1804 - val_mean_squared_error: 3518.1804
# Epoch 14/100
# 2/2 [==============================] - 1s 664ms/step - loss: 2788.4180 - mean_squared_error: 2788.4180 - val_loss: 3425.3054 - val_mean_squared_error: 3425.3054
# Epoch 15/100
# 2/2 [==============================] - 1s 590ms/step - loss: 2722.6565 - mean_squared_error: 2722.6565 - val_loss: 3335.4250 - val_mean_squared_error: 3335.4250
# Epoch 16/100
# 2/2 [==============================] - 2s 1s/step - loss: 2657.6401 - mean_squared_error: 2657.6401 - val_loss: 3247.3103 - val_mean_squared_error: 3247.3103
# Epoch 17/100
# 2/2 [==============================] - 1s 673ms/step - loss: 2597.2690 - mean_squared_error: 2597.2690 - val_loss: 3162.1240 - val_mean_squared_error: 3162.1240
# Epoch 18/100
# 2/2 [==============================] - 1s 672ms/step - loss: 2535.5632 - mean_squared_error: 2535.5632 - val_loss: 3078.8547 - val_mean_squared_error: 3078.8547
# Epoch 19/100
# 2/2 [==============================] - 1s 684ms/step - loss: 2472.3672 - mean_squared_error: 2472.3672 - val_loss: 2998.4402 - val_mean_squared_error: 2998.4402
# Epoch 20/100
# 2/2 [==============================] - 1s 561ms/step - loss: 2419.8442 - mean_squared_error: 2419.8442 - val_loss: 2919.9827 - val_mean_squared_error: 2919.9827
# Epoch 21/100
# 2/2 [==============================] - 1s 547ms/step - loss: 2361.8794 - mean_squared_error: 2361.8794 - val_loss: 2842.9460 - val_mean_squared_error: 2842.9460
# Epoch 22/100
# 2/2 [==============================] - 1s 548ms/step - loss: 2308.3965 - mean_squared_error: 2308.3965 - val_loss: 2767.7424 - val_mean_squared_error: 2767.7424
# Epoch 23/100
# 2/2 [==============================] - 1s 672ms/step - loss: 2261.3105 - mean_squared_error: 2261.3105 - val_loss: 2694.2488 - val_mean_squared_error: 2694.2488
# Epoch 24/100
# 2/2 [==============================] - 1s 665ms/step - loss: 2208.2712 - mean_squared_error: 2208.2712 - val_loss: 2622.5945 - val_mean_squared_error: 2622.5945
# Epoch 25/100
# 2/2 [==============================] - 2s 905ms/step - loss: 2162.5483 - mean_squared_error: 2162.5483 - val_loss: 2553.0078 - val_mean_squared_error: 2553.0078
# Epoch 26/100
# 2/2 [==============================] - 1s 565ms/step - loss: 2112.5825 - mean_squared_error: 2112.5825 - val_loss: 2485.5872 - val_mean_squared_error: 2485.5872
# Epoch 27/100
# 2/2 [==============================] - 1s 546ms/step - loss: 2068.5745 - mean_squared_error: 2068.5745 - val_loss: 2419.2375 - val_mean_squared_error: 2419.2375
# Epoch 28/100
# 2/2 [==============================] - 1s 670ms/step - loss: 2023.5293 - mean_squared_error: 2023.5294 - val_loss: 2354.1729 - val_mean_squared_error: 2354.1729
# Epoch 29/100
# 2/2 [==============================] - 1s 662ms/step - loss: 1982.4855 - mean_squared_error: 1982.4855 - val_loss: 2291.5642 - val_mean_squared_error: 2291.5642
# Epoch 30/100
# 2/2 [==============================] - 1s 532ms/step - loss: 1942.2822 - mean_squared_error: 1942.2822 - val_loss: 2230.5286 - val_mean_squared_error: 2230.5286
# Epoch 31/100
# 2/2 [==============================] - 1s 671ms/step - loss: 1899.8588 - mean_squared_error: 1899.8588 - val_loss: 2171.6228 - val_mean_squared_error: 2171.6228
# Epoch 32/100
# 2/2 [==============================] - 1s 563ms/step - loss: 1858.8026 - mean_squared_error: 1858.8026 - val_loss: 2114.1902 - val_mean_squared_error: 2114.1902
# Epoch 33/100
# 2/2 [==============================] - 1s 555ms/step - loss: 1825.3583 - mean_squared_error: 1825.3583 - val_loss: 2058.2231 - val_mean_squared_error: 2058.2231
# Epoch 34/100
# 2/2 [==============================] - 1s 843ms/step - loss: 1788.5490 - mean_squared_error: 1788.5490 - val_loss: 2004.0707 - val_mean_squared_error: 2004.0707
# Epoch 35/100
# 2/2 [==============================] - 1s 530ms/step - loss: 1753.2468 - mean_squared_error: 1753.2468 - val_loss: 1951.1948 - val_mean_squared_error: 1951.1948
# Epoch 36/100
# 2/2 [==============================] - 1s 663ms/step - loss: 1716.5714 - mean_squared_error: 1716.5714 - val_loss: 1899.8209 - val_mean_squared_error: 1899.8209
# Epoch 37/100
# 2/2 [==============================] - 1s 703ms/step - loss: 1687.5580 - mean_squared_error: 1687.5580 - val_loss: 1849.7642 - val_mean_squared_error: 1849.7642
# Epoch 38/100
# 2/2 [==============================] - 1s 692ms/step - loss: 1654.7220 - mean_squared_error: 1654.7220 - val_loss: 1801.1949 - val_mean_squared_error: 1801.1949
# Epoch 39/100
# 2/2 [==============================] - 1s 537ms/step - loss: 1623.0255 - mean_squared_error: 1623.0255 - val_loss: 1753.6001 - val_mean_squared_error: 1753.6001
# Epoch 40/100
# 2/2 [==============================] - 1s 665ms/step - loss: 1596.6755 - mean_squared_error: 1596.6755 - val_loss: 1707.4030 - val_mean_squared_error: 1707.4030
# Epoch 41/100
# 2/2 [==============================] - 1s 686ms/step - loss: 1571.4684 - mean_squared_error: 1571.4684 - val_loss: 1662.4344 - val_mean_squared_error: 1662.4344
# Epoch 42/100
# 2/2 [==============================] - 1s 542ms/step - loss: 1539.3884 - mean_squared_error: 1539.3884 - val_loss: 1619.8278 - val_mean_squared_error: 1619.8278
# Epoch 43/100
# 2/2 [==============================] - 2s 980ms/step - loss: 1516.8890 - mean_squared_error: 1516.8890 - val_loss: 1578.6831 - val_mean_squared_error: 1578.6831
# Epoch 44/100
# 2/2 [==============================] - 1s 670ms/step - loss: 1490.7145 - mean_squared_error: 1490.7145 - val_loss: 1539.2700 - val_mean_squared_error: 1539.2700
# Epoch 45/100
# 2/2 [==============================] - 1s 666ms/step - loss: 1466.9384 - mean_squared_error: 1466.9384 - val_loss: 1501.1437 - val_mean_squared_error: 1501.1437
# Epoch 46/100
# 2/2 [==============================] - 1s 547ms/step - loss: 1442.3552 - mean_squared_error: 1442.3551 - val_loss: 1464.2891 - val_mean_squared_error: 1464.2891
# Epoch 47/100
# 2/2 [==============================] - 1s 690ms/step - loss: 1420.9017 - mean_squared_error: 1420.9017 - val_loss: 1429.2885 - val_mean_squared_error: 1429.2885
# Epoch 48/100
# 2/2 [==============================] - 1s 677ms/step - loss: 1400.3629 - mean_squared_error: 1400.3629 - val_loss: 1395.0625 - val_mean_squared_error: 1395.0625
# Epoch 49/100
# 2/2 [==============================] - 1s 679ms/step - loss: 1377.5516 - mean_squared_error: 1377.5516 - val_loss: 1361.8246 - val_mean_squared_error: 1361.8246
# Epoch 50/100
# 2/2 [==============================] - 1s 683ms/step - loss: 1363.4913 - mean_squared_error: 1363.4913 - val_loss: 1329.0865 - val_mean_squared_error: 1329.0865
# Epoch 51/100
# 2/2 [==============================] - 1s 667ms/step - loss: 1338.5834 - mean_squared_error: 1338.5834 - val_loss: 1298.4226 - val_mean_squared_error: 1298.4226
# Epoch 52/100
# 2/2 [==============================] - 2s 923ms/step - loss: 1322.4554 - mean_squared_error: 1322.4554 - val_loss: 1268.2770 - val_mean_squared_error: 1268.2770
# Epoch 53/100
# 2/2 [==============================] - 2s 772ms/step - loss: 1304.6744 - mean_squared_error: 1304.6746 - val_loss: 1239.3218 - val_mean_squared_error: 1239.3218
# Epoch 54/100
# 2/2 [==============================] - 1s 563ms/step - loss: 1291.5361 - mean_squared_error: 1291.5361 - val_loss: 1211.2833 - val_mean_squared_error: 1211.2833
# Epoch 55/100
# 2/2 [==============================] - 1s 567ms/step - loss: 1273.4423 - mean_squared_error: 1273.4423 - val_loss: 1184.5145 - val_mean_squared_error: 1184.5145
# Epoch 56/100
# 2/2 [==============================] - 1s 688ms/step - loss: 1256.3658 - mean_squared_error: 1256.3658 - val_loss: 1158.3372 - val_mean_squared_error: 1158.3372
# Epoch 57/100
# 2/2 [==============================] - 1s 543ms/step - loss: 1243.6198 - mean_squared_error: 1243.6198 - val_loss: 1133.2694 - val_mean_squared_error: 1133.2694
# Epoch 58/100
# 2/2 [==============================] - 1s 530ms/step - loss: 1227.6261 - mean_squared_error: 1227.6261 - val_loss: 1108.5668 - val_mean_squared_error: 1108.5668
# Epoch 59/100
# 2/2 [==============================] - 1s 678ms/step - loss: 1214.1368 - mean_squared_error: 1214.1368 - val_loss: 1084.7374 - val_mean_squared_error: 1084.7374
# Epoch 60/100
# 2/2 [==============================] - 1s 687ms/step - loss: 1202.8793 - mean_squared_error: 1202.8793 - val_loss: 1062.0907 - val_mean_squared_error: 1062.0907
# Epoch 61/100
# 2/2 [==============================] - 1s 688ms/step - loss: 1190.4583 - mean_squared_error: 1190.4583 - val_loss: 1040.0258 - val_mean_squared_error: 1040.0258
# Epoch 62/100
# 2/2 [==============================] - 2s 1s/step - loss: 1177.7238 - mean_squared_error: 1177.7238 - val_loss: 1018.5266 - val_mean_squared_error: 1018.5266
# Epoch 63/100
# 2/2 [==============================] - 1s 666ms/step - loss: 1165.7999 - mean_squared_error: 1165.7999 - val_loss: 997.8703 - val_mean_squared_error: 997.8703
# Epoch 64/100
# 2/2 [==============================] - 1s 543ms/step - loss: 1156.0735 - mean_squared_error: 1156.0735 - val_loss: 977.2051 - val_mean_squared_error: 977.2051
# Epoch 65/100
# 2/2 [==============================] - 1s 543ms/step - loss: 1146.4969 - mean_squared_error: 1146.4969 - val_loss: 957.1491 - val_mean_squared_error: 957.1491
# Epoch 66/100
# 2/2 [==============================] - 1s 686ms/step - loss: 1135.8136 - mean_squared_error: 1135.8136 - val_loss: 937.6613 - val_mean_squared_error: 937.6613
# Epoch 67/100
# 2/2 [==============================] - 2s 1s/step - loss: 1126.7247 - mean_squared_error: 1126.7247 - val_loss: 919.2310 - val_mean_squared_error: 919.2310
# Epoch 68/100
# 2/2 [==============================] - 1s 666ms/step - loss: 1117.7883 - mean_squared_error: 1117.7883 - val_loss: 902.5316 - val_mean_squared_error: 902.5316
# Epoch 69/100
# 2/2 [==============================] - 1s 653ms/step - loss: 1108.8344 - mean_squared_error: 1108.8344 - val_loss: 885.7629 - val_mean_squared_error: 885.7629
# Epoch 70/100
# 2/2 [==============================] - 2s 1s/step - loss: 1102.1910 - mean_squared_error: 1102.1910 - val_loss: 870.3011 - val_mean_squared_error: 870.3011
# Epoch 71/100
# 2/2 [==============================] - 1s 541ms/step - loss: 1094.7999 - mean_squared_error: 1094.7999 - val_loss: 855.0322 - val_mean_squared_error: 855.0322
# Epoch 72/100
# 2/2 [==============================] - 1s 537ms/step - loss: 1085.7776 - mean_squared_error: 1085.7776 - val_loss: 840.3532 - val_mean_squared_error: 840.3532
# Epoch 73/100
# 2/2 [==============================] - 1s 563ms/step - loss: 1080.9797 - mean_squared_error: 1080.9797 - val_loss: 826.6212 - val_mean_squared_error: 826.6212
# Epoch 74/100
# 2/2 [==============================] - 1s 674ms/step - loss: 1072.0148 - mean_squared_error: 1072.0148 - val_loss: 813.3369 - val_mean_squared_error: 813.3369
# Epoch 75/100
# 2/2 [==============================] - 1s 558ms/step - loss: 1067.1465 - mean_squared_error: 1067.1465 - val_loss: 800.9474 - val_mean_squared_error: 800.9474
# Epoch 76/100
# 2/2 [==============================] - 1s 693ms/step - loss: 1060.8186 - mean_squared_error: 1060.8186 - val_loss: 788.1035 - val_mean_squared_error: 788.1035
# Epoch 77/100
# 2/2 [==============================] - 1s 683ms/step - loss: 1054.8771 - mean_squared_error: 1054.8771 - val_loss: 776.2297 - val_mean_squared_error: 776.2297
# Epoch 78/100
# 2/2 [==============================] - 1s 544ms/step - loss: 1049.0417 - mean_squared_error: 1049.0417 - val_loss: 765.3001 - val_mean_squared_error: 765.3001
# Epoch 79/100
# 2/2 [==============================] - 1s 866ms/step - loss: 1044.4919 - mean_squared_error: 1044.4919 - val_loss: 754.2571 - val_mean_squared_error: 754.2571
# Epoch 80/100
# 2/2 [==============================] - 1s 683ms/step - loss: 1039.5731 - mean_squared_error: 1039.5731 - val_loss: 743.2989 - val_mean_squared_error: 743.2989
# Epoch 81/100
# 2/2 [==============================] - 1s 685ms/step - loss: 1034.8674 - mean_squared_error: 1034.8674 - val_loss: 732.0564 - val_mean_squared_error: 732.0564
# Epoch 82/100
# 2/2 [==============================] - 1s 572ms/step - loss: 1029.8817 - mean_squared_error: 1029.8817 - val_loss: 722.3152 - val_mean_squared_error: 722.3152
# Epoch 83/100
# 2/2 [==============================] - 1s 549ms/step - loss: 1025.6718 - mean_squared_error: 1025.6718 - val_loss: 712.0494 - val_mean_squared_error: 712.0494
# Epoch 84/100
# 2/2 [==============================] - 1s 538ms/step - loss: 1023.0098 - mean_squared_error: 1023.0098 - val_loss: 702.8139 - val_mean_squared_error: 702.8139
# Epoch 85/100
# 2/2 [==============================] - 1s 661ms/step - loss: 1019.1508 - mean_squared_error: 1019.1508 - val_loss: 693.6971 - val_mean_squared_error: 693.6971
# Epoch 86/100
# 2/2 [==============================] - 1s 536ms/step - loss: 1014.6557 - mean_squared_error: 1014.6557 - val_loss: 685.3206 - val_mean_squared_error: 685.3206
# Epoch 87/100
# 2/2 [==============================] - 1s 679ms/step - loss: 1010.6253 - mean_squared_error: 1010.6253 - val_loss: 677.1405 - val_mean_squared_error: 677.1405
# Epoch 88/100
# 2/2 [==============================] - 1s 841ms/step - loss: 1007.4753 - mean_squared_error: 1007.4753 - val_loss: 668.9725 - val_mean_squared_error: 668.9725
# Epoch 89/100
# 2/2 [==============================] - 2s 881ms/step - loss: 1005.3259 - mean_squared_error: 1005.3259 - val_loss: 660.8117 - val_mean_squared_error: 660.8117
# Epoch 90/100
# 2/2 [==============================] - 1s 661ms/step - loss: 1001.8027 - mean_squared_error: 1001.8027 - val_loss: 652.9872 - val_mean_squared_error: 652.9872
# Epoch 91/100
# 2/2 [==============================] - 1s 676ms/step - loss: 999.1005 - mean_squared_error: 999.1005 - val_loss: 645.5727 - val_mean_squared_error: 645.5727
# Epoch 92/100
# 2/2 [==============================] - 1s 677ms/step - loss: 997.2614 - mean_squared_error: 997.2614 - val_loss: 638.1450 - val_mean_squared_error: 638.1450
# Epoch 93/100
# 2/2 [==============================] - 1s 689ms/step - loss: 993.4428 - mean_squared_error: 993.4428 - val_loss: 631.5446 - val_mean_squared_error: 631.5446
# Epoch 94/100
# 2/2 [==============================] - 1s 559ms/step - loss: 992.5656 - mean_squared_error: 992.5656 - val_loss: 624.2227 - val_mean_squared_error: 624.2227
# Epoch 95/100
# 2/2 [==============================] - 1s 657ms/step - loss: 990.2675 - mean_squared_error: 990.2675 - val_loss: 618.2175 - val_mean_squared_error: 618.2175
# Epoch 96/100
# 2/2 [==============================] - 1s 550ms/step - loss: 987.7687 - mean_squared_error: 987.7687 - val_loss: 612.7414 - val_mean_squared_error: 612.7414
# Epoch 97/100
# 2/2 [==============================] - 1s 667ms/step - loss: 985.6219 - mean_squared_error: 985.6219 - val_loss: 607.1490 - val_mean_squared_error: 607.1490
# Epoch 98/100
# 2/2 [==============================] - 2s 933ms/step - loss: 983.9688 - mean_squared_error: 983.9688 - val_loss: 601.6193 - val_mean_squared_error: 601.6193
# Epoch 99/100
# 2/2 [==============================] - 1s 554ms/step - loss: 982.1709 - mean_squared_error: 982.1709 - val_loss: 596.6544 - val_mean_squared_error: 596.6544
# Epoch 100/100
# 2/2 [==============================] - 1s 674ms/step - loss: 980.4663 - mean_squared_error: 980.4663 - val_loss: 591.7115 - val_mean_squared_error: 591.7115
# 1/1 [==============================] - 0s 190ms/step - loss: 7062.9473 - mean_squared_error: 7062.9473
# Test error: 7062.95

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  14.531153055826822
# MSE:  256.71053455349175
# RMSE:  16.02218881905627
# r2_score:  -1.4329979574538485
# MSLE:  6.061199183398199
# MAPE:  5.793093120530842e+16
# ===== flank_wear results =====
# MAE:  99.21094258626302
# MSE:  20852.248992010478
# RMSE:  144.40307819437396
# r2_score:  -0.3014471565351926
# MSLE:  0.7406785160805013
# MAPE:  0.6045698145480484
# ===== overhang results =====
# MAE:  6.8512372843424485
# MSE:  79.88032053227354
# RMSE:  8.937579120336421
# r2_score:  -2.959868758354136
# MSLE:  0.37767570145505985
# MAPE:  0.8095448667091144
# ===== multi results =====
# MAE:  40.197777642144096
# MSE:  7062.946615698747
# RMSE:  56.454282044588886
# r2_score:  -1.5647712907810591
# MSLE:  2.39318446697792
# MAPE:  1.931031040176947e+16
