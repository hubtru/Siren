# %%
# !pip install tensorflow_addons
# !pip install keras-tuner --upgrade

# clone siren repository, refresh folder to see the siren repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Siren/
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5
# Cloning into 'Siren'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 313 (delta 9), reused 7 (delta 2), pack-reused 297
# Receiving objects: 100% (313/313), 57.54 MiB | 11.19 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "3"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
# architecture
image_size = 256
filters = 256
depth = 4
columns = 4
kernel_size = 5
patch_size = 16
num_classes = 3

in_channel = 3
img_rows, img_cols = image_size, image_size
input_shape = (img_rows, img_cols, in_channel)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "chip"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

# dataset
csv_path = "/content/Siren/dataset/labels_reg_sample.csv"
chip_path = f"/content/Siren/dataset/{modality}"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chips/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                        chip
# 14   /content/Siren/dataset/chip/T8R3B4.jpg
# 10   /content/Siren/dataset/chip/T6R9B3.jpg
# 0    /content/Siren/dataset/chip/T1R2B1.jpg
# 3   /content/Siren/dataset/chip/T2R13B4.jpg
# 1    /content/Siren/dataset/chip/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                        chip
# 16   /content/Siren/dataset/chip/T9R7B4.jpg
# 18  /content/Siren/dataset/chip/T10R3B4.jpg
# 9   /content/Siren/dataset/chip/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                        chip
# 5   /content/Siren/dataset/chip/T3R10B1.jpg
# 13  /content/Siren/dataset/chip/T7R14B3.jpg
# 12   /content/Siren/dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_chip, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_chip, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_chip, labels_val))

# %%
# ============================== augment ==============================
auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation",
)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
#Functions
#Reversed Column implementation of Truchan (2023). Minape: Multimodal Isotropic Neural Architecture with Patch Embedding.
#https://github.com/hubtru/minape
def activation_module(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def base_module(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_module(x)


def depth_point_module(
    x, pe_block, column, level, depth, r_arr, filters: int, kernel_size: int
):
    if column == 0:
        # Depthwise convolution.
        x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        r_arr = reverasable_output_array(x, r_arr, column, level)
        return x, r_arr
    else:
        if level == 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], pe_block)
        elif level < len(r_arr[0]) - 1 and level != 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], x)
        else:
            x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x0)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        if column != 0:
            x = fusion_block_double(r_arr[column - 1][level], x)

        r_arr = reverasable_output_array(x, r_arr, column, level)

        return x, r_arr


def fusion_block_double(x, y):
    return layers.Add()([x, y])


def reverasable_output_array(x, r_arr, column, level):
    r_arr[column][level] = x
    return r_arr


def load_siren(
    image_size=image_size,
    filters=filters,
    depth=depth,
    columns=columns,
    kernel_size=kernel_size,
    patch_size=patch_size,
    num_classes=num_classes,
):
    r_arr = [[None for _ in range(depth)] for _ in range(columns)]

    inputs = k.Input(input_shape)
    # x = layers.Rescaling(scale=1.0 / 255)(inputs)         # already rescaled

    # Extract patch embeddings.
    x = base_module(inputs, filters, patch_size)
    pe_block = x

    # Siren blocks.
    for column in range(columns):
        for level in range(depth):
            x, r_arr = depth_point_module(
                x, pe_block, column, level, depth, r_arr, filters, kernel_size
            )

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="linear")(x)

    return k.Model(inputs, outputs)

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 16, 16, 256)          196864    ['input_1[0][0]']
#
#  activation (Activation)     (None, 16, 16, 256)          0         ['conv2d[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 256)          1024      ['activation[0][0]']
#  Normalization)
#
#  depthwise_conv2d (Depthwis  (None, 16, 16, 256)          6656      ['batch_normalization[0][0]']
#  eConv2D)
#
#  activation_1 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 16, 256)          1024      ['activation_1[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 16, 16, 256)          0         ['batch_normalization_1[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)          65792     ['add[0][0]']
#
#  activation_2 (Activation)   (None, 16, 16, 256)          0         ['conv2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 16, 256)          1024      ['activation_2[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_1 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_2[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_3 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 16, 256)          1024      ['activation_3[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_2[0][0]
#                                                                     ']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)          65792     ['add_1[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 256)          0         ['conv2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 16, 16, 256)          1024      ['activation_4[0][0]']
#  chNormalization)
#
#  add_4 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  depthwise_conv2d_4 (Depthw  (None, 16, 16, 256)          6656      ['add_4[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_2 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_4[0][0]']
#
#  activation_5 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 256)          1024      ['activation_9[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 16, 16, 256)          1024      ['activation_5[0][0]']
#  chNormalization)
#
#  add_5 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     , 'add_4[0][0]']
#
#  add_2 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)          65792     ['add_5[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)          65792     ['add_2[0][0]']
#
#  activation_10 (Activation)  (None, 16, 16, 256)          0         ['conv2d_5[0][0]']
#
#  activation_6 (Activation)   (None, 16, 16, 256)          0         ['conv2d_3[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 256)          1024      ['activation_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_6 (Bat  (None, 16, 16, 256)          1024      ['activation_6[0][0]']
#  chNormalization)
#
#  add_6 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_2[0][0]'
#                                                                     , 'batch_normalization_10[0][0
#                                                                     ]']
#
#  add_7 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'add_6[0][0]']
#
#  depthwise_conv2d_5 (Depthw  (None, 16, 16, 256)          6656      ['add_7[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_3 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_6[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_11 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_5[0][0]']
#
#  activation_7 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_3[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 256)          1024      ['activation_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_7 (Bat  (None, 16, 16, 256)          1024      ['activation_7[0][0]']
#  chNormalization)
#
#  add_8 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  add_3 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)          65792     ['add_8[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          65792     ['add_3[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 256)          0         ['conv2d_6[0][0]']
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['conv2d_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 256)          1024      ['activation_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_8 (Bat  (None, 16, 16, 256)          1024      ['activation_8[0][0]']
#  chNormalization)
#
#  add_9 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization_12[0][0
#                                                                     ]']
#
#  add_10 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'add_9[0][0]']
#
#  add_15 (Add)                (None, 16, 16, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_6 (Depthw  (None, 16, 16, 256)          6656      ['add_10[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_8 (Depthw  (None, 16, 16, 256)          6656      ['add_15[0][0]']
#  iseConv2D)
#
#  activation_13 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_6[0][0]']
#
#  activation_17 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_8[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 256)          1024      ['activation_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 16, 16, 256)          1024      ['activation_17[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'add_10[0][0]']
#
#  add_16 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 256)          65792     ['add_11[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          65792     ['add_16[0][0]']
#
#  activation_14 (Activation)  (None, 16, 16, 256)          0         ['conv2d_7[0][0]']
#
#  activation_18 (Activation)  (None, 16, 16, 256)          0         ['conv2d_9[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 256)          1024      ['activation_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 16, 16, 256)          1024      ['activation_18[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_14[0][0
#                                                                     ]']
#
#  add_17 (Add)                (None, 16, 16, 256)          0         ['add_6[0][0]',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 16, 16, 256)          0         ['add_12[0][0]',
#                                                                      'add_17[0][0]']
#
#  depthwise_conv2d_7 (Depthw  (None, 16, 16, 256)          6656      ['add_12[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_9 (Depthw  (None, 16, 16, 256)          6656      ['add_18[0][0]']
#  iseConv2D)
#
#  activation_15 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_7[0][0]']
#
#  activation_19 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_9[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 256)          1024      ['activation_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 16, 16, 256)          1024      ['activation_19[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'add_12[0][0]']
#
#  add_19 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'add_18[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          65792     ['add_13[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)          65792     ['add_19[0][0]']
#
#  activation_16 (Activation)  (None, 16, 16, 256)          0         ['conv2d_8[0][0]']
#
#  activation_20 (Activation)  (None, 16, 16, 256)          0         ['conv2d_10[0][0]']
#
#  batch_normalization_16 (Ba  (None, 16, 16, 256)          1024      ['activation_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 16, 16, 256)          1024      ['activation_20[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_16[0][0
#                                                                     ]']
#
#  add_20 (Add)                (None, 16, 16, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization_20[0][0]
#                                                                     ']
#
#  add_21 (Add)                (None, 16, 16, 256)          0         ['add_14[0][0]',
#                                                                      'add_20[0][0]']
#
#  add_26 (Add)                (None, 16, 16, 256)          0         ['add_20[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_10 (Depth  (None, 16, 16, 256)          6656      ['add_21[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_12 (Depth  (None, 16, 16, 256)          6656      ['add_26[0][0]']
#  wiseConv2D)
#
#  activation_21 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_10[0][0]']
#
#  activation_25 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_12[0][0]']
#
#  batch_normalization_21 (Ba  (None, 16, 16, 256)          1024      ['activation_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 16, 16, 256)          1024      ['activation_25[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'add_21[0][0]']
#
#  add_27 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ',
#                                                                      'add_26[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)          65792     ['add_22[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 256)          65792     ['add_27[0][0]']
#
#  activation_22 (Activation)  (None, 16, 16, 256)          0         ['conv2d_11[0][0]']
#
#  activation_26 (Activation)  (None, 16, 16, 256)          0         ['conv2d_13[0][0]']
#
#  batch_normalization_22 (Ba  (None, 16, 16, 256)          1024      ['activation_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 16, 16, 256)          1024      ['activation_26[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 16, 16, 256)          0         ['add_12[0][0]',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  add_28 (Add)                (None, 16, 16, 256)          0         ['add_17[0][0]',
#                                                                      'batch_normalization_26[0][0]
#                                                                     ']
#
#  add_29 (Add)                (None, 16, 16, 256)          0         ['add_23[0][0]',
#                                                                      'add_28[0][0]']
#
#  depthwise_conv2d_11 (Depth  (None, 16, 16, 256)          6656      ['add_23[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_13 (Depth  (None, 16, 16, 256)          6656      ['add_29[0][0]']
#  wiseConv2D)
#
#  activation_23 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_11[0][0]']
#
#  activation_27 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_13[0][0]']
#
#  batch_normalization_23 (Ba  (None, 16, 16, 256)          1024      ['activation_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 16, 16, 256)          1024      ['activation_27[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'add_23[0][0]']
#
#  add_30 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'add_29[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 256)          65792     ['add_24[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)          65792     ['add_30[0][0]']
#
#  activation_24 (Activation)  (None, 16, 16, 256)          0         ['conv2d_12[0][0]']
#
#  activation_28 (Activation)  (None, 16, 16, 256)          0         ['conv2d_14[0][0]']
#
#  batch_normalization_24 (Ba  (None, 16, 16, 256)          1024      ['activation_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 16, 16, 256)          1024      ['activation_28[0][0]']
#  tchNormalization)
#
#  add_25 (Add)                (None, 16, 16, 256)          0         ['add_14[0][0]',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ']
#
#  add_31 (Add)                (None, 16, 16, 256)          0         ['add_20[0][0]',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  add_32 (Add)                (None, 16, 16, 256)          0         ['add_25[0][0]',
#                                                                      'add_31[0][0]']
#
#  depthwise_conv2d_14 (Depth  (None, 16, 16, 256)          6656      ['add_32[0][0]']
#  wiseConv2D)
#
#  activation_29 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_14[0][0]']
#
#  batch_normalization_29 (Ba  (None, 16, 16, 256)          1024      ['activation_29[0][0]']
#  tchNormalization)
#
#  add_33 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'add_32[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 256)          65792     ['add_33[0][0]']
#
#  activation_30 (Activation)  (None, 16, 16, 256)          0         ['conv2d_15[0][0]']
#
#  batch_normalization_30 (Ba  (None, 16, 16, 256)          1024      ['activation_30[0][0]']
#  tchNormalization)
#
#  add_34 (Add)                (None, 16, 16, 256)          0         ['add_23[0][0]',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  depthwise_conv2d_15 (Depth  (None, 16, 16, 256)          6656      ['add_34[0][0]']
#  wiseConv2D)
#
#  activation_31 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_15[0][0]']
#
#  batch_normalization_31 (Ba  (None, 16, 16, 256)          1024      ['activation_31[0][0]']
#  tchNormalization)
#
#  add_35 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ',
#                                                                      'add_34[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 256)          65792     ['add_35[0][0]']
#
#  activation_32 (Activation)  (None, 16, 16, 256)          0         ['conv2d_16[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 16, 256)          1024      ['activation_32[0][0]']
#  tchNormalization)
#
#  add_36 (Add)                (None, 16, 16, 256)          0         ['add_25[0][0]',
#                                                                      'batch_normalization_32[0][0]
#                                                                     ']
#
#  global_average_pooling2d (  (None, 256)                  0         ['add_36[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                    771       ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 1390595 (5.30 MB)
# Trainable params: 1373699 (5.24 MB)
# Non-trainable params: 16896 (66.00 KB)
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 10s 2s/step - loss: 3940.9214 - mean_squared_error: 3940.9214 - val_loss: 4975.6958 - val_mean_squared_error: 4975.6958
# Epoch 2/100
# 2/2 [==============================] - 1s 570ms/step - loss: 3838.7305 - mean_squared_error: 3838.7305 - val_loss: 5032.2065 - val_mean_squared_error: 5032.2065
# Epoch 3/100
# 2/2 [==============================] - 1s 502ms/step - loss: 3685.1953 - mean_squared_error: 3685.1953 - val_loss: 5094.5024 - val_mean_squared_error: 5094.5024
# Epoch 4/100
# 2/2 [==============================] - 1s 529ms/step - loss: 3528.2573 - mean_squared_error: 3528.2573 - val_loss: 5180.7603 - val_mean_squared_error: 5180.7603
# Epoch 5/100
# 2/2 [==============================] - 1s 622ms/step - loss: 3721.5923 - mean_squared_error: 3721.5923 - val_loss: 5054.4800 - val_mean_squared_error: 5054.4800
# Epoch 6/100
# 2/2 [==============================] - 1s 530ms/step - loss: 3358.0781 - mean_squared_error: 3358.0781 - val_loss: 5179.7388 - val_mean_squared_error: 5179.7388
# Epoch 7/100
# 2/2 [==============================] - 1s 546ms/step - loss: 3327.7856 - mean_squared_error: 3327.7856 - val_loss: 5620.9126 - val_mean_squared_error: 5620.9126
# Epoch 8/100
# 2/2 [==============================] - 2s 953ms/step - loss: 3233.7444 - mean_squared_error: 3233.7444 - val_loss: 5509.4058 - val_mean_squared_error: 5509.4058
# Epoch 9/100
# 2/2 [==============================] - 2s 832ms/step - loss: 3422.9910 - mean_squared_error: 3422.9910 - val_loss: 5100.1299 - val_mean_squared_error: 5100.1299
# Epoch 10/100
# 2/2 [==============================] - 1s 598ms/step - loss: 3390.5005 - mean_squared_error: 3390.5005 - val_loss: 5101.7261 - val_mean_squared_error: 5101.7261
# Epoch 11/100
# 2/2 [==============================] - 1s 551ms/step - loss: 3136.8398 - mean_squared_error: 3136.8398 - val_loss: 5325.9370 - val_mean_squared_error: 5325.9370
# Epoch 12/100
# 2/2 [==============================] - 1s 525ms/step - loss: 3215.9980 - mean_squared_error: 3215.9980 - val_loss: 4954.8091 - val_mean_squared_error: 4954.8091
# Epoch 13/100
# 2/2 [==============================] - 1s 513ms/step - loss: 3510.8933 - mean_squared_error: 3510.8933 - val_loss: 5149.7285 - val_mean_squared_error: 5149.7285
# Epoch 14/100
# 2/2 [==============================] - 1s 513ms/step - loss: 3199.9089 - mean_squared_error: 3199.9089 - val_loss: 5225.8999 - val_mean_squared_error: 5225.8999
# Epoch 15/100
# 2/2 [==============================] - 1s 670ms/step - loss: 3035.2200 - mean_squared_error: 3035.2200 - val_loss: 4888.8853 - val_mean_squared_error: 4888.8853
# Epoch 16/100
# 2/2 [==============================] - 2s 894ms/step - loss: 2983.7949 - mean_squared_error: 2983.7947 - val_loss: 4812.4004 - val_mean_squared_error: 4812.4004
# Epoch 17/100
# 2/2 [==============================] - 1s 548ms/step - loss: 2972.4192 - mean_squared_error: 2972.4192 - val_loss: 5142.5259 - val_mean_squared_error: 5142.5259
# Epoch 18/100
# 2/2 [==============================] - 1s 520ms/step - loss: 3021.5559 - mean_squared_error: 3021.5559 - val_loss: 4690.8267 - val_mean_squared_error: 4690.8267
# Epoch 19/100
# 2/2 [==============================] - 1s 559ms/step - loss: 2877.6746 - mean_squared_error: 2877.6746 - val_loss: 4519.5928 - val_mean_squared_error: 4519.5928
# Epoch 20/100
# 2/2 [==============================] - 1s 706ms/step - loss: 2816.9565 - mean_squared_error: 2816.9565 - val_loss: 4551.4033 - val_mean_squared_error: 4551.4033
# Epoch 21/100
# 2/2 [==============================] - 2s 863ms/step - loss: 2775.3723 - mean_squared_error: 2775.3723 - val_loss: 5018.0972 - val_mean_squared_error: 5018.0972
# Epoch 22/100
# 2/2 [==============================] - 1s 550ms/step - loss: 2958.3386 - mean_squared_error: 2958.3386 - val_loss: 4354.7783 - val_mean_squared_error: 4354.7783
# Epoch 23/100
# 2/2 [==============================] - 1s 555ms/step - loss: 2789.2310 - mean_squared_error: 2789.2310 - val_loss: 3917.7292 - val_mean_squared_error: 3917.7292
# Epoch 24/100
# 2/2 [==============================] - 2s 835ms/step - loss: 2897.9082 - mean_squared_error: 2897.9082 - val_loss: 4397.0396 - val_mean_squared_error: 4397.0396
# Epoch 25/100
# 2/2 [==============================] - 1s 581ms/step - loss: 3055.5139 - mean_squared_error: 3055.5139 - val_loss: 4892.8638 - val_mean_squared_error: 4892.8638
# Epoch 26/100
# 2/2 [==============================] - 1s 547ms/step - loss: 3021.8708 - mean_squared_error: 3021.8708 - val_loss: 5043.1460 - val_mean_squared_error: 5043.1460
# Epoch 27/100
# 2/2 [==============================] - 1s 581ms/step - loss: 2772.1311 - mean_squared_error: 2772.1311 - val_loss: 4612.6997 - val_mean_squared_error: 4612.6997
# Epoch 28/100
# 2/2 [==============================] - 2s 858ms/step - loss: 2697.9380 - mean_squared_error: 2697.9380 - val_loss: 4172.4351 - val_mean_squared_error: 4172.4351
# Epoch 29/100
# 2/2 [==============================] - 1s 550ms/step - loss: 2616.7361 - mean_squared_error: 2616.7358 - val_loss: 4042.0027 - val_mean_squared_error: 4042.0027
# Epoch 30/100
# 2/2 [==============================] - 1s 550ms/step - loss: 2714.6562 - mean_squared_error: 2714.6562 - val_loss: 4017.1755 - val_mean_squared_error: 4017.1755
# Epoch 31/100
# 2/2 [==============================] - 1s 785ms/step - loss: 2631.4563 - mean_squared_error: 2631.4563 - val_loss: 3745.1399 - val_mean_squared_error: 3745.1399
# Epoch 32/100
# 2/2 [==============================] - 2s 816ms/step - loss: 2625.2148 - mean_squared_error: 2625.2146 - val_loss: 3693.7805 - val_mean_squared_error: 3693.7805
# Epoch 33/100
# 2/2 [==============================] - 1s 548ms/step - loss: 2564.1672 - mean_squared_error: 2564.1672 - val_loss: 4075.6052 - val_mean_squared_error: 4075.6052
# Epoch 34/100
# 2/2 [==============================] - 2s 633ms/step - loss: 2982.0583 - mean_squared_error: 2982.0583 - val_loss: 3576.4004 - val_mean_squared_error: 3576.4004
# Epoch 35/100
# 2/2 [==============================] - 1s 535ms/step - loss: 2551.5513 - mean_squared_error: 2551.5513 - val_loss: 3310.4641 - val_mean_squared_error: 3310.4641
# Epoch 36/100
# 2/2 [==============================] - 1s 550ms/step - loss: 2705.4644 - mean_squared_error: 2705.4644 - val_loss: 3636.3699 - val_mean_squared_error: 3636.3699
# Epoch 37/100
# 2/2 [==============================] - 1s 539ms/step - loss: 2555.9453 - mean_squared_error: 2555.9453 - val_loss: 3713.6272 - val_mean_squared_error: 3713.6272
# Epoch 38/100
# 2/2 [==============================] - 1s 600ms/step - loss: 2379.6118 - mean_squared_error: 2379.6118 - val_loss: 3291.2590 - val_mean_squared_error: 3291.2590
# Epoch 39/100
# 2/2 [==============================] - 1s 546ms/step - loss: 2379.9258 - mean_squared_error: 2379.9258 - val_loss: 3018.6169 - val_mean_squared_error: 3018.6169
# Epoch 40/100
# 2/2 [==============================] - 2s 808ms/step - loss: 2281.9597 - mean_squared_error: 2281.9597 - val_loss: 2901.4766 - val_mean_squared_error: 2901.4766
# Epoch 41/100
# 2/2 [==============================] - 1s 512ms/step - loss: 2657.5273 - mean_squared_error: 2657.5273 - val_loss: 3217.2424 - val_mean_squared_error: 3217.2424
# Epoch 42/100
# 2/2 [==============================] - 1s 522ms/step - loss: 2267.4187 - mean_squared_error: 2267.4187 - val_loss: 3952.8779 - val_mean_squared_error: 3952.8779
# Epoch 43/100
# 2/2 [==============================] - 1s 528ms/step - loss: 2491.2952 - mean_squared_error: 2491.2952 - val_loss: 3741.5381 - val_mean_squared_error: 3741.5381
# Epoch 44/100
# 2/2 [==============================] - 1s 541ms/step - loss: 2210.7600 - mean_squared_error: 2210.7600 - val_loss: 3425.8230 - val_mean_squared_error: 3425.8230
# Epoch 45/100
# 2/2 [==============================] - 1s 548ms/step - loss: 2228.7415 - mean_squared_error: 2228.7415 - val_loss: 3240.0398 - val_mean_squared_error: 3240.0398
# Epoch 46/100
# 2/2 [==============================] - 1s 543ms/step - loss: 2193.7346 - mean_squared_error: 2193.7346 - val_loss: 3126.6609 - val_mean_squared_error: 3126.6609
# Epoch 47/100
# 2/2 [==============================] - 1s 550ms/step - loss: 2079.2886 - mean_squared_error: 2079.2886 - val_loss: 3136.6074 - val_mean_squared_error: 3136.6074
# Epoch 48/100
# 2/2 [==============================] - 1s 675ms/step - loss: 2023.6613 - mean_squared_error: 2023.6613 - val_loss: 3237.7170 - val_mean_squared_error: 3237.7170
# Epoch 49/100
# 2/2 [==============================] - 2s 905ms/step - loss: 2015.5262 - mean_squared_error: 2015.5262 - val_loss: 3047.6963 - val_mean_squared_error: 3047.6963
# Epoch 50/100
# 2/2 [==============================] - 2s 811ms/step - loss: 2047.1505 - mean_squared_error: 2047.1505 - val_loss: 2703.2756 - val_mean_squared_error: 2703.2756
# Epoch 51/100
# 2/2 [==============================] - 1s 544ms/step - loss: 2203.5940 - mean_squared_error: 2203.5940 - val_loss: 2455.2791 - val_mean_squared_error: 2455.2791
# Epoch 52/100
# 2/2 [==============================] - 1s 553ms/step - loss: 2028.9983 - mean_squared_error: 2028.9983 - val_loss: 2488.4678 - val_mean_squared_error: 2488.4678
# Epoch 53/100
# 2/2 [==============================] - 1s 608ms/step - loss: 1999.1775 - mean_squared_error: 1999.1775 - val_loss: 2729.4077 - val_mean_squared_error: 2729.4077
# Epoch 54/100
# 2/2 [==============================] - 1s 550ms/step - loss: 1842.8531 - mean_squared_error: 1842.8531 - val_loss: 2997.2842 - val_mean_squared_error: 2997.2842
# Epoch 55/100
# 2/2 [==============================] - 1s 527ms/step - loss: 1874.7780 - mean_squared_error: 1874.7780 - val_loss: 3140.5706 - val_mean_squared_error: 3140.5706
# Epoch 56/100
# 2/2 [==============================] - 1s 547ms/step - loss: 1854.4684 - mean_squared_error: 1854.4684 - val_loss: 2880.9646 - val_mean_squared_error: 2880.9646
# Epoch 57/100
# 2/2 [==============================] - 1s 591ms/step - loss: 1829.4906 - mean_squared_error: 1829.4906 - val_loss: 2671.8389 - val_mean_squared_error: 2671.8389
# Epoch 58/100
# 2/2 [==============================] - 2s 684ms/step - loss: 1678.9451 - mean_squared_error: 1678.9451 - val_loss: 2627.6064 - val_mean_squared_error: 2627.6064
# Epoch 59/100
# 2/2 [==============================] - 1s 532ms/step - loss: 1921.6671 - mean_squared_error: 1921.6671 - val_loss: 2439.2161 - val_mean_squared_error: 2439.2161
# Epoch 60/100
# 2/2 [==============================] - 1s 558ms/step - loss: 1582.2634 - mean_squared_error: 1582.2634 - val_loss: 2261.9094 - val_mean_squared_error: 2261.9094
# Epoch 61/100
# 2/2 [==============================] - 1s 544ms/step - loss: 1656.6376 - mean_squared_error: 1656.6376 - val_loss: 2080.0830 - val_mean_squared_error: 2080.0830
# Epoch 62/100
# 2/2 [==============================] - 1s 550ms/step - loss: 1513.2040 - mean_squared_error: 1513.2040 - val_loss: 1851.3013 - val_mean_squared_error: 1851.3013
# Epoch 63/100
# 2/2 [==============================] - 1s 541ms/step - loss: 1538.1456 - mean_squared_error: 1538.1456 - val_loss: 1684.7963 - val_mean_squared_error: 1684.7963
# Epoch 64/100
# 2/2 [==============================] - 1s 565ms/step - loss: 1503.4752 - mean_squared_error: 1503.4752 - val_loss: 1523.4897 - val_mean_squared_error: 1523.4897
# Epoch 65/100
# 2/2 [==============================] - 2s 863ms/step - loss: 1449.5067 - mean_squared_error: 1449.5067 - val_loss: 1466.2350 - val_mean_squared_error: 1466.2350
# Epoch 66/100
# 2/2 [==============================] - 1s 562ms/step - loss: 1446.2450 - mean_squared_error: 1446.2450 - val_loss: 1630.2310 - val_mean_squared_error: 1630.2310
# Epoch 67/100
# 2/2 [==============================] - 1s 528ms/step - loss: 1453.0684 - mean_squared_error: 1453.0684 - val_loss: 1644.8081 - val_mean_squared_error: 1644.8081
# Epoch 68/100
# 2/2 [==============================] - 1s 568ms/step - loss: 1291.7250 - mean_squared_error: 1291.7250 - val_loss: 1493.2764 - val_mean_squared_error: 1493.2764
# Epoch 69/100
# 2/2 [==============================] - 2s 823ms/step - loss: 1321.9531 - mean_squared_error: 1321.9531 - val_loss: 1352.5018 - val_mean_squared_error: 1352.5018
# Epoch 70/100
# 2/2 [==============================] - 2s 618ms/step - loss: 1264.9154 - mean_squared_error: 1264.9154 - val_loss: 1597.7284 - val_mean_squared_error: 1597.7284
# Epoch 71/100
# 2/2 [==============================] - 1s 637ms/step - loss: 1220.9559 - mean_squared_error: 1220.9559 - val_loss: 1998.7988 - val_mean_squared_error: 1998.7988
# Epoch 72/100
# 2/2 [==============================] - 2s 861ms/step - loss: 1411.9603 - mean_squared_error: 1411.9603 - val_loss: 1862.9961 - val_mean_squared_error: 1862.9961
# Epoch 73/100
# 2/2 [==============================] - 1s 534ms/step - loss: 1093.4512 - mean_squared_error: 1093.4512 - val_loss: 1935.2012 - val_mean_squared_error: 1935.2012
# Epoch 74/100
# 2/2 [==============================] - 1s 612ms/step - loss: 1109.5682 - mean_squared_error: 1109.5682 - val_loss: 2130.5168 - val_mean_squared_error: 2130.5168
# Epoch 75/100
# 2/2 [==============================] - 1s 541ms/step - loss: 1016.5948 - mean_squared_error: 1016.5948 - val_loss: 2121.7649 - val_mean_squared_error: 2121.7649
# Epoch 76/100
# 2/2 [==============================] - 1s 538ms/step - loss: 1027.7413 - mean_squared_error: 1027.7413 - val_loss: 1908.9946 - val_mean_squared_error: 1908.9946
# Epoch 77/100
# 2/2 [==============================] - 1s 533ms/step - loss: 1093.0510 - mean_squared_error: 1093.0510 - val_loss: 1663.8810 - val_mean_squared_error: 1663.8810
# Epoch 78/100
# 2/2 [==============================] - 1s 610ms/step - loss: 1032.5035 - mean_squared_error: 1032.5035 - val_loss: 1501.7123 - val_mean_squared_error: 1501.7123
# Epoch 79/100
# 2/2 [==============================] - 1s 553ms/step - loss: 931.6075 - mean_squared_error: 931.6075 - val_loss: 1519.2894 - val_mean_squared_error: 1519.2894
# Epoch 80/100
# 2/2 [==============================] - 1s 540ms/step - loss: 892.8688 - mean_squared_error: 892.8688 - val_loss: 1533.4337 - val_mean_squared_error: 1533.4337
# Epoch 81/100
# 2/2 [==============================] - 1s 777ms/step - loss: 981.7867 - mean_squared_error: 981.7867 - val_loss: 1612.9814 - val_mean_squared_error: 1612.9814
# Epoch 82/100
# 2/2 [==============================] - 1s 540ms/step - loss: 901.2326 - mean_squared_error: 901.2326 - val_loss: 1391.8120 - val_mean_squared_error: 1391.8120
# Epoch 83/100
# 2/2 [==============================] - 1s 557ms/step - loss: 807.5446 - mean_squared_error: 807.5446 - val_loss: 1240.6298 - val_mean_squared_error: 1240.6298
# Epoch 84/100
# 2/2 [==============================] - 1s 539ms/step - loss: 872.6932 - mean_squared_error: 872.6932 - val_loss: 1246.1051 - val_mean_squared_error: 1246.1051
# Epoch 85/100
# 2/2 [==============================] - 1s 532ms/step - loss: 751.3587 - mean_squared_error: 751.3587 - val_loss: 1292.6091 - val_mean_squared_error: 1292.6091
# Epoch 86/100
# 2/2 [==============================] - 1s 538ms/step - loss: 685.4395 - mean_squared_error: 685.4395 - val_loss: 1257.8976 - val_mean_squared_error: 1257.8976
# Epoch 87/100
# 2/2 [==============================] - 1s 542ms/step - loss: 706.0817 - mean_squared_error: 706.0817 - val_loss: 1093.5499 - val_mean_squared_error: 1093.5499
# Epoch 88/100
# 2/2 [==============================] - 1s 549ms/step - loss: 700.1211 - mean_squared_error: 700.1211 - val_loss: 865.1398 - val_mean_squared_error: 865.1398
# Epoch 89/100
# 2/2 [==============================] - 1s 604ms/step - loss: 730.2951 - mean_squared_error: 730.2951 - val_loss: 759.5916 - val_mean_squared_error: 759.5916
# Epoch 90/100
# 2/2 [==============================] - 2s 930ms/step - loss: 615.8714 - mean_squared_error: 615.8714 - val_loss: 671.1282 - val_mean_squared_error: 671.1282
# Epoch 91/100
# 2/2 [==============================] - 2s 881ms/step - loss: 654.6939 - mean_squared_error: 654.6939 - val_loss: 636.3928 - val_mean_squared_error: 636.3928
# Epoch 92/100
# 2/2 [==============================] - 1s 537ms/step - loss: 641.5180 - mean_squared_error: 641.5180 - val_loss: 661.4759 - val_mean_squared_error: 661.4759
# Epoch 93/100
# 2/2 [==============================] - 1s 542ms/step - loss: 530.9825 - mean_squared_error: 530.9825 - val_loss: 798.5852 - val_mean_squared_error: 798.5852
# Epoch 94/100
# 2/2 [==============================] - 1s 532ms/step - loss: 596.2057 - mean_squared_error: 596.2057 - val_loss: 819.0331 - val_mean_squared_error: 819.0331
# Epoch 95/100
# 2/2 [==============================] - 1s 531ms/step - loss: 470.0270 - mean_squared_error: 470.0270 - val_loss: 726.8245 - val_mean_squared_error: 726.8245
# Epoch 96/100
# 2/2 [==============================] - 1s 525ms/step - loss: 460.6156 - mean_squared_error: 460.6156 - val_loss: 703.5242 - val_mean_squared_error: 703.5242
# Epoch 97/100
# 2/2 [==============================] - 1s 513ms/step - loss: 492.3954 - mean_squared_error: 492.3954 - val_loss: 848.5555 - val_mean_squared_error: 848.5555
# Epoch 98/100
# 2/2 [==============================] - 1s 799ms/step - loss: 694.6177 - mean_squared_error: 694.6177 - val_loss: 899.1970 - val_mean_squared_error: 899.1970
# Epoch 99/100
# 2/2 [==============================] - 2s 799ms/step - loss: 418.7508 - mean_squared_error: 418.7508 - val_loss: 985.5427 - val_mean_squared_error: 985.5427
# Epoch 100/100
# 2/2 [==============================] - 1s 518ms/step - loss: 393.5549 - mean_squared_error: 393.5549 - val_loss: 1015.4630 - val_mean_squared_error: 1015.4630
# 1/1 [==============================] - 0s 72ms/step - loss: 8210.6094 - mean_squared_error: 8210.6094
# Test error: 8210.61

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 1s 828ms/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  12.696588370005289
# MSE:  250.07008844813504
# RMSE:  15.813604536857973
# r2_score:  -1.3700625121320722
# MSLE_min_shifted:  0.27901192366086197
# MAPE:  1.818461450587341e+16
# ===== flank_wear results =====
# MAE:  104.4538345336914
# MSE:  24356.535705671955
# RMSE:  156.06580569001
# r2_score:  -0.5201594873214876
# MSLE:  0.9390507586386306
# MAPE:  0.47121314474800946
# ===== overhang results =====
# MAE:  4.7096080271403
# MSE:  25.220199046217875
# RMSE:  5.021971629372061
# r2_score:  -0.25022881251761664
# MSLE:  0.1469404320750167
# MAPE:  0.3612053662242595
# ===== multi results =====
# MAE:  40.620010310279
# MSE:  8210.608664388768
# RMSE:  58.96712728541335
# r2_score:  -0.7134836039903921
# MSLE_min_shifted:  2.3678836187340333
# MAPE:  6061538168624469.0
