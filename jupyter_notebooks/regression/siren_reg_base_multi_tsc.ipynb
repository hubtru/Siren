# %%
# !pip install tensorflow_addons
# !pip install keras-tuner --upgrade

# clone siren repository, refresh folder to see the siren repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Siren/
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5
# Cloning into 'Siren'...
# remote: Enumerating objects: 351, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 351 (delta 26), reused 48 (delta 22), pack-reused 297
# Receiving objects: 100% (351/351), 188.93 MiB | 26.51 MiB/s, done.
# Resolving deltas: 100% (98/98), done.
# Updating files: 100% (236/236), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_spec = 9
in_channel_chip = 3
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_spec = (img_rows, img_cols, in_channel_spec)
input_shape_chip = (img_rows, img_cols, in_channel_chip)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_tsc"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_tool.h5"
model_spec_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_spec.h5"
model_chip_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_chip.h5"

# dataset
csv_path = "/content/Siren/dataset/labels_reg_sample.csv"
tool_path = "/content/Siren/dataset/tool"
spec_path = "/content/Siren/dataset/spec"
chip_path = "/content/Siren/dataset/chip"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                        tool  \
# 14   /content/Siren/dataset/tool/T8R3B4.jpg
# 10   /content/Siren/dataset/tool/T6R9B3.jpg
# 0    /content/Siren/dataset/tool/T1R2B1.jpg
# 3   /content/Siren/dataset/tool/T2R13B4.jpg
# 1    /content/Siren/dataset/tool/T1R7B4.jpg
#
#                                        spec_x  \
# 14   /content/Siren/dataset/spec/x/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/x/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/x/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/x/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/x/T1R7B4.jpg
#
#                                        spec_y  \
# 14   /content/Siren/dataset/spec/y/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/y/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/y/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/y/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/y/T1R7B4.jpg
#
#                                        spec_z  \
# 14   /content/Siren/dataset/spec/z/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/z/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/z/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/z/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/z/T1R7B4.jpg
#
#                                        chip
# 14   /content/Siren/dataset/chip/T8R3B4.jpg
# 10   /content/Siren/dataset/chip/T6R9B3.jpg
# 0    /content/Siren/dataset/chip/T1R2B1.jpg
# 3   /content/Siren/dataset/chip/T2R13B4.jpg
# 1    /content/Siren/dataset/chip/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                        tool  \
# 16   /content/Siren/dataset/tool/T9R7B4.jpg
# 18  /content/Siren/dataset/tool/T10R3B4.jpg
# 9   /content/Siren/dataset/tool/T5R12B1.jpg
#
#                                        spec_x  \
# 16   /content/Siren/dataset/spec/x/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/x/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/x/T5R12B1.jpg
#
#                                        spec_y  \
# 16   /content/Siren/dataset/spec/y/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/y/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/y/T5R12B1.jpg
#
#                                        spec_z  \
# 16   /content/Siren/dataset/spec/z/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/z/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/z/T5R12B1.jpg
#
#                                        chip
# 16   /content/Siren/dataset/chip/T9R7B4.jpg
# 18  /content/Siren/dataset/chip/T10R3B4.jpg
# 9   /content/Siren/dataset/chip/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                        tool  \
# 5   /content/Siren/dataset/tool/T3R10B1.jpg
# 13  /content/Siren/dataset/tool/T7R14B3.jpg
# 12   /content/Siren/dataset/tool/T7R8B3.jpg
#
#                                        spec_x  \
# 5   /content/Siren/dataset/spec/x/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/x/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/x/T7R8B3.jpg
#
#                                        spec_y  \
# 5   /content/Siren/dataset/spec/y/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/y/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/y/T7R8B3.jpg
#
#                                        spec_z  \
# 5   /content/Siren/dataset/spec/z/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/z/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/z/T7R8B3.jpg
#
#                                        chip
# 5   /content/Siren/dataset/chip/T3R10B1.jpg
# 13  /content/Siren/dataset/chip/T7R14B3.jpg
# 12   /content/Siren/dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images


def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []
    for i in range(file_paths_x.size):
        img = []
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_x)

        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_y)

        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_z)
        img = np.concatenate(img, axis=2)
        images.append(img)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / 255.0

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Split the last dimension into 3 separate spectrograms
spectrogram1 = x_train_spec[0, :, :, 0:3]  # First spectrogram (channels 0-2)
spectrogram2 = x_train_spec[0, :, :, 3:6]  # Second spectrogram (channels 3-5)
spectrogram3 = x_train_spec[0, :, :, 6:9]  # Third spectrogram (channels 6-8)
# Convert arrays to images
pil_img1 = tf.keras.utils.array_to_img(spectrogram1)
pil_img2 = tf.keras.utils.array_to_img(spectrogram2)
pil_img3 = tf.keras.utils.array_to_img(spectrogram3)
# Display the images
fig, ax = plt.subplots(1,3, figsize=(10,30))
ax[0].imshow(pil_img1)
ax[1].imshow(pil_img2)
ax[2].imshow(pil_img3)
plt.plot()
# Out:
# []

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
# ============================== augment 1/3 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)

# %%
# ============================== augment 2/3 ==============================
data_augmentation_spec = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_spec",
)

# %%
# ============================== augment 3/3==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_spec = data_augmentation_spec(x_train_spec)
x_train_chip = data_augmentation_chip(x_train_chip)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_spec": x_train_spec,
            "input_1_chip": x_train_chip,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_spec": x_test_spec,
            "input_1_chip": x_test_chip,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_spec": x_val_spec,
            "input_1_chip": x_val_chip,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs2 = k.Input(input_shape_spec)
inputs3 = k.Input(input_shape_chip)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_spec': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
model_tool = k.models.load_model(model_tool_path, compile=False)
model_spec = k.models.load_model(model_spec_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)

model_tool.trainable = False
model_spec.trainable = False
model_chip.trainable = False


def load_siren(model_tool, model_spec, model_chip):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs2 = model_spec.input
    inputs2._name = "input_spec"
    inputs3 = model_chip.input
    inputs3._name = "input_chip"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_spec = k.Model(
        inputs=model_spec.input, outputs=model_spec.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_spec.output,
            truncated_model_chip.output,
        ]
    )
    output = layers.Dense(num_classes, activation="linear", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs2, inputs3], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_spec.layers:
    layer._name = layer.name + str("_spec")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren(model_tool, model_spec, model_chip)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1_tool (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_1_spec (InputLayer)      [(None, 256, 256, 9  0           []
#                                 )]
#
#  input_1_chip (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_tool (Conv2D)           (None, 16, 16, 256)  196864      ['input_1_tool[0][0]']
#
#  conv2d_spec (Conv2D)           (None, 16, 16, 256)  590080      ['input_1_spec[0][0]']
#
#  conv2d_chip (Conv2D)           (None, 16, 16, 256)  196864      ['input_1_chip[0][0]']
#
#  activation_tool (Activation)   (None, 16, 16, 256)  0           ['conv2d_tool[0][0]']
#
#  activation_spec (Activation)   (None, 16, 16, 256)  0           ['conv2d_spec[0][0]']
#
#  activation_chip (Activation)   (None, 16, 16, 256)  0           ['conv2d_chip[0][0]']
#
#  batch_normalization_tool (Batc  (None, 16, 16, 256)  1024       ['activation_tool[0][0]']
#  hNormalization)
#
#  batch_normalization_spec (Batc  (None, 16, 16, 256)  1024       ['activation_spec[0][0]']
#  hNormalization)
#
#  batch_normalization_chip (Batc  (None, 16, 16, 256)  1024       ['activation_chip[0][0]']
#  hNormalization)
#
#  depthwise_conv2d_tool (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_tool[0][0]'
#  seConv2D)                                                       ]
#
#  depthwise_conv2d_spec (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_spec[0][0]'
#  seConv2D)                                                       ]
#
#  depthwise_conv2d_chip (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_chip[0][0]'
#  seConv2D)                                                       ]
#
#  activation_1_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_tool[0][0]']
#
#  activation_1_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_spec[0][0]']
#
#  activation_1_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_chip[0][0]']
#
#  batch_normalization_1_tool (Ba  (None, 16, 16, 256)  1024       ['activation_1_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_1_spec (Ba  (None, 16, 16, 256)  1024       ['activation_1_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_1_chip (Ba  (None, 16, 16, 256)  1024       ['activation_1_chip[0][0]']
#  tchNormalization)
#
#  add_tool (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_spec (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  add_chip (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  conv2d_1_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_tool[0][0]']
#
#  conv2d_1_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_spec[0][0]']
#
#  conv2d_1_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_chip[0][0]']
#
#  activation_2_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_tool[0][0]']
#
#  activation_2_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_spec[0][0]']
#
#  activation_2_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_chip[0][0]']
#
#  batch_normalization_2_tool (Ba  (None, 16, 16, 256)  1024       ['activation_2_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_2_spec (Ba  (None, 16, 16, 256)  1024       ['activation_2_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_2_chip (Ba  (None, 16, 16, 256)  1024       ['activation_2_chip[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_1_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  depthwise_conv2d_1_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  depthwise_conv2d_1_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_3_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_tool[0][0]']
#
#  activation_3_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_spec[0][0]']
#
#  activation_3_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_chip[0][0]']
#
#  batch_normalization_3_tool (Ba  (None, 16, 16, 256)  1024       ['activation_3_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_3_spec (Ba  (None, 16, 16, 256)  1024       ['activation_3_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_3_chip (Ba  (None, 16, 16, 256)  1024       ['activation_3_chip[0][0]']
#  tchNormalization)
#
#  add_1_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_tool[0][0
#                                                                  ]']
#
#  add_1_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_spec[0][0
#                                                                  ]']
#
#  add_1_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_chip[0][0
#                                                                  ]']
#
#  conv2d_2_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_tool[0][0]']
#
#  conv2d_2_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_spec[0][0]']
#
#  conv2d_2_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_chip[0][0]']
#
#  activation_4_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_tool[0][0]']
#
#  activation_4_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_spec[0][0]']
#
#  activation_4_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_chip[0][0]']
#
#  batch_normalization_4_tool (Ba  (None, 16, 16, 256)  1024       ['activation_4_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_4_spec (Ba  (None, 16, 16, 256)  1024       ['activation_4_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_4_chip (Ba  (None, 16, 16, 256)  1024       ['activation_4_chip[0][0]']
#  tchNormalization)
#
#  add_4_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_4_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  add_4_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_4_tool (Depth  (None, 16, 16, 256)  6656       ['add_4_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_4_spec (Depth  (None, 16, 16, 256)  6656       ['add_4_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_4_chip (Depth  (None, 16, 16, 256)  6656       ['add_4_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_2_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_tool[0][0]']
#
#  depthwise_conv2d_2_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_spec[0][0]']
#
#  depthwise_conv2d_2_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_chip[0][0]']
#
#  activation_5_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_tool[0][0]']
#
#  batch_normalization_9_tool (Ba  (None, 16, 16, 256)  1024       ['activation_9_tool[0][0]']
#  tchNormalization)
#
#  activation_5_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_spec[0][0]']
#
#  batch_normalization_9_spec (Ba  (None, 16, 16, 256)  1024       ['activation_9_spec[0][0]']
#  tchNormalization)
#
#  activation_5_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_chip[0][0]']
#
#  batch_normalization_9_chip (Ba  (None, 16, 16, 256)  1024       ['activation_9_chip[0][0]']
#  tchNormalization)
#
#  batch_normalization_5_tool (Ba  (None, 16, 16, 256)  1024       ['activation_5_tool[0][0]']
#  tchNormalization)
#
#  add_5_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_tool[0][0
#                                                                  ]',
#                                                                   'add_4_tool[0][0]']
#
#  batch_normalization_5_spec (Ba  (None, 16, 16, 256)  1024       ['activation_5_spec[0][0]']
#  tchNormalization)
#
#  add_5_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_spec[0][0
#                                                                  ]',
#                                                                   'add_4_spec[0][0]']
#
#  batch_normalization_5_chip (Ba  (None, 16, 16, 256)  1024       ['activation_5_chip[0][0]']
#  tchNormalization)
#
#  add_5_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_chip[0][0
#                                                                  ]',
#                                                                   'add_4_chip[0][0]']
#
#  add_2_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_tool[0][0
#                                                                  ]']
#
#  conv2d_5_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_tool[0][0]']
#
#  add_2_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_spec[0][0
#                                                                  ]']
#
#  conv2d_5_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_spec[0][0]']
#
#  add_2_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_chip[0][0
#                                                                  ]']
#
#  conv2d_5_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_chip[0][0]']
#
#  conv2d_3_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_tool[0][0]']
#
#  activation_10_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_5_tool[0][0]']
#  )
#
#  conv2d_3_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_spec[0][0]']
#
#  activation_10_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_5_spec[0][0]']
#  )
#
#  conv2d_3_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_chip[0][0]']
#
#  activation_10_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_5_chip[0][0]']
#  )
#
#  activation_6_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_tool[0][0]']
#
#  batch_normalization_10_tool (B  (None, 16, 16, 256)  1024       ['activation_10_tool[0][0]']
#  atchNormalization)
#
#  activation_6_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_spec[0][0]']
#
#  batch_normalization_10_spec (B  (None, 16, 16, 256)  1024       ['activation_10_spec[0][0]']
#  atchNormalization)
#
#  activation_6_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_chip[0][0]']
#
#  batch_normalization_10_chip (B  (None, 16, 16, 256)  1024       ['activation_10_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_6_tool (Ba  (None, 16, 16, 256)  1024       ['activation_6_tool[0][0]']
#  tchNormalization)
#
#  add_6_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_tool[0][
#                                                                  0]']
#
#  batch_normalization_6_spec (Ba  (None, 16, 16, 256)  1024       ['activation_6_spec[0][0]']
#  tchNormalization)
#
#  add_6_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_spec[0][
#                                                                  0]']
#
#  batch_normalization_6_chip (Ba  (None, 16, 16, 256)  1024       ['activation_6_chip[0][0]']
#  tchNormalization)
#
#  add_6_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_chip[0][
#                                                                  0]']
#
#  add_7_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_tool[0][0
#                                                                  ]',
#                                                                   'add_6_tool[0][0]']
#
#  add_7_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_spec[0][0
#                                                                  ]',
#                                                                   'add_6_spec[0][0]']
#
#  add_7_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_chip[0][0
#                                                                  ]',
#                                                                   'add_6_chip[0][0]']
#
#  depthwise_conv2d_5_tool (Depth  (None, 16, 16, 256)  6656       ['add_7_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_5_spec (Depth  (None, 16, 16, 256)  6656       ['add_7_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_5_chip (Depth  (None, 16, 16, 256)  6656       ['add_7_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_3_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_tool[0][0]']
#  )
#
#  depthwise_conv2d_3_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_spec[0][0]']
#  )
#
#  depthwise_conv2d_3_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_chip[0][0]']
#  )
#
#  activation_7_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_tool[0][0]']
#
#  batch_normalization_11_tool (B  (None, 16, 16, 256)  1024       ['activation_11_tool[0][0]']
#  atchNormalization)
#
#  activation_7_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_spec[0][0]']
#
#  batch_normalization_11_spec (B  (None, 16, 16, 256)  1024       ['activation_11_spec[0][0]']
#  atchNormalization)
#
#  activation_7_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_chip[0][0]']
#
#  batch_normalization_11_chip (B  (None, 16, 16, 256)  1024       ['activation_11_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_7_tool (Ba  (None, 16, 16, 256)  1024       ['activation_7_tool[0][0]']
#  tchNormalization)
#
#  add_8_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_tool[0][
#                                                                  0]',
#                                                                   'add_7_tool[0][0]']
#
#  batch_normalization_7_spec (Ba  (None, 16, 16, 256)  1024       ['activation_7_spec[0][0]']
#  tchNormalization)
#
#  add_8_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_spec[0][
#                                                                  0]',
#                                                                   'add_7_spec[0][0]']
#
#  batch_normalization_7_chip (Ba  (None, 16, 16, 256)  1024       ['activation_7_chip[0][0]']
#  tchNormalization)
#
#  add_8_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_chip[0][
#                                                                  0]',
#                                                                   'add_7_chip[0][0]']
#
#  add_3_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_tool[0][0
#                                                                  ]']
#
#  conv2d_6_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_tool[0][0]']
#
#  add_3_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_spec[0][0
#                                                                  ]']
#
#  conv2d_6_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_spec[0][0]']
#
#  add_3_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_chip[0][0
#                                                                  ]']
#
#  conv2d_6_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_chip[0][0]']
#
#  conv2d_4_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_tool[0][0]']
#
#  activation_12_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_6_tool[0][0]']
#  )
#
#  conv2d_4_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_spec[0][0]']
#
#  activation_12_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_6_spec[0][0]']
#  )
#
#  conv2d_4_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_chip[0][0]']
#
#  activation_12_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_6_chip[0][0]']
#  )
#
#  activation_8_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_tool[0][0]']
#
#  batch_normalization_12_tool (B  (None, 16, 16, 256)  1024       ['activation_12_tool[0][0]']
#  atchNormalization)
#
#  activation_8_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_spec[0][0]']
#
#  batch_normalization_12_spec (B  (None, 16, 16, 256)  1024       ['activation_12_spec[0][0]']
#  atchNormalization)
#
#  activation_8_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_chip[0][0]']
#
#  batch_normalization_12_chip (B  (None, 16, 16, 256)  1024       ['activation_12_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_8_tool (Ba  (None, 16, 16, 256)  1024       ['activation_8_tool[0][0]']
#  tchNormalization)
#
#  add_9_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_tool[0][
#                                                                  0]']
#
#  batch_normalization_8_spec (Ba  (None, 16, 16, 256)  1024       ['activation_8_spec[0][0]']
#  tchNormalization)
#
#  add_9_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_spec[0][
#                                                                  0]']
#
#  batch_normalization_8_chip (Ba  (None, 16, 16, 256)  1024       ['activation_8_chip[0][0]']
#  tchNormalization)
#
#  add_9_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_chip[0][
#                                                                  0]']
#
#  add_10_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_tool[0][0
#                                                                  ]',
#                                                                   'add_9_tool[0][0]']
#
#  add_15_tool (Add)              (None, 16, 16, 256)  0           ['add_9_tool[0][0]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_10_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_spec[0][0
#                                                                  ]',
#                                                                   'add_9_spec[0][0]']
#
#  add_15_spec (Add)              (None, 16, 16, 256)  0           ['add_9_spec[0][0]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  add_10_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_chip[0][0
#                                                                  ]',
#                                                                   'add_9_chip[0][0]']
#
#  add_15_chip (Add)              (None, 16, 16, 256)  0           ['add_9_chip[0][0]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_6_tool (Depth  (None, 16, 16, 256)  6656       ['add_10_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_tool (Depth  (None, 16, 16, 256)  6656       ['add_15_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_6_spec (Depth  (None, 16, 16, 256)  6656       ['add_10_spec[0][0]']
# ...
#  )                                                               ]
#
#  activation_29_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_spec[0][0]'
#  )                                                               ]
#
#  activation_29_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_chip[0][0]'
#  )                                                               ]
#
#  batch_normalization_29_tool (B  (None, 16, 16, 256)  1024       ['activation_29_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_29_spec (B  (None, 16, 16, 256)  1024       ['activation_29_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_29_chip (B  (None, 16, 16, 256)  1024       ['activation_29_chip[0][0]']
#  atchNormalization)
#
#  add_33_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_tool[0][
#                                                                  0]',
#                                                                   'add_32_tool[0][0]']
#
#  add_33_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_spec[0][
#                                                                  0]',
#                                                                   'add_32_spec[0][0]']
#
#  add_33_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_chip[0][
#                                                                  0]',
#                                                                   'add_32_chip[0][0]']
#
#  conv2d_15_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_tool[0][0]']
#
#  conv2d_15_spec (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_spec[0][0]']
#
#  conv2d_15_chip (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_chip[0][0]']
#
#  activation_30_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_15_tool[0][0]']
#  )
#
#  activation_30_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_15_spec[0][0]']
#  )
#
#  activation_30_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_15_chip[0][0]']
#  )
#
#  batch_normalization_30_tool (B  (None, 16, 16, 256)  1024       ['activation_30_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_30_spec (B  (None, 16, 16, 256)  1024       ['activation_30_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_30_chip (B  (None, 16, 16, 256)  1024       ['activation_30_chip[0][0]']
#  atchNormalization)
#
#  add_34_tool (Add)              (None, 16, 16, 256)  0           ['add_23_tool[0][0]',
#                                                                   'batch_normalization_30_tool[0][
#                                                                  0]']
#
#  add_34_spec (Add)              (None, 16, 16, 256)  0           ['add_23_spec[0][0]',
#                                                                   'batch_normalization_30_spec[0][
#                                                                  0]']
#
#  add_34_chip (Add)              (None, 16, 16, 256)  0           ['add_23_chip[0][0]',
#                                                                   'batch_normalization_30_chip[0][
#                                                                  0]']
#
#  depthwise_conv2d_15_tool (Dept  (None, 16, 16, 256)  6656       ['add_34_tool[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_15_spec (Dept  (None, 16, 16, 256)  6656       ['add_34_spec[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_15_chip (Dept  (None, 16, 16, 256)  6656       ['add_34_chip[0][0]']
#  hwiseConv2D)
#
#  activation_31_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_tool[0][0]'
#  )                                                               ]
#
#  activation_31_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_spec[0][0]'
#  )                                                               ]
#
#  activation_31_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_chip[0][0]'
#  )                                                               ]
#
#  batch_normalization_31_tool (B  (None, 16, 16, 256)  1024       ['activation_31_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_31_spec (B  (None, 16, 16, 256)  1024       ['activation_31_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_31_chip (B  (None, 16, 16, 256)  1024       ['activation_31_chip[0][0]']
#  atchNormalization)
#
#  add_35_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_tool[0][
#                                                                  0]',
#                                                                   'add_34_tool[0][0]']
#
#  add_35_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_spec[0][
#                                                                  0]',
#                                                                   'add_34_spec[0][0]']
#
#  add_35_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_chip[0][
#                                                                  0]',
#                                                                   'add_34_chip[0][0]']
#
#  conv2d_16_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_tool[0][0]']
#
#  conv2d_16_spec (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_spec[0][0]']
#
#  conv2d_16_chip (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_chip[0][0]']
#
#  activation_32_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_16_tool[0][0]']
#  )
#
#  activation_32_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_16_spec[0][0]']
#  )
#
#  activation_32_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_16_chip[0][0]']
#  )
#
#  batch_normalization_32_tool (B  (None, 16, 16, 256)  1024       ['activation_32_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_32_spec (B  (None, 16, 16, 256)  1024       ['activation_32_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_32_chip (B  (None, 16, 16, 256)  1024       ['activation_32_chip[0][0]']
#  atchNormalization)
#
#  add_36_tool (Add)              (None, 16, 16, 256)  0           ['add_25_tool[0][0]',
#                                                                   'batch_normalization_32_tool[0][
#                                                                  0]']
#
#  add_36_spec (Add)              (None, 16, 16, 256)  0           ['add_25_spec[0][0]',
#                                                                   'batch_normalization_32_spec[0][
#                                                                  0]']
#
#  add_36_chip (Add)              (None, 16, 16, 256)  0           ['add_25_chip[0][0]',
#                                                                   'batch_normalization_32_chip[0][
#                                                                  0]']
#
#  global_average_pooling2d_tool   (None, 256)         0           ['add_36_tool[0][0]']
#  (GlobalAveragePooling2D)
#
#  global_average_pooling2d_spec   (None, 256)         0           ['add_36_spec[0][0]']
#  (GlobalAveragePooling2D)
#
#  global_average_pooling2d_chip   (None, 256)         0           ['add_36_chip[0][0]']
#  (GlobalAveragePooling2D)
#
#  concatenate (Concatenate)      (None, 768)          0           ['global_average_pooling2d_tool[0
#                                                                  ][0]',
#                                                                   'global_average_pooling2d_spec[0
#                                                                  ][0]',
#                                                                   'global_average_pooling2d_chip[0
#                                                                  ][0]']
#
#  output_mult (Dense)            (None, 3)            2307        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 4,564,995
# Trainable params: 2,307
# Non-trainable params: 4,562,688
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 34s 5s/step - loss: 3933.4045 - mean_squared_error: 3933.4045 - val_loss: 4738.3716 - val_mean_squared_error: 4738.3716
# Epoch 2/100
# 2/2 [==============================] - 2s 847ms/step - loss: 3757.0188 - mean_squared_error: 3757.0188 - val_loss: 4552.5088 - val_mean_squared_error: 4552.5088
# Epoch 3/100
# 2/2 [==============================] - 2s 859ms/step - loss: 3611.7131 - mean_squared_error: 3611.7131 - val_loss: 4374.8535 - val_mean_squared_error: 4374.8535
# Epoch 4/100
# 2/2 [==============================] - 2s 875ms/step - loss: 3446.9299 - mean_squared_error: 3446.9299 - val_loss: 4206.8208 - val_mean_squared_error: 4206.8208
# Epoch 5/100
# 2/2 [==============================] - 2s 981ms/step - loss: 3316.3384 - mean_squared_error: 3316.3384 - val_loss: 4045.1758 - val_mean_squared_error: 4045.1758
# Epoch 6/100
# 2/2 [==============================] - 2s 802ms/step - loss: 3198.2600 - mean_squared_error: 3198.2600 - val_loss: 3890.6008 - val_mean_squared_error: 3890.6008
# Epoch 7/100
# 2/2 [==============================] - 2s 847ms/step - loss: 3073.7893 - mean_squared_error: 3073.7893 - val_loss: 3743.7246 - val_mean_squared_error: 3743.7246
# Epoch 8/100
# 2/2 [==============================] - 2s 826ms/step - loss: 2950.0742 - mean_squared_error: 2950.0742 - val_loss: 3604.4099 - val_mean_squared_error: 3604.4099
# Epoch 9/100
# 2/2 [==============================] - 2s 854ms/step - loss: 2839.3865 - mean_squared_error: 2839.3865 - val_loss: 3471.3252 - val_mean_squared_error: 3471.3252
# Epoch 10/100
# 2/2 [==============================] - 2s 816ms/step - loss: 2737.2761 - mean_squared_error: 2737.2761 - val_loss: 3344.0969 - val_mean_squared_error: 3344.0969
# Epoch 11/100
# 2/2 [==============================] - 3s 1s/step - loss: 2631.6438 - mean_squared_error: 2631.6438 - val_loss: 3223.3489 - val_mean_squared_error: 3223.3489
# Epoch 12/100
# 2/2 [==============================] - 2s 852ms/step - loss: 2536.0530 - mean_squared_error: 2536.0530 - val_loss: 3107.0576 - val_mean_squared_error: 3107.0576
# Epoch 13/100
# 2/2 [==============================] - 2s 1s/step - loss: 2436.4062 - mean_squared_error: 2436.4062 - val_loss: 2995.0388 - val_mean_squared_error: 2995.0388
# Epoch 14/100
# 2/2 [==============================] - 3s 2s/step - loss: 2359.1372 - mean_squared_error: 2359.1372 - val_loss: 2886.4822 - val_mean_squared_error: 2886.4822
# Epoch 15/100
# 2/2 [==============================] - 4s 1s/step - loss: 2279.7659 - mean_squared_error: 2279.7659 - val_loss: 2781.3984 - val_mean_squared_error: 2781.3984
# Epoch 16/100
# 2/2 [==============================] - 2s 819ms/step - loss: 2192.1831 - mean_squared_error: 2192.1831 - val_loss: 2680.9548 - val_mean_squared_error: 2680.9548
# Epoch 17/100
# 2/2 [==============================] - 2s 857ms/step - loss: 2106.8132 - mean_squared_error: 2106.8132 - val_loss: 2583.4099 - val_mean_squared_error: 2583.4099
# Epoch 18/100
# 2/2 [==============================] - 2s 862ms/step - loss: 2044.9270 - mean_squared_error: 2044.9270 - val_loss: 2487.9272 - val_mean_squared_error: 2487.9272
# Epoch 19/100
# 2/2 [==============================] - 2s 845ms/step - loss: 1972.2552 - mean_squared_error: 1972.2552 - val_loss: 2395.7864 - val_mean_squared_error: 2395.7864
# Epoch 20/100
# 2/2 [==============================] - 2s 2s/step - loss: 1903.2389 - mean_squared_error: 1903.2389 - val_loss: 2306.7102 - val_mean_squared_error: 2306.7102
# Epoch 21/100
# 2/2 [==============================] - 2s 805ms/step - loss: 1833.1068 - mean_squared_error: 1833.1068 - val_loss: 2220.4741 - val_mean_squared_error: 2220.4741
# Epoch 22/100
# 2/2 [==============================] - 2s 856ms/step - loss: 1771.6686 - mean_squared_error: 1771.6686 - val_loss: 2137.1003 - val_mean_squared_error: 2137.1003
# Epoch 23/100
# 2/2 [==============================] - 2s 847ms/step - loss: 1718.0801 - mean_squared_error: 1718.0801 - val_loss: 2057.2749 - val_mean_squared_error: 2057.2749
# Epoch 24/100
# 2/2 [==============================] - 2s 838ms/step - loss: 1662.7030 - mean_squared_error: 1662.7030 - val_loss: 1980.5093 - val_mean_squared_error: 1980.5093
# Epoch 25/100
# 2/2 [==============================] - 2s 816ms/step - loss: 1595.8331 - mean_squared_error: 1595.8331 - val_loss: 1908.1919 - val_mean_squared_error: 1908.1919
# Epoch 26/100
# 2/2 [==============================] - 2s 858ms/step - loss: 1550.5383 - mean_squared_error: 1550.5383 - val_loss: 1838.1045 - val_mean_squared_error: 1838.1045
# Epoch 27/100
# 2/2 [==============================] - 2s 923ms/step - loss: 1504.1348 - mean_squared_error: 1504.1348 - val_loss: 1769.8961 - val_mean_squared_error: 1769.8961
# Epoch 28/100
# 2/2 [==============================] - 2s 842ms/step - loss: 1451.7428 - mean_squared_error: 1451.7428 - val_loss: 1704.5748 - val_mean_squared_error: 1704.5748
# Epoch 29/100
# 2/2 [==============================] - 2s 1s/step - loss: 1408.7775 - mean_squared_error: 1408.7775 - val_loss: 1641.8461 - val_mean_squared_error: 1641.8461
# Epoch 30/100
# 2/2 [==============================] - 2s 845ms/step - loss: 1364.0175 - mean_squared_error: 1364.0175 - val_loss: 1582.2496 - val_mean_squared_error: 1582.2496
# Epoch 31/100
# 2/2 [==============================] - 2s 801ms/step - loss: 1326.8292 - mean_squared_error: 1326.8292 - val_loss: 1525.2085 - val_mean_squared_error: 1525.2085
# Epoch 32/100
# 2/2 [==============================] - 2s 793ms/step - loss: 1285.2517 - mean_squared_error: 1285.2517 - val_loss: 1469.6825 - val_mean_squared_error: 1469.6825
# Epoch 33/100
# 2/2 [==============================] - 2s 1s/step - loss: 1250.5382 - mean_squared_error: 1250.5382 - val_loss: 1416.8656 - val_mean_squared_error: 1416.8656
# Epoch 34/100
# 2/2 [==============================] - 2s 835ms/step - loss: 1210.0187 - mean_squared_error: 1210.0187 - val_loss: 1366.1886 - val_mean_squared_error: 1366.1886
# Epoch 35/100
# 2/2 [==============================] - 2s 820ms/step - loss: 1182.3153 - mean_squared_error: 1182.3153 - val_loss: 1316.8558 - val_mean_squared_error: 1316.8558
# Epoch 36/100
# 2/2 [==============================] - 2s 821ms/step - loss: 1155.0972 - mean_squared_error: 1155.0972 - val_loss: 1269.0497 - val_mean_squared_error: 1269.0497
# Epoch 37/100
# 2/2 [==============================] - 2s 819ms/step - loss: 1124.8054 - mean_squared_error: 1124.8054 - val_loss: 1223.6422 - val_mean_squared_error: 1223.6422
# Epoch 38/100
# 2/2 [==============================] - 2s 841ms/step - loss: 1095.1387 - mean_squared_error: 1095.1387 - val_loss: 1181.2625 - val_mean_squared_error: 1181.2625
# Epoch 39/100
# 2/2 [==============================] - 2s 1s/step - loss: 1070.6613 - mean_squared_error: 1070.6613 - val_loss: 1140.5616 - val_mean_squared_error: 1140.5616
# Epoch 40/100
# 2/2 [==============================] - 2s 825ms/step - loss: 1038.6134 - mean_squared_error: 1038.6134 - val_loss: 1102.7604 - val_mean_squared_error: 1102.7604
# Epoch 41/100
# 2/2 [==============================] - 2s 823ms/step - loss: 1018.7402 - mean_squared_error: 1018.7402 - val_loss: 1066.2860 - val_mean_squared_error: 1066.2860
# Epoch 42/100
# 2/2 [==============================] - 2s 817ms/step - loss: 996.1548 - mean_squared_error: 996.1548 - val_loss: 1030.8046 - val_mean_squared_error: 1030.8046
# Epoch 43/100
# 2/2 [==============================] - 2s 848ms/step - loss: 973.8757 - mean_squared_error: 973.8757 - val_loss: 997.4631 - val_mean_squared_error: 997.4631
# Epoch 44/100
# 2/2 [==============================] - 2s 1s/step - loss: 953.7304 - mean_squared_error: 953.7304 - val_loss: 965.7493 - val_mean_squared_error: 965.7493
# Epoch 45/100
# 2/2 [==============================] - 2s 859ms/step - loss: 935.9055 - mean_squared_error: 935.9055 - val_loss: 935.1169 - val_mean_squared_error: 935.1169
# Epoch 46/100
# 2/2 [==============================] - 2s 866ms/step - loss: 922.5504 - mean_squared_error: 922.5504 - val_loss: 905.9171 - val_mean_squared_error: 905.9171
# Epoch 47/100
# 2/2 [==============================] - 2s 877ms/step - loss: 904.6302 - mean_squared_error: 904.6302 - val_loss: 878.3970 - val_mean_squared_error: 878.3970
# Epoch 48/100
# 2/2 [==============================] - 2s 822ms/step - loss: 887.4968 - mean_squared_error: 887.4968 - val_loss: 852.3875 - val_mean_squared_error: 852.3875
# Epoch 49/100
# 2/2 [==============================] - 2s 840ms/step - loss: 872.9503 - mean_squared_error: 872.9503 - val_loss: 827.4435 - val_mean_squared_error: 827.4435
# Epoch 50/100
# 2/2 [==============================] - 2s 1s/step - loss: 857.0952 - mean_squared_error: 857.0952 - val_loss: 803.8535 - val_mean_squared_error: 803.8535
# Epoch 51/100
# 2/2 [==============================] - 2s 844ms/step - loss: 845.5999 - mean_squared_error: 845.5999 - val_loss: 781.8203 - val_mean_squared_error: 781.8203
# Epoch 52/100
# 2/2 [==============================] - 2s 851ms/step - loss: 835.5384 - mean_squared_error: 835.5384 - val_loss: 760.3798 - val_mean_squared_error: 760.3798
# Epoch 53/100
# 2/2 [==============================] - 1s 812ms/step - loss: 820.3781 - mean_squared_error: 820.3781 - val_loss: 740.0616 - val_mean_squared_error: 740.0616
# Epoch 54/100
# 2/2 [==============================] - 2s 825ms/step - loss: 813.1025 - mean_squared_error: 813.1025 - val_loss: 720.7193 - val_mean_squared_error: 720.7193
# Epoch 55/100
# 2/2 [==============================] - 2s 843ms/step - loss: 800.0070 - mean_squared_error: 800.0070 - val_loss: 702.8515 - val_mean_squared_error: 702.8515
# Epoch 56/100
# 2/2 [==============================] - 2s 2s/step - loss: 792.6053 - mean_squared_error: 792.6053 - val_loss: 685.7691 - val_mean_squared_error: 685.7691
# Epoch 57/100
# 2/2 [==============================] - 2s 854ms/step - loss: 784.1906 - mean_squared_error: 784.1906 - val_loss: 669.8241 - val_mean_squared_error: 669.8241
# Epoch 58/100
# 2/2 [==============================] - 2s 815ms/step - loss: 775.2539 - mean_squared_error: 775.2539 - val_loss: 655.1146 - val_mean_squared_error: 655.1146
# Epoch 59/100
# 2/2 [==============================] - 2s 851ms/step - loss: 767.6862 - mean_squared_error: 767.6862 - val_loss: 641.0113 - val_mean_squared_error: 641.0113
# Epoch 60/100
# 2/2 [==============================] - 2s 847ms/step - loss: 761.3202 - mean_squared_error: 761.3202 - val_loss: 627.2388 - val_mean_squared_error: 627.2388
# Epoch 61/100
# 2/2 [==============================] - 2s 837ms/step - loss: 751.9305 - mean_squared_error: 751.9305 - val_loss: 614.5914 - val_mean_squared_error: 614.5914
# Epoch 62/100
# 2/2 [==============================] - 2s 1s/step - loss: 746.4034 - mean_squared_error: 746.4034 - val_loss: 602.2195 - val_mean_squared_error: 602.2195
# Epoch 63/100
# 2/2 [==============================] - 2s 851ms/step - loss: 740.9360 - mean_squared_error: 740.9360 - val_loss: 590.4179 - val_mean_squared_error: 590.4179
# Epoch 64/100
# 2/2 [==============================] - 2s 829ms/step - loss: 737.4579 - mean_squared_error: 737.4579 - val_loss: 579.5762 - val_mean_squared_error: 579.5762
# Epoch 65/100
# 2/2 [==============================] - 2s 818ms/step - loss: 728.5778 - mean_squared_error: 728.5778 - val_loss: 570.0579 - val_mean_squared_error: 570.0579
# Epoch 66/100
# 2/2 [==============================] - 2s 875ms/step - loss: 725.4177 - mean_squared_error: 725.4177 - val_loss: 560.3873 - val_mean_squared_error: 560.3873
# Epoch 67/100
# 2/2 [==============================] - 2s 813ms/step - loss: 719.1055 - mean_squared_error: 719.1055 - val_loss: 551.1229 - val_mean_squared_error: 551.1229
# Epoch 68/100
# 2/2 [==============================] - 2s 810ms/step - loss: 714.9697 - mean_squared_error: 714.9697 - val_loss: 542.4038 - val_mean_squared_error: 542.4038
# Epoch 69/100
# 2/2 [==============================] - 2s 1s/step - loss: 713.6295 - mean_squared_error: 713.6295 - val_loss: 534.0510 - val_mean_squared_error: 534.0510
# Epoch 70/100
# 2/2 [==============================] - 2s 848ms/step - loss: 707.2614 - mean_squared_error: 707.2614 - val_loss: 526.7103 - val_mean_squared_error: 526.7103
# Epoch 71/100
# 2/2 [==============================] - 2s 789ms/step - loss: 704.2525 - mean_squared_error: 704.2525 - val_loss: 519.1159 - val_mean_squared_error: 519.1159
# Epoch 72/100
# 2/2 [==============================] - 2s 818ms/step - loss: 700.2189 - mean_squared_error: 700.2189 - val_loss: 512.8501 - val_mean_squared_error: 512.8501
# Epoch 73/100
# 2/2 [==============================] - 2s 787ms/step - loss: 696.0020 - mean_squared_error: 696.0020 - val_loss: 506.0870 - val_mean_squared_error: 506.0870
# Epoch 74/100
# 2/2 [==============================] - 2s 854ms/step - loss: 692.8434 - mean_squared_error: 692.8434 - val_loss: 499.7799 - val_mean_squared_error: 499.7799
# Epoch 75/100
# 2/2 [==============================] - 2s 848ms/step - loss: 691.9387 - mean_squared_error: 691.9387 - val_loss: 493.8506 - val_mean_squared_error: 493.8506
# Epoch 76/100
# 2/2 [==============================] - 2s 869ms/step - loss: 687.2962 - mean_squared_error: 687.2962 - val_loss: 488.6296 - val_mean_squared_error: 488.6296
# Epoch 77/100
# 2/2 [==============================] - 2s 852ms/step - loss: 683.8852 - mean_squared_error: 683.8852 - val_loss: 483.5876 - val_mean_squared_error: 483.5876
# Epoch 78/100
# 2/2 [==============================] - 2s 821ms/step - loss: 681.6061 - mean_squared_error: 681.6061 - val_loss: 478.7729 - val_mean_squared_error: 478.7729
# Epoch 79/100
# 2/2 [==============================] - 2s 830ms/step - loss: 680.3406 - mean_squared_error: 680.3406 - val_loss: 473.7866 - val_mean_squared_error: 473.7866
# Epoch 80/100
# 2/2 [==============================] - 2s 2s/step - loss: 676.0138 - mean_squared_error: 676.0138 - val_loss: 469.4460 - val_mean_squared_error: 469.4460
# Epoch 81/100
# 2/2 [==============================] - 2s 985ms/step - loss: 673.9634 - mean_squared_error: 673.9634 - val_loss: 464.9299 - val_mean_squared_error: 464.9299
# Epoch 82/100
# 2/2 [==============================] - 1s 798ms/step - loss: 673.3316 - mean_squared_error: 673.3316 - val_loss: 461.0168 - val_mean_squared_error: 461.0168
# Epoch 83/100
# 2/2 [==============================] - 2s 851ms/step - loss: 669.8910 - mean_squared_error: 669.8910 - val_loss: 457.3185 - val_mean_squared_error: 457.3185
# Epoch 84/100
# 2/2 [==============================] - 2s 809ms/step - loss: 668.8354 - mean_squared_error: 668.8354 - val_loss: 453.7323 - val_mean_squared_error: 453.7323
# Epoch 85/100
# 2/2 [==============================] - 4s 3s/step - loss: 665.2266 - mean_squared_error: 665.2266 - val_loss: 450.2074 - val_mean_squared_error: 450.2074
# Epoch 86/100
# 2/2 [==============================] - 2s 859ms/step - loss: 664.6918 - mean_squared_error: 664.6918 - val_loss: 446.9975 - val_mean_squared_error: 446.9975
# Epoch 87/100
# 2/2 [==============================] - 2s 814ms/step - loss: 661.5699 - mean_squared_error: 661.5699 - val_loss: 444.1006 - val_mean_squared_error: 444.1006
# Epoch 88/100
# 2/2 [==============================] - 2s 830ms/step - loss: 660.0858 - mean_squared_error: 660.0858 - val_loss: 441.3853 - val_mean_squared_error: 441.3853
# Epoch 89/100
# 2/2 [==============================] - 2s 844ms/step - loss: 657.7241 - mean_squared_error: 657.7241 - val_loss: 438.8052 - val_mean_squared_error: 438.8052
# Epoch 90/100
# 2/2 [==============================] - 2s 1s/step - loss: 656.1161 - mean_squared_error: 656.1161 - val_loss: 436.2545 - val_mean_squared_error: 436.2545
# Epoch 91/100
# 2/2 [==============================] - 2s 795ms/step - loss: 654.9343 - mean_squared_error: 654.9343 - val_loss: 433.4276 - val_mean_squared_error: 433.4276
# Epoch 92/100
# 2/2 [==============================] - 2s 844ms/step - loss: 653.5717 - mean_squared_error: 653.5717 - val_loss: 430.5421 - val_mean_squared_error: 430.5421
# Epoch 93/100
# 2/2 [==============================] - 2s 852ms/step - loss: 650.5169 - mean_squared_error: 650.5169 - val_loss: 428.2104 - val_mean_squared_error: 428.2104
# Epoch 94/100
# 2/2 [==============================] - 2s 852ms/step - loss: 648.9559 - mean_squared_error: 648.9559 - val_loss: 426.0151 - val_mean_squared_error: 426.0151
# Epoch 95/100
# 2/2 [==============================] - 2s 869ms/step - loss: 648.3532 - mean_squared_error: 648.3532 - val_loss: 423.4920 - val_mean_squared_error: 423.4920
# Epoch 96/100
# 2/2 [==============================] - 3s 2s/step - loss: 645.8318 - mean_squared_error: 645.8318 - val_loss: 421.3520 - val_mean_squared_error: 421.3520
# Epoch 97/100
# 2/2 [==============================] - 2s 868ms/step - loss: 644.5340 - mean_squared_error: 644.5340 - val_loss: 419.7737 - val_mean_squared_error: 419.7737
# Epoch 98/100
# 2/2 [==============================] - 2s 807ms/step - loss: 643.3278 - mean_squared_error: 643.3278 - val_loss: 418.2885 - val_mean_squared_error: 418.2885
# Epoch 99/100
# 2/2 [==============================] - 2s 877ms/step - loss: 641.7391 - mean_squared_error: 641.7391 - val_loss: 416.4698 - val_mean_squared_error: 416.4698
# Epoch 100/100
# 2/2 [==============================] - 2s 1s/step - loss: 640.2655 - mean_squared_error: 640.2655 - val_loss: 414.8687 - val_mean_squared_error: 414.8687
# 1/1 [==============================] - 0s 297ms/step - loss: 6460.5474 - mean_squared_error: 6460.5474
# Test error: 6460.55

# %%
model.save(model_save_path)

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 5s 5s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  13.142485764821371
# MSE:  294.91573767820626
# RMSE:  17.173110891105498
# r2_score:  -1.795091321982957
# MSLE:  4.969611132640418
# MAPE:  5.10472389436375e+16
# ===== flank_wear results =====
# MAE:  98.0321528116862
# MSE:  19022.89311636612
# RMSE:  137.92350458267117
# r2_score:  -0.18727194197869523
# MSLE:  0.6807222828900427
# MAPE:  0.6746426637044234
# ===== overhang results =====
# MAE:  5.875668601989747
# MSE:  63.831043794916326
# RMSE:  7.989433258680889
# r2_score:  -2.164265672100073
# MSLE:  0.3276891033208472
# MAPE:  0.7113910711016097
# ===== multi results =====
# MAE:  39.016769059499104
# MSE:  6460.54663261308
# RMSE:  54.36201624415252
# r2_score:  -1.3822096453539083
# MSLE:  1.992674172950436
# MAPE:  1.7015746314545834e+16
