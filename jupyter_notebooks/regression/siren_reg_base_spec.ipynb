# %%
# !pip install tensorflow_addons
# !pip install keras-tuner --upgrade

# clone siren repository, refresh folder to see the siren repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Siren/
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.10/dist-packages (1.4.6)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# fatal: destination path 'Siren' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
# architecture
image_size = 256
filters = 256
depth = 4
columns = 4
kernel_size = 5
patch_size = 16
num_classes = 3

in_channel = 9
img_rows, img_cols = image_size, image_size
input_shape = (img_rows, img_cols, in_channel)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "spec"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

# dataset
csv_path = "/content/Siren/dataset/labels_reg_sample.csv"
spec_path = f"/content/Siren/dataset/{modality}"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chips/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                        spec_x  \
# 14   /content/Siren/dataset/spec/x/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/x/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/x/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/x/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/x/T1R7B4.jpg
#
#                                        spec_y  \
# 14   /content/Siren/dataset/spec/y/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/y/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/y/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/y/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/y/T1R7B4.jpg
#
#                                        spec_z
# 14   /content/Siren/dataset/spec/z/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/z/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/z/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/z/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/z/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                        spec_x  \
# 16   /content/Siren/dataset/spec/x/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/x/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/x/T5R12B1.jpg
#
#                                        spec_y  \
# 16   /content/Siren/dataset/spec/y/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/y/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/y/T5R12B1.jpg
#
#                                        spec_z
# 16   /content/Siren/dataset/spec/z/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/z/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/z/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                        spec_x  \
# 5   /content/Siren/dataset/spec/x/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/x/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/x/T7R8B3.jpg
#
#                                        spec_y  \
# 5   /content/Siren/dataset/spec/y/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/y/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/y/T7R8B3.jpg
#
#                                        spec_z
# 5   /content/Siren/dataset/spec/z/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/z/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/z/T7R8B3.jpg

# %%
def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []
    for i in range(file_paths_x.size):
        img = []
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_x)

        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_y)

        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_z)
        img = np.concatenate(img, axis=2)
        images.append(img)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / 255.0

    return images

# %%
x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel,
)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
# Split the last dimension into 3 separate spectrograms
spectrogram1 = x_train_spec[0, :, :, 0:3]  # First spectrogram (channels 0-2)
spectrogram2 = x_train_spec[0, :, :, 3:6]  # Second spectrogram (channels 3-5)
spectrogram3 = x_train_spec[0, :, :, 6:9]  # Third spectrogram (channels 6-8)
# Convert arrays to images
pil_img1 = tf.keras.utils.array_to_img(spectrogram1)
pil_img2 = tf.keras.utils.array_to_img(spectrogram2)
pil_img3 = tf.keras.utils.array_to_img(spectrogram3)
# Display the images
fig, ax = plt.subplots(1,3, figsize=(10,30))
ax[0].imshow(pil_img1)
ax[1].imshow(pil_img2)
ax[2].imshow(pil_img3)
plt.plot()
# Out:
# []

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_spec, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_spec, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_spec, labels_val))

# %%
# ============================== augment ==============================
auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation",
)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
#Functions
#Reversed Column implementation of Truchan (2023). Minape: Multimodal Isotropic Neural Architecture with Patch Embedding.
#https://github.com/hubtru/minape
def activation_module(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def base_module(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_module(x)


def depth_point_module(
    x, pe_block, column, level, depth, r_arr, filters: int, kernel_size: int
):
    if column == 0:
        # Depthwise convolution.
        x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        r_arr = reverasable_output_array(x, r_arr, column, level)
        return x, r_arr
    else:
        if level == 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], pe_block)
        elif level < len(r_arr[0]) - 1 and level != 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], x)
        else:
            x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x0)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        if column != 0:
            x = fusion_block_double(r_arr[column - 1][level], x)

        r_arr = reverasable_output_array(x, r_arr, column, level)

        return x, r_arr


def fusion_block_double(x, y):
    return layers.Add()([x, y])


def reverasable_output_array(x, r_arr, column, level):
    r_arr[column][level] = x
    return r_arr


def load_siren(
    image_size=image_size,
    filters=filters,
    depth=depth,
    columns=columns,
    kernel_size=kernel_size,
    patch_size=patch_size,
    num_classes=num_classes,
):
    r_arr = [[None for _ in range(depth)] for _ in range(columns)]

    inputs = k.Input(input_shape)
    # x = layers.Rescaling(scale=1.0 / 255)(inputs)         # already rescaled

    # Extract patch embeddings.
    x = base_module(inputs, filters, patch_size)
    pe_block = x

    # Siren blocks.
    for column in range(columns):
        for level in range(depth):
            x, r_arr = depth_point_module(
                x, pe_block, column, level, depth, r_arr, filters, kernel_size
            )

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="linear")(x)

    return k.Model(inputs, outputs)

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 9)]        0         []
#
#  conv2d (Conv2D)             (None, 16, 16, 256)          590080    ['input_1[0][0]']
#
#  activation (Activation)     (None, 16, 16, 256)          0         ['conv2d[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 256)          1024      ['activation[0][0]']
#  Normalization)
#
#  depthwise_conv2d (Depthwis  (None, 16, 16, 256)          6656      ['batch_normalization[0][0]']
#  eConv2D)
#
#  activation_1 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 16, 256)          1024      ['activation_1[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 16, 16, 256)          0         ['batch_normalization_1[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)          65792     ['add[0][0]']
#
#  activation_2 (Activation)   (None, 16, 16, 256)          0         ['conv2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 16, 256)          1024      ['activation_2[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_1 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_2[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_3 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 16, 256)          1024      ['activation_3[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_2[0][0]
#                                                                     ']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)          65792     ['add_1[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 256)          0         ['conv2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 16, 16, 256)          1024      ['activation_4[0][0]']
#  chNormalization)
#
#  add_4 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  depthwise_conv2d_4 (Depthw  (None, 16, 16, 256)          6656      ['add_4[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_2 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_4[0][0]']
#
#  activation_5 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 256)          1024      ['activation_9[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 16, 16, 256)          1024      ['activation_5[0][0]']
#  chNormalization)
#
#  add_5 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     , 'add_4[0][0]']
#
#  add_2 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)          65792     ['add_5[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)          65792     ['add_2[0][0]']
#
#  activation_10 (Activation)  (None, 16, 16, 256)          0         ['conv2d_5[0][0]']
#
#  activation_6 (Activation)   (None, 16, 16, 256)          0         ['conv2d_3[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 256)          1024      ['activation_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_6 (Bat  (None, 16, 16, 256)          1024      ['activation_6[0][0]']
#  chNormalization)
#
#  add_6 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_2[0][0]'
#                                                                     , 'batch_normalization_10[0][0
#                                                                     ]']
#
#  add_7 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'add_6[0][0]']
#
#  depthwise_conv2d_5 (Depthw  (None, 16, 16, 256)          6656      ['add_7[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_3 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_6[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_11 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_5[0][0]']
#
#  activation_7 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_3[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 256)          1024      ['activation_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_7 (Bat  (None, 16, 16, 256)          1024      ['activation_7[0][0]']
#  chNormalization)
#
#  add_8 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  add_3 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)          65792     ['add_8[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          65792     ['add_3[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 256)          0         ['conv2d_6[0][0]']
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['conv2d_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 256)          1024      ['activation_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_8 (Bat  (None, 16, 16, 256)          1024      ['activation_8[0][0]']
#  chNormalization)
#
#  add_9 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization_12[0][0
#                                                                     ]']
#
#  add_10 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'add_9[0][0]']
#
#  add_15 (Add)                (None, 16, 16, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_6 (Depthw  (None, 16, 16, 256)          6656      ['add_10[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_8 (Depthw  (None, 16, 16, 256)          6656      ['add_15[0][0]']
#  iseConv2D)
#
#  activation_13 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_6[0][0]']
#
#  activation_17 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_8[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 256)          1024      ['activation_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 16, 16, 256)          1024      ['activation_17[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'add_10[0][0]']
#
#  add_16 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 256)          65792     ['add_11[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          65792     ['add_16[0][0]']
#
#  activation_14 (Activation)  (None, 16, 16, 256)          0         ['conv2d_7[0][0]']
#
#  activation_18 (Activation)  (None, 16, 16, 256)          0         ['conv2d_9[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 256)          1024      ['activation_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 16, 16, 256)          1024      ['activation_18[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_14[0][0
#                                                                     ]']
#
#  add_17 (Add)                (None, 16, 16, 256)          0         ['add_6[0][0]',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 16, 16, 256)          0         ['add_12[0][0]',
#                                                                      'add_17[0][0]']
#
#  depthwise_conv2d_7 (Depthw  (None, 16, 16, 256)          6656      ['add_12[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_9 (Depthw  (None, 16, 16, 256)          6656      ['add_18[0][0]']
#  iseConv2D)
#
#  activation_15 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_7[0][0]']
#
#  activation_19 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_9[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 256)          1024      ['activation_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 16, 16, 256)          1024      ['activation_19[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'add_12[0][0]']
#
#  add_19 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'add_18[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          65792     ['add_13[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)          65792     ['add_19[0][0]']
#
#  activation_16 (Activation)  (None, 16, 16, 256)          0         ['conv2d_8[0][0]']
#
#  activation_20 (Activation)  (None, 16, 16, 256)          0         ['conv2d_10[0][0]']
#
#  batch_normalization_16 (Ba  (None, 16, 16, 256)          1024      ['activation_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 16, 16, 256)          1024      ['activation_20[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_16[0][0
#                                                                     ]']
#
#  add_20 (Add)                (None, 16, 16, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization_20[0][0]
#                                                                     ']
#
#  add_21 (Add)                (None, 16, 16, 256)          0         ['add_14[0][0]',
#                                                                      'add_20[0][0]']
#
#  add_26 (Add)                (None, 16, 16, 256)          0         ['add_20[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_10 (Depth  (None, 16, 16, 256)          6656      ['add_21[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_12 (Depth  (None, 16, 16, 256)          6656      ['add_26[0][0]']
#  wiseConv2D)
#
#  activation_21 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_10[0][0]']
#
#  activation_25 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_12[0][0]']
#
#  batch_normalization_21 (Ba  (None, 16, 16, 256)          1024      ['activation_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 16, 16, 256)          1024      ['activation_25[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'add_21[0][0]']
#
#  add_27 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ',
#                                                                      'add_26[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)          65792     ['add_22[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 256)          65792     ['add_27[0][0]']
#
#  activation_22 (Activation)  (None, 16, 16, 256)          0         ['conv2d_11[0][0]']
#
#  activation_26 (Activation)  (None, 16, 16, 256)          0         ['conv2d_13[0][0]']
#
#  batch_normalization_22 (Ba  (None, 16, 16, 256)          1024      ['activation_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 16, 16, 256)          1024      ['activation_26[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 16, 16, 256)          0         ['add_12[0][0]',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  add_28 (Add)                (None, 16, 16, 256)          0         ['add_17[0][0]',
#                                                                      'batch_normalization_26[0][0]
#                                                                     ']
#
#  add_29 (Add)                (None, 16, 16, 256)          0         ['add_23[0][0]',
#                                                                      'add_28[0][0]']
#
#  depthwise_conv2d_11 (Depth  (None, 16, 16, 256)          6656      ['add_23[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_13 (Depth  (None, 16, 16, 256)          6656      ['add_29[0][0]']
#  wiseConv2D)
#
#  activation_23 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_11[0][0]']
#
#  activation_27 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_13[0][0]']
#
#  batch_normalization_23 (Ba  (None, 16, 16, 256)          1024      ['activation_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 16, 16, 256)          1024      ['activation_27[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'add_23[0][0]']
#
#  add_30 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'add_29[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 256)          65792     ['add_24[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)          65792     ['add_30[0][0]']
#
#  activation_24 (Activation)  (None, 16, 16, 256)          0         ['conv2d_12[0][0]']
#
#  activation_28 (Activation)  (None, 16, 16, 256)          0         ['conv2d_14[0][0]']
#
#  batch_normalization_24 (Ba  (None, 16, 16, 256)          1024      ['activation_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 16, 16, 256)          1024      ['activation_28[0][0]']
#  tchNormalization)
#
#  add_25 (Add)                (None, 16, 16, 256)          0         ['add_14[0][0]',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ']
#
#  add_31 (Add)                (None, 16, 16, 256)          0         ['add_20[0][0]',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  add_32 (Add)                (None, 16, 16, 256)          0         ['add_25[0][0]',
#                                                                      'add_31[0][0]']
#
#  depthwise_conv2d_14 (Depth  (None, 16, 16, 256)          6656      ['add_32[0][0]']
#  wiseConv2D)
#
#  activation_29 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_14[0][0]']
#
#  batch_normalization_29 (Ba  (None, 16, 16, 256)          1024      ['activation_29[0][0]']
#  tchNormalization)
#
#  add_33 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'add_32[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 256)          65792     ['add_33[0][0]']
#
#  activation_30 (Activation)  (None, 16, 16, 256)          0         ['conv2d_15[0][0]']
#
#  batch_normalization_30 (Ba  (None, 16, 16, 256)          1024      ['activation_30[0][0]']
#  tchNormalization)
#
#  add_34 (Add)                (None, 16, 16, 256)          0         ['add_23[0][0]',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  depthwise_conv2d_15 (Depth  (None, 16, 16, 256)          6656      ['add_34[0][0]']
#  wiseConv2D)
#
#  activation_31 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_15[0][0]']
#
#  batch_normalization_31 (Ba  (None, 16, 16, 256)          1024      ['activation_31[0][0]']
#  tchNormalization)
#
#  add_35 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ',
#                                                                      'add_34[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 256)          65792     ['add_35[0][0]']
#
#  activation_32 (Activation)  (None, 16, 16, 256)          0         ['conv2d_16[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 16, 256)          1024      ['activation_32[0][0]']
#  tchNormalization)
#
#  add_36 (Add)                (None, 16, 16, 256)          0         ['add_25[0][0]',
#                                                                      'batch_normalization_32[0][0]
#                                                                     ']
#
#  global_average_pooling2d (  (None, 256)                  0         ['add_36[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                    771       ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 1783811 (6.80 MB)
# Trainable params: 1766915 (6.74 MB)
# Non-trainable params: 16896 (66.00 KB)
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 26s 3s/step - loss: 3880.3591 - mean_squared_error: 3880.3591 - val_loss: 4875.9541 - val_mean_squared_error: 4875.9541
# Epoch 2/100
# 2/2 [==============================] - 1s 668ms/step - loss: 3908.3679 - mean_squared_error: 3908.3679 - val_loss: 4559.4316 - val_mean_squared_error: 4559.4316
# Epoch 3/100
# 2/2 [==============================] - 2s 704ms/step - loss: 3822.4270 - mean_squared_error: 3822.4270 - val_loss: 4188.1167 - val_mean_squared_error: 4188.1167
# Epoch 4/100
# 2/2 [==============================] - 2s 722ms/step - loss: 3621.4419 - mean_squared_error: 3621.4419 - val_loss: 4138.5928 - val_mean_squared_error: 4138.5928
# Epoch 5/100
# 2/2 [==============================] - 2s 728ms/step - loss: 3490.9368 - mean_squared_error: 3490.9363 - val_loss: 4082.9075 - val_mean_squared_error: 4082.9075
# Epoch 6/100
# 2/2 [==============================] - 2s 926ms/step - loss: 3472.8074 - mean_squared_error: 3472.8074 - val_loss: 3629.4656 - val_mean_squared_error: 3629.4656
# Epoch 7/100
# 2/2 [==============================] - 2s 922ms/step - loss: 3456.2708 - mean_squared_error: 3456.2708 - val_loss: 3107.9558 - val_mean_squared_error: 3107.9558
# Epoch 8/100
# 2/2 [==============================] - 1s 680ms/step - loss: 3318.4783 - mean_squared_error: 3318.4783 - val_loss: 3142.3330 - val_mean_squared_error: 3142.3330
# Epoch 9/100
# 2/2 [==============================] - 2s 707ms/step - loss: 3536.9817 - mean_squared_error: 3536.9817 - val_loss: 3252.8210 - val_mean_squared_error: 3252.8210
# Epoch 10/100
# 2/2 [==============================] - 2s 716ms/step - loss: 3435.4734 - mean_squared_error: 3435.4734 - val_loss: 3439.6443 - val_mean_squared_error: 3439.6443
# Epoch 11/100
# 2/2 [==============================] - 1s 646ms/step - loss: 3343.6958 - mean_squared_error: 3343.6958 - val_loss: 3474.1091 - val_mean_squared_error: 3474.1091
# Epoch 12/100
# 2/2 [==============================] - 2s 681ms/step - loss: 3266.2219 - mean_squared_error: 3266.2219 - val_loss: 3532.7737 - val_mean_squared_error: 3532.7737
# Epoch 13/100
# 2/2 [==============================] - 2s 901ms/step - loss: 3253.5659 - mean_squared_error: 3253.5659 - val_loss: 3642.1367 - val_mean_squared_error: 3642.1367
# Epoch 14/100
# 2/2 [==============================] - 1s 707ms/step - loss: 3379.8789 - mean_squared_error: 3379.8789 - val_loss: 3806.8826 - val_mean_squared_error: 3806.8826
# Epoch 15/100
# 2/2 [==============================] - 1s 716ms/step - loss: 3197.4700 - mean_squared_error: 3197.4700 - val_loss: 3808.1963 - val_mean_squared_error: 3808.1963
# Epoch 16/100
# 2/2 [==============================] - 1s 650ms/step - loss: 3273.2595 - mean_squared_error: 3273.2595 - val_loss: 4028.0164 - val_mean_squared_error: 4028.0164
# Epoch 17/100
# 2/2 [==============================] - 2s 709ms/step - loss: 3132.1160 - mean_squared_error: 3132.1160 - val_loss: 4540.4673 - val_mean_squared_error: 4540.4673
# Epoch 18/100
# 2/2 [==============================] - 1s 670ms/step - loss: 3245.8113 - mean_squared_error: 3245.8113 - val_loss: 4642.9502 - val_mean_squared_error: 4642.9502
# Epoch 19/100
# 2/2 [==============================] - 2s 1s/step - loss: 3225.5583 - mean_squared_error: 3225.5583 - val_loss: 4481.3286 - val_mean_squared_error: 4481.3286
# Epoch 20/100
# 2/2 [==============================] - 1s 657ms/step - loss: 3211.5234 - mean_squared_error: 3211.5234 - val_loss: 4395.4331 - val_mean_squared_error: 4395.4331
# Epoch 21/100
# 2/2 [==============================] - 2s 708ms/step - loss: 3437.9565 - mean_squared_error: 3437.9565 - val_loss: 4700.0850 - val_mean_squared_error: 4700.0850
# Epoch 22/100
# 2/2 [==============================] - 1s 670ms/step - loss: 3126.9514 - mean_squared_error: 3126.9514 - val_loss: 5114.5356 - val_mean_squared_error: 5114.5356
# Epoch 23/100
# 2/2 [==============================] - 2s 713ms/step - loss: 2958.3745 - mean_squared_error: 2958.3745 - val_loss: 5255.9111 - val_mean_squared_error: 5255.9111
# Epoch 24/100
# 2/2 [==============================] - 2s 734ms/step - loss: 3101.5320 - mean_squared_error: 3101.5320 - val_loss: 5262.1978 - val_mean_squared_error: 5262.1978
# Epoch 25/100
# 2/2 [==============================] - 2s 664ms/step - loss: 3144.5261 - mean_squared_error: 3144.5261 - val_loss: 5616.7524 - val_mean_squared_error: 5616.7524
# Epoch 26/100
# 2/2 [==============================] - 1s 721ms/step - loss: 2918.9497 - mean_squared_error: 2918.9497 - val_loss: 5999.9688 - val_mean_squared_error: 5999.9688
# Epoch 27/100
# 2/2 [==============================] - 1s 655ms/step - loss: 3028.0149 - mean_squared_error: 3028.0149 - val_loss: 5855.6675 - val_mean_squared_error: 5855.6675
# Epoch 28/100
# 2/2 [==============================] - 2s 730ms/step - loss: 2943.0503 - mean_squared_error: 2943.0503 - val_loss: 5666.4067 - val_mean_squared_error: 5666.4067
# Epoch 29/100
# 2/2 [==============================] - 1s 651ms/step - loss: 2819.8113 - mean_squared_error: 2819.8113 - val_loss: 5546.2700 - val_mean_squared_error: 5546.2700
# Epoch 30/100
# 2/2 [==============================] - 2s 1s/step - loss: 3095.4314 - mean_squared_error: 3095.4314 - val_loss: 5945.0854 - val_mean_squared_error: 5945.0854
# Epoch 31/100
# 2/2 [==============================] - 2s 655ms/step - loss: 2833.9280 - mean_squared_error: 2833.9280 - val_loss: 6434.3594 - val_mean_squared_error: 6434.3594
# Epoch 32/100
# 2/2 [==============================] - 2s 711ms/step - loss: 2863.2327 - mean_squared_error: 2863.2327 - val_loss: 6287.4712 - val_mean_squared_error: 6287.4712
# Epoch 33/100
# 2/2 [==============================] - 1s 729ms/step - loss: 2920.8376 - mean_squared_error: 2920.8376 - val_loss: 5758.3633 - val_mean_squared_error: 5758.3633
# Epoch 34/100
# 2/2 [==============================] - 1s 645ms/step - loss: 2702.0142 - mean_squared_error: 2702.0142 - val_loss: 5635.5171 - val_mean_squared_error: 5635.5171
# Epoch 35/100
# 2/2 [==============================] - 1s 656ms/step - loss: 2660.8181 - mean_squared_error: 2660.8181 - val_loss: 5803.8384 - val_mean_squared_error: 5803.8384
# Epoch 36/100
# 2/2 [==============================] - 2s 963ms/step - loss: 2559.0403 - mean_squared_error: 2559.0403 - val_loss: 6037.3765 - val_mean_squared_error: 6037.3765
# Epoch 37/100
# 2/2 [==============================] - 1s 652ms/step - loss: 2754.1133 - mean_squared_error: 2754.1133 - val_loss: 6421.2812 - val_mean_squared_error: 6421.2812
# Epoch 38/100
# 2/2 [==============================] - 2s 729ms/step - loss: 2688.5920 - mean_squared_error: 2688.5920 - val_loss: 6563.5474 - val_mean_squared_error: 6563.5474
# Epoch 39/100
# 2/2 [==============================] - 1s 661ms/step - loss: 2784.3677 - mean_squared_error: 2784.3677 - val_loss: 6001.1177 - val_mean_squared_error: 6001.1177
# Epoch 40/100
# 2/2 [==============================] - 1s 729ms/step - loss: 2685.4604 - mean_squared_error: 2685.4604 - val_loss: 5618.3906 - val_mean_squared_error: 5618.3906
# Epoch 41/100
# 2/2 [==============================] - 2s 927ms/step - loss: 2682.4285 - mean_squared_error: 2682.4285 - val_loss: 5886.0317 - val_mean_squared_error: 5886.0317
# Epoch 42/100
# 2/2 [==============================] - 1s 664ms/step - loss: 2350.6836 - mean_squared_error: 2350.6836 - val_loss: 6315.9790 - val_mean_squared_error: 6315.9790
# Epoch 43/100
# 2/2 [==============================] - 1s 665ms/step - loss: 2552.6052 - mean_squared_error: 2552.6052 - val_loss: 6674.0547 - val_mean_squared_error: 6674.0547
# Epoch 44/100
# 2/2 [==============================] - 1s 657ms/step - loss: 2333.1721 - mean_squared_error: 2333.1721 - val_loss: 6366.7153 - val_mean_squared_error: 6366.7153
# Epoch 45/100
# 2/2 [==============================] - 2s 1s/step - loss: 2492.5715 - mean_squared_error: 2492.5715 - val_loss: 5306.5464 - val_mean_squared_error: 5306.5464
# Epoch 46/100
# 2/2 [==============================] - 1s 677ms/step - loss: 2601.1365 - mean_squared_error: 2601.1365 - val_loss: 5177.3403 - val_mean_squared_error: 5177.3403
# Epoch 47/100
# 2/2 [==============================] - 2s 1s/step - loss: 2413.9553 - mean_squared_error: 2413.9553 - val_loss: 5741.2603 - val_mean_squared_error: 5741.2603
# Epoch 48/100
# 2/2 [==============================] - 2s 669ms/step - loss: 2586.1580 - mean_squared_error: 2586.1580 - val_loss: 6098.2437 - val_mean_squared_error: 6098.2437
# Epoch 49/100
# 2/2 [==============================] - 2s 720ms/step - loss: 2340.5530 - mean_squared_error: 2340.5530 - val_loss: 6019.0161 - val_mean_squared_error: 6019.0161
# Epoch 50/100
# 2/2 [==============================] - 2s 722ms/step - loss: 2304.3774 - mean_squared_error: 2304.3774 - val_loss: 5953.3384 - val_mean_squared_error: 5953.3384
# Epoch 51/100
# 2/2 [==============================] - 1s 655ms/step - loss: 2242.7437 - mean_squared_error: 2242.7437 - val_loss: 6098.7534 - val_mean_squared_error: 6098.7534
# Epoch 52/100
# 2/2 [==============================] - 2s 727ms/step - loss: 2117.9270 - mean_squared_error: 2117.9272 - val_loss: 6290.5645 - val_mean_squared_error: 6290.5645
# Epoch 53/100
# 2/2 [==============================] - 2s 734ms/step - loss: 2105.0066 - mean_squared_error: 2105.0066 - val_loss: 6222.7944 - val_mean_squared_error: 6222.7944
# Epoch 54/100
# 2/2 [==============================] - 2s 1s/step - loss: 1989.3015 - mean_squared_error: 1989.3015 - val_loss: 6247.2104 - val_mean_squared_error: 6247.2104
# Epoch 55/100
# 2/2 [==============================] - 1s 723ms/step - loss: 2331.0801 - mean_squared_error: 2331.0801 - val_loss: 6233.0991 - val_mean_squared_error: 6233.0991
# Epoch 56/100
# 2/2 [==============================] - 1s 667ms/step - loss: 2035.0924 - mean_squared_error: 2035.0924 - val_loss: 6222.0415 - val_mean_squared_error: 6222.0415
# Epoch 57/100
# 2/2 [==============================] - 2s 718ms/step - loss: 1964.8500 - mean_squared_error: 1964.8500 - val_loss: 6270.8374 - val_mean_squared_error: 6270.8374
# Epoch 58/100
# 2/2 [==============================] - 1s 707ms/step - loss: 1858.0452 - mean_squared_error: 1858.0452 - val_loss: 5928.4414 - val_mean_squared_error: 5928.4414
# Epoch 59/100
# 2/2 [==============================] - 2s 1s/step - loss: 1948.7904 - mean_squared_error: 1948.7904 - val_loss: 5331.8755 - val_mean_squared_error: 5331.8755
# Epoch 60/100
# 2/2 [==============================] - 2s 712ms/step - loss: 1898.0530 - mean_squared_error: 1898.0530 - val_loss: 5097.2114 - val_mean_squared_error: 5097.2114
# Epoch 61/100
# 2/2 [==============================] - 1s 665ms/step - loss: 1951.6495 - mean_squared_error: 1951.6497 - val_loss: 5328.5308 - val_mean_squared_error: 5328.5308
# Epoch 62/100
# 2/2 [==============================] - 1s 642ms/step - loss: 2071.0071 - mean_squared_error: 2071.0071 - val_loss: 4801.5728 - val_mean_squared_error: 4801.5728
# Epoch 63/100
# 2/2 [==============================] - 1s 666ms/step - loss: 1815.4147 - mean_squared_error: 1815.4147 - val_loss: 4535.0659 - val_mean_squared_error: 4535.0659
# Epoch 64/100
# 2/2 [==============================] - 2s 723ms/step - loss: 1641.0701 - mean_squared_error: 1641.0701 - val_loss: 4662.2231 - val_mean_squared_error: 4662.2231
# Epoch 65/100
# 2/2 [==============================] - 1s 708ms/step - loss: 1558.1404 - mean_squared_error: 1558.1404 - val_loss: 3973.6191 - val_mean_squared_error: 3973.6191
# Epoch 66/100
# 2/2 [==============================] - 2s 1s/step - loss: 1672.6290 - mean_squared_error: 1672.6290 - val_loss: 3198.7747 - val_mean_squared_error: 3198.7747
# Epoch 67/100
# 2/2 [==============================] - 2s 716ms/step - loss: 1577.4314 - mean_squared_error: 1577.4314 - val_loss: 3057.9695 - val_mean_squared_error: 3057.9695
# Epoch 68/100
# 2/2 [==============================] - 1s 665ms/step - loss: 1464.0262 - mean_squared_error: 1464.0262 - val_loss: 3350.6379 - val_mean_squared_error: 3350.6379
# Epoch 69/100
# 2/2 [==============================] - 1s 712ms/step - loss: 1513.4590 - mean_squared_error: 1513.4590 - val_loss: 3163.6257 - val_mean_squared_error: 3163.6257
# Epoch 70/100
# 2/2 [==============================] - 1s 726ms/step - loss: 1496.0785 - mean_squared_error: 1496.0785 - val_loss: 3312.7854 - val_mean_squared_error: 3312.7854
# Epoch 71/100
# 2/2 [==============================] - 1s 696ms/step - loss: 1368.9303 - mean_squared_error: 1368.9303 - val_loss: 3580.0168 - val_mean_squared_error: 3580.0168
# Epoch 72/100
# 2/2 [==============================] - 2s 864ms/step - loss: 1265.7002 - mean_squared_error: 1265.7002 - val_loss: 3808.1633 - val_mean_squared_error: 3808.1633
# Epoch 73/100
# 2/2 [==============================] - 2s 644ms/step - loss: 1203.6229 - mean_squared_error: 1203.6229 - val_loss: 4024.4128 - val_mean_squared_error: 4024.4128
# Epoch 74/100
# 2/2 [==============================] - 1s 661ms/step - loss: 1211.9738 - mean_squared_error: 1211.9738 - val_loss: 3895.5508 - val_mean_squared_error: 3895.5508
# Epoch 75/100
# 2/2 [==============================] - 1s 702ms/step - loss: 1147.9855 - mean_squared_error: 1147.9855 - val_loss: 3648.2722 - val_mean_squared_error: 3648.2722
# Epoch 76/100
# 2/2 [==============================] - 2s 719ms/step - loss: 1094.7274 - mean_squared_error: 1094.7274 - val_loss: 3485.2910 - val_mean_squared_error: 3485.2910
# Epoch 77/100
# 2/2 [==============================] - 1s 709ms/step - loss: 1048.7224 - mean_squared_error: 1048.7224 - val_loss: 3417.6482 - val_mean_squared_error: 3417.6482
# Epoch 78/100
# 2/2 [==============================] - 1s 673ms/step - loss: 1061.5748 - mean_squared_error: 1061.5748 - val_loss: 3380.8115 - val_mean_squared_error: 3380.8115
# Epoch 79/100
# 2/2 [==============================] - 2s 683ms/step - loss: 976.7926 - mean_squared_error: 976.7926 - val_loss: 3230.6868 - val_mean_squared_error: 3230.6868
# Epoch 80/100
# 2/2 [==============================] - 2s 725ms/step - loss: 1114.7720 - mean_squared_error: 1114.7720 - val_loss: 3041.2126 - val_mean_squared_error: 3041.2126
# Epoch 81/100
# 2/2 [==============================] - 2s 727ms/step - loss: 969.4302 - mean_squared_error: 969.4302 - val_loss: 2916.9734 - val_mean_squared_error: 2916.9734
# Epoch 82/100
# 2/2 [==============================] - 2s 737ms/step - loss: 855.7783 - mean_squared_error: 855.7783 - val_loss: 2873.7395 - val_mean_squared_error: 2873.7395
# Epoch 83/100
# 2/2 [==============================] - 1s 676ms/step - loss: 866.9525 - mean_squared_error: 866.9525 - val_loss: 3041.2410 - val_mean_squared_error: 3041.2410
# Epoch 84/100
# 2/2 [==============================] - 2s 672ms/step - loss: 993.6716 - mean_squared_error: 993.6716 - val_loss: 3296.4021 - val_mean_squared_error: 3296.4021
# Epoch 85/100
# 2/2 [==============================] - 1s 727ms/step - loss: 875.3380 - mean_squared_error: 875.3380 - val_loss: 3575.1953 - val_mean_squared_error: 3575.1953
# Epoch 86/100
# 2/2 [==============================] - 1s 652ms/step - loss: 771.4354 - mean_squared_error: 771.4354 - val_loss: 3747.6160 - val_mean_squared_error: 3747.6160
# Epoch 87/100
# 2/2 [==============================] - 1s 719ms/step - loss: 757.6100 - mean_squared_error: 757.6100 - val_loss: 3939.4629 - val_mean_squared_error: 3939.4629
# Epoch 88/100
# 2/2 [==============================] - 1s 647ms/step - loss: 722.4261 - mean_squared_error: 722.4261 - val_loss: 4175.7666 - val_mean_squared_error: 4175.7666
# Epoch 89/100
# 2/2 [==============================] - 2s 1s/step - loss: 724.5212 - mean_squared_error: 724.5212 - val_loss: 4226.5220 - val_mean_squared_error: 4226.5220
# Epoch 90/100
# 2/2 [==============================] - 2s 681ms/step - loss: 1022.5958 - mean_squared_error: 1022.5958 - val_loss: 4071.5256 - val_mean_squared_error: 4071.5256
# Epoch 91/100
# 2/2 [==============================] - 1s 703ms/step - loss: 732.5883 - mean_squared_error: 732.5883 - val_loss: 3731.2861 - val_mean_squared_error: 3731.2861
# Epoch 92/100
# 2/2 [==============================] - 1s 724ms/step - loss: 590.4905 - mean_squared_error: 590.4905 - val_loss: 3569.9426 - val_mean_squared_error: 3569.9426
# Epoch 93/100
# 2/2 [==============================] - 1s 658ms/step - loss: 571.0239 - mean_squared_error: 571.0239 - val_loss: 3575.6348 - val_mean_squared_error: 3575.6348
# Epoch 94/100
# 2/2 [==============================] - 1s 670ms/step - loss: 639.4352 - mean_squared_error: 639.4352 - val_loss: 3631.6970 - val_mean_squared_error: 3631.6970
# Epoch 95/100
# 2/2 [==============================] - 2s 987ms/step - loss: 507.0977 - mean_squared_error: 507.0977 - val_loss: 3724.3665 - val_mean_squared_error: 3724.3665
# Epoch 96/100
# 2/2 [==============================] - 2s 888ms/step - loss: 511.5831 - mean_squared_error: 511.5831 - val_loss: 3660.9675 - val_mean_squared_error: 3660.9675
# Epoch 97/100
# 2/2 [==============================] - 1s 642ms/step - loss: 607.3203 - mean_squared_error: 607.3203 - val_loss: 3457.7571 - val_mean_squared_error: 3457.7571
# Epoch 98/100
# 2/2 [==============================] - 2s 716ms/step - loss: 502.6704 - mean_squared_error: 502.6704 - val_loss: 3388.1602 - val_mean_squared_error: 3388.1602
# Epoch 99/100
# 2/2 [==============================] - 1s 665ms/step - loss: 435.9974 - mean_squared_error: 435.9974 - val_loss: 3419.8347 - val_mean_squared_error: 3419.8347
# Epoch 100/100
# 2/2 [==============================] - 2s 907ms/step - loss: 564.8565 - mean_squared_error: 564.8565 - val_loss: 3420.9299 - val_mean_squared_error: 3420.9299
# 1/1 [==============================] - 0s 98ms/step - loss: 12064.5557 - mean_squared_error: 12064.5557
# Test error: 12064.56

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  26.6913410949707
# MSE:  803.0404192960414
# RMSE:  28.33796780462638
# r2_score:  -6.610890232060309
# MSLE_min_shifted:  0.3490041309634699
# MAPE:  5.994959446754372e+16
# ===== flank_wear results =====
# MAE:  149.16858514785767
# MSE:  35137.350160727285
# RMSE:  187.44959365313994
# r2_score:  -1.1930202575454136
# MSLE_min_shifted:  0.0055041684213141566
# MAPE:  1.0001396589268292
# ===== overhang results =====
# MAE:  15.273324635823565
# MSE:  253.2762692476615
# RMSE:  15.914655800477165
# r2_score:  -11.55554283136725
# MSLE:  0.7404336044759451
# MAPE:  1.4915682599168785
# ===== multi results =====
# MAE:  63.71108362621732
# MSE:  12064.555616423662
# RMSE:  77.23407241941449
# r2_score:  -6.453151106990991
# MSLE_min_shifted:  4.601355923169783
# MAPE:  1.9983198155847908e+16
