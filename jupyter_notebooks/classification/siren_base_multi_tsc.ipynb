# %%
# !pip install tensorflow_addons
# !pip install keras-tuner --upgrade

# clone siren repository, refresh folder to see the siren repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Siren/
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 980.0 kB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5
# Cloning into 'Siren'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 332 (delta 16), reused 29 (delta 12), pack-reused 297
# Receiving objects: 100% (332/332), 186.05 MiB | 34.37 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# Updating files: 100% (236/236), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_spec = 9
in_channel_chip = 3
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_spec = (img_rows, img_cols, in_channel_spec)
input_shape_chip = (img_rows, img_cols, in_channel_chip)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_tsc"
exp_name = f"siren"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"/content/Siren/models/classification/{exp_name}_{sub_exp_name}_tool.h5"
model_spec_path = f"/content/Siren/models/classification/{exp_name}_{sub_exp_name}_spec.h5"
model_chip_path = f"/content/Siren/models/classification/{exp_name}_{sub_exp_name}_chip.h5"

# dataset
csv_path = "/content/Siren/dataset/labels_sample.csv"
tool_path = "/content/Siren/dataset/tool"
spec_path = "/content/Siren/dataset/spec"
chip_path = "/content/Siren/dataset/chip"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["tool_label"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id image_label  tool_label                                     tool  \
# 14   T8R3B4       sharp           1   /content/Siren/dataset/tool/T8R3B4.jpg
# 10   T6R9B3        used           2   /content/Siren/dataset/tool/T6R9B3.jpg
# 0    T1R2B1       sharp           1   /content/Siren/dataset/tool/T1R2B1.jpg
# 3   T2R13B4      dulled           3  /content/Siren/dataset/tool/T2R13B4.jpg
# 1    T1R7B4        used           2   /content/Siren/dataset/tool/T1R7B4.jpg
#
#                                        spec_x  \
# 14   /content/Siren/dataset/spec/x/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/x/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/x/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/x/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/x/T1R7B4.jpg
#
#                                        spec_y  \
# 14   /content/Siren/dataset/spec/y/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/y/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/y/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/y/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/y/T1R7B4.jpg
#
#                                        spec_z  \
# 14   /content/Siren/dataset/spec/z/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/z/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/z/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/z/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/z/T1R7B4.jpg
#
#                                        chip
# 14   /content/Siren/dataset/chip/T8R3B4.jpg
# 10   /content/Siren/dataset/chip/T6R9B3.jpg
# 0    /content/Siren/dataset/chip/T1R2B1.jpg
# 3   /content/Siren/dataset/chip/T2R13B4.jpg
# 1    /content/Siren/dataset/chip/T1R7B4.jpg
# test_head          id image_label  tool_label                                     tool  \
# 16   T9R7B4        used           2   /content/Siren/dataset/tool/T9R7B4.jpg
# 18  T10R3B4       sharp           1  /content/Siren/dataset/tool/T10R3B4.jpg
# 9   T5R12B1      dulled           3  /content/Siren/dataset/tool/T5R12B1.jpg
#
#                                        spec_x  \
# 16   /content/Siren/dataset/spec/x/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/x/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/x/T5R12B1.jpg
#
#                                        spec_y  \
# 16   /content/Siren/dataset/spec/y/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/y/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/y/T5R12B1.jpg
#
#                                        spec_z  \
# 16   /content/Siren/dataset/spec/z/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/z/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/z/T5R12B1.jpg
#
#                                        chip
# 16   /content/Siren/dataset/chip/T9R7B4.jpg
# 18  /content/Siren/dataset/chip/T10R3B4.jpg
# 9   /content/Siren/dataset/chip/T5R12B1.jpg
# val_head          id image_label  tool_label                                     tool  \
# 5   T3R10B1      dulled           3  /content/Siren/dataset/tool/T3R10B1.jpg
# 13  T7R14B3      dulled           3  /content/Siren/dataset/tool/T7R14B3.jpg
# 12   T7R8B3        used           2   /content/Siren/dataset/tool/T7R8B3.jpg
#
#                                        spec_x  \
# 5   /content/Siren/dataset/spec/x/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/x/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/x/T7R8B3.jpg
#
#                                        spec_y  \
# 5   /content/Siren/dataset/spec/y/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/y/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/y/T7R8B3.jpg
#
#                                        spec_z  \
# 5   /content/Siren/dataset/spec/z/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/z/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/z/T7R8B3.jpg
#
#                                        chip
# 5   /content/Siren/dataset/chip/T3R10B1.jpg
# 13  /content/Siren/dataset/chip/T7R14B3.jpg
# 12   /content/Siren/dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images


def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for i in range(file_paths_x.size):
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_x)
        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_y)
        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_z)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(file_paths_x.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df.tool_label.values
labels_test = test_df.tool_label.values
labels_val = val_df.tool_label.values

labels_train
# Out:
# array([1, 2, 1, 3, 2, 2, 3, 2, 1, 1, 3, 1, 2, 3])

# %%
labels_train = labels_train - 1
labels_test = labels_test - 1
labels_val = labels_val - 1

labels_train = tf.keras.utils.to_categorical(
    labels_train, num_classes=num_classes, dtype="float32"
)
labels_test = tf.keras.utils.to_categorical(
    labels_test, num_classes=num_classes, dtype="float32"
)
labels_val = tf.keras.utils.to_categorical(
    labels_val, num_classes=num_classes, dtype="float32"
)

# %%
# ============================== augment 1/3 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)

# %%
# ============================== augment 2/3 ==============================
data_augmentation_spec = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_spec",
)

# %%
# ============================== augment 3/3==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_spec = data_augmentation_spec(x_train_spec)
x_train_chip = data_augmentation_chip(x_train_chip)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_spec": x_train_spec,
            "input_1_chip": x_train_chip,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_spec": x_test_spec,
            "input_1_chip": x_test_chip,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_spec": x_val_spec,
            "input_1_chip": x_val_chip,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs2 = k.Input(input_shape_spec)
inputs3 = k.Input(input_shape_chip)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_spec': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
model_tool = k.models.load_model(model_tool_path, compile=False)
model_spec = k.models.load_model(model_spec_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)

model_tool.trainable = False
model_spec.trainable = False
model_chip.trainable = False


def load_siren(model_tool, model_spec, model_chip):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs2 = model_spec.input
    inputs2._name = "input_spec"
    inputs3 = model_chip.input
    inputs3._name = "input_chip"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_spec = k.Model(
        inputs=model_spec.input, outputs=model_spec.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_spec.output,
            truncated_model_chip.output,
        ]
    )
    output = layers.Dense(num_classes, activation="softmax", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs2, inputs3], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_spec.layers:
    layer._name = layer.name + str("_spec")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, model

# %%
model = load_siren(model_tool, model_spec, model_chip)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1_tool (InputLayer)   [(None, 256, 256, 3)]        0         []
#
#  input_1_spec (InputLayer)   [(None, 256, 256, 9)]        0         []
#
#  input_1_chip (InputLayer)   [(None, 256, 256, 3)]        0         []
#
#  conv2d_tool (Conv2D)        (None, 16, 16, 256)          196864    ['input_1_tool[0][0]']
#
#  conv2d_spec (Conv2D)        (None, 16, 16, 256)          590080    ['input_1_spec[0][0]']
#
#  conv2d_chip (Conv2D)        (None, 16, 16, 256)          196864    ['input_1_chip[0][0]']
#
#  activation_tool (Activatio  (None, 16, 16, 256)          0         ['conv2d_tool[0][0]']
#  n)
#
#  activation_spec (Activatio  (None, 16, 16, 256)          0         ['conv2d_spec[0][0]']
#  n)
#
#  activation_chip (Activatio  (None, 16, 16, 256)          0         ['conv2d_chip[0][0]']
#  n)
#
#  batch_normalization_tool (  (None, 16, 16, 256)          1024      ['activation_tool[0][0]']
#  BatchNormalization)
#
#  batch_normalization_spec (  (None, 16, 16, 256)          1024      ['activation_spec[0][0]']
#  BatchNormalization)
#
#  batch_normalization_chip (  (None, 16, 16, 256)          1024      ['activation_chip[0][0]']
#  BatchNormalization)
#
#  depthwise_conv2d_tool (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_tool[0][
#  thwiseConv2D)                                                      0]']
#
#  depthwise_conv2d_spec (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_spec[0][
#  thwiseConv2D)                                                      0]']
#
#  depthwise_conv2d_chip (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_chip[0][
#  thwiseConv2D)                                                      0]']
#
#  activation_1_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_tool[0][0]'
#  ion)                                                               ]
#
#  activation_1_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_spec[0][0]'
#  ion)                                                               ]
#
#  activation_1_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_chip[0][0]'
#  ion)                                                               ]
#
#  batch_normalization_1_tool  (None, 16, 16, 256)          1024      ['activation_1_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_1_spec  (None, 16, 16, 256)          1024      ['activation_1_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_1_chip  (None, 16, 16, 256)          1024      ['activation_1_chip[0][0]']
#   (BatchNormalization)
#
#  add_tool (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_spec (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  add_chip (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  conv2d_1_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_tool[0][0]']
#
#  conv2d_1_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_spec[0][0]']
#
#  conv2d_1_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_chip[0][0]']
#
#  activation_2_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_1_tool[0][0]']
#  ion)
#
#  activation_2_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_1_spec[0][0]']
#  ion)
#
#  activation_2_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_1_chip[0][0]']
#  ion)
#
#  batch_normalization_2_tool  (None, 16, 16, 256)          1024      ['activation_2_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_2_spec  (None, 16, 16, 256)          1024      ['activation_2_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_2_chip  (None, 16, 16, 256)          1024      ['activation_2_chip[0][0]']
#   (BatchNormalization)
#
#  depthwise_conv2d_1_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  depthwise_conv2d_1_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  depthwise_conv2d_1_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_3_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_tool[0][0
#  ion)                                                               ]']
#
#  activation_3_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_spec[0][0
#  ion)                                                               ]']
#
#  activation_3_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_3_tool  (None, 16, 16, 256)          1024      ['activation_3_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_3_spec  (None, 16, 16, 256)          1024      ['activation_3_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_3_chip  (None, 16, 16, 256)          1024      ['activation_3_chip[0][0]']
#   (BatchNormalization)
#
#  add_1_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_tool[0
#                                                                     ][0]']
#
#  add_1_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_spec[0
#                                                                     ][0]']
#
#  add_1_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_chip[0
#                                                                     ][0]']
#
#  conv2d_2_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_tool[0][0]']
#
#  conv2d_2_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_spec[0][0]']
#
#  conv2d_2_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_chip[0][0]']
#
#  activation_4_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_2_tool[0][0]']
#  ion)
#
#  activation_4_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_2_spec[0][0]']
#  ion)
#
#  activation_4_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_2_chip[0][0]']
#  ion)
#
#  batch_normalization_4_tool  (None, 16, 16, 256)          1024      ['activation_4_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_4_spec  (None, 16, 16, 256)          1024      ['activation_4_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_4_chip  (None, 16, 16, 256)          1024      ['activation_4_chip[0][0]']
#   (BatchNormalization)
#
#  add_4_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_4_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  add_4_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  depthwise_conv2d_4_tool (D  (None, 16, 16, 256)          6656      ['add_4_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_4_spec (D  (None, 16, 16, 256)          6656      ['add_4_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_4_chip (D  (None, 16, 16, 256)          6656      ['add_4_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_2_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_tool[0][0
#  ion)                                                               ]']
#
#  depthwise_conv2d_2_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_spec[0][0
#  ion)                                                               ]']
#
#  depthwise_conv2d_2_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_chip[0][0
#  ion)                                                               ]']
#
#  activation_5_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_tool[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_tool  (None, 16, 16, 256)          1024      ['activation_9_tool[0][0]']
#   (BatchNormalization)
#
#  activation_5_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_spec[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_spec  (None, 16, 16, 256)          1024      ['activation_9_spec[0][0]']
#   (BatchNormalization)
#
#  activation_5_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_chip  (None, 16, 16, 256)          1024      ['activation_9_chip[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_5_tool  (None, 16, 16, 256)          1024      ['activation_5_tool[0][0]']
#   (BatchNormalization)
#
#  add_5_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_tool[0
#                                                                     ][0]',
#                                                                      'add_4_tool[0][0]']
#
#  batch_normalization_5_spec  (None, 16, 16, 256)          1024      ['activation_5_spec[0][0]']
#   (BatchNormalization)
#
#  add_5_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_spec[0
#                                                                     ][0]',
#                                                                      'add_4_spec[0][0]']
#
#  batch_normalization_5_chip  (None, 16, 16, 256)          1024      ['activation_5_chip[0][0]']
#   (BatchNormalization)
#
#  add_5_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_chip[0
#                                                                     ][0]',
#                                                                      'add_4_chip[0][0]']
#
#  add_2_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_tool[0
#                                                                     ][0]']
#
#  conv2d_5_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_tool[0][0]']
#
#  add_2_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_spec[0
#                                                                     ][0]']
#
#  conv2d_5_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_spec[0][0]']
#
#  add_2_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_chip[0
#                                                                     ][0]']
#
#  conv2d_5_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_chip[0][0]']
#
#  conv2d_3_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_tool[0][0]']
#
#  activation_10_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_5_tool[0][0]']
#  tion)
#
#  conv2d_3_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_spec[0][0]']
#
#  activation_10_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_5_spec[0][0]']
#  tion)
#
#  conv2d_3_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_chip[0][0]']
#
#  activation_10_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_5_chip[0][0]']
#  tion)
#
#  activation_6_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_3_tool[0][0]']
#  ion)
#
#  batch_normalization_10_too  (None, 16, 16, 256)          1024      ['activation_10_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_6_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_3_spec[0][0]']
#  ion)
#
#  batch_normalization_10_spe  (None, 16, 16, 256)          1024      ['activation_10_spec[0][0]']
#  c (BatchNormalization)
#
#  activation_6_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_3_chip[0][0]']
#  ion)
#
#  batch_normalization_10_chi  (None, 16, 16, 256)          1024      ['activation_10_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_6_tool  (None, 16, 16, 256)          1024      ['activation_6_tool[0][0]']
#   (BatchNormalization)
#
#  add_6_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_tool[
#                                                                     0][0]']
#
#  batch_normalization_6_spec  (None, 16, 16, 256)          1024      ['activation_6_spec[0][0]']
#   (BatchNormalization)
#
#  add_6_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_spec[
#                                                                     0][0]']
#
#  batch_normalization_6_chip  (None, 16, 16, 256)          1024      ['activation_6_chip[0][0]']
#   (BatchNormalization)
#
#  add_6_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_chip[
#                                                                     0][0]']
#
#  add_7_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_tool[0
#                                                                     ][0]',
#                                                                      'add_6_tool[0][0]']
#
#  add_7_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_spec[0
#                                                                     ][0]',
#                                                                      'add_6_spec[0][0]']
#
#  add_7_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_chip[0
#                                                                     ][0]',
#                                                                      'add_6_chip[0][0]']
#
#  depthwise_conv2d_5_tool (D  (None, 16, 16, 256)          6656      ['add_7_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_5_spec (D  (None, 16, 16, 256)          6656      ['add_7_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_5_chip (D  (None, 16, 16, 256)          6656      ['add_7_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_3_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_tool[0][0
#  tion)                                                              ]']
#
#  depthwise_conv2d_3_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_spec[0][0
#  tion)                                                              ]']
#
#  depthwise_conv2d_3_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_chip[0][0
#  tion)                                                              ]']
#
#  activation_7_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_tool[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_too  (None, 16, 16, 256)          1024      ['activation_11_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_7_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_spec[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_spe  (None, 16, 16, 256)          1024      ['activation_11_spec[0][0]']
#  c (BatchNormalization)
#
#  activation_7_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_chi  (None, 16, 16, 256)          1024      ['activation_11_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_7_tool  (None, 16, 16, 256)          1024      ['activation_7_tool[0][0]']
#   (BatchNormalization)
#
#  add_8_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_tool[
#                                                                     0][0]',
#                                                                      'add_7_tool[0][0]']
#
#  batch_normalization_7_spec  (None, 16, 16, 256)          1024      ['activation_7_spec[0][0]']
#   (BatchNormalization)
#
#  add_8_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_spec[
#                                                                     0][0]',
#                                                                      'add_7_spec[0][0]']
#
#  batch_normalization_7_chip  (None, 16, 16, 256)          1024      ['activation_7_chip[0][0]']
#   (BatchNormalization)
#
#  add_8_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_chip[
#                                                                     0][0]',
#                                                                      'add_7_chip[0][0]']
#
#  add_3_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_tool[0
#                                                                     ][0]']
#
#  conv2d_6_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_tool[0][0]']
#
#  add_3_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_spec[0
#                                                                     ][0]']
#
#  conv2d_6_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_spec[0][0]']
#
#  add_3_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_chip[0
#                                                                     ][0]']
#
#  conv2d_6_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_chip[0][0]']
#
#  conv2d_4_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_tool[0][0]']
#
#  activation_12_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_6_tool[0][0]']
#  tion)
#
#  conv2d_4_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_spec[0][0]']
#
#  activation_12_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_6_spec[0][0]']
#  tion)
#
#  conv2d_4_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_chip[0][0]']
#
#  activation_12_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_6_chip[0][0]']
#  tion)
#
#  activation_8_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_4_tool[0][0]']
#  ion)
#
#  batch_normalization_12_too  (None, 16, 16, 256)          1024      ['activation_12_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_8_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_4_spec[0][0]']
#  ion)
#
#  batch_normalization_12_spe  (None, 16, 16, 256)          1024      ['activation_12_spec[0][0]']
#  c (BatchNormalization)
#
#  activation_8_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_4_chip[0][0]']
#  ion)
#
#  batch_normalization_12_chi  (None, 16, 16, 256)          1024      ['activation_12_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_8_tool  (None, 16, 16, 256)          1024      ['activation_8_tool[0][0]']
#   (BatchNormalization)
#
#  add_9_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_tool[
#                                                                     0][0]']
#
#  batch_normalization_8_spec  (None, 16, 16, 256)          1024      ['activation_8_spec[0][0]']
#   (BatchNormalization)
#
#  add_9_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_spec[
#                                                                     0][0]']
#
#  batch_normalization_8_chip  (None, 16, 16, 256)          1024      ['activation_8_chip[0][0]']
#   (BatchNormalization)
#
#  add_9_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_chip[
#                                                                     0][0]']
#
#  add_10_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_8_tool[0
#                                                                     ][0]',
#                                                                      'add_9_tool[0][0]']
#
# ...
#  tion)                                                              0]']
#
#  activation_29_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_14_chip[0][
#  tion)                                                              0]']
#
#  batch_normalization_29_too  (None, 16, 16, 256)          1024      ['activation_29_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_29_spe  (None, 16, 16, 256)          1024      ['activation_29_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_29_chi  (None, 16, 16, 256)          1024      ['activation_29_chip[0][0]']
#  p (BatchNormalization)
#
#  add_33_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_tool[
#                                                                     0][0]',
#                                                                      'add_32_tool[0][0]']
#
#  add_33_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_spec[
#                                                                     0][0]',
#                                                                      'add_32_spec[0][0]']
#
#  add_33_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_chip[
#                                                                     0][0]',
#                                                                      'add_32_chip[0][0]']
#
#  conv2d_15_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_tool[0][0]']
#
#  conv2d_15_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_spec[0][0]']
#
#  conv2d_15_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_chip[0][0]']
#
#  activation_30_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_15_tool[0][0]']
#  tion)
#
#  activation_30_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_15_spec[0][0]']
#  tion)
#
#  activation_30_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_15_chip[0][0]']
#  tion)
#
#  batch_normalization_30_too  (None, 16, 16, 256)          1024      ['activation_30_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_30_spe  (None, 16, 16, 256)          1024      ['activation_30_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_30_chi  (None, 16, 16, 256)          1024      ['activation_30_chip[0][0]']
#  p (BatchNormalization)
#
#  add_34_tool (Add)           (None, 16, 16, 256)          0         ['add_23_tool[0][0]',
#                                                                      'batch_normalization_30_tool[
#                                                                     0][0]']
#
#  add_34_spec (Add)           (None, 16, 16, 256)          0         ['add_23_spec[0][0]',
#                                                                      'batch_normalization_30_spec[
#                                                                     0][0]']
#
#  add_34_chip (Add)           (None, 16, 16, 256)          0         ['add_23_chip[0][0]',
#                                                                      'batch_normalization_30_chip[
#                                                                     0][0]']
#
#  depthwise_conv2d_15_tool (  (None, 16, 16, 256)          6656      ['add_34_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_15_spec (  (None, 16, 16, 256)          6656      ['add_34_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_15_chip (  (None, 16, 16, 256)          6656      ['add_34_chip[0][0]']
#  DepthwiseConv2D)
#
#  activation_31_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_tool[0][
#  tion)                                                              0]']
#
#  activation_31_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_spec[0][
#  tion)                                                              0]']
#
#  activation_31_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_chip[0][
#  tion)                                                              0]']
#
#  batch_normalization_31_too  (None, 16, 16, 256)          1024      ['activation_31_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_31_spe  (None, 16, 16, 256)          1024      ['activation_31_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_31_chi  (None, 16, 16, 256)          1024      ['activation_31_chip[0][0]']
#  p (BatchNormalization)
#
#  add_35_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_tool[
#                                                                     0][0]',
#                                                                      'add_34_tool[0][0]']
#
#  add_35_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_spec[
#                                                                     0][0]',
#                                                                      'add_34_spec[0][0]']
#
#  add_35_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_chip[
#                                                                     0][0]',
#                                                                      'add_34_chip[0][0]']
#
#  conv2d_16_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_tool[0][0]']
#
#  conv2d_16_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_spec[0][0]']
#
#  conv2d_16_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_chip[0][0]']
#
#  activation_32_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_16_tool[0][0]']
#  tion)
#
#  activation_32_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_16_spec[0][0]']
#  tion)
#
#  activation_32_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_16_chip[0][0]']
#  tion)
#
#  batch_normalization_32_too  (None, 16, 16, 256)          1024      ['activation_32_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_32_spe  (None, 16, 16, 256)          1024      ['activation_32_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_32_chi  (None, 16, 16, 256)          1024      ['activation_32_chip[0][0]']
#  p (BatchNormalization)
#
#  add_36_tool (Add)           (None, 16, 16, 256)          0         ['add_25_tool[0][0]',
#                                                                      'batch_normalization_32_tool[
#                                                                     0][0]']
#
#  add_36_spec (Add)           (None, 16, 16, 256)          0         ['add_25_spec[0][0]',
#                                                                      'batch_normalization_32_spec[
#                                                                     0][0]']
#
#  add_36_chip (Add)           (None, 16, 16, 256)          0         ['add_25_chip[0][0]',
#                                                                      'batch_normalization_32_chip[
#                                                                     0][0]']
#
#  global_average_pooling2d_t  (None, 256)                  0         ['add_36_tool[0][0]']
#  ool (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_s  (None, 256)                  0         ['add_36_spec[0][0]']
#  pec (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_c  (None, 256)                  0         ['add_36_chip[0][0]']
#  hip (GlobalAveragePooling2
#  D)
#
#  concatenate (Concatenate)   (None, 768)                  0         ['global_average_pooling2d_too
#                                                                     l[0][0]',
#                                                                      'global_average_pooling2d_spe
#                                                                     c[0][0]',
#                                                                      'global_average_pooling2d_chi
#                                                                     p[0][0]']
#
#  output_mult (Dense)         (None, 3)                    2307      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 4564995 (17.41 MB)
# Trainable params: 2307 (9.01 KB)
# Non-trainable params: 4562688 (17.41 MB)
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 29s 4s/step - loss: 3.0861 - accuracy: 0.3571 - val_loss: 1.4088 - val_accuracy: 0.3333
# Epoch 2/100
# 2/2 [==============================] - 1s 654ms/step - loss: 1.3126 - accuracy: 0.5714 - val_loss: 0.9321 - val_accuracy: 0.6667
# Epoch 3/100
# 2/2 [==============================] - 1s 671ms/step - loss: 1.2976 - accuracy: 0.6429 - val_loss: 0.4999 - val_accuracy: 1.0000
# Epoch 4/100
# 2/2 [==============================] - 1s 653ms/step - loss: 1.3483 - accuracy: 0.5000 - val_loss: 0.4608 - val_accuracy: 0.6667
# Epoch 5/100
# 2/2 [==============================] - 1s 619ms/step - loss: 1.3312 - accuracy: 0.5000 - val_loss: 0.4711 - val_accuracy: 0.6667
# Epoch 6/100
# 2/2 [==============================] - 1s 630ms/step - loss: 1.2537 - accuracy: 0.4286 - val_loss: 0.5058 - val_accuracy: 0.6667
# Epoch 7/100
# 2/2 [==============================] - 1s 625ms/step - loss: 1.0496 - accuracy: 0.4286 - val_loss: 0.6527 - val_accuracy: 0.6667
# Epoch 8/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.9380 - accuracy: 0.5714 - val_loss: 0.9003 - val_accuracy: 0.6667
# Epoch 9/100
# 2/2 [==============================] - 1s 640ms/step - loss: 0.9563 - accuracy: 0.6429 - val_loss: 1.0653 - val_accuracy: 0.6667
# Epoch 10/100
# 2/2 [==============================] - 1s 634ms/step - loss: 1.0381 - accuracy: 0.6429 - val_loss: 1.0858 - val_accuracy: 0.6667
# Epoch 11/100
# 2/2 [==============================] - 1s 639ms/step - loss: 0.9436 - accuracy: 0.5714 - val_loss: 0.9150 - val_accuracy: 0.6667
# Epoch 12/100
# 2/2 [==============================] - 1s 654ms/step - loss: 0.8844 - accuracy: 0.7143 - val_loss: 0.6840 - val_accuracy: 0.6667
# Epoch 13/100
# 2/2 [==============================] - 1s 657ms/step - loss: 0.8266 - accuracy: 0.7143 - val_loss: 0.5828 - val_accuracy: 1.0000
# Epoch 14/100
# 2/2 [==============================] - 1s 636ms/step - loss: 0.8446 - accuracy: 0.7143 - val_loss: 0.5545 - val_accuracy: 1.0000
# Epoch 15/100
# 2/2 [==============================] - 1s 642ms/step - loss: 0.8788 - accuracy: 0.6429 - val_loss: 0.5777 - val_accuracy: 0.6667
# Epoch 16/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.8648 - accuracy: 0.4286 - val_loss: 0.6399 - val_accuracy: 0.6667
# Epoch 17/100
# 2/2 [==============================] - 1s 662ms/step - loss: 0.7902 - accuracy: 0.5000 - val_loss: 0.7337 - val_accuracy: 0.6667
# Epoch 18/100
# 2/2 [==============================] - 1s 641ms/step - loss: 0.7498 - accuracy: 0.7143 - val_loss: 0.8745 - val_accuracy: 0.6667
# Epoch 19/100
# 2/2 [==============================] - 1s 621ms/step - loss: 0.7868 - accuracy: 0.7857 - val_loss: 0.9663 - val_accuracy: 0.6667
# Epoch 20/100
# 2/2 [==============================] - 1s 617ms/step - loss: 0.7849 - accuracy: 0.7143 - val_loss: 0.9095 - val_accuracy: 0.6667
# Epoch 21/100
# 2/2 [==============================] - 1s 627ms/step - loss: 0.7648 - accuracy: 0.7143 - val_loss: 0.8059 - val_accuracy: 0.6667
# Epoch 22/100
# 2/2 [==============================] - 1s 653ms/step - loss: 0.7050 - accuracy: 0.7143 - val_loss: 0.7419 - val_accuracy: 0.6667
# Epoch 23/100
# 2/2 [==============================] - 1s 617ms/step - loss: 0.6969 - accuracy: 0.7143 - val_loss: 0.7062 - val_accuracy: 1.0000
# Epoch 24/100
# 2/2 [==============================] - 1s 739ms/step - loss: 0.7177 - accuracy: 0.7143 - val_loss: 0.6919 - val_accuracy: 1.0000
# Epoch 25/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.7069 - accuracy: 0.7143 - val_loss: 0.7392 - val_accuracy: 0.6667
# Epoch 26/100
# 2/2 [==============================] - 1s 649ms/step - loss: 0.6753 - accuracy: 0.7143 - val_loss: 0.8110 - val_accuracy: 0.6667
# Epoch 27/100
# 2/2 [==============================] - 1s 674ms/step - loss: 0.6633 - accuracy: 0.7857 - val_loss: 0.8605 - val_accuracy: 0.6667
# Epoch 28/100
# 2/2 [==============================] - 1s 637ms/step - loss: 0.6618 - accuracy: 0.7857 - val_loss: 0.8978 - val_accuracy: 0.6667
# Epoch 29/100
# 2/2 [==============================] - 1s 631ms/step - loss: 0.6715 - accuracy: 0.8571 - val_loss: 0.9049 - val_accuracy: 0.6667
# Epoch 30/100
# 2/2 [==============================] - 1s 636ms/step - loss: 0.6524 - accuracy: 0.8571 - val_loss: 0.8751 - val_accuracy: 0.6667
# Epoch 31/100
# 2/2 [==============================] - 1s 627ms/step - loss: 0.6393 - accuracy: 0.8571 - val_loss: 0.8089 - val_accuracy: 0.6667
# Epoch 32/100
# 2/2 [==============================] - 1s 629ms/step - loss: 0.6292 - accuracy: 0.7857 - val_loss: 0.7576 - val_accuracy: 0.6667
# Epoch 33/100
# 2/2 [==============================] - 1s 618ms/step - loss: 0.6351 - accuracy: 0.7857 - val_loss: 0.7321 - val_accuracy: 0.6667
# Epoch 34/100
# 2/2 [==============================] - 2s 993ms/step - loss: 0.6317 - accuracy: 0.7143 - val_loss: 0.7525 - val_accuracy: 0.6667
# Epoch 35/100
# 2/2 [==============================] - 2s 717ms/step - loss: 0.6207 - accuracy: 0.7143 - val_loss: 0.8250 - val_accuracy: 0.6667
# Epoch 36/100
# 2/2 [==============================] - 1s 643ms/step - loss: 0.6214 - accuracy: 0.8571 - val_loss: 0.8935 - val_accuracy: 0.6667
# Epoch 37/100
# 2/2 [==============================] - 1s 645ms/step - loss: 0.6194 - accuracy: 0.8571 - val_loss: 0.9072 - val_accuracy: 0.6667
# Epoch 38/100
# 2/2 [==============================] - 1s 631ms/step - loss: 0.6078 - accuracy: 0.8571 - val_loss: 0.8618 - val_accuracy: 0.6667
# Epoch 39/100
# 2/2 [==============================] - 1s 725ms/step - loss: 0.5911 - accuracy: 0.8571 - val_loss: 0.8294 - val_accuracy: 0.6667
# Epoch 40/100
# 2/2 [==============================] - 1s 661ms/step - loss: 0.5944 - accuracy: 0.7857 - val_loss: 0.7863 - val_accuracy: 0.6667
# Epoch 41/100
# 2/2 [==============================] - 1s 629ms/step - loss: 0.5870 - accuracy: 0.7857 - val_loss: 0.7797 - val_accuracy: 0.6667
# Epoch 42/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.5770 - accuracy: 0.7857 - val_loss: 0.7905 - val_accuracy: 0.6667
# Epoch 43/100
# 2/2 [==============================] - 1s 664ms/step - loss: 0.5762 - accuracy: 0.8571 - val_loss: 0.8378 - val_accuracy: 0.6667
# Epoch 44/100
# 2/2 [==============================] - 1s 638ms/step - loss: 0.5771 - accuracy: 0.8571 - val_loss: 0.8646 - val_accuracy: 0.6667
# Epoch 45/100
# 2/2 [==============================] - 1s 629ms/step - loss: 0.5605 - accuracy: 0.8571 - val_loss: 0.8899 - val_accuracy: 0.6667
# Epoch 46/100
# 2/2 [==============================] - 1s 732ms/step - loss: 0.5575 - accuracy: 0.8571 - val_loss: 0.9222 - val_accuracy: 0.6667
# Epoch 47/100
# 2/2 [==============================] - 1s 640ms/step - loss: 0.5944 - accuracy: 0.7857 - val_loss: 0.9058 - val_accuracy: 0.6667
# Epoch 48/100
# 2/2 [==============================] - 1s 606ms/step - loss: 0.5574 - accuracy: 0.8571 - val_loss: 0.8446 - val_accuracy: 0.6667
# Epoch 49/100
# 2/2 [==============================] - 1s 714ms/step - loss: 0.5348 - accuracy: 0.8571 - val_loss: 0.8045 - val_accuracy: 0.6667
# Epoch 50/100
# 2/2 [==============================] - 1s 656ms/step - loss: 0.5503 - accuracy: 0.8571 - val_loss: 0.7826 - val_accuracy: 0.6667
# Epoch 51/100
# 2/2 [==============================] - 1s 638ms/step - loss: 0.5437 - accuracy: 0.9286 - val_loss: 0.7957 - val_accuracy: 0.6667
# Epoch 52/100
# 2/2 [==============================] - 1s 629ms/step - loss: 0.5298 - accuracy: 0.7857 - val_loss: 0.8143 - val_accuracy: 0.6667
# Epoch 53/100
# 2/2 [==============================] - 1s 620ms/step - loss: 0.5312 - accuracy: 0.7857 - val_loss: 0.8727 - val_accuracy: 0.6667
# Epoch 54/100
# 2/2 [==============================] - 1s 655ms/step - loss: 0.5378 - accuracy: 0.8571 - val_loss: 0.9006 - val_accuracy: 0.6667
# Epoch 55/100
# 2/2 [==============================] - 1s 630ms/step - loss: 0.5162 - accuracy: 0.8571 - val_loss: 0.8572 - val_accuracy: 0.6667
# Epoch 56/100
# 2/2 [==============================] - 1s 634ms/step - loss: 0.5100 - accuracy: 0.8571 - val_loss: 0.8227 - val_accuracy: 0.6667
# Epoch 57/100
# 2/2 [==============================] - 1s 755ms/step - loss: 0.5196 - accuracy: 0.9286 - val_loss: 0.7956 - val_accuracy: 0.3333
# Epoch 58/100
# 2/2 [==============================] - 1s 646ms/step - loss: 0.5160 - accuracy: 0.9286 - val_loss: 0.7860 - val_accuracy: 0.6667
# Epoch 59/100
# 2/2 [==============================] - 1s 674ms/step - loss: 0.4971 - accuracy: 0.7857 - val_loss: 0.8146 - val_accuracy: 0.6667
# Epoch 60/100
# 2/2 [==============================] - 1s 631ms/step - loss: 0.5135 - accuracy: 0.7857 - val_loss: 0.8552 - val_accuracy: 0.6667
# Epoch 61/100
# 2/2 [==============================] - 1s 621ms/step - loss: 0.5150 - accuracy: 0.7857 - val_loss: 0.8550 - val_accuracy: 0.6667
# Epoch 62/100
# 2/2 [==============================] - 1s 632ms/step - loss: 0.4898 - accuracy: 0.8571 - val_loss: 0.8287 - val_accuracy: 0.6667
# Epoch 63/100
# 2/2 [==============================] - 1s 633ms/step - loss: 0.4770 - accuracy: 0.8571 - val_loss: 0.8038 - val_accuracy: 0.6667
# Epoch 64/100
# 2/2 [==============================] - 1s 652ms/step - loss: 0.4747 - accuracy: 0.9286 - val_loss: 0.7966 - val_accuracy: 0.3333
# Epoch 65/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.4864 - accuracy: 0.9286 - val_loss: 0.8037 - val_accuracy: 0.3333
# Epoch 66/100
# 2/2 [==============================] - 1s 673ms/step - loss: 0.4698 - accuracy: 0.9286 - val_loss: 0.8133 - val_accuracy: 0.6667
# Epoch 67/100
# 2/2 [==============================] - 1s 653ms/step - loss: 0.4618 - accuracy: 0.8571 - val_loss: 0.8167 - val_accuracy: 0.6667
# Epoch 68/100
# 2/2 [==============================] - 1s 629ms/step - loss: 0.4758 - accuracy: 0.7857 - val_loss: 0.8013 - val_accuracy: 0.6667
# Epoch 69/100
# 2/2 [==============================] - 1s 715ms/step - loss: 0.4703 - accuracy: 0.7857 - val_loss: 0.8091 - val_accuracy: 0.6667
# Epoch 70/100
# 2/2 [==============================] - 1s 641ms/step - loss: 0.4495 - accuracy: 0.8571 - val_loss: 0.8176 - val_accuracy: 0.6667
# Epoch 71/100
# 2/2 [==============================] - 1s 645ms/step - loss: 0.4639 - accuracy: 0.8571 - val_loss: 0.8495 - val_accuracy: 0.6667
# Epoch 72/100
# 2/2 [==============================] - 1s 658ms/step - loss: 0.4622 - accuracy: 0.9286 - val_loss: 0.8426 - val_accuracy: 0.6667
# Epoch 73/100
# 2/2 [==============================] - 1s 639ms/step - loss: 0.4404 - accuracy: 0.9286 - val_loss: 0.8119 - val_accuracy: 0.6667
# Epoch 74/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.4373 - accuracy: 0.8571 - val_loss: 0.7947 - val_accuracy: 0.6667
# Epoch 75/100
# 2/2 [==============================] - 2s 714ms/step - loss: 0.4408 - accuracy: 0.8571 - val_loss: 0.8037 - val_accuracy: 0.6667
# Epoch 76/100
# 2/2 [==============================] - 1s 636ms/step - loss: 0.4488 - accuracy: 0.8571 - val_loss: 0.7935 - val_accuracy: 0.3333
# Epoch 77/100
# 2/2 [==============================] - 1s 721ms/step - loss: 0.4457 - accuracy: 0.8571 - val_loss: 0.8030 - val_accuracy: 0.3333
# Epoch 78/100
# 2/2 [==============================] - 1s 664ms/step - loss: 0.4321 - accuracy: 0.8571 - val_loss: 0.8410 - val_accuracy: 0.6667
# Epoch 79/100
# 2/2 [==============================] - 1s 659ms/step - loss: 0.4288 - accuracy: 0.8571 - val_loss: 0.8364 - val_accuracy: 0.6667
# Epoch 80/100
# 2/2 [==============================] - 1s 621ms/step - loss: 0.4277 - accuracy: 0.8571 - val_loss: 0.8315 - val_accuracy: 0.6667
# Epoch 81/100
# 2/2 [==============================] - 1s 620ms/step - loss: 0.4203 - accuracy: 0.8571 - val_loss: 0.8104 - val_accuracy: 0.3333
# Epoch 82/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.4088 - accuracy: 0.8571 - val_loss: 0.7725 - val_accuracy: 0.3333
# Epoch 83/100
# 2/2 [==============================] - 2s 907ms/step - loss: 0.4066 - accuracy: 0.7857 - val_loss: 0.7478 - val_accuracy: 0.3333
# Epoch 84/100
# 2/2 [==============================] - 1s 632ms/step - loss: 0.4149 - accuracy: 0.7857 - val_loss: 0.7579 - val_accuracy: 0.3333
# Epoch 85/100
# 2/2 [==============================] - 1s 642ms/step - loss: 0.4087 - accuracy: 0.7857 - val_loss: 0.7961 - val_accuracy: 0.3333
# Epoch 86/100
# 2/2 [==============================] - 1s 620ms/step - loss: 0.4001 - accuracy: 0.8571 - val_loss: 0.8239 - val_accuracy: 0.3333
# Epoch 87/100
# 2/2 [==============================] - 1s 639ms/step - loss: 0.3915 - accuracy: 0.8571 - val_loss: 0.8584 - val_accuracy: 0.3333
# Epoch 88/100
# 2/2 [==============================] - 1s 640ms/step - loss: 0.4125 - accuracy: 0.8571 - val_loss: 0.8750 - val_accuracy: 0.3333
# Epoch 89/100
# 2/2 [==============================] - 1s 630ms/step - loss: 0.3985 - accuracy: 0.9286 - val_loss: 0.8410 - val_accuracy: 0.3333
# Epoch 90/100
# 2/2 [==============================] - 1s 644ms/step - loss: 0.3930 - accuracy: 0.8571 - val_loss: 0.8023 - val_accuracy: 0.3333
# Epoch 91/100
# 2/2 [==============================] - 1s 639ms/step - loss: 0.3862 - accuracy: 0.8571 - val_loss: 0.7924 - val_accuracy: 0.3333
# Epoch 92/100
# 2/2 [==============================] - 2s 983ms/step - loss: 0.3800 - accuracy: 0.9286 - val_loss: 0.7929 - val_accuracy: 0.3333
# Epoch 93/100
# 2/2 [==============================] - 1s 616ms/step - loss: 0.3862 - accuracy: 0.9286 - val_loss: 0.8099 - val_accuracy: 0.3333
# Epoch 94/100
# 2/2 [==============================] - 1s 641ms/step - loss: 0.3697 - accuracy: 0.9286 - val_loss: 0.8342 - val_accuracy: 0.3333
# Epoch 95/100
# 2/2 [==============================] - 1s 644ms/step - loss: 0.3991 - accuracy: 0.8571 - val_loss: 0.8316 - val_accuracy: 0.3333
# Epoch 96/100
# 2/2 [==============================] - 1s 637ms/step - loss: 0.3835 - accuracy: 0.8571 - val_loss: 0.8344 - val_accuracy: 0.3333
# Epoch 97/100
# 2/2 [==============================] - 1s 631ms/step - loss: 0.3654 - accuracy: 0.9286 - val_loss: 0.8236 - val_accuracy: 0.3333
# Epoch 98/100
# 2/2 [==============================] - 1s 655ms/step - loss: 0.3687 - accuracy: 0.9286 - val_loss: 0.8098 - val_accuracy: 0.3333
# Epoch 99/100
# 2/2 [==============================] - 1s 650ms/step - loss: 0.3807 - accuracy: 1.0000 - val_loss: 0.8030 - val_accuracy: 0.3333
# Epoch 100/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.3748 - accuracy: 1.0000 - val_loss: 0.7876 - val_accuracy: 0.3333
# 1/1 [==============================] - 0s 218ms/step - loss: 0.8098 - accuracy: 0.3333
# Test accuracy: 33.33%

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("model accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
x_test = test_ds
y_test = labels_test
y_score = model.predict(x_test)
y_test = y_test

n_classes = num_classes
# Plot linewidth.
lw = 2
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})" "".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})" "".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})" "".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic multi-class")
plt.legend(loc="lower right")
plt.show()
# Out:
# 1/1 [==============================] - 0s 229ms/step
# <ipython-input-36-0227eecc12f4>:27: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %%
y_classes = np.argmax(y_score, axis=1)
labels_test_f1 = np.argmax(y_test, axis=1)

print(metrics.confusion_matrix(labels_test_f1, y_classes))
print(classification_report(labels_test_f1, y_classes))
# Out:
# [[0 1 0]
#  [0 0 1]
#  [0 0 1]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.00      0.00      0.00         1
#            2       0.50      1.00      0.67         1
#
#     accuracy                           0.33         3
#    macro avg       0.17      0.33      0.22         3
# weighted avg       0.17      0.33      0.22         3
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fpr, tpr, thresholds = metrics.roc_curve(labels_test_f1, y_classes, pos_label=2)
print("AUC: ", metrics.auc(fpr, tpr))
# Out:
# AUC:  0.75
