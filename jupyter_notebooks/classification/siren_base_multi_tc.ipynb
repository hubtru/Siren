# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os
os.environ["CUDA_VISIBLE_DEVICES"]="3"
# Out:
# 2023-09-20 16:47:04.252414: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-20 16:47:06.162968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  1
# GPUs:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-09-20 16:47:10.665301: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-20 16:47:10.711519: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-20 16:47:10.712783: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_chip = 3
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_chip = (img_rows, img_cols, in_channel_chip)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_tc"
exp_name = f"siren"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"./{exp_name}_{sub_exp_name}_tool.h5"
model_chip_path = f"./{exp_name}_{sub_exp_name}_chip.h5"

# dataset
csv_path = "../../dataset/labels_sample.csv"
tool_path = "../../dataset/tool"
chip_path = "../../dataset/chip"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6,6))
sns.displot(train_df['tool_label'])
plt.title('Label Distribution')
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id image_label  tool_label                            tool  \
# 14   T8R3B4       sharp           1   ../../dataset/tool/T8R3B4.jpg
# 10   T6R9B3        used           2   ../../dataset/tool/T6R9B3.jpg
# 0    T1R2B1       sharp           1   ../../dataset/tool/T1R2B1.jpg
# 3   T2R13B4      dulled           3  ../../dataset/tool/T2R13B4.jpg
# 1    T1R7B4        used           2   ../../dataset/tool/T1R7B4.jpg
#
#                               chip
# 14   ../../dataset/chip/T8R3B4.jpg
# 10   ../../dataset/chip/T6R9B3.jpg
# 0    ../../dataset/chip/T1R2B1.jpg
# 3   ../../dataset/chip/T2R13B4.jpg
# 1    ../../dataset/chip/T1R7B4.jpg
# test_head          id image_label  tool_label                            tool  \
# 16   T9R7B4        used           2   ../../dataset/tool/T9R7B4.jpg
# 18  T10R3B4       sharp           1  ../../dataset/tool/T10R3B4.jpg
# 9   T5R12B1      dulled           3  ../../dataset/tool/T5R12B1.jpg
#
#                               chip
# 16   ../../dataset/chip/T9R7B4.jpg
# 18  ../../dataset/chip/T10R3B4.jpg
# 9   ../../dataset/chip/T5R12B1.jpg
# val_head          id image_label  tool_label                            tool  \
# 5   T3R10B1      dulled           3  ../../dataset/tool/T3R10B1.jpg
# 13  T7R14B3      dulled           3  ../../dataset/tool/T7R14B3.jpg
# 12   T7R8B3        used           2   ../../dataset/tool/T7R8B3.jpg
#
#                               chip
# 5   ../../dataset/chip/T3R10B1.jpg
# 13  ../../dataset/chip/T7R14B3.jpg
# 12   ../../dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df.tool_label.values
labels_test = test_df.tool_label.values
labels_val = val_df.tool_label.values

labels_train
# Out:
# array([1, 2, 1, 3, 2, 2, 3, 2, 1, 1, 3, 1, 2, 3])

# %%
labels_train = labels_train - 1
labels_test = labels_test - 1
labels_val = labels_val - 1

labels_train = tf.keras.utils.to_categorical(
    labels_train, num_classes=num_classes, dtype="float32"
)
labels_test = tf.keras.utils.to_categorical(
    labels_test, num_classes=num_classes, dtype="float32"
)
labels_val = tf.keras.utils.to_categorical(
    labels_val, num_classes=num_classes, dtype="float32"
)

# %%
# ============================== augment 1/2 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)
# Out:
# 2023-09-20 16:47:13.119906: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-20 16:47:13.121361: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-20 16:47:13.122517: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-20 16:47:14.232854: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-20 16:47:14.234190: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-20 16:47:14.236938: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-20 16:47:14.237941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10377 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:00:1c.0, compute capability: 6.1

# %%
# ============================== augment 2/2 ==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_chip = data_augmentation_chip(x_train_chip)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_chip": x_train_chip,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_chip": x_test_chip,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_chip": x_val_chip,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs3 = k.Input(input_shape_chip)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
model_tool = k.models.load_model(model_tool_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)

model_tool.trainable = False
model_chip.trainable = False


def load_multi_mixer(model_tool, model_chip):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs3 = model_chip.input
    inputs3._name = "input_chip"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_chip.output,
        ]
    )
    output = layers.Dense(num_classes, activation="softmax", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs3], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, model

# %%
model = load_multi_mixer(model_tool, model_chip)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1_tool (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_1_chip (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_tool (Conv2D)           (None, 16, 16, 256)  196864      ['input_1_tool[0][0]']
#
#  conv2d_chip (Conv2D)           (None, 16, 16, 256)  196864      ['input_1_chip[0][0]']
#
#  activation_tool (Activation)   (None, 16, 16, 256)  0           ['conv2d_tool[0][0]']
#
#  activation_chip (Activation)   (None, 16, 16, 256)  0           ['conv2d_chip[0][0]']
#
#  batch_normalization_tool (Batc  (None, 16, 16, 256)  1024       ['activation_tool[0][0]']
#  hNormalization)
#
#  batch_normalization_chip (Batc  (None, 16, 16, 256)  1024       ['activation_chip[0][0]']
#  hNormalization)
#
#  depthwise_conv2d_tool (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_tool[0][0]'
#  seConv2D)                                                       ]
#
#  depthwise_conv2d_chip (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_chip[0][0]'
#  seConv2D)                                                       ]
#
#  activation_1_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_tool[0][0]']
#
#  activation_1_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_chip[0][0]']
#
#  batch_normalization_1_tool (Ba  (None, 16, 16, 256)  1024       ['activation_1_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_1_chip (Ba  (None, 16, 16, 256)  1024       ['activation_1_chip[0][0]']
#  tchNormalization)
#
#  add_tool (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_chip (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  conv2d_1_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_tool[0][0]']
#
#  conv2d_1_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_chip[0][0]']
#
#  activation_2_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_tool[0][0]']
#
#  activation_2_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_chip[0][0]']
#
#  batch_normalization_2_tool (Ba  (None, 16, 16, 256)  1024       ['activation_2_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_2_chip (Ba  (None, 16, 16, 256)  1024       ['activation_2_chip[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_1_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  depthwise_conv2d_1_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_3_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_tool[0][0]']
#
#  activation_3_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_chip[0][0]']
#
#  batch_normalization_3_tool (Ba  (None, 16, 16, 256)  1024       ['activation_3_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_3_chip (Ba  (None, 16, 16, 256)  1024       ['activation_3_chip[0][0]']
#  tchNormalization)
#
#  add_1_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_tool[0][0
#                                                                  ]']
#
#  add_1_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_chip[0][0
#                                                                  ]']
#
#  conv2d_2_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_tool[0][0]']
#
#  conv2d_2_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_chip[0][0]']
#
#  activation_4_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_tool[0][0]']
#
#  activation_4_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_chip[0][0]']
#
#  batch_normalization_4_tool (Ba  (None, 16, 16, 256)  1024       ['activation_4_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_4_chip (Ba  (None, 16, 16, 256)  1024       ['activation_4_chip[0][0]']
#  tchNormalization)
#
#  add_4_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_4_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_4_tool (Depth  (None, 16, 16, 256)  6656       ['add_4_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_4_chip (Depth  (None, 16, 16, 256)  6656       ['add_4_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_2_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_tool[0][0]']
#
#  depthwise_conv2d_2_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_chip[0][0]']
#
#  activation_5_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_tool[0][0]']
#
#  batch_normalization_9_tool (Ba  (None, 16, 16, 256)  1024       ['activation_9_tool[0][0]']
#  tchNormalization)
#
#  activation_5_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_chip[0][0]']
#
#  batch_normalization_9_chip (Ba  (None, 16, 16, 256)  1024       ['activation_9_chip[0][0]']
#  tchNormalization)
#
#  batch_normalization_5_tool (Ba  (None, 16, 16, 256)  1024       ['activation_5_tool[0][0]']
#  tchNormalization)
#
#  add_5_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_tool[0][0
#                                                                  ]',
#                                                                   'add_4_tool[0][0]']
#
#  batch_normalization_5_chip (Ba  (None, 16, 16, 256)  1024       ['activation_5_chip[0][0]']
#  tchNormalization)
#
#  add_5_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_chip[0][0
#                                                                  ]',
#                                                                   'add_4_chip[0][0]']
#
#  add_2_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_tool[0][0
#                                                                  ]']
#
#  conv2d_5_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_tool[0][0]']
#
#  add_2_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_chip[0][0
#                                                                  ]']
#
#  conv2d_5_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_chip[0][0]']
#
#  conv2d_3_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_tool[0][0]']
#
#  activation_10_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_5_tool[0][0]']
#  )
#
#  conv2d_3_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_chip[0][0]']
#
#  activation_10_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_5_chip[0][0]']
#  )
#
#  activation_6_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_tool[0][0]']
#
#  batch_normalization_10_tool (B  (None, 16, 16, 256)  1024       ['activation_10_tool[0][0]']
#  atchNormalization)
#
#  activation_6_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_chip[0][0]']
#
#  batch_normalization_10_chip (B  (None, 16, 16, 256)  1024       ['activation_10_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_6_tool (Ba  (None, 16, 16, 256)  1024       ['activation_6_tool[0][0]']
#  tchNormalization)
#
#  add_6_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_tool[0][
#                                                                  0]']
#
#  batch_normalization_6_chip (Ba  (None, 16, 16, 256)  1024       ['activation_6_chip[0][0]']
#  tchNormalization)
#
#  add_6_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_chip[0][
#                                                                  0]']
#
#  add_7_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_tool[0][0
#                                                                  ]',
#                                                                   'add_6_tool[0][0]']
#
#  add_7_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_chip[0][0
#                                                                  ]',
#                                                                   'add_6_chip[0][0]']
#
#  depthwise_conv2d_5_tool (Depth  (None, 16, 16, 256)  6656       ['add_7_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_5_chip (Depth  (None, 16, 16, 256)  6656       ['add_7_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_3_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_tool[0][0]']
#  )
#
#  depthwise_conv2d_3_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_chip[0][0]']
#  )
#
#  activation_7_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_tool[0][0]']
#
#  batch_normalization_11_tool (B  (None, 16, 16, 256)  1024       ['activation_11_tool[0][0]']
#  atchNormalization)
#
#  activation_7_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_chip[0][0]']
#
#  batch_normalization_11_chip (B  (None, 16, 16, 256)  1024       ['activation_11_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_7_tool (Ba  (None, 16, 16, 256)  1024       ['activation_7_tool[0][0]']
#  tchNormalization)
#
#  add_8_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_tool[0][
#                                                                  0]',
#                                                                   'add_7_tool[0][0]']
#
#  batch_normalization_7_chip (Ba  (None, 16, 16, 256)  1024       ['activation_7_chip[0][0]']
#  tchNormalization)
#
#  add_8_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_chip[0][
#                                                                  0]',
#                                                                   'add_7_chip[0][0]']
#
#  add_3_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_tool[0][0
#                                                                  ]']
#
#  conv2d_6_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_tool[0][0]']
#
#  add_3_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_chip[0][0
#                                                                  ]']
#
#  conv2d_6_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_chip[0][0]']
#
#  conv2d_4_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_tool[0][0]']
#
#  activation_12_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_6_tool[0][0]']
#  )
#
#  conv2d_4_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_chip[0][0]']
#
#  activation_12_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_6_chip[0][0]']
#  )
#
#  activation_8_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_tool[0][0]']
#
#  batch_normalization_12_tool (B  (None, 16, 16, 256)  1024       ['activation_12_tool[0][0]']
#  atchNormalization)
#
#  activation_8_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_chip[0][0]']
#
#  batch_normalization_12_chip (B  (None, 16, 16, 256)  1024       ['activation_12_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_8_tool (Ba  (None, 16, 16, 256)  1024       ['activation_8_tool[0][0]']
#  tchNormalization)
#
#  add_9_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_tool[0][
#                                                                  0]']
#
#  batch_normalization_8_chip (Ba  (None, 16, 16, 256)  1024       ['activation_8_chip[0][0]']
#  tchNormalization)
#
#  add_9_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_chip[0][
#                                                                  0]']
#
#  add_10_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_tool[0][0
#                                                                  ]',
#                                                                   'add_9_tool[0][0]']
#
#  add_15_tool (Add)              (None, 16, 16, 256)  0           ['add_9_tool[0][0]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_10_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_chip[0][0
#                                                                  ]',
#                                                                   'add_9_chip[0][0]']
#
#  add_15_chip (Add)              (None, 16, 16, 256)  0           ['add_9_chip[0][0]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_6_tool (Depth  (None, 16, 16, 256)  6656       ['add_10_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_tool (Depth  (None, 16, 16, 256)  6656       ['add_15_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_6_chip (Depth  (None, 16, 16, 256)  6656       ['add_10_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_chip (Depth  (None, 16, 16, 256)  6656       ['add_15_chip[0][0]']
#  wiseConv2D)
#
#  activation_13_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_6_tool[0][0]']
#  )
#
#  activation_17_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_8_tool[0][0]']
#  )
#
#  activation_13_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_6_chip[0][0]']
#  )
#
#  activation_17_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_8_chip[0][0]']
#  )
#
#  batch_normalization_13_tool (B  (None, 16, 16, 256)  1024       ['activation_13_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_17_tool (B  (None, 16, 16, 256)  1024       ['activation_17_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_13_chip (B  (None, 16, 16, 256)  1024       ['activation_13_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_17_chip (B  (None, 16, 16, 256)  1024       ['activation_17_chip[0][0]']
#  atchNormalization)
#
#  add_11_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_13_tool[0][
#                                                                  0]',
#                                                                   'add_10_tool[0][0]']
#
#  add_16_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_17_tool[0][
#                                                                  0]',
#                                                                   'add_15_tool[0][0]']
#
#  add_11_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_13_chip[0][
#                                                                  0]',
#                                                                   'add_10_chip[0][0]']
#
#  add_16_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_17_chip[0][
#                                                                  0]',
#                                                                   'add_15_chip[0][0]']
#
#  conv2d_7_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_11_tool[0][0]']
#
#  conv2d_9_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_16_tool[0][0]']
#
#  conv2d_7_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_11_chip[0][0]']
#
#  conv2d_9_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_16_chip[0][0]']
#
#  activation_14_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_7_tool[0][0]']
#  )
#
#  activation_18_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_9_tool[0][0]']
#  )
#
#  activation_14_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_7_chip[0][0]']
#  )
#
#  activation_18_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_9_chip[0][0]']
#  )
#
#  batch_normalization_14_tool (B  (None, 16, 16, 256)  1024       ['activation_14_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_18_tool (B  (None, 16, 16, 256)  1024       ['activation_18_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_14_chip (B  (None, 16, 16, 256)  1024       ['activation_14_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_18_chip (B  (None, 16, 16, 256)  1024       ['activation_18_chip[0][0]']
#  atchNormalization)
#
#  add_12_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_6_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_14_tool[0][
#                                                                  0]']
#
#  add_17_tool (Add)              (None, 16, 16, 256)  0           ['add_6_tool[0][0]',
#                                                                   'batch_normalization_18_tool[0][
#                                                                  0]']
#
#  add_12_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_6_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_14_chip[0][
#                                                                  0]']
#
#  add_17_chip (Add)              (None, 16, 16, 256)  0           ['add_6_chip[0][0]',
#                                                                   'batch_normalization_18_chip[0][
#                                                                  0]']
#
#  add_18_tool (Add)              (None, 16, 16, 256)  0           ['add_12_tool[0][0]',
#                                                                   'add_17_tool[0][0]']
#
#  add_18_chip (Add)              (None, 16, 16, 256)  0           ['add_12_chip[0][0]',
#                                                                   'add_17_chip[0][0]']
#
#  depthwise_conv2d_7_tool (Depth  (None, 16, 16, 256)  6656       ['add_12_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_9_tool (Depth  (None, 16, 16, 256)  6656       ['add_18_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_7_chip (Depth  (None, 16, 16, 256)  6656       ['add_12_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_9_chip (Depth  (None, 16, 16, 256)  6656       ['add_18_chip[0][0]']
#  wiseConv2D)
#
#  activation_15_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_7_tool[0][0]']
#  )
#
#  activation_19_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_9_tool[0][0]']
#  )
#
#  activation_15_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_7_chip[0][0]']
#  )
#
#  activation_19_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_9_chip[0][0]']
#  )
#
#  batch_normalization_15_tool (B  (None, 16, 16, 256)  1024       ['activation_15_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_19_tool (B  (None, 16, 16, 256)  1024       ['activation_19_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_15_chip (B  (None, 16, 16, 256)  1024       ['activation_15_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_19_chip (B  (None, 16, 16, 256)  1024       ['activation_19_chip[0][0]']
#  atchNormalization)
#
#  add_13_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_15_tool[0][
#                                                                  0]',
#                                                                   'add_12_tool[0][0]']
#
#  add_19_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_19_tool[0][
#                                                                  0]',
#                                                                   'add_18_tool[0][0]']
#
#  add_13_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_15_chip[0][
#                                                                  0]',
#                                                                   'add_12_chip[0][0]']
#
#  add_19_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_19_chip[0][
#                                                                  0]',
#                                                                   'add_18_chip[0][0]']
#
#  conv2d_8_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_13_tool[0][0]']
#
#  conv2d_10_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_19_tool[0][0]']
#
#  conv2d_8_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_13_chip[0][0]']
# ...
#  )
#
#  activation_28_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_14_tool[0][0]']
#  )
#
#  activation_24_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_12_chip[0][0]']
#  )
#
#  activation_28_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_14_chip[0][0]']
#  )
#
#  batch_normalization_24_tool (B  (None, 16, 16, 256)  1024       ['activation_24_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_28_tool (B  (None, 16, 16, 256)  1024       ['activation_28_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_24_chip (B  (None, 16, 16, 256)  1024       ['activation_24_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_28_chip (B  (None, 16, 16, 256)  1024       ['activation_28_chip[0][0]']
#  atchNormalization)
#
#  add_25_tool (Add)              (None, 16, 16, 256)  0           ['add_14_tool[0][0]',
#                                                                   'batch_normalization_24_tool[0][
#                                                                  0]']
#
#  add_31_tool (Add)              (None, 16, 16, 256)  0           ['add_20_tool[0][0]',
#                                                                   'batch_normalization_28_tool[0][
#                                                                  0]']
#
#  add_25_chip (Add)              (None, 16, 16, 256)  0           ['add_14_chip[0][0]',
#                                                                   'batch_normalization_24_chip[0][
#                                                                  0]']
#
#  add_31_chip (Add)              (None, 16, 16, 256)  0           ['add_20_chip[0][0]',
#                                                                   'batch_normalization_28_chip[0][
#                                                                  0]']
#
#  add_32_tool (Add)              (None, 16, 16, 256)  0           ['add_25_tool[0][0]',
#                                                                   'add_31_tool[0][0]']
#
#  add_32_chip (Add)              (None, 16, 16, 256)  0           ['add_25_chip[0][0]',
#                                                                   'add_31_chip[0][0]']
#
#  depthwise_conv2d_14_tool (Dept  (None, 16, 16, 256)  6656       ['add_32_tool[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_14_chip (Dept  (None, 16, 16, 256)  6656       ['add_32_chip[0][0]']
#  hwiseConv2D)
#
#  activation_29_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_tool[0][0]'
#  )                                                               ]
#
#  activation_29_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_chip[0][0]'
#  )                                                               ]
#
#  batch_normalization_29_tool (B  (None, 16, 16, 256)  1024       ['activation_29_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_29_chip (B  (None, 16, 16, 256)  1024       ['activation_29_chip[0][0]']
#  atchNormalization)
#
#  add_33_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_tool[0][
#                                                                  0]',
#                                                                   'add_32_tool[0][0]']
#
#  add_33_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_chip[0][
#                                                                  0]',
#                                                                   'add_32_chip[0][0]']
#
#  conv2d_15_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_tool[0][0]']
#
#  conv2d_15_chip (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_chip[0][0]']
#
#  activation_30_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_15_tool[0][0]']
#  )
#
#  activation_30_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_15_chip[0][0]']
#  )
#
#  batch_normalization_30_tool (B  (None, 16, 16, 256)  1024       ['activation_30_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_30_chip (B  (None, 16, 16, 256)  1024       ['activation_30_chip[0][0]']
#  atchNormalization)
#
#  add_34_tool (Add)              (None, 16, 16, 256)  0           ['add_23_tool[0][0]',
#                                                                   'batch_normalization_30_tool[0][
#                                                                  0]']
#
#  add_34_chip (Add)              (None, 16, 16, 256)  0           ['add_23_chip[0][0]',
#                                                                   'batch_normalization_30_chip[0][
#                                                                  0]']
#
#  depthwise_conv2d_15_tool (Dept  (None, 16, 16, 256)  6656       ['add_34_tool[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_15_chip (Dept  (None, 16, 16, 256)  6656       ['add_34_chip[0][0]']
#  hwiseConv2D)
#
#  activation_31_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_tool[0][0]'
#  )                                                               ]
#
#  activation_31_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_chip[0][0]'
#  )                                                               ]
#
#  batch_normalization_31_tool (B  (None, 16, 16, 256)  1024       ['activation_31_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_31_chip (B  (None, 16, 16, 256)  1024       ['activation_31_chip[0][0]']
#  atchNormalization)
#
#  add_35_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_tool[0][
#                                                                  0]',
#                                                                   'add_34_tool[0][0]']
#
#  add_35_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_chip[0][
#                                                                  0]',
#                                                                   'add_34_chip[0][0]']
#
#  conv2d_16_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_tool[0][0]']
#
#  conv2d_16_chip (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_chip[0][0]']
#
#  activation_32_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_16_tool[0][0]']
#  )
#
#  activation_32_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_16_chip[0][0]']
#  )
#
#  batch_normalization_32_tool (B  (None, 16, 16, 256)  1024       ['activation_32_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_32_chip (B  (None, 16, 16, 256)  1024       ['activation_32_chip[0][0]']
#  atchNormalization)
#
#  add_36_tool (Add)              (None, 16, 16, 256)  0           ['add_25_tool[0][0]',
#                                                                   'batch_normalization_32_tool[0][
#                                                                  0]']
#
#  add_36_chip (Add)              (None, 16, 16, 256)  0           ['add_25_chip[0][0]',
#                                                                   'batch_normalization_32_chip[0][
#                                                                  0]']
#
#  global_average_pooling2d_tool   (None, 256)         0           ['add_36_tool[0][0]']
#  (GlobalAveragePooling2D)
#
#  global_average_pooling2d_chip   (None, 256)         0           ['add_36_chip[0][0]']
#  (GlobalAveragePooling2D)
#
#  concatenate (Concatenate)      (None, 512)          0           ['global_average_pooling2d_tool[0
#                                                                  ][0]',
#                                                                   'global_average_pooling2d_chip[0
#                                                                  ][0]']
#
#  output_mult (Dense)            (None, 3)            1539        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 2,781,187
# Trainable params: 1,539
# Non-trainable params: 2,779,648
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2023-09-20 16:47:18.959908: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [14,256,256,3]
# 	 [[{{node Placeholder/_1}}]]
# 2023-09-20 16:47:18.960398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [14,3]
# 	 [[{{node Placeholder/_2}}]]
# 2023-09-20 16:47:29.253844: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2/2 [==============================] - ETA: 0s - loss: 2.9580 - accuracy: 0.5000
# 2023-09-20 16:47:30.263691: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,3]
# 	 [[{{node Placeholder/_2}}]]
# 2/2 [==============================] - 13s 2s/step - loss: 2.9580 - accuracy: 0.5000 - val_loss: 3.1286 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1.9016 - accuracy: 0.4286 - val_loss: 2.6703 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 2/2 [==============================] - 0s 71ms/step - loss: 1.8295 - accuracy: 0.3571 - val_loss: 1.8662 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.3555 - accuracy: 0.2857 - val_loss: 1.2352 - val_accuracy: 0.3333
# Epoch 5/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1.1118 - accuracy: 0.4286 - val_loss: 0.9115 - val_accuracy: 0.6667
# Epoch 6/100
# 2/2 [==============================] - 0s 62ms/step - loss: 1.2635 - accuracy: 0.2857 - val_loss: 0.8515 - val_accuracy: 0.6667
# Epoch 7/100
# 2/2 [==============================] - 0s 64ms/step - loss: 1.2656 - accuracy: 0.2857 - val_loss: 0.9564 - val_accuracy: 0.6667
# Epoch 8/100
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1538 - accuracy: 0.4286 - val_loss: 1.1799 - val_accuracy: 0.3333
# Epoch 9/100
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0402 - accuracy: 0.5000 - val_loss: 1.3363 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1.0290 - accuracy: 0.5714 - val_loss: 1.3817 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1.0476 - accuracy: 0.5000 - val_loss: 1.3768 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0186 - accuracy: 0.5000 - val_loss: 1.2455 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.9660 - accuracy: 0.5714 - val_loss: 1.1291 - val_accuracy: 0.6667
# Epoch 14/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.9210 - accuracy: 0.6429 - val_loss: 1.0752 - val_accuracy: 0.6667
# Epoch 15/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.9368 - accuracy: 0.5714 - val_loss: 1.0701 - val_accuracy: 0.6667
# Epoch 16/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9409 - accuracy: 0.5714 - val_loss: 1.1058 - val_accuracy: 0.6667
# Epoch 17/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.9209 - accuracy: 0.6429 - val_loss: 1.1477 - val_accuracy: 0.6667
# Epoch 18/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8895 - accuracy: 0.5714 - val_loss: 1.1872 - val_accuracy: 0.6667
# Epoch 19/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.8907 - accuracy: 0.5000 - val_loss: 1.2613 - val_accuracy: 0.3333
# Epoch 20/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.9076 - accuracy: 0.5000 - val_loss: 1.2743 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8925 - accuracy: 0.5714 - val_loss: 1.2180 - val_accuracy: 0.6667
# Epoch 22/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.8780 - accuracy: 0.5714 - val_loss: 1.1827 - val_accuracy: 0.6667
# Epoch 23/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.8671 - accuracy: 0.6429 - val_loss: 1.1641 - val_accuracy: 0.6667
# Epoch 24/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.8590 - accuracy: 0.6429 - val_loss: 1.1447 - val_accuracy: 0.6667
# Epoch 25/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.8427 - accuracy: 0.6429 - val_loss: 1.1125 - val_accuracy: 0.6667
# Epoch 26/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.8321 - accuracy: 0.5714 - val_loss: 1.1042 - val_accuracy: 0.6667
# Epoch 27/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8299 - accuracy: 0.5714 - val_loss: 1.0973 - val_accuracy: 0.6667
# Epoch 28/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.8257 - accuracy: 0.5714 - val_loss: 1.0975 - val_accuracy: 0.6667
# Epoch 29/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.8324 - accuracy: 0.5714 - val_loss: 1.1159 - val_accuracy: 0.6667
# Epoch 30/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.8184 - accuracy: 0.5714 - val_loss: 1.1043 - val_accuracy: 0.6667
# Epoch 31/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.8093 - accuracy: 0.5714 - val_loss: 1.0966 - val_accuracy: 0.6667
# Epoch 32/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.8166 - accuracy: 0.5714 - val_loss: 1.1120 - val_accuracy: 0.6667
# Epoch 33/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.7919 - accuracy: 0.6429 - val_loss: 1.1172 - val_accuracy: 0.6667
# Epoch 34/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.7881 - accuracy: 0.6429 - val_loss: 1.1134 - val_accuracy: 0.6667
# Epoch 35/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7931 - accuracy: 0.5714 - val_loss: 1.1060 - val_accuracy: 0.6667
# Epoch 36/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.7845 - accuracy: 0.5714 - val_loss: 1.1267 - val_accuracy: 0.6667
# Epoch 37/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.7916 - accuracy: 0.5714 - val_loss: 1.1521 - val_accuracy: 0.6667
# Epoch 38/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.8140 - accuracy: 0.6429 - val_loss: 1.1451 - val_accuracy: 0.6667
# Epoch 39/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7654 - accuracy: 0.7143 - val_loss: 1.1316 - val_accuracy: 0.6667
# Epoch 40/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.7743 - accuracy: 0.6429 - val_loss: 1.1178 - val_accuracy: 0.6667
# Epoch 41/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.7831 - accuracy: 0.6429 - val_loss: 1.1209 - val_accuracy: 0.6667
# Epoch 42/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.7732 - accuracy: 0.6429 - val_loss: 1.1666 - val_accuracy: 0.6667
# Epoch 43/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7632 - accuracy: 0.7143 - val_loss: 1.1599 - val_accuracy: 0.6667
# Epoch 44/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.7597 - accuracy: 0.7143 - val_loss: 1.1655 - val_accuracy: 0.6667
# Epoch 45/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7657 - accuracy: 0.7143 - val_loss: 1.1504 - val_accuracy: 0.6667
# Epoch 46/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.7595 - accuracy: 0.7143 - val_loss: 1.1506 - val_accuracy: 0.6667
# Epoch 47/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.7401 - accuracy: 0.7143 - val_loss: 1.1351 - val_accuracy: 0.6667
# Epoch 48/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.7372 - accuracy: 0.6429 - val_loss: 1.1179 - val_accuracy: 0.6667
# Epoch 49/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7648 - accuracy: 0.6429 - val_loss: 1.0843 - val_accuracy: 0.6667
# Epoch 50/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7414 - accuracy: 0.6429 - val_loss: 1.0871 - val_accuracy: 0.6667
# Epoch 51/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7298 - accuracy: 0.6429 - val_loss: 1.1067 - val_accuracy: 0.6667
# Epoch 52/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.7255 - accuracy: 0.7143 - val_loss: 1.1143 - val_accuracy: 0.6667
# Epoch 53/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.7671 - accuracy: 0.7143 - val_loss: 1.1377 - val_accuracy: 0.6667
# Epoch 54/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7490 - accuracy: 0.7143 - val_loss: 1.1233 - val_accuracy: 0.6667
# Epoch 55/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.7247 - accuracy: 0.7143 - val_loss: 1.0855 - val_accuracy: 0.6667
# Epoch 56/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.7253 - accuracy: 0.6429 - val_loss: 1.0628 - val_accuracy: 0.6667
# Epoch 57/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.7442 - accuracy: 0.6429 - val_loss: 1.0555 - val_accuracy: 0.6667
# Epoch 58/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.7371 - accuracy: 0.6429 - val_loss: 1.0547 - val_accuracy: 0.6667
# Epoch 59/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.7132 - accuracy: 0.6429 - val_loss: 1.0527 - val_accuracy: 0.6667
# Epoch 60/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.7252 - accuracy: 0.6429 - val_loss: 1.0568 - val_accuracy: 0.6667
# Epoch 61/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.7269 - accuracy: 0.7143 - val_loss: 1.0720 - val_accuracy: 0.6667
# Epoch 62/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.7111 - accuracy: 0.7143 - val_loss: 1.0947 - val_accuracy: 0.6667
# Epoch 63/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7109 - accuracy: 0.7143 - val_loss: 1.1216 - val_accuracy: 0.6667
# Epoch 64/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.7129 - accuracy: 0.7143 - val_loss: 1.1270 - val_accuracy: 0.6667
# Epoch 65/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.7025 - accuracy: 0.7143 - val_loss: 1.1069 - val_accuracy: 0.6667
# Epoch 66/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6955 - accuracy: 0.7143 - val_loss: 1.0837 - val_accuracy: 0.6667
# Epoch 67/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6957 - accuracy: 0.6429 - val_loss: 1.0650 - val_accuracy: 0.6667
# Epoch 68/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7157 - accuracy: 0.6429 - val_loss: 1.0606 - val_accuracy: 0.6667
# Epoch 69/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.7035 - accuracy: 0.6429 - val_loss: 1.0691 - val_accuracy: 0.6667
# Epoch 70/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6991 - accuracy: 0.6429 - val_loss: 1.0921 - val_accuracy: 0.6667
# Epoch 71/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.7082 - accuracy: 0.6429 - val_loss: 1.1057 - val_accuracy: 0.6667
# Epoch 72/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6968 - accuracy: 0.7143 - val_loss: 1.1284 - val_accuracy: 0.6667
# Epoch 73/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.6988 - accuracy: 0.6429 - val_loss: 1.1257 - val_accuracy: 0.6667
# Epoch 74/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6992 - accuracy: 0.6429 - val_loss: 1.1351 - val_accuracy: 0.6667
# Epoch 75/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6985 - accuracy: 0.6429 - val_loss: 1.1350 - val_accuracy: 0.6667
# Epoch 76/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6905 - accuracy: 0.6429 - val_loss: 1.1018 - val_accuracy: 0.6667
# Epoch 77/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6794 - accuracy: 0.6429 - val_loss: 1.0842 - val_accuracy: 0.6667
# Epoch 78/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7113 - accuracy: 0.6429 - val_loss: 1.0793 - val_accuracy: 0.6667
# Epoch 79/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7020 - accuracy: 0.6429 - val_loss: 1.0621 - val_accuracy: 0.6667
# Epoch 80/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6868 - accuracy: 0.7143 - val_loss: 1.0732 - val_accuracy: 0.6667
# Epoch 81/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6800 - accuracy: 0.7143 - val_loss: 1.0862 - val_accuracy: 0.6667
# Epoch 82/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6669 - accuracy: 0.7143 - val_loss: 1.1138 - val_accuracy: 0.6667
# Epoch 83/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6946 - accuracy: 0.6429 - val_loss: 1.1424 - val_accuracy: 0.6667
# Epoch 84/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7063 - accuracy: 0.5714 - val_loss: 1.1218 - val_accuracy: 0.6667
# Epoch 85/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6796 - accuracy: 0.6429 - val_loss: 1.1042 - val_accuracy: 0.6667
# Epoch 86/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.6950 - accuracy: 0.6429 - val_loss: 1.0729 - val_accuracy: 0.6667
# Epoch 87/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6868 - accuracy: 0.6429 - val_loss: 1.0540 - val_accuracy: 0.6667
# Epoch 88/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.6685 - accuracy: 0.6429 - val_loss: 1.0586 - val_accuracy: 0.6667
# Epoch 89/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6850 - accuracy: 0.7143 - val_loss: 1.0706 - val_accuracy: 0.6667
# Epoch 90/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6734 - accuracy: 0.7143 - val_loss: 1.0796 - val_accuracy: 0.6667
# Epoch 91/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6673 - accuracy: 0.7143 - val_loss: 1.0897 - val_accuracy: 0.6667
# Epoch 92/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6628 - accuracy: 0.6429 - val_loss: 1.0955 - val_accuracy: 0.6667
# Epoch 93/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6657 - accuracy: 0.6429 - val_loss: 1.0983 - val_accuracy: 0.6667
# Epoch 94/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6828 - accuracy: 0.6429 - val_loss: 1.0977 - val_accuracy: 0.6667
# Epoch 95/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6653 - accuracy: 0.6429 - val_loss: 1.0850 - val_accuracy: 0.6667
# Epoch 96/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6557 - accuracy: 0.6429 - val_loss: 1.0803 - val_accuracy: 0.6667
# Epoch 97/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6788 - accuracy: 0.6429 - val_loss: 1.0846 - val_accuracy: 0.6667
# Epoch 98/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6679 - accuracy: 0.6429 - val_loss: 1.1020 - val_accuracy: 0.6667
# Epoch 99/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6624 - accuracy: 0.6429 - val_loss: 1.1146 - val_accuracy: 0.6667
# Epoch 100/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6686 - accuracy: 0.6429 - val_loss: 1.1249 - val_accuracy: 0.6667
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1682 - accuracy: 0.6667
# Test accuracy: 66.67%
# 2023-09-20 16:47:43.594910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype float and shape [3,3]
# 	 [[{{node Placeholder/_2}}]]

# %%
model.save(model_save_path)

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("model accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
x_test = test_ds
y_test = labels_test
y_score = model.predict(x_test)
y_test = y_test

n_classes = num_classes
# Plot linewidth.
lw = 2
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})" "".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})" "".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})" "".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic multi-class")
plt.legend(loc="lower right")
plt.show()
# Out:
# 1/1 [==============================] - 0s 33ms/step
# /tmp/ipykernel_4169483/1739064555.py:27: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %%
y_classes = np.argmax(y_score, axis=1)
labels_test_f1 = np.argmax(y_test, axis=1)

print(metrics.confusion_matrix(labels_test_f1, y_classes))
print(classification_report(labels_test_f1, y_classes))
# Out:
# [[1 0 0]
#  [0 0 1]
#  [0 0 1]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       0.00      0.00      0.00         1
#            2       0.50      1.00      0.67         1
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.67      0.56         3
# weighted avg       0.50      0.67      0.56         3
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fpr, tpr, thresholds = metrics.roc_curve(labels_test_f1, y_classes, pos_label=2)
print("AUC: ", metrics.auc(fpr, tpr))
# Out:
# AUC:  0.75
