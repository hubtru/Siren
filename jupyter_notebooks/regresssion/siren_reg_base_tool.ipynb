# %%
# !pip install tensorflow_addons
# !pip install keras-tuner --upgrade

# clone siren repository, refresh folder to see the siren repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Siren/
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5
# Cloning into 'Siren'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 313 (delta 9), reused 7 (delta 2), pack-reused 297
# Receiving objects: 100% (313/313), 57.54 MiB | 34.82 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
# architecture
image_size = 256
filters = 256
depth = 4
columns = 4
kernel_size = 5
patch_size = 16
num_classes = 3

in_channel = 3
img_rows, img_cols = image_size, image_size
input_shape = (img_rows, img_cols, in_channel)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "tool"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

# dataset
csv_path = "/content/Siren/dataset/labels_reg_sample.csv"
tool_path = f"/content/Siren/dataset/{modality}"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chips/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                        tool
# 14   /content/Siren/dataset/tool/T8R3B4.jpg
# 10   /content/Siren/dataset/tool/T6R9B3.jpg
# 0    /content/Siren/dataset/tool/T1R2B1.jpg
# 3   /content/Siren/dataset/tool/T2R13B4.jpg
# 1    /content/Siren/dataset/tool/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                        tool
# 16   /content/Siren/dataset/tool/T9R7B4.jpg
# 18  /content/Siren/dataset/tool/T10R3B4.jpg
# 9   /content/Siren/dataset/tool/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                        tool
# 5   /content/Siren/dataset/tool/T3R10B1.jpg
# 13  /content/Siren/dataset/tool/T7R14B3.jpg
# 12   /content/Siren/dataset/tool/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_tool, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_tool, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_tool, labels_val))

# %%
# ============================== augment ==============================
auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation",
)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
#Functions
#Reversed Column implementation of Truchan (2023). Minape: Multimodal Isotropic Neural Architecture with Patch Embedding.
#https://github.com/hubtru/minape
def activation_module(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def base_module(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_module(x)


def depth_point_module(
    x, pe_block, column, level, depth, r_arr, filters: int, kernel_size: int
):
    if column == 0:
        # Depthwise convolution.
        x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        r_arr = reverasable_output_array(x, r_arr, column, level)
        return x, r_arr
    else:
        if level == 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], pe_block)
        elif level < len(r_arr[0]) - 1 and level != 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], x)
        else:
            x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x0)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        if column != 0:
            x = fusion_block_double(r_arr[column - 1][level], x)

        r_arr = reverasable_output_array(x, r_arr, column, level)

        return x, r_arr


def fusion_block_double(x, y):
    return layers.Add()([x, y])


def reverasable_output_array(x, r_arr, column, level):
    r_arr[column][level] = x
    return r_arr


def load_siren(
    image_size=image_size,
    filters=filters,
    depth=depth,
    columns=columns,
    kernel_size=kernel_size,
    patch_size=patch_size,
    num_classes=num_classes,
):
    r_arr = [[None for _ in range(depth)] for _ in range(columns)]

    inputs = k.Input(input_shape)
    # x = layers.Rescaling(scale=1.0 / 255)(inputs)         # already rescaled

    # Extract patch embeddings.
    x = base_module(inputs, filters, patch_size)
    pe_block = x

    # Siren blocks.
    for column in range(columns):
        for level in range(depth):
            x, r_arr = depth_point_module(
                x, pe_block, column, level, depth, r_arr, filters, kernel_size
            )

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="linear")(x)

    return k.Model(inputs, outputs)

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 16, 16, 256)          196864    ['input_1[0][0]']
#
#  activation (Activation)     (None, 16, 16, 256)          0         ['conv2d[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 256)          1024      ['activation[0][0]']
#  Normalization)
#
#  depthwise_conv2d (Depthwis  (None, 16, 16, 256)          6656      ['batch_normalization[0][0]']
#  eConv2D)
#
#  activation_1 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 16, 256)          1024      ['activation_1[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 16, 16, 256)          0         ['batch_normalization_1[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)          65792     ['add[0][0]']
#
#  activation_2 (Activation)   (None, 16, 16, 256)          0         ['conv2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 16, 256)          1024      ['activation_2[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_1 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_2[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_3 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 16, 256)          1024      ['activation_3[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_2[0][0]
#                                                                     ']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)          65792     ['add_1[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 256)          0         ['conv2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 16, 16, 256)          1024      ['activation_4[0][0]']
#  chNormalization)
#
#  add_4 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  depthwise_conv2d_4 (Depthw  (None, 16, 16, 256)          6656      ['add_4[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_2 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_4[0][0]']
#
#  activation_5 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 256)          1024      ['activation_9[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 16, 16, 256)          1024      ['activation_5[0][0]']
#  chNormalization)
#
#  add_5 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     , 'add_4[0][0]']
#
#  add_2 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)          65792     ['add_5[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)          65792     ['add_2[0][0]']
#
#  activation_10 (Activation)  (None, 16, 16, 256)          0         ['conv2d_5[0][0]']
#
#  activation_6 (Activation)   (None, 16, 16, 256)          0         ['conv2d_3[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 256)          1024      ['activation_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_6 (Bat  (None, 16, 16, 256)          1024      ['activation_6[0][0]']
#  chNormalization)
#
#  add_6 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_2[0][0]'
#                                                                     , 'batch_normalization_10[0][0
#                                                                     ]']
#
#  add_7 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'add_6[0][0]']
#
#  depthwise_conv2d_5 (Depthw  (None, 16, 16, 256)          6656      ['add_7[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_3 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_6[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_11 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_5[0][0]']
#
#  activation_7 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_3[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 256)          1024      ['activation_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_7 (Bat  (None, 16, 16, 256)          1024      ['activation_7[0][0]']
#  chNormalization)
#
#  add_8 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  add_3 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)          65792     ['add_8[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          65792     ['add_3[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 256)          0         ['conv2d_6[0][0]']
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['conv2d_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 256)          1024      ['activation_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_8 (Bat  (None, 16, 16, 256)          1024      ['activation_8[0][0]']
#  chNormalization)
#
#  add_9 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization_12[0][0
#                                                                     ]']
#
#  add_10 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'add_9[0][0]']
#
#  add_15 (Add)                (None, 16, 16, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_6 (Depthw  (None, 16, 16, 256)          6656      ['add_10[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_8 (Depthw  (None, 16, 16, 256)          6656      ['add_15[0][0]']
#  iseConv2D)
#
#  activation_13 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_6[0][0]']
#
#  activation_17 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_8[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 256)          1024      ['activation_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 16, 16, 256)          1024      ['activation_17[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'add_10[0][0]']
#
#  add_16 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 256)          65792     ['add_11[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          65792     ['add_16[0][0]']
#
#  activation_14 (Activation)  (None, 16, 16, 256)          0         ['conv2d_7[0][0]']
#
#  activation_18 (Activation)  (None, 16, 16, 256)          0         ['conv2d_9[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 256)          1024      ['activation_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 16, 16, 256)          1024      ['activation_18[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_14[0][0
#                                                                     ]']
#
#  add_17 (Add)                (None, 16, 16, 256)          0         ['add_6[0][0]',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 16, 16, 256)          0         ['add_12[0][0]',
#                                                                      'add_17[0][0]']
#
#  depthwise_conv2d_7 (Depthw  (None, 16, 16, 256)          6656      ['add_12[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_9 (Depthw  (None, 16, 16, 256)          6656      ['add_18[0][0]']
#  iseConv2D)
#
#  activation_15 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_7[0][0]']
#
#  activation_19 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_9[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 256)          1024      ['activation_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 16, 16, 256)          1024      ['activation_19[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'add_12[0][0]']
#
#  add_19 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'add_18[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          65792     ['add_13[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)          65792     ['add_19[0][0]']
#
#  activation_16 (Activation)  (None, 16, 16, 256)          0         ['conv2d_8[0][0]']
#
#  activation_20 (Activation)  (None, 16, 16, 256)          0         ['conv2d_10[0][0]']
#
#  batch_normalization_16 (Ba  (None, 16, 16, 256)          1024      ['activation_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 16, 16, 256)          1024      ['activation_20[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_16[0][0
#                                                                     ]']
#
#  add_20 (Add)                (None, 16, 16, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization_20[0][0]
#                                                                     ']
#
#  add_21 (Add)                (None, 16, 16, 256)          0         ['add_14[0][0]',
#                                                                      'add_20[0][0]']
#
#  add_26 (Add)                (None, 16, 16, 256)          0         ['add_20[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_10 (Depth  (None, 16, 16, 256)          6656      ['add_21[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_12 (Depth  (None, 16, 16, 256)          6656      ['add_26[0][0]']
#  wiseConv2D)
#
#  activation_21 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_10[0][0]']
#
#  activation_25 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_12[0][0]']
#
#  batch_normalization_21 (Ba  (None, 16, 16, 256)          1024      ['activation_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 16, 16, 256)          1024      ['activation_25[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'add_21[0][0]']
#
#  add_27 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ',
#                                                                      'add_26[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)          65792     ['add_22[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 256)          65792     ['add_27[0][0]']
#
#  activation_22 (Activation)  (None, 16, 16, 256)          0         ['conv2d_11[0][0]']
#
#  activation_26 (Activation)  (None, 16, 16, 256)          0         ['conv2d_13[0][0]']
#
#  batch_normalization_22 (Ba  (None, 16, 16, 256)          1024      ['activation_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 16, 16, 256)          1024      ['activation_26[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 16, 16, 256)          0         ['add_12[0][0]',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  add_28 (Add)                (None, 16, 16, 256)          0         ['add_17[0][0]',
#                                                                      'batch_normalization_26[0][0]
#                                                                     ']
#
#  add_29 (Add)                (None, 16, 16, 256)          0         ['add_23[0][0]',
#                                                                      'add_28[0][0]']
#
#  depthwise_conv2d_11 (Depth  (None, 16, 16, 256)          6656      ['add_23[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_13 (Depth  (None, 16, 16, 256)          6656      ['add_29[0][0]']
#  wiseConv2D)
#
#  activation_23 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_11[0][0]']
#
#  activation_27 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_13[0][0]']
#
#  batch_normalization_23 (Ba  (None, 16, 16, 256)          1024      ['activation_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 16, 16, 256)          1024      ['activation_27[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'add_23[0][0]']
#
#  add_30 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'add_29[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 256)          65792     ['add_24[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)          65792     ['add_30[0][0]']
#
#  activation_24 (Activation)  (None, 16, 16, 256)          0         ['conv2d_12[0][0]']
#
#  activation_28 (Activation)  (None, 16, 16, 256)          0         ['conv2d_14[0][0]']
#
#  batch_normalization_24 (Ba  (None, 16, 16, 256)          1024      ['activation_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 16, 16, 256)          1024      ['activation_28[0][0]']
#  tchNormalization)
#
#  add_25 (Add)                (None, 16, 16, 256)          0         ['add_14[0][0]',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ']
#
#  add_31 (Add)                (None, 16, 16, 256)          0         ['add_20[0][0]',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  add_32 (Add)                (None, 16, 16, 256)          0         ['add_25[0][0]',
#                                                                      'add_31[0][0]']
#
#  depthwise_conv2d_14 (Depth  (None, 16, 16, 256)          6656      ['add_32[0][0]']
#  wiseConv2D)
#
#  activation_29 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_14[0][0]']
#
#  batch_normalization_29 (Ba  (None, 16, 16, 256)          1024      ['activation_29[0][0]']
#  tchNormalization)
#
#  add_33 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'add_32[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 256)          65792     ['add_33[0][0]']
#
#  activation_30 (Activation)  (None, 16, 16, 256)          0         ['conv2d_15[0][0]']
#
#  batch_normalization_30 (Ba  (None, 16, 16, 256)          1024      ['activation_30[0][0]']
#  tchNormalization)
#
#  add_34 (Add)                (None, 16, 16, 256)          0         ['add_23[0][0]',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  depthwise_conv2d_15 (Depth  (None, 16, 16, 256)          6656      ['add_34[0][0]']
#  wiseConv2D)
#
#  activation_31 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_15[0][0]']
#
#  batch_normalization_31 (Ba  (None, 16, 16, 256)          1024      ['activation_31[0][0]']
#  tchNormalization)
#
#  add_35 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ',
#                                                                      'add_34[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 256)          65792     ['add_35[0][0]']
#
#  activation_32 (Activation)  (None, 16, 16, 256)          0         ['conv2d_16[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 16, 256)          1024      ['activation_32[0][0]']
#  tchNormalization)
#
#  add_36 (Add)                (None, 16, 16, 256)          0         ['add_25[0][0]',
#                                                                      'batch_normalization_32[0][0]
#                                                                     ']
#
#  global_average_pooling2d (  (None, 256)                  0         ['add_36[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                    771       ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 1390595 (5.30 MB)
# Trainable params: 1373699 (5.24 MB)
# Non-trainable params: 16896 (66.00 KB)
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 29s 6s/step - loss: 3898.2791 - mean_squared_error: 3898.2791 - val_loss: 4819.1206 - val_mean_squared_error: 4819.1206
# Epoch 2/100
# 2/2 [==============================] - 4s 1s/step - loss: 3927.1121 - mean_squared_error: 3927.1121 - val_loss: 4621.7583 - val_mean_squared_error: 4621.7583
# Epoch 3/100
# 2/2 [==============================] - 3s 2s/step - loss: 3876.1863 - mean_squared_error: 3876.1863 - val_loss: 4543.6494 - val_mean_squared_error: 4543.6494
# Epoch 4/100
# 2/2 [==============================] - 2s 789ms/step - loss: 3780.7778 - mean_squared_error: 3780.7778 - val_loss: 4833.8657 - val_mean_squared_error: 4833.8657
# Epoch 5/100
# 2/2 [==============================] - 2s 823ms/step - loss: 3935.1814 - mean_squared_error: 3935.1814 - val_loss: 5077.1016 - val_mean_squared_error: 5077.1016
# Epoch 6/100
# 2/2 [==============================] - 2s 787ms/step - loss: 3735.0725 - mean_squared_error: 3735.0725 - val_loss: 4996.9517 - val_mean_squared_error: 4996.9517
# Epoch 7/100
# 2/2 [==============================] - 2s 813ms/step - loss: 3820.1272 - mean_squared_error: 3820.1272 - val_loss: 4970.1899 - val_mean_squared_error: 4970.1899
# Epoch 8/100
# 2/2 [==============================] - 1s 658ms/step - loss: 3579.4419 - mean_squared_error: 3579.4419 - val_loss: 4923.7759 - val_mean_squared_error: 4923.7759
# Epoch 9/100
# 2/2 [==============================] - 2s 793ms/step - loss: 3608.5974 - mean_squared_error: 3608.5974 - val_loss: 4648.1958 - val_mean_squared_error: 4648.1958
# Epoch 10/100
# 2/2 [==============================] - 3s 1s/step - loss: 3574.2170 - mean_squared_error: 3574.2170 - val_loss: 4371.9956 - val_mean_squared_error: 4371.9956
# Epoch 11/100
# 2/2 [==============================] - 2s 734ms/step - loss: 3358.8762 - mean_squared_error: 3358.8762 - val_loss: 3949.0212 - val_mean_squared_error: 3949.0212
# Epoch 12/100
# 2/2 [==============================] - 2s 770ms/step - loss: 3529.8772 - mean_squared_error: 3529.8772 - val_loss: 3662.8040 - val_mean_squared_error: 3662.8040
# Epoch 13/100
# 2/2 [==============================] - 2s 784ms/step - loss: 3318.0715 - mean_squared_error: 3318.0715 - val_loss: 3690.3796 - val_mean_squared_error: 3690.3796
# Epoch 14/100
# 2/2 [==============================] - 2s 788ms/step - loss: 3612.2244 - mean_squared_error: 3612.2244 - val_loss: 3693.9500 - val_mean_squared_error: 3693.9500
# Epoch 15/100
# 2/2 [==============================] - 2s 710ms/step - loss: 3275.0190 - mean_squared_error: 3275.0190 - val_loss: 3524.2627 - val_mean_squared_error: 3524.2627
# Epoch 16/100
# 2/2 [==============================] - 2s 1s/step - loss: 3346.2712 - mean_squared_error: 3346.2712 - val_loss: 3358.7842 - val_mean_squared_error: 3358.7842
# Epoch 17/100
# 2/2 [==============================] - 2s 790ms/step - loss: 3312.8281 - mean_squared_error: 3312.8281 - val_loss: 3365.1355 - val_mean_squared_error: 3365.1355
# Epoch 18/100
# 2/2 [==============================] - 2s 792ms/step - loss: 3448.7974 - mean_squared_error: 3448.7974 - val_loss: 3671.6025 - val_mean_squared_error: 3671.6025
# Epoch 19/100
# 2/2 [==============================] - 1s 724ms/step - loss: 3220.9258 - mean_squared_error: 3220.9258 - val_loss: 3863.4783 - val_mean_squared_error: 3863.4783
# Epoch 20/100
# 2/2 [==============================] - 2s 729ms/step - loss: 3136.0845 - mean_squared_error: 3136.0845 - val_loss: 4025.6270 - val_mean_squared_error: 4025.6270
# Epoch 21/100
# 2/2 [==============================] - 2s 1s/step - loss: 3032.4993 - mean_squared_error: 3032.4993 - val_loss: 4170.0195 - val_mean_squared_error: 4170.0195
# Epoch 22/100
# 2/2 [==============================] - 2s 1s/step - loss: 2988.6785 - mean_squared_error: 2988.6785 - val_loss: 4302.5522 - val_mean_squared_error: 4302.5522
# Epoch 23/100
# 2/2 [==============================] - 2s 728ms/step - loss: 3127.1519 - mean_squared_error: 3127.1519 - val_loss: 4489.3228 - val_mean_squared_error: 4489.3228
# Epoch 24/100
# 2/2 [==============================] - 2s 707ms/step - loss: 2996.0249 - mean_squared_error: 2996.0249 - val_loss: 4726.9600 - val_mean_squared_error: 4726.9600
# Epoch 25/100
# 2/2 [==============================] - 2s 746ms/step - loss: 3178.5647 - mean_squared_error: 3178.5647 - val_loss: 5070.4800 - val_mean_squared_error: 5070.4800
# Epoch 26/100
# 2/2 [==============================] - 2s 1s/step - loss: 2962.4375 - mean_squared_error: 2962.4375 - val_loss: 5182.2549 - val_mean_squared_error: 5182.2549
# Epoch 27/100
# 2/2 [==============================] - 2s 750ms/step - loss: 3029.5056 - mean_squared_error: 3029.5056 - val_loss: 5352.1470 - val_mean_squared_error: 5352.1470
# Epoch 28/100
# 2/2 [==============================] - 2s 1s/step - loss: 3087.0676 - mean_squared_error: 3087.0676 - val_loss: 5213.3735 - val_mean_squared_error: 5213.3735
# Epoch 29/100
# 2/2 [==============================] - 2s 749ms/step - loss: 2910.6133 - mean_squared_error: 2910.6133 - val_loss: 5199.8633 - val_mean_squared_error: 5199.8633
# Epoch 30/100
# 2/2 [==============================] - 2s 732ms/step - loss: 2784.4844 - mean_squared_error: 2784.4844 - val_loss: 5012.1284 - val_mean_squared_error: 5012.1284
# Epoch 31/100
# 2/2 [==============================] - 2s 731ms/step - loss: 3016.1177 - mean_squared_error: 3016.1177 - val_loss: 5062.9819 - val_mean_squared_error: 5062.9819
# Epoch 32/100
# 2/2 [==============================] - 2s 791ms/step - loss: 2848.4983 - mean_squared_error: 2848.4983 - val_loss: 5343.6519 - val_mean_squared_error: 5343.6519
# Epoch 33/100
# 2/2 [==============================] - 1s 726ms/step - loss: 2789.3284 - mean_squared_error: 2789.3284 - val_loss: 4992.9028 - val_mean_squared_error: 4992.9028
# Epoch 34/100
# 2/2 [==============================] - 1s 697ms/step - loss: 2632.2771 - mean_squared_error: 2632.2771 - val_loss: 4639.2988 - val_mean_squared_error: 4639.2988
# Epoch 35/100
# 2/2 [==============================] - 2s 729ms/step - loss: 2717.9790 - mean_squared_error: 2717.9790 - val_loss: 4675.0317 - val_mean_squared_error: 4675.0317
# Epoch 36/100
# 2/2 [==============================] - 2s 855ms/step - loss: 2700.6597 - mean_squared_error: 2700.6597 - val_loss: 5017.6279 - val_mean_squared_error: 5017.6279
# Epoch 37/100
# 2/2 [==============================] - 2s 1s/step - loss: 2537.1877 - mean_squared_error: 2537.1877 - val_loss: 5286.0737 - val_mean_squared_error: 5286.0737
# Epoch 38/100
# 2/2 [==============================] - 2s 818ms/step - loss: 2594.0242 - mean_squared_error: 2594.0242 - val_loss: 5706.9282 - val_mean_squared_error: 5706.9282
# Epoch 39/100
# 2/2 [==============================] - 2s 746ms/step - loss: 2485.9714 - mean_squared_error: 2485.9714 - val_loss: 5628.4214 - val_mean_squared_error: 5628.4214
# Epoch 40/100
# 2/2 [==============================] - 2s 1s/step - loss: 2684.9731 - mean_squared_error: 2684.9731 - val_loss: 4859.9893 - val_mean_squared_error: 4859.9893
# Epoch 41/100
# 2/2 [==============================] - 2s 710ms/step - loss: 2553.8796 - mean_squared_error: 2553.8796 - val_loss: 3655.7568 - val_mean_squared_error: 3655.7568
# Epoch 42/100
# 2/2 [==============================] - 2s 925ms/step - loss: 2617.8376 - mean_squared_error: 2617.8376 - val_loss: 3379.3938 - val_mean_squared_error: 3379.3938
# Epoch 43/100
# 2/2 [==============================] - 2s 771ms/step - loss: 2414.9275 - mean_squared_error: 2414.9275 - val_loss: 3306.6982 - val_mean_squared_error: 3306.6982
# Epoch 44/100
# 2/2 [==============================] - 1s 719ms/step - loss: 2401.8359 - mean_squared_error: 2401.8359 - val_loss: 3118.4705 - val_mean_squared_error: 3118.4705
# Epoch 45/100
# 2/2 [==============================] - 2s 708ms/step - loss: 2452.6057 - mean_squared_error: 2452.6057 - val_loss: 2849.2917 - val_mean_squared_error: 2849.2917
# Epoch 46/100
# 2/2 [==============================] - 2s 778ms/step - loss: 2352.7397 - mean_squared_error: 2352.7397 - val_loss: 2607.4587 - val_mean_squared_error: 2607.4587
# Epoch 47/100
# 2/2 [==============================] - 2s 1s/step - loss: 2398.8254 - mean_squared_error: 2398.8254 - val_loss: 2569.2627 - val_mean_squared_error: 2569.2627
# Epoch 48/100
# 2/2 [==============================] - 2s 815ms/step - loss: 2321.0134 - mean_squared_error: 2321.0134 - val_loss: 2441.3389 - val_mean_squared_error: 2441.3389
# Epoch 49/100
# 2/2 [==============================] - 2s 758ms/step - loss: 2214.2463 - mean_squared_error: 2214.2463 - val_loss: 2283.9915 - val_mean_squared_error: 2283.9915
# Epoch 50/100
# 2/2 [==============================] - 2s 716ms/step - loss: 2329.8491 - mean_squared_error: 2329.8491 - val_loss: 2179.7666 - val_mean_squared_error: 2179.7666
# Epoch 51/100
# 2/2 [==============================] - 2s 685ms/step - loss: 2107.1880 - mean_squared_error: 2107.1880 - val_loss: 2008.1510 - val_mean_squared_error: 2008.1510
# Epoch 52/100
# 2/2 [==============================] - 2s 762ms/step - loss: 2131.4019 - mean_squared_error: 2131.4019 - val_loss: 1942.5009 - val_mean_squared_error: 1942.5009
# Epoch 53/100
# 2/2 [==============================] - 2s 1s/step - loss: 2048.0969 - mean_squared_error: 2048.0969 - val_loss: 1799.7490 - val_mean_squared_error: 1799.7490
# Epoch 54/100
# 2/2 [==============================] - 2s 728ms/step - loss: 2217.7507 - mean_squared_error: 2217.7507 - val_loss: 1980.3265 - val_mean_squared_error: 1980.3265
# Epoch 55/100
# 2/2 [==============================] - 2s 788ms/step - loss: 2046.6975 - mean_squared_error: 2046.6975 - val_loss: 2107.7041 - val_mean_squared_error: 2107.7041
# Epoch 56/100
# 2/2 [==============================] - 2s 799ms/step - loss: 2033.6222 - mean_squared_error: 2033.6222 - val_loss: 2089.1287 - val_mean_squared_error: 2089.1287
# Epoch 57/100
# 2/2 [==============================] - 2s 800ms/step - loss: 1891.3263 - mean_squared_error: 1891.3263 - val_loss: 2061.6755 - val_mean_squared_error: 2061.6755
# Epoch 58/100
# 2/2 [==============================] - 2s 693ms/step - loss: 1859.2819 - mean_squared_error: 1859.2819 - val_loss: 1967.4965 - val_mean_squared_error: 1967.4965
# Epoch 59/100
# 2/2 [==============================] - 2s 1s/step - loss: 1870.7825 - mean_squared_error: 1870.7825 - val_loss: 1849.1974 - val_mean_squared_error: 1849.1974
# Epoch 60/100
# 2/2 [==============================] - 2s 701ms/step - loss: 1815.9453 - mean_squared_error: 1815.9453 - val_loss: 1807.6996 - val_mean_squared_error: 1807.6996
# Epoch 61/100
# 2/2 [==============================] - 2s 747ms/step - loss: 1934.4052 - mean_squared_error: 1934.4052 - val_loss: 1780.5118 - val_mean_squared_error: 1780.5118
# Epoch 62/100
# 2/2 [==============================] - 1s 664ms/step - loss: 1674.3672 - mean_squared_error: 1674.3672 - val_loss: 1679.5011 - val_mean_squared_error: 1679.5011
# Epoch 63/100
# 2/2 [==============================] - 2s 720ms/step - loss: 1765.4690 - mean_squared_error: 1765.4690 - val_loss: 1524.0488 - val_mean_squared_error: 1524.0488
# Epoch 64/100
# 2/2 [==============================] - 2s 743ms/step - loss: 1660.4310 - mean_squared_error: 1660.4310 - val_loss: 1500.2534 - val_mean_squared_error: 1500.2534
# Epoch 65/100
# 2/2 [==============================] - 2s 1s/step - loss: 1689.6757 - mean_squared_error: 1689.6757 - val_loss: 1485.3661 - val_mean_squared_error: 1485.3661
# Epoch 66/100
# 2/2 [==============================] - 2s 684ms/step - loss: 1589.3602 - mean_squared_error: 1589.3602 - val_loss: 1511.1332 - val_mean_squared_error: 1511.1332
# Epoch 67/100
# 2/2 [==============================] - 1s 656ms/step - loss: 1541.4023 - mean_squared_error: 1541.4023 - val_loss: 1478.1417 - val_mean_squared_error: 1478.1417
# Epoch 68/100
# 2/2 [==============================] - 1s 682ms/step - loss: 1577.4542 - mean_squared_error: 1577.4542 - val_loss: 1408.2085 - val_mean_squared_error: 1408.2085
# Epoch 69/100
# 2/2 [==============================] - 2s 794ms/step - loss: 1532.5752 - mean_squared_error: 1532.5752 - val_loss: 1433.9995 - val_mean_squared_error: 1433.9995
# Epoch 70/100
# 2/2 [==============================] - 1s 711ms/step - loss: 1439.2031 - mean_squared_error: 1439.2031 - val_loss: 1366.0850 - val_mean_squared_error: 1366.0850
# Epoch 71/100
# 2/2 [==============================] - 3s 1s/step - loss: 1384.2451 - mean_squared_error: 1384.2451 - val_loss: 1307.7067 - val_mean_squared_error: 1307.7067
# Epoch 72/100
# 2/2 [==============================] - 2s 763ms/step - loss: 1413.7704 - mean_squared_error: 1413.7704 - val_loss: 1284.5986 - val_mean_squared_error: 1284.5986
# Epoch 73/100
# 2/2 [==============================] - 2s 794ms/step - loss: 1346.7089 - mean_squared_error: 1346.7089 - val_loss: 1290.4573 - val_mean_squared_error: 1290.4573
# Epoch 74/100
# 2/2 [==============================] - 2s 800ms/step - loss: 1272.5792 - mean_squared_error: 1272.5792 - val_loss: 1378.3729 - val_mean_squared_error: 1378.3729
# Epoch 75/100
# 2/2 [==============================] - 2s 798ms/step - loss: 1323.9406 - mean_squared_error: 1323.9406 - val_loss: 1368.8756 - val_mean_squared_error: 1368.8756
# Epoch 76/100
# 2/2 [==============================] - 2s 754ms/step - loss: 1289.9391 - mean_squared_error: 1289.9391 - val_loss: 1369.5630 - val_mean_squared_error: 1369.5630
# Epoch 77/100
# 2/2 [==============================] - 2s 742ms/step - loss: 1179.9862 - mean_squared_error: 1179.9862 - val_loss: 1431.5898 - val_mean_squared_error: 1431.5898
# Epoch 78/100
# 2/2 [==============================] - 2s 723ms/step - loss: 1225.2122 - mean_squared_error: 1225.2122 - val_loss: 1514.9219 - val_mean_squared_error: 1514.9219
# Epoch 79/100
# 2/2 [==============================] - 2s 802ms/step - loss: 1266.7279 - mean_squared_error: 1266.7279 - val_loss: 1522.3804 - val_mean_squared_error: 1522.3804
# Epoch 80/100
# 2/2 [==============================] - 2s 745ms/step - loss: 1166.4979 - mean_squared_error: 1166.4979 - val_loss: 1511.3973 - val_mean_squared_error: 1511.3973
# Epoch 81/100
# 2/2 [==============================] - 2s 1s/step - loss: 1202.1584 - mean_squared_error: 1202.1584 - val_loss: 1509.1089 - val_mean_squared_error: 1509.1089
# Epoch 82/100
# 2/2 [==============================] - 2s 793ms/step - loss: 1005.1500 - mean_squared_error: 1005.1500 - val_loss: 1521.6068 - val_mean_squared_error: 1521.6068
# Epoch 83/100
# 2/2 [==============================] - 2s 1s/step - loss: 1004.6151 - mean_squared_error: 1004.6151 - val_loss: 1458.9769 - val_mean_squared_error: 1458.9769
# Epoch 84/100
# 2/2 [==============================] - 2s 742ms/step - loss: 921.5532 - mean_squared_error: 921.5532 - val_loss: 1331.4935 - val_mean_squared_error: 1331.4935
# Epoch 85/100
# 2/2 [==============================] - 2s 715ms/step - loss: 973.6354 - mean_squared_error: 973.6354 - val_loss: 1284.9058 - val_mean_squared_error: 1284.9058
# Epoch 86/100
# 2/2 [==============================] - 2s 780ms/step - loss: 929.8153 - mean_squared_error: 929.8153 - val_loss: 1213.8405 - val_mean_squared_error: 1213.8405
# Epoch 87/100
# 2/2 [==============================] - 2s 964ms/step - loss: 945.2618 - mean_squared_error: 945.2618 - val_loss: 1218.0250 - val_mean_squared_error: 1218.0250
# Epoch 88/100
# 2/2 [==============================] - 2s 1s/step - loss: 874.6370 - mean_squared_error: 874.6370 - val_loss: 1263.8615 - val_mean_squared_error: 1263.8615
# Epoch 89/100
# 2/2 [==============================] - 2s 761ms/step - loss: 917.4185 - mean_squared_error: 917.4185 - val_loss: 1284.6322 - val_mean_squared_error: 1284.6322
# Epoch 90/100
# 2/2 [==============================] - 2s 828ms/step - loss: 785.6694 - mean_squared_error: 785.6694 - val_loss: 1388.1514 - val_mean_squared_error: 1388.1514
# Epoch 91/100
# 2/2 [==============================] - 2s 686ms/step - loss: 810.7700 - mean_squared_error: 810.7700 - val_loss: 1409.7762 - val_mean_squared_error: 1409.7762
# Epoch 92/100
# 2/2 [==============================] - 2s 723ms/step - loss: 858.4882 - mean_squared_error: 858.4882 - val_loss: 1329.0851 - val_mean_squared_error: 1329.0851
# Epoch 93/100
# 2/2 [==============================] - 2s 1s/step - loss: 703.8344 - mean_squared_error: 703.8344 - val_loss: 1278.1930 - val_mean_squared_error: 1278.1930
# Epoch 94/100
# 2/2 [==============================] - 2s 705ms/step - loss: 708.5535 - mean_squared_error: 708.5535 - val_loss: 1218.0648 - val_mean_squared_error: 1218.0648
# Epoch 95/100
# 2/2 [==============================] - 2s 741ms/step - loss: 652.9691 - mean_squared_error: 652.9691 - val_loss: 1220.6495 - val_mean_squared_error: 1220.6495
# Epoch 96/100
# 2/2 [==============================] - 2s 706ms/step - loss: 558.7325 - mean_squared_error: 558.7324 - val_loss: 1275.1881 - val_mean_squared_error: 1275.1881
# Epoch 97/100
# 2/2 [==============================] - 2s 1s/step - loss: 583.5167 - mean_squared_error: 583.5167 - val_loss: 1286.3325 - val_mean_squared_error: 1286.3325
# Epoch 98/100
# 2/2 [==============================] - 2s 728ms/step - loss: 562.9002 - mean_squared_error: 562.9002 - val_loss: 1296.8828 - val_mean_squared_error: 1296.8828
# Epoch 99/100
# 2/2 [==============================] - 3s 1s/step - loss: 589.1282 - mean_squared_error: 589.1282 - val_loss: 1274.4443 - val_mean_squared_error: 1274.4443
# Epoch 100/100
# 2/2 [==============================] - 2s 741ms/step - loss: 552.9999 - mean_squared_error: 552.9999 - val_loss: 1264.8811 - val_mean_squared_error: 1264.8811
# 1/1 [==============================] - 0s 101ms/step - loss: 8835.3486 - mean_squared_error: 8835.3486
# Test error: 8835.35

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  7.541066301663716
# MSE:  145.5308221152367
# RMSE:  12.063615631942055
# r2_score:  -0.37928189650966604
# MSLE:  2.297712575233176
# MAPE:  2653189561472341.5
# ===== flank_wear results =====
# MAE:  109.21102650960286
# MSE:  26266.66821405475
# RMSE:  162.06994852240422
# r2_score:  -0.6393761973556287
# MSLE:  1.1379598790084589
# MAPE:  0.5332259567881632
# ===== overhang results =====
# MAE:  8.025687840779623
# MSE:  93.8413070769925
# RMSE:  9.687172295205269
# r2_score:  -3.6519500380217504
# MSLE:  0.41267854607229243
# MAPE:  0.894220418212015
# ===== multi results =====
# MAE:  41.59259355068207
# MSE:  8835.346781082326
# RMSE:  61.27357881651718
# r2_score:  -1.5568693772956816
# MSLE:  1.282783666771309
# MAPE:  884396520490781.0
