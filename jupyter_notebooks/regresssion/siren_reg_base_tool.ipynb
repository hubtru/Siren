# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2"
# Out:
# 2023-09-23 13:09:01.336215: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-23 13:09:03.413093: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  1
# GPUs:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-09-23 13:09:08.141308: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:09:08.202052: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:09:08.203146: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# ============================== variables ==============================
# architecture
image_size = 256
filters = 256
depth = 4
columns = 4
kernel_size = 5
patch_size = 16
num_classes = 3

in_channel = 3
img_rows, img_cols = image_size, image_size
input_shape = (img_rows, img_cols, in_channel)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "tool"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

# dataset
csv_path = "../../dataset/labels_reg_sample.csv"
tool_path = f"../../dataset/{modality}"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chips/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang                            tool
# 14   T8R3B4   6.88       40.92     14.54   ../../dataset/tool/T8R3B4.jpg
# 10   T6R9B3  12.94       95.63     16.65   ../../dataset/tool/T6R9B3.jpg
# 0    T1R2B1   7.67       34.89     48.61   ../../dataset/tool/T1R2B1.jpg
# 3   T2R13B4   0.00      122.59     25.55  ../../dataset/tool/T2R13B4.jpg
# 1    T1R7B4  13.89       85.41     50.25   ../../dataset/tool/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang                            tool
# 16   T9R7B4   0.00       94.62     17.05   ../../dataset/tool/T9R7B4.jpg
# 18  T10R3B4   0.00       44.26      7.10  ../../dataset/tool/T10R3B4.jpg
# 9   T5R12B1  21.79      334.39     16.14  ../../dataset/tool/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang                            tool
# 5   T3R10B1   5.00      128.39     35.26  ../../dataset/tool/T3R10B1.jpg
# 13  T7R14B3  13.67      141.91     14.62  ../../dataset/tool/T7R14B3.jpg
# 12   T7R8B3   7.45       77.05     19.02   ../../dataset/tool/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_tool, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_tool, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_tool, labels_val))
# Out:
# 2023-09-23 13:09:10.317990: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:09:10.318991: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:09:10.319785: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:09:11.271175: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:09:11.271870: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:09:11.272438: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:09:11.272936: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1942 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:00:1b.0, compute capability: 6.1

# %%
# ============================== augment ==============================
auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation",
)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
def activation_module(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def base_module(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_module(x)


def multi_mixer_module(
    x, pe_block, column, level, depth, r_arr, filters: int, kernel_size: int
):
    if column == 0:
        # Depthwise convolution.
        x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        r_arr = reverasable_output_array(x, r_arr, column, level)
        return x, r_arr
    else:
        if level == 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], pe_block)
        elif level < len(r_arr[0]) - 1 and level != 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], x)
        else:
            x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x0)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        if column != 0:
            x = fusion_block_double(r_arr[column - 1][level], x)

        r_arr = reverasable_output_array(x, r_arr, column, level)

        return x, r_arr


def fusion_block_double(x, y):
    return layers.Add()([x, y])


def reverasable_output_array(x, r_arr, column, level):
    r_arr[column][level] = x
    return r_arr


def load_multi_mixer(
    image_size=image_size,
    filters=filters,
    depth=depth,
    columns=columns,
    kernel_size=kernel_size,
    patch_size=patch_size,
    num_classes=num_classes,
):
    r_arr = [[None for _ in range(depth)] for _ in range(columns)]

    inputs = k.Input(input_shape)
    # x = layers.Rescaling(scale=1.0 / 255)(inputs)         # already rescaled

    # Extract patch embeddings.
    x = base_module(inputs, filters, patch_size)
    pe_block = x

    # ConvMixer blocks.
    for column in range(columns):
        for level in range(depth):
            x, r_arr = multi_mixer_module(
                x, pe_block, column, level, depth, r_arr, filters, kernel_size
            )

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="linear")(x)

    return k.Model(inputs, outputs)

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_multi_mixer()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 16, 16, 256)  196864      ['input_1[0][0]']
#
#  activation (Activation)        (None, 16, 16, 256)  0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 256)  1024       ['activation[0][0]']
#  alization)
#
#  depthwise_conv2d (DepthwiseCon  (None, 16, 16, 256)  6656       ['batch_normalization[0][0]']
#  v2D)
#
#  activation_1 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 256)  1024       ['activation_1[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 16, 16, 256)  0           ['batch_normalization_1[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 256)  65792       ['add[0][0]']
#
#  activation_2 (Activation)      (None, 16, 16, 256)  0           ['conv2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 256)  1024       ['activation_2[0][0]']
#  rmalization)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 16, 16, 256)  6656       ['batch_normalization_2[0][0]']
#  onv2D)
#
#  activation_3 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 256)  1024       ['activation_3[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 256)  65792       ['add_1[0][0]']
#
#  activation_4 (Activation)      (None, 16, 16, 256)  0           ['conv2d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 256)  1024       ['activation_4[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_4[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_4[0][0]']
#  onv2D)
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 16, 16, 256)  6656       ['batch_normalization_4[0][0]']
#  onv2D)
#
#  activation_9 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d_4[0][0]']
#
#  activation_5 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 256)  1024       ['activation_9[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 256)  1024       ['activation_5[0][0]']
#  rmalization)
#
#  add_5 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_9[0][0]',
#                                                                   'add_4[0][0]']
#
#  add_2 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 256)  65792       ['add_5[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 256)  65792       ['add_2[0][0]']
#
#  activation_10 (Activation)     (None, 16, 16, 256)  0           ['conv2d_5[0][0]']
#
#  activation_6 (Activation)      (None, 16, 16, 256)  0           ['conv2d_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 256)  1024       ['activation_10[0][0]']
#  ormalization)
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 256)  1024       ['activation_6[0][0]']
#  rmalization)
#
#  add_6 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_2[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  add_7 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_6[0][0]',
#                                                                   'add_6[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_7[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 16, 16, 256)  6656       ['batch_normalization_6[0][0]']
#  onv2D)
#
#  activation_11 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_5[0][0]']
#
#  activation_7 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 256)  1024       ['activation_11[0][0]']
#  ormalization)
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 256)  1024       ['activation_7[0][0]']
#  rmalization)
#
#  add_8 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_11[0][0]',
#                                                                   'add_7[0][0]']
#
#  add_3 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  65792       ['add_8[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 256)  65792       ['add_3[0][0]']
#
#  activation_12 (Activation)     (None, 16, 16, 256)  0           ['conv2d_6[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 256)  0           ['conv2d_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 256)  1024       ['activation_12[0][0]']
#  ormalization)
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 256)  1024       ['activation_8[0][0]']
#  rmalization)
#
#  add_9 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_4[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  add_10 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_8[0][0]',
#                                                                   'add_9[0][0]']
#
#  add_15 (Add)                   (None, 16, 16, 256)  0           ['add_9[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_10[0][0]']
#  onv2D)
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_15[0][0]']
#  onv2D)
#
#  activation_13 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_6[0][0]']
#
#  activation_17 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_8[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 256)  1024       ['activation_13[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 256)  1024       ['activation_17[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_13[0][0]',
#                                                                   'add_10[0][0]']
#
#  add_16 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_17[0][0]',
#                                                                   'add_15[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  65792       ['add_11[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  65792       ['add_16[0][0]']
#
#  activation_14 (Activation)     (None, 16, 16, 256)  0           ['conv2d_7[0][0]']
#
#  activation_18 (Activation)     (None, 16, 16, 256)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 256)  1024       ['activation_14[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 256)  1024       ['activation_18[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  add_17 (Add)                   (None, 16, 16, 256)  0           ['add_6[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  add_18 (Add)                   (None, 16, 16, 256)  0           ['add_12[0][0]',
#                                                                   'add_17[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_12[0][0]']
#  onv2D)
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_18[0][0]']
#  onv2D)
#
#  activation_15 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_7[0][0]']
#
#  activation_19 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 256)  1024       ['activation_15[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 256)  1024       ['activation_19[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_15[0][0]',
#                                                                   'add_12[0][0]']
#
#  add_19 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_19[0][0]',
#                                                                   'add_18[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  65792       ['add_13[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  65792       ['add_19[0][0]']
#
#  activation_16 (Activation)     (None, 16, 16, 256)  0           ['conv2d_8[0][0]']
#
#  activation_20 (Activation)     (None, 16, 16, 256)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 256)  1024       ['activation_16[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 256)  1024       ['activation_20[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  add_20 (Add)                   (None, 16, 16, 256)  0           ['add_9[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  add_21 (Add)                   (None, 16, 16, 256)  0           ['add_14[0][0]',
#                                                                   'add_20[0][0]']
#
#  add_26 (Add)                   (None, 16, 16, 256)  0           ['add_20[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 16, 16, 256)  6656       ['add_21[0][0]']
#  Conv2D)
#
#  depthwise_conv2d_12 (Depthwise  (None, 16, 16, 256)  6656       ['add_26[0][0]']
#  Conv2D)
#
#  activation_21 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_10[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_12[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 256)  1024       ['activation_21[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 256)  1024       ['activation_25[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_21[0][0]',
#                                                                   'add_21[0][0]']
#
#  add_27 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_25[0][0]',
#                                                                   'add_26[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  65792       ['add_22[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 256)  65792       ['add_27[0][0]']
#
#  activation_22 (Activation)     (None, 16, 16, 256)  0           ['conv2d_11[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 256)  0           ['conv2d_13[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 256)  1024       ['activation_22[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 256)  1024       ['activation_26[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 16, 16, 256)  0           ['add_12[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  add_28 (Add)                   (None, 16, 16, 256)  0           ['add_17[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  add_29 (Add)                   (None, 16, 16, 256)  0           ['add_23[0][0]',
#                                                                   'add_28[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 16, 16, 256)  6656       ['add_23[0][0]']
#  Conv2D)
#
#  depthwise_conv2d_13 (Depthwise  (None, 16, 16, 256)  6656       ['add_29[0][0]']
#  Conv2D)
#
#  activation_23 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_11[0][0]']
#
#  activation_27 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_13[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 256)  1024       ['activation_23[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 256)  1024       ['activation_27[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_23[0][0]',
#                                                                   'add_23[0][0]']
#
#  add_30 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_27[0][0]',
#                                                                   'add_29[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 256)  65792       ['add_24[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 256)  65792       ['add_30[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 256)  0           ['conv2d_12[0][0]']
#
#  activation_28 (Activation)     (None, 16, 16, 256)  0           ['conv2d_14[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 256)  1024       ['activation_24[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 256)  1024       ['activation_28[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 16, 16, 256)  0           ['add_14[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  add_31 (Add)                   (None, 16, 16, 256)  0           ['add_20[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  add_32 (Add)                   (None, 16, 16, 256)  0           ['add_25[0][0]',
#                                                                   'add_31[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 16, 16, 256)  6656       ['add_32[0][0]']
#  Conv2D)
#
#  activation_29 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_14[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 256)  1024       ['activation_29[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_29[0][0]',
#                                                                   'add_32[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 256)  65792       ['add_33[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 256)  0           ['conv2d_15[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 256)  1024       ['activation_30[0][0]']
#  ormalization)
#
#  add_34 (Add)                   (None, 16, 16, 256)  0           ['add_23[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 16, 16, 256)  6656       ['add_34[0][0]']
#  Conv2D)
#
#  activation_31 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_15[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 256)  1024       ['activation_31[0][0]']
#  ormalization)
#
#  add_35 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_31[0][0]',
#                                                                   'add_34[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 256)  65792       ['add_35[0][0]']
#
#  activation_32 (Activation)     (None, 16, 16, 256)  0           ['conv2d_16[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 256)  1024       ['activation_32[0][0]']
#  ormalization)
#
#  add_36 (Add)                   (None, 16, 16, 256)  0           ['add_25[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_36[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 3)            771         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 1,390,595
# Trainable params: 1,373,699
# Non-trainable params: 16,896
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2023-09-23 13:09:13.228549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_12' with dtype resource
# 	 [[{{node Placeholder/_12}}]]
# 2023-09-23 13:09:13.228975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_12' with dtype resource
# 	 [[{{node Placeholder/_12}}]]
# 2023-09-23 13:09:22.333886: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2/2 [==============================] - ETA: 0s - loss: 3859.2346 - mean_squared_error: 3859.2346
# 2023-09-23 13:09:23.412401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_1}}]]
# 2/2 [==============================] - 11s 1s/step - loss: 3859.2346 - mean_squared_error: 3859.2346 - val_loss: 5012.0386 - val_mean_squared_error: 5012.0386
# Epoch 2/100
# 2/2 [==============================] - 0s 51ms/step - loss: 4134.7710 - mean_squared_error: 4134.7710 - val_loss: 5090.0317 - val_mean_squared_error: 5090.0317
# Epoch 3/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3839.5347 - mean_squared_error: 3839.5347 - val_loss: 5263.0898 - val_mean_squared_error: 5263.0898
# Epoch 4/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3683.3303 - mean_squared_error: 3683.3303 - val_loss: 5469.5532 - val_mean_squared_error: 5469.5532
# Epoch 5/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3739.4587 - mean_squared_error: 3739.4587 - val_loss: 5596.0586 - val_mean_squared_error: 5596.0586
# Epoch 6/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3707.2703 - mean_squared_error: 3707.2703 - val_loss: 5454.9004 - val_mean_squared_error: 5454.9004
# Epoch 7/100
# 2/2 [==============================] - 0s 50ms/step - loss: 3773.3113 - mean_squared_error: 3773.3113 - val_loss: 5416.4473 - val_mean_squared_error: 5416.4473
# Epoch 8/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3565.5215 - mean_squared_error: 3565.5215 - val_loss: 5685.0254 - val_mean_squared_error: 5685.0254
# Epoch 9/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3509.8828 - mean_squared_error: 3509.8828 - val_loss: 6074.1855 - val_mean_squared_error: 6074.1855
# Epoch 10/100
# 2/2 [==============================] - 0s 47ms/step - loss: 3418.3318 - mean_squared_error: 3418.3318 - val_loss: 6124.7368 - val_mean_squared_error: 6124.7368
# Epoch 11/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3382.0474 - mean_squared_error: 3382.0474 - val_loss: 6239.6890 - val_mean_squared_error: 6239.6890
# Epoch 12/100
# 2/2 [==============================] - 0s 47ms/step - loss: 3515.7661 - mean_squared_error: 3515.7661 - val_loss: 6469.6040 - val_mean_squared_error: 6469.6040
# Epoch 13/100
# 2/2 [==============================] - 0s 47ms/step - loss: 3574.4387 - mean_squared_error: 3574.4387 - val_loss: 6887.9312 - val_mean_squared_error: 6887.9312
# Epoch 14/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3361.3333 - mean_squared_error: 3361.3333 - val_loss: 6667.5522 - val_mean_squared_error: 6667.5522
# Epoch 15/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3463.4963 - mean_squared_error: 3463.4963 - val_loss: 6107.0703 - val_mean_squared_error: 6107.0703
# Epoch 16/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3324.1067 - mean_squared_error: 3324.1067 - val_loss: 5109.8076 - val_mean_squared_error: 5109.8076
# Epoch 17/100
# 2/2 [==============================] - 0s 46ms/step - loss: 3664.1340 - mean_squared_error: 3664.1340 - val_loss: 5090.5879 - val_mean_squared_error: 5090.5879
# Epoch 18/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3263.2166 - mean_squared_error: 3263.2166 - val_loss: 5141.7671 - val_mean_squared_error: 5141.7671
# Epoch 19/100
# 2/2 [==============================] - 0s 47ms/step - loss: 3125.7751 - mean_squared_error: 3125.7751 - val_loss: 4762.0962 - val_mean_squared_error: 4762.0962
# Epoch 20/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3235.1909 - mean_squared_error: 3235.1909 - val_loss: 4481.0024 - val_mean_squared_error: 4481.0024
# Epoch 21/100
# 2/2 [==============================] - 0s 47ms/step - loss: 3209.9939 - mean_squared_error: 3209.9939 - val_loss: 3948.5554 - val_mean_squared_error: 3948.5554
# Epoch 22/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3254.0645 - mean_squared_error: 3254.0645 - val_loss: 3944.3767 - val_mean_squared_error: 3944.3767
# Epoch 23/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3147.7065 - mean_squared_error: 3147.7065 - val_loss: 3869.4641 - val_mean_squared_error: 3869.4641
# Epoch 24/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2995.8931 - mean_squared_error: 2995.8931 - val_loss: 3860.2346 - val_mean_squared_error: 3860.2346
# Epoch 25/100
# 2/2 [==============================] - 0s 50ms/step - loss: 3026.2961 - mean_squared_error: 3026.2961 - val_loss: 3633.5920 - val_mean_squared_error: 3633.5920
# Epoch 26/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3133.6418 - mean_squared_error: 3133.6418 - val_loss: 3459.6243 - val_mean_squared_error: 3459.6243
# Epoch 27/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2962.7512 - mean_squared_error: 2962.7512 - val_loss: 3450.6379 - val_mean_squared_error: 3450.6379
# Epoch 28/100
# 2/2 [==============================] - 0s 52ms/step - loss: 3332.8923 - mean_squared_error: 3332.8923 - val_loss: 3082.0247 - val_mean_squared_error: 3082.0247
# Epoch 29/100
# 2/2 [==============================] - 0s 45ms/step - loss: 2960.9382 - mean_squared_error: 2960.9382 - val_loss: 3004.7356 - val_mean_squared_error: 3004.7356
# Epoch 30/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2778.9944 - mean_squared_error: 2778.9944 - val_loss: 2956.8398 - val_mean_squared_error: 2956.8398
# Epoch 31/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2853.6223 - mean_squared_error: 2853.6223 - val_loss: 3313.7373 - val_mean_squared_error: 3313.7373
# Epoch 32/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2960.1526 - mean_squared_error: 2960.1526 - val_loss: 3942.0732 - val_mean_squared_error: 3942.0732
# Epoch 33/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2829.8962 - mean_squared_error: 2829.8962 - val_loss: 4639.3159 - val_mean_squared_error: 4639.3159
# Epoch 34/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2844.5513 - mean_squared_error: 2844.5513 - val_loss: 4525.1450 - val_mean_squared_error: 4525.1450
# Epoch 35/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2826.8416 - mean_squared_error: 2826.8416 - val_loss: 4372.2202 - val_mean_squared_error: 4372.2202
# Epoch 36/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2743.4575 - mean_squared_error: 2743.4575 - val_loss: 3723.3557 - val_mean_squared_error: 3723.3557
# Epoch 37/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2610.4136 - mean_squared_error: 2610.4136 - val_loss: 3442.8245 - val_mean_squared_error: 3442.8245
# Epoch 38/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2691.6968 - mean_squared_error: 2691.6968 - val_loss: 3468.7205 - val_mean_squared_error: 3468.7205
# Epoch 39/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2628.0442 - mean_squared_error: 2628.0442 - val_loss: 3652.4141 - val_mean_squared_error: 3652.4141
# Epoch 40/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2573.4771 - mean_squared_error: 2573.4771 - val_loss: 3857.3787 - val_mean_squared_error: 3857.3787
# Epoch 41/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2478.5090 - mean_squared_error: 2478.5090 - val_loss: 3887.2351 - val_mean_squared_error: 3887.2351
# Epoch 42/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2490.4006 - mean_squared_error: 2490.4006 - val_loss: 3763.5349 - val_mean_squared_error: 3763.5349
# Epoch 43/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2560.9058 - mean_squared_error: 2560.9058 - val_loss: 3700.0967 - val_mean_squared_error: 3700.0967
# Epoch 44/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2351.8542 - mean_squared_error: 2351.8542 - val_loss: 3685.9792 - val_mean_squared_error: 3685.9792
# Epoch 45/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2377.4058 - mean_squared_error: 2377.4058 - val_loss: 3566.3672 - val_mean_squared_error: 3566.3672
# Epoch 46/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2296.6960 - mean_squared_error: 2296.6960 - val_loss: 3251.2549 - val_mean_squared_error: 3251.2549
# Epoch 47/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2430.5547 - mean_squared_error: 2430.5547 - val_loss: 3040.6096 - val_mean_squared_error: 3040.6096
# Epoch 48/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2361.5308 - mean_squared_error: 2361.5308 - val_loss: 2922.6931 - val_mean_squared_error: 2922.6931
# Epoch 49/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2276.4900 - mean_squared_error: 2276.4900 - val_loss: 2708.1045 - val_mean_squared_error: 2708.1045
# Epoch 50/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2277.4531 - mean_squared_error: 2277.4531 - val_loss: 2355.5112 - val_mean_squared_error: 2355.5112
# Epoch 51/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2160.9116 - mean_squared_error: 2160.9116 - val_loss: 1895.7715 - val_mean_squared_error: 1895.7715
# Epoch 52/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2101.4429 - mean_squared_error: 2101.4429 - val_loss: 1563.0894 - val_mean_squared_error: 1563.0894
# Epoch 53/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2069.8047 - mean_squared_error: 2069.8047 - val_loss: 1418.3091 - val_mean_squared_error: 1418.3091
# Epoch 54/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2010.1598 - mean_squared_error: 2010.1599 - val_loss: 1512.4025 - val_mean_squared_error: 1512.4025
# Epoch 55/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2100.5427 - mean_squared_error: 2100.5427 - val_loss: 1781.1764 - val_mean_squared_error: 1781.1764
# Epoch 56/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2197.0476 - mean_squared_error: 2197.0476 - val_loss: 2046.2460 - val_mean_squared_error: 2046.2460
# Epoch 57/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1944.9545 - mean_squared_error: 1944.9545 - val_loss: 2172.7898 - val_mean_squared_error: 2172.7898
# Epoch 58/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1834.4255 - mean_squared_error: 1834.4255 - val_loss: 2223.3718 - val_mean_squared_error: 2223.3718
# Epoch 59/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2106.5176 - mean_squared_error: 2106.5176 - val_loss: 2092.5579 - val_mean_squared_error: 2092.5579
# Epoch 60/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2008.6550 - mean_squared_error: 2008.6550 - val_loss: 1995.9315 - val_mean_squared_error: 1995.9315
# Epoch 61/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1758.0759 - mean_squared_error: 1758.0759 - val_loss: 2003.1162 - val_mean_squared_error: 2003.1162
# Epoch 62/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1711.8021 - mean_squared_error: 1711.8021 - val_loss: 1989.9551 - val_mean_squared_error: 1989.9551
# Epoch 63/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1681.0237 - mean_squared_error: 1681.0237 - val_loss: 1941.8141 - val_mean_squared_error: 1941.8141
# Epoch 64/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1623.9010 - mean_squared_error: 1623.9010 - val_loss: 1946.4066 - val_mean_squared_error: 1946.4066
# Epoch 65/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1740.2213 - mean_squared_error: 1740.2213 - val_loss: 2083.3464 - val_mean_squared_error: 2083.3464
# Epoch 66/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1577.2384 - mean_squared_error: 1577.2384 - val_loss: 2183.1199 - val_mean_squared_error: 2183.1199
# Epoch 67/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1535.0446 - mean_squared_error: 1535.0446 - val_loss: 2213.6487 - val_mean_squared_error: 2213.6487
# Epoch 68/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1482.6490 - mean_squared_error: 1482.6490 - val_loss: 2154.4238 - val_mean_squared_error: 2154.4238
# Epoch 69/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1599.9160 - mean_squared_error: 1599.9160 - val_loss: 2176.4958 - val_mean_squared_error: 2176.4958
# Epoch 70/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1379.3884 - mean_squared_error: 1379.3884 - val_loss: 2264.9988 - val_mean_squared_error: 2264.9988
# Epoch 71/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1453.9425 - mean_squared_error: 1453.9425 - val_loss: 2197.4099 - val_mean_squared_error: 2197.4099
# Epoch 72/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1449.8134 - mean_squared_error: 1449.8134 - val_loss: 2215.4905 - val_mean_squared_error: 2215.4905
# Epoch 73/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1347.1984 - mean_squared_error: 1347.1984 - val_loss: 2030.6952 - val_mean_squared_error: 2030.6952
# Epoch 74/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1245.0957 - mean_squared_error: 1245.0957 - val_loss: 1843.5468 - val_mean_squared_error: 1843.5468
# Epoch 75/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1239.5613 - mean_squared_error: 1239.5613 - val_loss: 1660.0468 - val_mean_squared_error: 1660.0468
# Epoch 76/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1142.0035 - mean_squared_error: 1142.0035 - val_loss: 1508.2484 - val_mean_squared_error: 1508.2484
# Epoch 77/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1210.1783 - mean_squared_error: 1210.1783 - val_loss: 1483.1288 - val_mean_squared_error: 1483.1288
# Epoch 78/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1148.5109 - mean_squared_error: 1148.5109 - val_loss: 1387.9780 - val_mean_squared_error: 1387.9780
# Epoch 79/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1103.4290 - mean_squared_error: 1103.4290 - val_loss: 1258.6681 - val_mean_squared_error: 1258.6681
# Epoch 80/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1136.5125 - mean_squared_error: 1136.5125 - val_loss: 1195.7062 - val_mean_squared_error: 1195.7062
# Epoch 81/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1060.9900 - mean_squared_error: 1060.9900 - val_loss: 1145.8724 - val_mean_squared_error: 1145.8724
# Epoch 82/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1155.2439 - mean_squared_error: 1155.2439 - val_loss: 1085.0238 - val_mean_squared_error: 1085.0238
# Epoch 83/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1029.7086 - mean_squared_error: 1029.7086 - val_loss: 1064.2596 - val_mean_squared_error: 1064.2596
# Epoch 84/100
# 2/2 [==============================] - 0s 51ms/step - loss: 929.0107 - mean_squared_error: 929.0107 - val_loss: 1190.3058 - val_mean_squared_error: 1190.3058
# Epoch 85/100
# 2/2 [==============================] - 0s 46ms/step - loss: 927.2778 - mean_squared_error: 927.2778 - val_loss: 1311.7969 - val_mean_squared_error: 1311.7969
# Epoch 86/100
# 2/2 [==============================] - 0s 47ms/step - loss: 830.1744 - mean_squared_error: 830.1744 - val_loss: 1370.5885 - val_mean_squared_error: 1370.5885
# Epoch 87/100
# 2/2 [==============================] - 0s 47ms/step - loss: 877.2713 - mean_squared_error: 877.2713 - val_loss: 1474.2843 - val_mean_squared_error: 1474.2843
# Epoch 88/100
# 2/2 [==============================] - 0s 48ms/step - loss: 807.4363 - mean_squared_error: 807.4363 - val_loss: 1563.3756 - val_mean_squared_error: 1563.3756
# Epoch 89/100
# 2/2 [==============================] - 0s 49ms/step - loss: 896.8697 - mean_squared_error: 896.8697 - val_loss: 1501.6141 - val_mean_squared_error: 1501.6141
# Epoch 90/100
# 2/2 [==============================] - 0s 47ms/step - loss: 776.7582 - mean_squared_error: 776.7582 - val_loss: 1247.1862 - val_mean_squared_error: 1247.1862
# Epoch 91/100
# 2/2 [==============================] - 0s 47ms/step - loss: 695.0291 - mean_squared_error: 695.0291 - val_loss: 982.2178 - val_mean_squared_error: 982.2178
# Epoch 92/100
# 2/2 [==============================] - 0s 48ms/step - loss: 730.2583 - mean_squared_error: 730.2583 - val_loss: 822.4744 - val_mean_squared_error: 822.4744
# Epoch 93/100
# 2/2 [==============================] - 0s 48ms/step - loss: 692.5961 - mean_squared_error: 692.5961 - val_loss: 768.3364 - val_mean_squared_error: 768.3364
# Epoch 94/100
# 2/2 [==============================] - 0s 49ms/step - loss: 651.1754 - mean_squared_error: 651.1754 - val_loss: 754.6158 - val_mean_squared_error: 754.6158
# Epoch 95/100
# 2/2 [==============================] - 0s 53ms/step - loss: 597.9254 - mean_squared_error: 597.9254 - val_loss: 738.6667 - val_mean_squared_error: 738.6667
# Epoch 96/100
# 2/2 [==============================] - 0s 48ms/step - loss: 550.2300 - mean_squared_error: 550.2300 - val_loss: 688.5527 - val_mean_squared_error: 688.5527
# Epoch 97/100
# 2/2 [==============================] - 0s 47ms/step - loss: 606.9446 - mean_squared_error: 606.9446 - val_loss: 643.7957 - val_mean_squared_error: 643.7957
# Epoch 98/100
# 2/2 [==============================] - 0s 49ms/step - loss: 648.4662 - mean_squared_error: 648.4662 - val_loss: 619.1935 - val_mean_squared_error: 619.1935
# Epoch 99/100
# 2/2 [==============================] - 0s 47ms/step - loss: 591.5085 - mean_squared_error: 591.5085 - val_loss: 619.9500 - val_mean_squared_error: 619.9500
# Epoch 100/100
# 2/2 [==============================] - 0s 53ms/step - loss: 441.4152 - mean_squared_error: 441.4152 - val_loss: 618.6801 - val_mean_squared_error: 618.6801
# 1/1 [==============================] - 0s 23ms/step - loss: 7228.6616 - mean_squared_error: 7228.6616
# Test error: 7228.66
# 2023-09-23 13:09:36.680074: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_1}}]]

# %%
model.save(model_save_path)

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 1s 849ms/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  7.620585891405741
# MSE:  161.84243540852995
# RMSE:  12.721730833834284
# r2_score:  -0.5338767279776748
# MSLE_min_shifted:  0.020268249618071353
# MAPE:  1256076808814592.2
# ===== flank_wear results =====
# MAE:  100.55423990885417
# MSE:  21340.43845674165
# RMSE:  146.08366937047293
# r2_score:  -0.3319164258676399
# MSLE:  0.7609049020257418
# MAPE:  0.5958549066135221
# ===== overhang results =====
# MAE:  11.76997469584147
# MSE:  183.70262025300545
# RMSE:  13.553693970759612
# r2_score:  -8.106601750224172
# MSLE:  0.616211796108708
# MAPE:  1.2525482634772414
# ===== multi results =====
# MAE:  39.98160016536713
# MSE:  7228.661170801061
# RMSE:  57.45303139168894
# r2_score:  -2.9907983013564956
# MSLE_min_shifted:  1.5813244783854434
# MAPE:  418692269604864.7
