# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "3"
# Out:
# 2023-09-23 13:20:40.329865: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-23 13:20:42.259676: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  1
# GPUs:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-09-23 13:20:46.731937: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:20:46.777321: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:20:46.778844: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# ============================== variables ==============================
# architecture
image_size = 256
filters = 256
depth = 4
columns = 4
kernel_size = 5
patch_size = 16
num_classes = 3

in_channel = 3
img_rows, img_cols = image_size, image_size
input_shape = (img_rows, img_cols, in_channel)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "chip"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

# dataset
csv_path = "../../dataset/labels_reg_sample.csv"
chip_path = f"../../dataset/{modality}"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chips/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang                            chip
# 14   T8R3B4   6.88       40.92     14.54   ../../dataset/chip/T8R3B4.jpg
# 10   T6R9B3  12.94       95.63     16.65   ../../dataset/chip/T6R9B3.jpg
# 0    T1R2B1   7.67       34.89     48.61   ../../dataset/chip/T1R2B1.jpg
# 3   T2R13B4   0.00      122.59     25.55  ../../dataset/chip/T2R13B4.jpg
# 1    T1R7B4  13.89       85.41     50.25   ../../dataset/chip/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang                            chip
# 16   T9R7B4   0.00       94.62     17.05   ../../dataset/chip/T9R7B4.jpg
# 18  T10R3B4   0.00       44.26      7.10  ../../dataset/chip/T10R3B4.jpg
# 9   T5R12B1  21.79      334.39     16.14  ../../dataset/chip/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang                            chip
# 5   T3R10B1   5.00      128.39     35.26  ../../dataset/chip/T3R10B1.jpg
# 13  T7R14B3  13.67      141.91     14.62  ../../dataset/chip/T7R14B3.jpg
# 12   T7R8B3   7.45       77.05     19.02   ../../dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_chip, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_chip, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_chip, labels_val))
# Out:
# 2023-09-23 13:20:49.906472: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:20:49.907966: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:20:49.909109: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:20:50.975879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:20:50.976829: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:20:50.977732: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:20:50.978627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10377 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:00:1c.0, compute capability: 6.1

# %%
# ============================== augment ==============================
auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation",
)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
def activation_module(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def base_module(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_module(x)


def depth_point_module(
    x, pe_block, column, level, depth, r_arr, filters: int, kernel_size: int
):
    if column == 0:
        # Depthwise convolution.
        x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        r_arr = reverasable_output_array(x, r_arr, column, level)
        return x, r_arr
    else:
        if level == 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], pe_block)
        elif level < len(r_arr[0]) - 1 and level != 0:
            x0 = fusion_block_double(r_arr[column - 1][level + 1], x)
        else:
            x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x0)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        if column != 0:
            x = fusion_block_double(r_arr[column - 1][level], x)

        r_arr = reverasable_output_array(x, r_arr, column, level)

        return x, r_arr


def fusion_block_double(x, y):
    return layers.Add()([x, y])


def reverasable_output_array(x, r_arr, column, level):
    r_arr[column][level] = x
    return r_arr


def load_siren(
    image_size=image_size,
    filters=filters,
    depth=depth,
    columns=columns,
    kernel_size=kernel_size,
    patch_size=patch_size,
    num_classes=num_classes,
):
    r_arr = [[None for _ in range(depth)] for _ in range(columns)]

    inputs = k.Input(input_shape)
    # x = layers.Rescaling(scale=1.0 / 255)(inputs)         # already rescaled

    # Extract patch embeddings.
    x = base_module(inputs, filters, patch_size)
    pe_block = x

    # Siren blocks.
    for column in range(columns):
        for level in range(depth):
            x, r_arr = depth_point_module(
                x, pe_block, column, level, depth, r_arr, filters, kernel_size
            )

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="linear")(x)

    return k.Model(inputs, outputs)

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 16, 16, 256)  196864      ['input_1[0][0]']
#
#  activation (Activation)        (None, 16, 16, 256)  0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 256)  1024       ['activation[0][0]']
#  alization)
#
#  depthwise_conv2d (DepthwiseCon  (None, 16, 16, 256)  6656       ['batch_normalization[0][0]']
#  v2D)
#
#  activation_1 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 256)  1024       ['activation_1[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 16, 16, 256)  0           ['batch_normalization_1[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 256)  65792       ['add[0][0]']
#
#  activation_2 (Activation)      (None, 16, 16, 256)  0           ['conv2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 256)  1024       ['activation_2[0][0]']
#  rmalization)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 16, 16, 256)  6656       ['batch_normalization_2[0][0]']
#  onv2D)
#
#  activation_3 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 256)  1024       ['activation_3[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 256)  65792       ['add_1[0][0]']
#
#  activation_4 (Activation)      (None, 16, 16, 256)  0           ['conv2d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 256)  1024       ['activation_4[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_4[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_4[0][0]']
#  onv2D)
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 16, 16, 256)  6656       ['batch_normalization_4[0][0]']
#  onv2D)
#
#  activation_9 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d_4[0][0]']
#
#  activation_5 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 256)  1024       ['activation_9[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 256)  1024       ['activation_5[0][0]']
#  rmalization)
#
#  add_5 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_9[0][0]',
#                                                                   'add_4[0][0]']
#
#  add_2 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 256)  65792       ['add_5[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 256)  65792       ['add_2[0][0]']
#
#  activation_10 (Activation)     (None, 16, 16, 256)  0           ['conv2d_5[0][0]']
#
#  activation_6 (Activation)      (None, 16, 16, 256)  0           ['conv2d_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 256)  1024       ['activation_10[0][0]']
#  ormalization)
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 256)  1024       ['activation_6[0][0]']
#  rmalization)
#
#  add_6 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_2[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  add_7 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_6[0][0]',
#                                                                   'add_6[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_7[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 16, 16, 256)  6656       ['batch_normalization_6[0][0]']
#  onv2D)
#
#  activation_11 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_5[0][0]']
#
#  activation_7 (Activation)      (None, 16, 16, 256)  0           ['depthwise_conv2d_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 256)  1024       ['activation_11[0][0]']
#  ormalization)
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 256)  1024       ['activation_7[0][0]']
#  rmalization)
#
#  add_8 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_11[0][0]',
#                                                                   'add_7[0][0]']
#
#  add_3 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  65792       ['add_8[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 256)  65792       ['add_3[0][0]']
#
#  activation_12 (Activation)     (None, 16, 16, 256)  0           ['conv2d_6[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 256)  0           ['conv2d_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 256)  1024       ['activation_12[0][0]']
#  ormalization)
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 256)  1024       ['activation_8[0][0]']
#  rmalization)
#
#  add_9 (Add)                    (None, 16, 16, 256)  0           ['batch_normalization_4[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  add_10 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_8[0][0]',
#                                                                   'add_9[0][0]']
#
#  add_15 (Add)                   (None, 16, 16, 256)  0           ['add_9[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_10[0][0]']
#  onv2D)
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_15[0][0]']
#  onv2D)
#
#  activation_13 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_6[0][0]']
#
#  activation_17 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_8[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 256)  1024       ['activation_13[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 256)  1024       ['activation_17[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_13[0][0]',
#                                                                   'add_10[0][0]']
#
#  add_16 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_17[0][0]',
#                                                                   'add_15[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  65792       ['add_11[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  65792       ['add_16[0][0]']
#
#  activation_14 (Activation)     (None, 16, 16, 256)  0           ['conv2d_7[0][0]']
#
#  activation_18 (Activation)     (None, 16, 16, 256)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 256)  1024       ['activation_14[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 256)  1024       ['activation_18[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  add_17 (Add)                   (None, 16, 16, 256)  0           ['add_6[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  add_18 (Add)                   (None, 16, 16, 256)  0           ['add_12[0][0]',
#                                                                   'add_17[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_12[0][0]']
#  onv2D)
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 16, 16, 256)  6656       ['add_18[0][0]']
#  onv2D)
#
#  activation_15 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_7[0][0]']
#
#  activation_19 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 256)  1024       ['activation_15[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 256)  1024       ['activation_19[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_15[0][0]',
#                                                                   'add_12[0][0]']
#
#  add_19 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_19[0][0]',
#                                                                   'add_18[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  65792       ['add_13[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  65792       ['add_19[0][0]']
#
#  activation_16 (Activation)     (None, 16, 16, 256)  0           ['conv2d_8[0][0]']
#
#  activation_20 (Activation)     (None, 16, 16, 256)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 256)  1024       ['activation_16[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 256)  1024       ['activation_20[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  add_20 (Add)                   (None, 16, 16, 256)  0           ['add_9[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  add_21 (Add)                   (None, 16, 16, 256)  0           ['add_14[0][0]',
#                                                                   'add_20[0][0]']
#
#  add_26 (Add)                   (None, 16, 16, 256)  0           ['add_20[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 16, 16, 256)  6656       ['add_21[0][0]']
#  Conv2D)
#
#  depthwise_conv2d_12 (Depthwise  (None, 16, 16, 256)  6656       ['add_26[0][0]']
#  Conv2D)
#
#  activation_21 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_10[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_12[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 256)  1024       ['activation_21[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 256)  1024       ['activation_25[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_21[0][0]',
#                                                                   'add_21[0][0]']
#
#  add_27 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_25[0][0]',
#                                                                   'add_26[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  65792       ['add_22[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 256)  65792       ['add_27[0][0]']
#
#  activation_22 (Activation)     (None, 16, 16, 256)  0           ['conv2d_11[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 256)  0           ['conv2d_13[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 256)  1024       ['activation_22[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 256)  1024       ['activation_26[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 16, 16, 256)  0           ['add_12[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  add_28 (Add)                   (None, 16, 16, 256)  0           ['add_17[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  add_29 (Add)                   (None, 16, 16, 256)  0           ['add_23[0][0]',
#                                                                   'add_28[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 16, 16, 256)  6656       ['add_23[0][0]']
#  Conv2D)
#
#  depthwise_conv2d_13 (Depthwise  (None, 16, 16, 256)  6656       ['add_29[0][0]']
#  Conv2D)
#
#  activation_23 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_11[0][0]']
#
#  activation_27 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_13[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 256)  1024       ['activation_23[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 256)  1024       ['activation_27[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_23[0][0]',
#                                                                   'add_23[0][0]']
#
#  add_30 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_27[0][0]',
#                                                                   'add_29[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 256)  65792       ['add_24[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 256)  65792       ['add_30[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 256)  0           ['conv2d_12[0][0]']
#
#  activation_28 (Activation)     (None, 16, 16, 256)  0           ['conv2d_14[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 256)  1024       ['activation_24[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 256)  1024       ['activation_28[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 16, 16, 256)  0           ['add_14[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  add_31 (Add)                   (None, 16, 16, 256)  0           ['add_20[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  add_32 (Add)                   (None, 16, 16, 256)  0           ['add_25[0][0]',
#                                                                   'add_31[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 16, 16, 256)  6656       ['add_32[0][0]']
#  Conv2D)
#
#  activation_29 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_14[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 256)  1024       ['activation_29[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_29[0][0]',
#                                                                   'add_32[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 256)  65792       ['add_33[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 256)  0           ['conv2d_15[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 256)  1024       ['activation_30[0][0]']
#  ormalization)
#
#  add_34 (Add)                   (None, 16, 16, 256)  0           ['add_23[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 16, 16, 256)  6656       ['add_34[0][0]']
#  Conv2D)
#
#  activation_31 (Activation)     (None, 16, 16, 256)  0           ['depthwise_conv2d_15[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 256)  1024       ['activation_31[0][0]']
#  ormalization)
#
#  add_35 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_31[0][0]',
#                                                                   'add_34[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 256)  65792       ['add_35[0][0]']
#
#  activation_32 (Activation)     (None, 16, 16, 256)  0           ['conv2d_16[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 256)  1024       ['activation_32[0][0]']
#  ormalization)
#
#  add_36 (Add)                   (None, 16, 16, 256)  0           ['add_25[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_36[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 3)            771         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 1,390,595
# Trainable params: 1,373,699
# Non-trainable params: 16,896
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2023-09-23 13:20:53.152118: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype double and shape [14,3]
# 	 [[{{node Placeholder/_1}}]]
# 2023-09-23 13:20:53.152631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_12' with dtype resource
# 	 [[{{node Placeholder/_12}}]]
# 2023-09-23 13:21:01.431735: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2/2 [==============================] - ETA: 0s - loss: 3933.4358 - mean_squared_error: 3933.4358
# 2023-09-23 13:21:02.541917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_1}}]]
# 2/2 [==============================] - 10s 1s/step - loss: 3933.4358 - mean_squared_error: 3933.4358 - val_loss: 4919.8677 - val_mean_squared_error: 4919.8677
# Epoch 2/100
# 2/2 [==============================] - 0s 50ms/step - loss: 3828.9788 - mean_squared_error: 3828.9788 - val_loss: 5007.4526 - val_mean_squared_error: 5007.4526
# Epoch 3/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3699.3230 - mean_squared_error: 3699.3230 - val_loss: 5233.7505 - val_mean_squared_error: 5233.7505
# Epoch 4/100
# 2/2 [==============================] - 0s 50ms/step - loss: 3551.8582 - mean_squared_error: 3551.8582 - val_loss: 5742.1821 - val_mean_squared_error: 5742.1821
# Epoch 5/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3650.7505 - mean_squared_error: 3650.7505 - val_loss: 6693.1938 - val_mean_squared_error: 6693.1938
# Epoch 6/100
# 2/2 [==============================] - 0s 50ms/step - loss: 3537.6619 - mean_squared_error: 3537.6619 - val_loss: 6314.9629 - val_mean_squared_error: 6314.9629
# Epoch 7/100
# 2/2 [==============================] - 0s 53ms/step - loss: 3511.6785 - mean_squared_error: 3511.6785 - val_loss: 5985.9077 - val_mean_squared_error: 5985.9077
# Epoch 8/100
# 2/2 [==============================] - 0s 55ms/step - loss: 3359.8845 - mean_squared_error: 3359.8845 - val_loss: 6096.8462 - val_mean_squared_error: 6096.8462
# Epoch 9/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3254.3572 - mean_squared_error: 3254.3572 - val_loss: 5906.2480 - val_mean_squared_error: 5906.2480
# Epoch 10/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3488.5500 - mean_squared_error: 3488.5500 - val_loss: 5736.9399 - val_mean_squared_error: 5736.9399
# Epoch 11/100
# 2/2 [==============================] - 0s 50ms/step - loss: 3302.5857 - mean_squared_error: 3302.5857 - val_loss: 5081.6797 - val_mean_squared_error: 5081.6797
# Epoch 12/100
# 2/2 [==============================] - 0s 52ms/step - loss: 3107.8589 - mean_squared_error: 3107.8589 - val_loss: 4662.5776 - val_mean_squared_error: 4662.5776
# Epoch 13/100
# 2/2 [==============================] - 0s 47ms/step - loss: 3119.8169 - mean_squared_error: 3119.8169 - val_loss: 4522.9839 - val_mean_squared_error: 4522.9839
# Epoch 14/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3065.6628 - mean_squared_error: 3065.6628 - val_loss: 4735.4634 - val_mean_squared_error: 4735.4634
# Epoch 15/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3093.0737 - mean_squared_error: 3093.0737 - val_loss: 4809.6699 - val_mean_squared_error: 4809.6699
# Epoch 16/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3064.7422 - mean_squared_error: 3064.7422 - val_loss: 4567.4473 - val_mean_squared_error: 4567.4473
# Epoch 17/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3084.4185 - mean_squared_error: 3084.4185 - val_loss: 4532.9668 - val_mean_squared_error: 4532.9668
# Epoch 18/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3557.4363 - mean_squared_error: 3557.4363 - val_loss: 4209.5918 - val_mean_squared_error: 4209.5918
# Epoch 19/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2956.1047 - mean_squared_error: 2956.1047 - val_loss: 3519.3555 - val_mean_squared_error: 3519.3555
# Epoch 20/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3186.7495 - mean_squared_error: 3186.7495 - val_loss: 3728.6387 - val_mean_squared_error: 3728.6387
# Epoch 21/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3000.3665 - mean_squared_error: 3000.3665 - val_loss: 4273.9355 - val_mean_squared_error: 4273.9355
# Epoch 22/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3339.5374 - mean_squared_error: 3339.5374 - val_loss: 4749.6938 - val_mean_squared_error: 4749.6938
# Epoch 23/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2899.4548 - mean_squared_error: 2899.4548 - val_loss: 4992.6045 - val_mean_squared_error: 4992.6045
# Epoch 24/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3140.4207 - mean_squared_error: 3140.4207 - val_loss: 4589.6929 - val_mean_squared_error: 4589.6929
# Epoch 25/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2782.2878 - mean_squared_error: 2782.2878 - val_loss: 4555.1792 - val_mean_squared_error: 4555.1792
# Epoch 26/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2789.8730 - mean_squared_error: 2789.8730 - val_loss: 4900.0078 - val_mean_squared_error: 4900.0078
# Epoch 27/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2795.9927 - mean_squared_error: 2795.9927 - val_loss: 5279.2563 - val_mean_squared_error: 5279.2563
# Epoch 28/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2747.4419 - mean_squared_error: 2747.4419 - val_loss: 5271.3184 - val_mean_squared_error: 5271.3184
# Epoch 29/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2743.8884 - mean_squared_error: 2743.8884 - val_loss: 5056.4316 - val_mean_squared_error: 5056.4316
# Epoch 30/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2668.5813 - mean_squared_error: 2668.5813 - val_loss: 5269.9824 - val_mean_squared_error: 5269.9824
# Epoch 31/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2750.9175 - mean_squared_error: 2750.9175 - val_loss: 4789.5581 - val_mean_squared_error: 4789.5581
# Epoch 32/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2947.7695 - mean_squared_error: 2947.7695 - val_loss: 5349.5508 - val_mean_squared_error: 5349.5508
# Epoch 33/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2679.0083 - mean_squared_error: 2679.0083 - val_loss: 5793.0020 - val_mean_squared_error: 5793.0020
# Epoch 34/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2653.2097 - mean_squared_error: 2653.2097 - val_loss: 6204.2930 - val_mean_squared_error: 6204.2930
# Epoch 35/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2621.0759 - mean_squared_error: 2621.0759 - val_loss: 6442.3008 - val_mean_squared_error: 6442.3008
# Epoch 36/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2825.3179 - mean_squared_error: 2825.3179 - val_loss: 6770.8794 - val_mean_squared_error: 6770.8794
# Epoch 37/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2570.0664 - mean_squared_error: 2570.0664 - val_loss: 6631.2051 - val_mean_squared_error: 6631.2051
# Epoch 38/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2488.5027 - mean_squared_error: 2488.5027 - val_loss: 6031.1421 - val_mean_squared_error: 6031.1421
# Epoch 39/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2393.1682 - mean_squared_error: 2393.1682 - val_loss: 5927.2427 - val_mean_squared_error: 5927.2427
# Epoch 40/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2415.3372 - mean_squared_error: 2415.3372 - val_loss: 6478.5913 - val_mean_squared_error: 6478.5913
# Epoch 41/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2370.4692 - mean_squared_error: 2370.4692 - val_loss: 7102.3413 - val_mean_squared_error: 7102.3413
# Epoch 42/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2633.6646 - mean_squared_error: 2633.6646 - val_loss: 6448.0767 - val_mean_squared_error: 6448.0767
# Epoch 43/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2332.4233 - mean_squared_error: 2332.4233 - val_loss: 4451.1147 - val_mean_squared_error: 4451.1147
# Epoch 44/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2521.9727 - mean_squared_error: 2521.9727 - val_loss: 3562.5840 - val_mean_squared_error: 3562.5840
# Epoch 45/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2351.9685 - mean_squared_error: 2351.9685 - val_loss: 3556.4092 - val_mean_squared_error: 3556.4092
# Epoch 46/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2520.9761 - mean_squared_error: 2520.9761 - val_loss: 3634.6292 - val_mean_squared_error: 3634.6292
# Epoch 47/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2344.2505 - mean_squared_error: 2344.2505 - val_loss: 3409.9827 - val_mean_squared_error: 3409.9827
# Epoch 48/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2159.8225 - mean_squared_error: 2159.8225 - val_loss: 3457.1602 - val_mean_squared_error: 3457.1602
# Epoch 49/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2136.3782 - mean_squared_error: 2136.3782 - val_loss: 3526.5310 - val_mean_squared_error: 3526.5310
# Epoch 50/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2007.2489 - mean_squared_error: 2007.2489 - val_loss: 3595.5078 - val_mean_squared_error: 3595.5078
# Epoch 51/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2061.1682 - mean_squared_error: 2061.1682 - val_loss: 3597.4219 - val_mean_squared_error: 3597.4219
# Epoch 52/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2055.3984 - mean_squared_error: 2055.3984 - val_loss: 3615.3782 - val_mean_squared_error: 3615.3782
# Epoch 53/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2211.6726 - mean_squared_error: 2211.6726 - val_loss: 3609.5286 - val_mean_squared_error: 3609.5286
# Epoch 54/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1959.2826 - mean_squared_error: 1959.2826 - val_loss: 3451.3274 - val_mean_squared_error: 3451.3274
# Epoch 55/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1970.4026 - mean_squared_error: 1970.4026 - val_loss: 2931.7424 - val_mean_squared_error: 2931.7424
# Epoch 56/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1931.4319 - mean_squared_error: 1931.4319 - val_loss: 2664.0652 - val_mean_squared_error: 2664.0652
# Epoch 57/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1963.8073 - mean_squared_error: 1963.8073 - val_loss: 2901.1296 - val_mean_squared_error: 2901.1296
# Epoch 58/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1782.0078 - mean_squared_error: 1782.0078 - val_loss: 2951.6135 - val_mean_squared_error: 2951.6135
# Epoch 59/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1720.3180 - mean_squared_error: 1720.3180 - val_loss: 2762.8835 - val_mean_squared_error: 2762.8835
# Epoch 60/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1733.5426 - mean_squared_error: 1733.5426 - val_loss: 2515.0750 - val_mean_squared_error: 2515.0750
# Epoch 61/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1582.5675 - mean_squared_error: 1582.5675 - val_loss: 2314.7966 - val_mean_squared_error: 2314.7966
# Epoch 62/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1585.6847 - mean_squared_error: 1585.6847 - val_loss: 2209.3530 - val_mean_squared_error: 2209.3530
# Epoch 63/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1556.3245 - mean_squared_error: 1556.3245 - val_loss: 2088.6838 - val_mean_squared_error: 2088.6838
# Epoch 64/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1597.0303 - mean_squared_error: 1597.0302 - val_loss: 2169.8203 - val_mean_squared_error: 2169.8203
# Epoch 65/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1569.5612 - mean_squared_error: 1569.5612 - val_loss: 2137.3916 - val_mean_squared_error: 2137.3916
# Epoch 66/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1512.6692 - mean_squared_error: 1512.6692 - val_loss: 2216.4697 - val_mean_squared_error: 2216.4697
# Epoch 67/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1386.1760 - mean_squared_error: 1386.1760 - val_loss: 2206.2820 - val_mean_squared_error: 2206.2820
# Epoch 68/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1384.0291 - mean_squared_error: 1384.0291 - val_loss: 2052.8367 - val_mean_squared_error: 2052.8367
# Epoch 69/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1397.3019 - mean_squared_error: 1397.3019 - val_loss: 2291.7346 - val_mean_squared_error: 2291.7346
# Epoch 70/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1268.2880 - mean_squared_error: 1268.2880 - val_loss: 2693.1458 - val_mean_squared_error: 2693.1458
# Epoch 71/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1261.9769 - mean_squared_error: 1261.9769 - val_loss: 3112.1025 - val_mean_squared_error: 3112.1025
# Epoch 72/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1261.7014 - mean_squared_error: 1261.7014 - val_loss: 3248.3596 - val_mean_squared_error: 3248.3596
# Epoch 73/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1259.6212 - mean_squared_error: 1259.6212 - val_loss: 3359.4824 - val_mean_squared_error: 3359.4824
# Epoch 74/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1185.3312 - mean_squared_error: 1185.3312 - val_loss: 3733.2512 - val_mean_squared_error: 3733.2512
# Epoch 75/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1121.0903 - mean_squared_error: 1121.0903 - val_loss: 3667.6208 - val_mean_squared_error: 3667.6208
# Epoch 76/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1073.7781 - mean_squared_error: 1073.7781 - val_loss: 3740.4133 - val_mean_squared_error: 3740.4133
# Epoch 77/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1014.4683 - mean_squared_error: 1014.4683 - val_loss: 3634.6094 - val_mean_squared_error: 3634.6094
# Epoch 78/100
# 2/2 [==============================] - 0s 48ms/step - loss: 972.7231 - mean_squared_error: 972.7231 - val_loss: 3411.3357 - val_mean_squared_error: 3411.3357
# Epoch 79/100
# 2/2 [==============================] - 0s 51ms/step - loss: 955.9366 - mean_squared_error: 955.9366 - val_loss: 3018.1824 - val_mean_squared_error: 3018.1824
# Epoch 80/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1135.5424 - mean_squared_error: 1135.5424 - val_loss: 2241.2358 - val_mean_squared_error: 2241.2358
# Epoch 81/100
# 2/2 [==============================] - 0s 51ms/step - loss: 928.1812 - mean_squared_error: 928.1812 - val_loss: 1913.2798 - val_mean_squared_error: 1913.2798
# Epoch 82/100
# 2/2 [==============================] - 0s 51ms/step - loss: 981.9178 - mean_squared_error: 981.9178 - val_loss: 1884.1613 - val_mean_squared_error: 1884.1613
# Epoch 83/100
# 2/2 [==============================] - 0s 52ms/step - loss: 881.4966 - mean_squared_error: 881.4966 - val_loss: 2221.4861 - val_mean_squared_error: 2221.4861
# Epoch 84/100
# 2/2 [==============================] - 0s 55ms/step - loss: 772.2319 - mean_squared_error: 772.2319 - val_loss: 3024.5752 - val_mean_squared_error: 3024.5752
# Epoch 85/100
# 2/2 [==============================] - 0s 48ms/step - loss: 957.1258 - mean_squared_error: 957.1258 - val_loss: 3615.3489 - val_mean_squared_error: 3615.3489
# Epoch 86/100
# 2/2 [==============================] - 0s 54ms/step - loss: 945.8009 - mean_squared_error: 945.8009 - val_loss: 3914.9492 - val_mean_squared_error: 3914.9492
# Epoch 87/100
# 2/2 [==============================] - 0s 52ms/step - loss: 762.8760 - mean_squared_error: 762.8760 - val_loss: 3852.4055 - val_mean_squared_error: 3852.4055
# Epoch 88/100
# 2/2 [==============================] - 0s 52ms/step - loss: 700.4689 - mean_squared_error: 700.4689 - val_loss: 3674.9148 - val_mean_squared_error: 3674.9148
# Epoch 89/100
# 2/2 [==============================] - 0s 92ms/step - loss: 748.1265 - mean_squared_error: 748.1265 - val_loss: 3428.7891 - val_mean_squared_error: 3428.7891
# Epoch 90/100
# 2/2 [==============================] - 0s 87ms/step - loss: 725.6570 - mean_squared_error: 725.6570 - val_loss: 2980.2559 - val_mean_squared_error: 2980.2559
# Epoch 91/100
# 2/2 [==============================] - 0s 83ms/step - loss: 994.8338 - mean_squared_error: 994.8338 - val_loss: 2329.1248 - val_mean_squared_error: 2329.1248
# Epoch 92/100
# 2/2 [==============================] - 0s 93ms/step - loss: 629.1286 - mean_squared_error: 629.1286 - val_loss: 1889.0504 - val_mean_squared_error: 1889.0504
# Epoch 93/100
# 2/2 [==============================] - 0s 83ms/step - loss: 608.6577 - mean_squared_error: 608.6577 - val_loss: 1837.7148 - val_mean_squared_error: 1837.7148
# Epoch 94/100
# 2/2 [==============================] - 0s 88ms/step - loss: 525.2260 - mean_squared_error: 525.2260 - val_loss: 1939.4829 - val_mean_squared_error: 1939.4829
# Epoch 95/100
# 2/2 [==============================] - 0s 82ms/step - loss: 588.1890 - mean_squared_error: 588.1890 - val_loss: 2202.3538 - val_mean_squared_error: 2202.3538
# Epoch 96/100
# 2/2 [==============================] - 0s 77ms/step - loss: 499.1439 - mean_squared_error: 499.1439 - val_loss: 2214.9731 - val_mean_squared_error: 2214.9731
# Epoch 97/100
# 2/2 [==============================] - 0s 86ms/step - loss: 446.4325 - mean_squared_error: 446.4325 - val_loss: 2061.3833 - val_mean_squared_error: 2061.3833
# Epoch 98/100
# 2/2 [==============================] - 0s 83ms/step - loss: 421.8987 - mean_squared_error: 421.8987 - val_loss: 1912.0385 - val_mean_squared_error: 1912.0385
# Epoch 99/100
# 2/2 [==============================] - 0s 87ms/step - loss: 471.2058 - mean_squared_error: 471.2058 - val_loss: 1723.4716 - val_mean_squared_error: 1723.4716
# Epoch 100/100
# 2/2 [==============================] - 0s 49ms/step - loss: 566.1800 - mean_squared_error: 566.1800 - val_loss: 1472.9458 - val_mean_squared_error: 1472.9458
# 1/1 [==============================] - 0s 21ms/step - loss: 8538.1611 - mean_squared_error: 8538.1611
# Test error: 8538.16
# 2023-09-23 13:21:16.954671: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_1}}]]

# %%
model.save(model_save_path)

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 1s 875ms/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  17.133889026641846
# MSE:  512.6697148267423
# RMSE:  22.642210908538555
# r2_score:  -3.8588748848637584
# MSLE:  4.9647319606069376
# MAPE:  5.950613837840384e+16
# ===== flank_wear results =====
# MAE:  113.1345443725586
# MSE:  25040.82110233868
# RMSE:  158.24291801637975
# r2_score:  -0.5628676519943572
# MSLE:  1.1125448975862535
# MAPE:  0.5931822956249646
# ===== overhang results =====
# MAE:  6.661664117177328
# MSE:  60.9916988444565
# RMSE:  7.809718230797863
# r2_score:  -2.023512188781565
# MSLE:  0.40986999300998156
# MAPE:  0.4262475858090112
# ===== multi results =====
# MAE:  45.64336583879259
# MSE:  8538.160838669959
# RMSE:  62.89828238523872
# r2_score:  -2.1484182418798934
# MSLE:  2.1623822837343907
# MAPE:  1.9835379459467948e+16
