# %%
# !pip install tensorflow_addons
# !pip install keras-tuner --upgrade

# clone siren repository, refresh folder to see the siren repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Siren/
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5
# Cloning into 'Siren'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 332 (delta 16), reused 29 (delta 12), pack-reused 297
# Receiving objects: 100% (332/332), 186.05 MiB | 32.63 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# Updating files: 100% (236/236), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_spec = 9
in_channel_chip = 3
img_rows, img_cols = image_size, image_size
input_shape_spec = (img_rows, img_cols, in_channel_spec)
input_shape_chip = (img_rows, img_cols, in_channel_chip)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_sc"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_spec_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_spec.h5"
model_chip_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_chip.h5"

# dataset
csv_path = "/content/Siren/dataset/labels_reg_sample.csv"
spec_path = "/content/Siren/dataset/spec"
chip_path = "/content/Siren/dataset/chip"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                        spec_x  \
# 14   /content/Siren/dataset/spec/x/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/x/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/x/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/x/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/x/T1R7B4.jpg
#
#                                        spec_y  \
# 14   /content/Siren/dataset/spec/y/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/y/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/y/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/y/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/y/T1R7B4.jpg
#
#                                        spec_z  \
# 14   /content/Siren/dataset/spec/z/T8R3B4.jpg
# 10   /content/Siren/dataset/spec/z/T6R9B3.jpg
# 0    /content/Siren/dataset/spec/z/T1R2B1.jpg
# 3   /content/Siren/dataset/spec/z/T2R13B4.jpg
# 1    /content/Siren/dataset/spec/z/T1R7B4.jpg
#
#                                        chip
# 14   /content/Siren/dataset/chip/T8R3B4.jpg
# 10   /content/Siren/dataset/chip/T6R9B3.jpg
# 0    /content/Siren/dataset/chip/T1R2B1.jpg
# 3   /content/Siren/dataset/chip/T2R13B4.jpg
# 1    /content/Siren/dataset/chip/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                        spec_x  \
# 16   /content/Siren/dataset/spec/x/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/x/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/x/T5R12B1.jpg
#
#                                        spec_y  \
# 16   /content/Siren/dataset/spec/y/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/y/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/y/T5R12B1.jpg
#
#                                        spec_z  \
# 16   /content/Siren/dataset/spec/z/T9R7B4.jpg
# 18  /content/Siren/dataset/spec/z/T10R3B4.jpg
# 9   /content/Siren/dataset/spec/z/T5R12B1.jpg
#
#                                        chip
# 16   /content/Siren/dataset/chip/T9R7B4.jpg
# 18  /content/Siren/dataset/chip/T10R3B4.jpg
# 9   /content/Siren/dataset/chip/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                        spec_x  \
# 5   /content/Siren/dataset/spec/x/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/x/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/x/T7R8B3.jpg
#
#                                        spec_y  \
# 5   /content/Siren/dataset/spec/y/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/y/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/y/T7R8B3.jpg
#
#                                        spec_z  \
# 5   /content/Siren/dataset/spec/z/T3R10B1.jpg
# 13  /content/Siren/dataset/spec/z/T7R14B3.jpg
# 12   /content/Siren/dataset/spec/z/T7R8B3.jpg
#
#                                        chip
# 5   /content/Siren/dataset/chip/T3R10B1.jpg
# 13  /content/Siren/dataset/chip/T7R14B3.jpg
# 12   /content/Siren/dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images


def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for i in range(file_paths_x.size):
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_x)
        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_y)
        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_z)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(file_paths_x.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
# ============================== augment 1/2 ==============================
data_augmentation_spec = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_spec",
)

# %%
# ============================== augment 2/2 ==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
x_train_spec = data_augmentation_spec(x_train_spec)
x_train_chip = data_augmentation_chip(x_train_chip)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_spec": x_train_spec,
            "input_1_chip": x_train_chip,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_spec": x_test_spec,
            "input_1_chip": x_test_chip,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_spec": x_val_spec,
            "input_1_chip": x_val_chip,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs2 = k.Input(input_shape_spec)
inputs3 = k.Input(input_shape_chip)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_spec': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
model_spec = k.models.load_model(model_spec_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)

model_spec.trainable = False
model_chip.trainable = False


def load_siren(model_spec, model_chip):
    inputs2 = model_spec.input
    inputs2._name = "input_spec"
    inputs3 = model_chip.input
    inputs3._name = "input_chip"

    truncated_model_spec = k.Model(
        inputs=model_spec.input, outputs=model_spec.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_spec.output,
            truncated_model_chip.output,
        ]
    )
    output = layers.Dense(num_classes, activation="linear", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs2, inputs3], outputs=output)


for layer in model_spec.layers:
    layer._name = layer.name + str("_spec")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren(model_spec, model_chip)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1_spec (InputLayer)   [(None, 256, 256, 9)]        0         []
#
#  input_1_chip (InputLayer)   [(None, 256, 256, 3)]        0         []
#
#  conv2d_spec (Conv2D)        (None, 16, 16, 256)          590080    ['input_1_spec[0][0]']
#
#  conv2d_chip (Conv2D)        (None, 16, 16, 256)          196864    ['input_1_chip[0][0]']
#
#  activation_spec (Activatio  (None, 16, 16, 256)          0         ['conv2d_spec[0][0]']
#  n)
#
#  activation_chip (Activatio  (None, 16, 16, 256)          0         ['conv2d_chip[0][0]']
#  n)
#
#  batch_normalization_spec (  (None, 16, 16, 256)          1024      ['activation_spec[0][0]']
#  BatchNormalization)
#
#  batch_normalization_chip (  (None, 16, 16, 256)          1024      ['activation_chip[0][0]']
#  BatchNormalization)
#
#  depthwise_conv2d_spec (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_spec[0][
#  thwiseConv2D)                                                      0]']
#
#  depthwise_conv2d_chip (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_chip[0][
#  thwiseConv2D)                                                      0]']
#
#  activation_1_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_spec[0][0]'
#  ion)                                                               ]
#
#  activation_1_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_chip[0][0]'
#  ion)                                                               ]
#
#  batch_normalization_1_spec  (None, 16, 16, 256)          1024      ['activation_1_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_1_chip  (None, 16, 16, 256)          1024      ['activation_1_chip[0][0]']
#   (BatchNormalization)
#
#  add_spec (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  add_chip (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  conv2d_1_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_spec[0][0]']
#
#  conv2d_1_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_chip[0][0]']
#
#  activation_2_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_1_spec[0][0]']
#  ion)
#
#  activation_2_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_1_chip[0][0]']
#  ion)
#
#  batch_normalization_2_spec  (None, 16, 16, 256)          1024      ['activation_2_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_2_chip  (None, 16, 16, 256)          1024      ['activation_2_chip[0][0]']
#   (BatchNormalization)
#
#  depthwise_conv2d_1_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  depthwise_conv2d_1_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_3_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_spec[0][0
#  ion)                                                               ]']
#
#  activation_3_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_3_spec  (None, 16, 16, 256)          1024      ['activation_3_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_3_chip  (None, 16, 16, 256)          1024      ['activation_3_chip[0][0]']
#   (BatchNormalization)
#
#  add_1_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_spec[0
#                                                                     ][0]']
#
#  add_1_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_chip[0
#                                                                     ][0]']
#
#  conv2d_2_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_spec[0][0]']
#
#  conv2d_2_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_chip[0][0]']
#
#  activation_4_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_2_spec[0][0]']
#  ion)
#
#  activation_4_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_2_chip[0][0]']
#  ion)
#
#  batch_normalization_4_spec  (None, 16, 16, 256)          1024      ['activation_4_spec[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_4_chip  (None, 16, 16, 256)          1024      ['activation_4_chip[0][0]']
#   (BatchNormalization)
#
#  add_4_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  add_4_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  depthwise_conv2d_4_spec (D  (None, 16, 16, 256)          6656      ['add_4_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_4_chip (D  (None, 16, 16, 256)          6656      ['add_4_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_2_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_spec[0][0
#  ion)                                                               ]']
#
#  depthwise_conv2d_2_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_chip[0][0
#  ion)                                                               ]']
#
#  activation_5_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_spec[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_spec  (None, 16, 16, 256)          1024      ['activation_9_spec[0][0]']
#   (BatchNormalization)
#
#  activation_5_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_chip  (None, 16, 16, 256)          1024      ['activation_9_chip[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_5_spec  (None, 16, 16, 256)          1024      ['activation_5_spec[0][0]']
#   (BatchNormalization)
#
#  add_5_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_spec[0
#                                                                     ][0]',
#                                                                      'add_4_spec[0][0]']
#
#  batch_normalization_5_chip  (None, 16, 16, 256)          1024      ['activation_5_chip[0][0]']
#   (BatchNormalization)
#
#  add_5_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_chip[0
#                                                                     ][0]',
#                                                                      'add_4_chip[0][0]']
#
#  add_2_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_spec[0
#                                                                     ][0]']
#
#  conv2d_5_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_spec[0][0]']
#
#  add_2_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_chip[0
#                                                                     ][0]']
#
#  conv2d_5_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_chip[0][0]']
#
#  conv2d_3_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_spec[0][0]']
#
#  activation_10_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_5_spec[0][0]']
#  tion)
#
#  conv2d_3_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_chip[0][0]']
#
#  activation_10_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_5_chip[0][0]']
#  tion)
#
#  activation_6_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_3_spec[0][0]']
#  ion)
#
#  batch_normalization_10_spe  (None, 16, 16, 256)          1024      ['activation_10_spec[0][0]']
#  c (BatchNormalization)
#
#  activation_6_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_3_chip[0][0]']
#  ion)
#
#  batch_normalization_10_chi  (None, 16, 16, 256)          1024      ['activation_10_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_6_spec  (None, 16, 16, 256)          1024      ['activation_6_spec[0][0]']
#   (BatchNormalization)
#
#  add_6_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_spec[
#                                                                     0][0]']
#
#  batch_normalization_6_chip  (None, 16, 16, 256)          1024      ['activation_6_chip[0][0]']
#   (BatchNormalization)
#
#  add_6_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_chip[
#                                                                     0][0]']
#
#  add_7_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_spec[0
#                                                                     ][0]',
#                                                                      'add_6_spec[0][0]']
#
#  add_7_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_chip[0
#                                                                     ][0]',
#                                                                      'add_6_chip[0][0]']
#
#  depthwise_conv2d_5_spec (D  (None, 16, 16, 256)          6656      ['add_7_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_5_chip (D  (None, 16, 16, 256)          6656      ['add_7_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_3_spec (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_spec[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_spec[0][0
#  tion)                                                              ]']
#
#  depthwise_conv2d_3_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_chip[0][0
#  tion)                                                              ]']
#
#  activation_7_spec (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_spec[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_spe  (None, 16, 16, 256)          1024      ['activation_11_spec[0][0]']
#  c (BatchNormalization)
#
#  activation_7_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_chi  (None, 16, 16, 256)          1024      ['activation_11_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_7_spec  (None, 16, 16, 256)          1024      ['activation_7_spec[0][0]']
#   (BatchNormalization)
#
#  add_8_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_spec[
#                                                                     0][0]',
#                                                                      'add_7_spec[0][0]']
#
#  batch_normalization_7_chip  (None, 16, 16, 256)          1024      ['activation_7_chip[0][0]']
#   (BatchNormalization)
#
#  add_8_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_chip[
#                                                                     0][0]',
#                                                                      'add_7_chip[0][0]']
#
#  add_3_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_spec[0
#                                                                     ][0]']
#
#  conv2d_6_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_spec[0][0]']
#
#  add_3_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_chip[0
#                                                                     ][0]']
#
#  conv2d_6_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_chip[0][0]']
#
#  conv2d_4_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_spec[0][0]']
#
#  activation_12_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_6_spec[0][0]']
#  tion)
#
#  conv2d_4_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_chip[0][0]']
#
#  activation_12_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_6_chip[0][0]']
#  tion)
#
#  activation_8_spec (Activat  (None, 16, 16, 256)          0         ['conv2d_4_spec[0][0]']
#  ion)
#
#  batch_normalization_12_spe  (None, 16, 16, 256)          1024      ['activation_12_spec[0][0]']
#  c (BatchNormalization)
#
#  activation_8_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_4_chip[0][0]']
#  ion)
#
#  batch_normalization_12_chi  (None, 16, 16, 256)          1024      ['activation_12_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_8_spec  (None, 16, 16, 256)          1024      ['activation_8_spec[0][0]']
#   (BatchNormalization)
#
#  add_9_spec (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_spec[
#                                                                     0][0]']
#
#  batch_normalization_8_chip  (None, 16, 16, 256)          1024      ['activation_8_chip[0][0]']
#   (BatchNormalization)
#
#  add_9_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_chip[
#                                                                     0][0]']
#
#  add_10_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_8_spec[0
#                                                                     ][0]',
#                                                                      'add_9_spec[0][0]']
#
#  add_15_spec (Add)           (None, 16, 16, 256)          0         ['add_9_spec[0][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  add_10_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_8_chip[0
#                                                                     ][0]',
#                                                                      'add_9_chip[0][0]']
#
#  add_15_chip (Add)           (None, 16, 16, 256)          0         ['add_9_chip[0][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  depthwise_conv2d_6_spec (D  (None, 16, 16, 256)          6656      ['add_10_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_8_spec (D  (None, 16, 16, 256)          6656      ['add_15_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_6_chip (D  (None, 16, 16, 256)          6656      ['add_10_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_8_chip (D  (None, 16, 16, 256)          6656      ['add_15_chip[0][0]']
#  epthwiseConv2D)
#
#  activation_13_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_6_spec[0][0
#  tion)                                                              ]']
#
#  activation_17_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_8_spec[0][0
#  tion)                                                              ]']
#
#  activation_13_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_6_chip[0][0
#  tion)                                                              ]']
#
#  activation_17_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_8_chip[0][0
#  tion)                                                              ]']
#
#  batch_normalization_13_spe  (None, 16, 16, 256)          1024      ['activation_13_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_17_spe  (None, 16, 16, 256)          1024      ['activation_17_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_13_chi  (None, 16, 16, 256)          1024      ['activation_13_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_17_chi  (None, 16, 16, 256)          1024      ['activation_17_chip[0][0]']
#  p (BatchNormalization)
#
#  add_11_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_13_spec[
#                                                                     0][0]',
#                                                                      'add_10_spec[0][0]']
#
#  add_16_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_17_spec[
#                                                                     0][0]',
#                                                                      'add_15_spec[0][0]']
#
#  add_11_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_13_chip[
#                                                                     0][0]',
#                                                                      'add_10_chip[0][0]']
#
#  add_16_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_17_chip[
#                                                                     0][0]',
#                                                                      'add_15_chip[0][0]']
#
#  conv2d_7_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_11_spec[0][0]']
#
#  conv2d_9_spec (Conv2D)      (None, 16, 16, 256)          65792     ['add_16_spec[0][0]']
#
#  conv2d_7_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_11_chip[0][0]']
#
#  conv2d_9_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_16_chip[0][0]']
#
#  activation_14_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_7_spec[0][0]']
#  tion)
#
#  activation_18_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_9_spec[0][0]']
#  tion)
#
#  activation_14_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_7_chip[0][0]']
#  tion)
#
#  activation_18_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_9_chip[0][0]']
#  tion)
#
#  batch_normalization_14_spe  (None, 16, 16, 256)          1024      ['activation_14_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_18_spe  (None, 16, 16, 256)          1024      ['activation_18_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_14_chi  (None, 16, 16, 256)          1024      ['activation_14_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_18_chi  (None, 16, 16, 256)          1024      ['activation_18_chip[0][0]']
#  p (BatchNormalization)
#
#  add_12_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_6_spec[0
#                                                                     ][0]',
#                                                                      'batch_normalization_14_spec[
#                                                                     0][0]']
#
#  add_17_spec (Add)           (None, 16, 16, 256)          0         ['add_6_spec[0][0]',
#                                                                      'batch_normalization_18_spec[
#                                                                     0][0]']
#
#  add_12_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_6_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_14_chip[
#                                                                     0][0]']
#
#  add_17_chip (Add)           (None, 16, 16, 256)          0         ['add_6_chip[0][0]',
#                                                                      'batch_normalization_18_chip[
#                                                                     0][0]']
#
#  add_18_spec (Add)           (None, 16, 16, 256)          0         ['add_12_spec[0][0]',
#                                                                      'add_17_spec[0][0]']
#
#  add_18_chip (Add)           (None, 16, 16, 256)          0         ['add_12_chip[0][0]',
#                                                                      'add_17_chip[0][0]']
#
#  depthwise_conv2d_7_spec (D  (None, 16, 16, 256)          6656      ['add_12_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_9_spec (D  (None, 16, 16, 256)          6656      ['add_18_spec[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_7_chip (D  (None, 16, 16, 256)          6656      ['add_12_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_9_chip (D  (None, 16, 16, 256)          6656      ['add_18_chip[0][0]']
#  epthwiseConv2D)
#
#  activation_15_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_7_spec[0][0
#  tion)                                                              ]']
#
#  activation_19_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_9_spec[0][0
#  tion)                                                              ]']
#
#  activation_15_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_7_chip[0][0
#  tion)                                                              ]']
#
#  activation_19_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_9_chip[0][0
#  tion)                                                              ]']
#
#  batch_normalization_15_spe  (None, 16, 16, 256)          1024      ['activation_15_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_19_spe  (None, 16, 16, 256)          1024      ['activation_19_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_15_chi  (None, 16, 16, 256)          1024      ['activation_15_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_19_chi  (None, 16, 16, 256)          1024      ['activation_19_chip[0][0]']
#  p (BatchNormalization)
#
#  add_13_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_15_spec[
#                                                                     0][0]',
#                                                                      'add_12_spec[0][0]']
# ...
#  activation_28_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_14_spec[0][0]']
#  tion)
#
#  activation_24_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_12_chip[0][0]']
#  tion)
#
#  activation_28_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_14_chip[0][0]']
#  tion)
#
#  batch_normalization_24_spe  (None, 16, 16, 256)          1024      ['activation_24_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_28_spe  (None, 16, 16, 256)          1024      ['activation_28_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_24_chi  (None, 16, 16, 256)          1024      ['activation_24_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_28_chi  (None, 16, 16, 256)          1024      ['activation_28_chip[0][0]']
#  p (BatchNormalization)
#
#  add_25_spec (Add)           (None, 16, 16, 256)          0         ['add_14_spec[0][0]',
#                                                                      'batch_normalization_24_spec[
#                                                                     0][0]']
#
#  add_31_spec (Add)           (None, 16, 16, 256)          0         ['add_20_spec[0][0]',
#                                                                      'batch_normalization_28_spec[
#                                                                     0][0]']
#
#  add_25_chip (Add)           (None, 16, 16, 256)          0         ['add_14_chip[0][0]',
#                                                                      'batch_normalization_24_chip[
#                                                                     0][0]']
#
#  add_31_chip (Add)           (None, 16, 16, 256)          0         ['add_20_chip[0][0]',
#                                                                      'batch_normalization_28_chip[
#                                                                     0][0]']
#
#  add_32_spec (Add)           (None, 16, 16, 256)          0         ['add_25_spec[0][0]',
#                                                                      'add_31_spec[0][0]']
#
#  add_32_chip (Add)           (None, 16, 16, 256)          0         ['add_25_chip[0][0]',
#                                                                      'add_31_chip[0][0]']
#
#  depthwise_conv2d_14_spec (  (None, 16, 16, 256)          6656      ['add_32_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_14_chip (  (None, 16, 16, 256)          6656      ['add_32_chip[0][0]']
#  DepthwiseConv2D)
#
#  activation_29_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_14_spec[0][
#  tion)                                                              0]']
#
#  activation_29_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_14_chip[0][
#  tion)                                                              0]']
#
#  batch_normalization_29_spe  (None, 16, 16, 256)          1024      ['activation_29_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_29_chi  (None, 16, 16, 256)          1024      ['activation_29_chip[0][0]']
#  p (BatchNormalization)
#
#  add_33_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_spec[
#                                                                     0][0]',
#                                                                      'add_32_spec[0][0]']
#
#  add_33_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_chip[
#                                                                     0][0]',
#                                                                      'add_32_chip[0][0]']
#
#  conv2d_15_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_spec[0][0]']
#
#  conv2d_15_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_chip[0][0]']
#
#  activation_30_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_15_spec[0][0]']
#  tion)
#
#  activation_30_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_15_chip[0][0]']
#  tion)
#
#  batch_normalization_30_spe  (None, 16, 16, 256)          1024      ['activation_30_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_30_chi  (None, 16, 16, 256)          1024      ['activation_30_chip[0][0]']
#  p (BatchNormalization)
#
#  add_34_spec (Add)           (None, 16, 16, 256)          0         ['add_23_spec[0][0]',
#                                                                      'batch_normalization_30_spec[
#                                                                     0][0]']
#
#  add_34_chip (Add)           (None, 16, 16, 256)          0         ['add_23_chip[0][0]',
#                                                                      'batch_normalization_30_chip[
#                                                                     0][0]']
#
#  depthwise_conv2d_15_spec (  (None, 16, 16, 256)          6656      ['add_34_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_15_chip (  (None, 16, 16, 256)          6656      ['add_34_chip[0][0]']
#  DepthwiseConv2D)
#
#  activation_31_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_spec[0][
#  tion)                                                              0]']
#
#  activation_31_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_chip[0][
#  tion)                                                              0]']
#
#  batch_normalization_31_spe  (None, 16, 16, 256)          1024      ['activation_31_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_31_chi  (None, 16, 16, 256)          1024      ['activation_31_chip[0][0]']
#  p (BatchNormalization)
#
#  add_35_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_spec[
#                                                                     0][0]',
#                                                                      'add_34_spec[0][0]']
#
#  add_35_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_chip[
#                                                                     0][0]',
#                                                                      'add_34_chip[0][0]']
#
#  conv2d_16_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_spec[0][0]']
#
#  conv2d_16_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_chip[0][0]']
#
#  activation_32_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_16_spec[0][0]']
#  tion)
#
#  activation_32_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_16_chip[0][0]']
#  tion)
#
#  batch_normalization_32_spe  (None, 16, 16, 256)          1024      ['activation_32_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_32_chi  (None, 16, 16, 256)          1024      ['activation_32_chip[0][0]']
#  p (BatchNormalization)
#
#  add_36_spec (Add)           (None, 16, 16, 256)          0         ['add_25_spec[0][0]',
#                                                                      'batch_normalization_32_spec[
#                                                                     0][0]']
#
#  add_36_chip (Add)           (None, 16, 16, 256)          0         ['add_25_chip[0][0]',
#                                                                      'batch_normalization_32_chip[
#                                                                     0][0]']
#
#  global_average_pooling2d_s  (None, 256)                  0         ['add_36_spec[0][0]']
#  pec (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_c  (None, 256)                  0         ['add_36_chip[0][0]']
#  hip (GlobalAveragePooling2
#  D)
#
#  concatenate (Concatenate)   (None, 512)                  0         ['global_average_pooling2d_spe
#                                                                     c[0][0]',
#                                                                      'global_average_pooling2d_chi
#                                                                     p[0][0]']
#
#  output_mult (Dense)         (None, 3)                    1539      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3174403 (12.11 MB)
# Trainable params: 1539 (6.01 KB)
# Non-trainable params: 3172864 (12.10 MB)
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 21s 2s/step - loss: 3760.6980 - mean_squared_error: 3760.6980 - val_loss: 4718.5986 - val_mean_squared_error: 4718.5986
# Epoch 2/100
# 2/2 [==============================] - 1s 460ms/step - loss: 3681.0435 - mean_squared_error: 3681.0435 - val_loss: 4612.2710 - val_mean_squared_error: 4612.2710
# Epoch 3/100
# 2/2 [==============================] - 1s 460ms/step - loss: 3601.7070 - mean_squared_error: 3601.7070 - val_loss: 4508.0620 - val_mean_squared_error: 4508.0620
# Epoch 4/100
# 2/2 [==============================] - 2s 802ms/step - loss: 3517.0559 - mean_squared_error: 3517.0559 - val_loss: 4406.7578 - val_mean_squared_error: 4406.7578
# Epoch 5/100
# 2/2 [==============================] - 1s 453ms/step - loss: 3442.1697 - mean_squared_error: 3442.1697 - val_loss: 4307.7231 - val_mean_squared_error: 4307.7231
# Epoch 6/100
# 2/2 [==============================] - 1s 458ms/step - loss: 3370.7991 - mean_squared_error: 3370.7991 - val_loss: 4211.2612 - val_mean_squared_error: 4211.2612
# Epoch 7/100
# 2/2 [==============================] - 1s 456ms/step - loss: 3299.4214 - mean_squared_error: 3299.4214 - val_loss: 4118.2471 - val_mean_squared_error: 4118.2471
# Epoch 8/100
# 2/2 [==============================] - 1s 450ms/step - loss: 3219.9702 - mean_squared_error: 3219.9702 - val_loss: 4028.7383 - val_mean_squared_error: 4028.7383
# Epoch 9/100
# 2/2 [==============================] - 1s 623ms/step - loss: 3159.8599 - mean_squared_error: 3159.8599 - val_loss: 3940.6387 - val_mean_squared_error: 3940.6387
# Epoch 10/100
# 2/2 [==============================] - 1s 478ms/step - loss: 3092.9114 - mean_squared_error: 3092.9114 - val_loss: 3855.1270 - val_mean_squared_error: 3855.1270
# Epoch 11/100
# 2/2 [==============================] - 1s 451ms/step - loss: 3023.0520 - mean_squared_error: 3023.0520 - val_loss: 3772.3896 - val_mean_squared_error: 3772.3896
# Epoch 12/100
# 2/2 [==============================] - 1s 449ms/step - loss: 2963.7478 - mean_squared_error: 2963.7478 - val_loss: 3691.3723 - val_mean_squared_error: 3691.3723
# Epoch 13/100
# 2/2 [==============================] - 1s 459ms/step - loss: 2899.1301 - mean_squared_error: 2899.1301 - val_loss: 3612.0417 - val_mean_squared_error: 3612.0417
# Epoch 14/100
# 2/2 [==============================] - 1s 515ms/step - loss: 2846.9587 - mean_squared_error: 2846.9587 - val_loss: 3534.1797 - val_mean_squared_error: 3534.1797
# Epoch 15/100
# 2/2 [==============================] - 1s 743ms/step - loss: 2784.6421 - mean_squared_error: 2784.6421 - val_loss: 3458.6133 - val_mean_squared_error: 3458.6133
# Epoch 16/100
# 2/2 [==============================] - 1s 664ms/step - loss: 2726.6685 - mean_squared_error: 2726.6685 - val_loss: 3385.0486 - val_mean_squared_error: 3385.0486
# Epoch 17/100
# 2/2 [==============================] - 1s 470ms/step - loss: 2674.7383 - mean_squared_error: 2674.7383 - val_loss: 3312.6956 - val_mean_squared_error: 3312.6956
# Epoch 18/100
# 2/2 [==============================] - 1s 457ms/step - loss: 2619.7971 - mean_squared_error: 2619.7971 - val_loss: 3242.1863 - val_mean_squared_error: 3242.1863
# Epoch 19/100
# 2/2 [==============================] - 1s 457ms/step - loss: 2573.3284 - mean_squared_error: 2573.3284 - val_loss: 3172.7893 - val_mean_squared_error: 3172.7893
# Epoch 20/100
# 2/2 [==============================] - 1s 473ms/step - loss: 2520.4216 - mean_squared_error: 2520.4216 - val_loss: 3105.6243 - val_mean_squared_error: 3105.6243
# Epoch 21/100
# 2/2 [==============================] - 1s 461ms/step - loss: 2468.8967 - mean_squared_error: 2468.8967 - val_loss: 3039.7068 - val_mean_squared_error: 3039.7068
# Epoch 22/100
# 2/2 [==============================] - 1s 458ms/step - loss: 2424.7114 - mean_squared_error: 2424.7114 - val_loss: 2975.1875 - val_mean_squared_error: 2975.1875
# Epoch 23/100
# 2/2 [==============================] - 1s 447ms/step - loss: 2378.9292 - mean_squared_error: 2378.9292 - val_loss: 2912.1514 - val_mean_squared_error: 2912.1514
# Epoch 24/100
# 2/2 [==============================] - 1s 439ms/step - loss: 2332.8276 - mean_squared_error: 2332.8276 - val_loss: 2850.6924 - val_mean_squared_error: 2850.6924
# Epoch 25/100
# 2/2 [==============================] - 1s 453ms/step - loss: 2286.1868 - mean_squared_error: 2286.1868 - val_loss: 2791.1614 - val_mean_squared_error: 2791.1614
# Epoch 26/100
# 2/2 [==============================] - 1s 766ms/step - loss: 2244.0403 - mean_squared_error: 2244.0403 - val_loss: 2731.6448 - val_mean_squared_error: 2731.6448
# Epoch 27/100
# 2/2 [==============================] - 1s 703ms/step - loss: 2198.2720 - mean_squared_error: 2198.2720 - val_loss: 2673.9749 - val_mean_squared_error: 2673.9749
# Epoch 28/100
# 2/2 [==============================] - 1s 457ms/step - loss: 2161.7883 - mean_squared_error: 2161.7883 - val_loss: 2617.1868 - val_mean_squared_error: 2617.1868
# Epoch 29/100
# 2/2 [==============================] - 1s 466ms/step - loss: 2120.5200 - mean_squared_error: 2120.5200 - val_loss: 2561.5686 - val_mean_squared_error: 2561.5686
# Epoch 30/100
# 2/2 [==============================] - 1s 463ms/step - loss: 2082.2419 - mean_squared_error: 2082.2419 - val_loss: 2506.7595 - val_mean_squared_error: 2506.7595
# Epoch 31/100
# 2/2 [==============================] - 1s 603ms/step - loss: 2043.9092 - mean_squared_error: 2043.9092 - val_loss: 2453.1057 - val_mean_squared_error: 2453.1057
# Epoch 32/100
# 2/2 [==============================] - 1s 449ms/step - loss: 2002.2799 - mean_squared_error: 2002.2799 - val_loss: 2401.0867 - val_mean_squared_error: 2401.0867
# Epoch 33/100
# 2/2 [==============================] - 1s 459ms/step - loss: 1966.5314 - mean_squared_error: 1966.5314 - val_loss: 2349.6094 - val_mean_squared_error: 2349.6094
# Epoch 34/100
# 2/2 [==============================] - 1s 472ms/step - loss: 1931.9216 - mean_squared_error: 1931.9216 - val_loss: 2299.5315 - val_mean_squared_error: 2299.5315
# Epoch 35/100
# 2/2 [==============================] - 1s 458ms/step - loss: 1899.3584 - mean_squared_error: 1899.3584 - val_loss: 2249.5925 - val_mean_squared_error: 2249.5925
# Epoch 36/100
# 2/2 [==============================] - 1s 840ms/step - loss: 1861.3440 - mean_squared_error: 1861.3440 - val_loss: 2200.8904 - val_mean_squared_error: 2200.8904
# Epoch 37/100
# 2/2 [==============================] - 1s 474ms/step - loss: 1831.3809 - mean_squared_error: 1831.3809 - val_loss: 2153.2722 - val_mean_squared_error: 2153.2722
# Epoch 38/100
# 2/2 [==============================] - 1s 444ms/step - loss: 1798.7336 - mean_squared_error: 1798.7336 - val_loss: 2106.9421 - val_mean_squared_error: 2106.9421
# Epoch 39/100
# 2/2 [==============================] - 1s 466ms/step - loss: 1763.8549 - mean_squared_error: 1763.8549 - val_loss: 2061.7595 - val_mean_squared_error: 2061.7595
# Epoch 40/100
# 2/2 [==============================] - 1s 477ms/step - loss: 1733.8184 - mean_squared_error: 1733.8184 - val_loss: 2017.4945 - val_mean_squared_error: 2017.4945
# Epoch 41/100
# 2/2 [==============================] - 1s 457ms/step - loss: 1705.9589 - mean_squared_error: 1705.9589 - val_loss: 1974.7808 - val_mean_squared_error: 1974.7808
# Epoch 42/100
# 2/2 [==============================] - 1s 625ms/step - loss: 1677.4557 - mean_squared_error: 1677.4557 - val_loss: 1932.9491 - val_mean_squared_error: 1932.9491
# Epoch 43/100
# 2/2 [==============================] - 1s 464ms/step - loss: 1645.6090 - mean_squared_error: 1645.6090 - val_loss: 1892.3468 - val_mean_squared_error: 1892.3468
# Epoch 44/100
# 2/2 [==============================] - 1s 468ms/step - loss: 1617.9459 - mean_squared_error: 1617.9459 - val_loss: 1852.8964 - val_mean_squared_error: 1852.8964
# Epoch 45/100
# 2/2 [==============================] - 1s 452ms/step - loss: 1593.6833 - mean_squared_error: 1593.6835 - val_loss: 1814.5822 - val_mean_squared_error: 1814.5822
# Epoch 46/100
# 2/2 [==============================] - 1s 799ms/step - loss: 1565.9738 - mean_squared_error: 1565.9738 - val_loss: 1777.4141 - val_mean_squared_error: 1777.4141
# Epoch 47/100
# 2/2 [==============================] - 1s 454ms/step - loss: 1541.9874 - mean_squared_error: 1541.9874 - val_loss: 1740.6636 - val_mean_squared_error: 1740.6636
# Epoch 48/100
# 2/2 [==============================] - 1s 465ms/step - loss: 1516.3763 - mean_squared_error: 1516.3763 - val_loss: 1704.5160 - val_mean_squared_error: 1704.5160
# Epoch 49/100
# 2/2 [==============================] - 1s 446ms/step - loss: 1489.4044 - mean_squared_error: 1489.4045 - val_loss: 1669.5586 - val_mean_squared_error: 1669.5586
# Epoch 50/100
# 2/2 [==============================] - 1s 454ms/step - loss: 1464.8555 - mean_squared_error: 1464.8555 - val_loss: 1635.4517 - val_mean_squared_error: 1635.4517
# Epoch 51/100
# 2/2 [==============================] - 1s 448ms/step - loss: 1442.4988 - mean_squared_error: 1442.4988 - val_loss: 1601.7754 - val_mean_squared_error: 1601.7754
# Epoch 52/100
# 2/2 [==============================] - 1s 460ms/step - loss: 1423.6603 - mean_squared_error: 1423.6603 - val_loss: 1568.3506 - val_mean_squared_error: 1568.3506
# Epoch 53/100
# 2/2 [==============================] - 1s 468ms/step - loss: 1398.9120 - mean_squared_error: 1398.9120 - val_loss: 1535.6816 - val_mean_squared_error: 1535.6816
# Epoch 54/100
# 2/2 [==============================] - 1s 467ms/step - loss: 1380.3317 - mean_squared_error: 1380.3317 - val_loss: 1504.0229 - val_mean_squared_error: 1504.0229
# Epoch 55/100
# 2/2 [==============================] - 1s 465ms/step - loss: 1358.9746 - mean_squared_error: 1358.9746 - val_loss: 1473.5616 - val_mean_squared_error: 1473.5616
# Epoch 56/100
# 2/2 [==============================] - 1s 780ms/step - loss: 1337.2980 - mean_squared_error: 1337.2980 - val_loss: 1444.0739 - val_mean_squared_error: 1444.0739
# Epoch 57/100
# 2/2 [==============================] - 1s 751ms/step - loss: 1317.6302 - mean_squared_error: 1317.6302 - val_loss: 1414.9354 - val_mean_squared_error: 1414.9354
# Epoch 58/100
# 2/2 [==============================] - 1s 464ms/step - loss: 1296.5167 - mean_squared_error: 1296.5167 - val_loss: 1386.3329 - val_mean_squared_error: 1386.3329
# Epoch 59/100
# 2/2 [==============================] - 1s 491ms/step - loss: 1281.8256 - mean_squared_error: 1281.8256 - val_loss: 1357.9884 - val_mean_squared_error: 1357.9884
# Epoch 60/100
# 2/2 [==============================] - 1s 469ms/step - loss: 1261.0248 - mean_squared_error: 1261.0248 - val_loss: 1330.2009 - val_mean_squared_error: 1330.2009
# Epoch 61/100
# 2/2 [==============================] - 1s 499ms/step - loss: 1243.5145 - mean_squared_error: 1243.5145 - val_loss: 1303.3641 - val_mean_squared_error: 1303.3641
# Epoch 62/100
# 2/2 [==============================] - 1s 490ms/step - loss: 1229.3943 - mean_squared_error: 1229.3943 - val_loss: 1277.4369 - val_mean_squared_error: 1277.4369
# Epoch 63/100
# 2/2 [==============================] - 1s 798ms/step - loss: 1209.7570 - mean_squared_error: 1209.7570 - val_loss: 1252.3568 - val_mean_squared_error: 1252.3568
# Epoch 64/100
# 2/2 [==============================] - 1s 806ms/step - loss: 1194.8019 - mean_squared_error: 1194.8019 - val_loss: 1228.7017 - val_mean_squared_error: 1228.7017
# Epoch 65/100
# 2/2 [==============================] - 1s 767ms/step - loss: 1176.7294 - mean_squared_error: 1176.7294 - val_loss: 1205.4430 - val_mean_squared_error: 1205.4430
# Epoch 66/100
# 2/2 [==============================] - 1s 460ms/step - loss: 1160.5697 - mean_squared_error: 1160.5698 - val_loss: 1182.6047 - val_mean_squared_error: 1182.6047
# Epoch 67/100
# 2/2 [==============================] - 1s 467ms/step - loss: 1147.4076 - mean_squared_error: 1147.4076 - val_loss: 1159.3970 - val_mean_squared_error: 1159.3970
# Epoch 68/100
# 2/2 [==============================] - 1s 462ms/step - loss: 1133.1847 - mean_squared_error: 1133.1847 - val_loss: 1137.4229 - val_mean_squared_error: 1137.4229
# Epoch 69/100
# 2/2 [==============================] - 1s 463ms/step - loss: 1119.0193 - mean_squared_error: 1119.0193 - val_loss: 1115.7504 - val_mean_squared_error: 1115.7504
# Epoch 70/100
# 2/2 [==============================] - 1s 463ms/step - loss: 1106.8499 - mean_squared_error: 1106.8499 - val_loss: 1095.3153 - val_mean_squared_error: 1095.3153
# Epoch 71/100
# 2/2 [==============================] - 1s 468ms/step - loss: 1093.5480 - mean_squared_error: 1093.5480 - val_loss: 1075.2850 - val_mean_squared_error: 1075.2850
# Epoch 72/100
# 2/2 [==============================] - 1s 462ms/step - loss: 1076.3818 - mean_squared_error: 1076.3818 - val_loss: 1056.1354 - val_mean_squared_error: 1056.1354
# Epoch 73/100
# 2/2 [==============================] - 1s 481ms/step - loss: 1067.6326 - mean_squared_error: 1067.6326 - val_loss: 1036.9429 - val_mean_squared_error: 1036.9429
# Epoch 74/100
# 2/2 [==============================] - 1s 443ms/step - loss: 1055.5933 - mean_squared_error: 1055.5933 - val_loss: 1018.2682 - val_mean_squared_error: 1018.2682
# Epoch 75/100
# 2/2 [==============================] - 1s 877ms/step - loss: 1041.7601 - mean_squared_error: 1041.7601 - val_loss: 999.9111 - val_mean_squared_error: 999.9111
# Epoch 76/100
# 2/2 [==============================] - 2s 1s/step - loss: 1029.8347 - mean_squared_error: 1029.8347 - val_loss: 982.4587 - val_mean_squared_error: 982.4587
# Epoch 77/100
# 2/2 [==============================] - 1s 470ms/step - loss: 1022.1927 - mean_squared_error: 1022.1927 - val_loss: 965.3437 - val_mean_squared_error: 965.3437
# Epoch 78/100
# 2/2 [==============================] - 1s 807ms/step - loss: 1007.4968 - mean_squared_error: 1007.4968 - val_loss: 948.6988 - val_mean_squared_error: 948.6988
# Epoch 79/100
# 2/2 [==============================] - 1s 454ms/step - loss: 999.1708 - mean_squared_error: 999.1708 - val_loss: 931.7661 - val_mean_squared_error: 931.7661
# Epoch 80/100
# 2/2 [==============================] - 1s 447ms/step - loss: 989.9188 - mean_squared_error: 989.9188 - val_loss: 916.0134 - val_mean_squared_error: 916.0134
# Epoch 81/100
# 2/2 [==============================] - 1s 463ms/step - loss: 978.4299 - mean_squared_error: 978.4299 - val_loss: 900.4765 - val_mean_squared_error: 900.4765
# Epoch 82/100
# 2/2 [==============================] - 1s 465ms/step - loss: 969.9780 - mean_squared_error: 969.9780 - val_loss: 886.1295 - val_mean_squared_error: 886.1295
# Epoch 83/100
# 2/2 [==============================] - 1s 466ms/step - loss: 961.2883 - mean_squared_error: 961.2883 - val_loss: 872.1077 - val_mean_squared_error: 872.1077
# Epoch 84/100
# 2/2 [==============================] - 1s 692ms/step - loss: 950.3110 - mean_squared_error: 950.3110 - val_loss: 858.0359 - val_mean_squared_error: 858.0359
# Epoch 85/100
# 2/2 [==============================] - 1s 783ms/step - loss: 943.1046 - mean_squared_error: 943.1046 - val_loss: 843.9200 - val_mean_squared_error: 843.9200
# Epoch 86/100
# 2/2 [==============================] - 1s 446ms/step - loss: 933.8890 - mean_squared_error: 933.8890 - val_loss: 830.9278 - val_mean_squared_error: 830.9278
# Epoch 87/100
# 2/2 [==============================] - 1s 459ms/step - loss: 927.6104 - mean_squared_error: 927.6104 - val_loss: 818.5750 - val_mean_squared_error: 818.5750
# Epoch 88/100
# 2/2 [==============================] - 1s 469ms/step - loss: 917.0558 - mean_squared_error: 917.0558 - val_loss: 806.6219 - val_mean_squared_error: 806.6219
# Epoch 89/100
# 2/2 [==============================] - 1s 457ms/step - loss: 909.7952 - mean_squared_error: 909.7952 - val_loss: 794.5573 - val_mean_squared_error: 794.5573
# Epoch 90/100
# 2/2 [==============================] - 1s 457ms/step - loss: 903.2764 - mean_squared_error: 903.2764 - val_loss: 783.7261 - val_mean_squared_error: 783.7261
# Epoch 91/100
# 2/2 [==============================] - 1s 458ms/step - loss: 894.4166 - mean_squared_error: 894.4166 - val_loss: 772.3641 - val_mean_squared_error: 772.3641
# Epoch 92/100
# 2/2 [==============================] - 1s 480ms/step - loss: 889.7637 - mean_squared_error: 889.7636 - val_loss: 761.2724 - val_mean_squared_error: 761.2724
# Epoch 93/100
# 2/2 [==============================] - 1s 605ms/step - loss: 882.5145 - mean_squared_error: 882.5145 - val_loss: 749.9587 - val_mean_squared_error: 749.9587
# Epoch 94/100
# 2/2 [==============================] - 1s 466ms/step - loss: 874.9185 - mean_squared_error: 874.9185 - val_loss: 738.7098 - val_mean_squared_error: 738.7098
# Epoch 95/100
# 2/2 [==============================] - 1s 457ms/step - loss: 868.6677 - mean_squared_error: 868.6677 - val_loss: 728.1550 - val_mean_squared_error: 728.1550
# Epoch 96/100
# 2/2 [==============================] - 1s 721ms/step - loss: 864.3952 - mean_squared_error: 864.3952 - val_loss: 718.4529 - val_mean_squared_error: 718.4529
# Epoch 97/100
# 2/2 [==============================] - 1s 467ms/step - loss: 856.8338 - mean_squared_error: 856.8338 - val_loss: 709.4930 - val_mean_squared_error: 709.4930
# Epoch 98/100
# 2/2 [==============================] - 1s 619ms/step - loss: 851.9775 - mean_squared_error: 851.9775 - val_loss: 700.1338 - val_mean_squared_error: 700.1338
# Epoch 99/100
# 2/2 [==============================] - 1s 449ms/step - loss: 845.1802 - mean_squared_error: 845.1802 - val_loss: 690.2803 - val_mean_squared_error: 690.2803
# Epoch 100/100
# 2/2 [==============================] - 1s 466ms/step - loss: 839.4352 - mean_squared_error: 839.4352 - val_loss: 681.2741 - val_mean_squared_error: 681.2741
# 1/1 [==============================] - 0s 164ms/step - loss: 7382.7153 - mean_squared_error: 7382.7153
# Test error: 7382.72

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  22.214015630086266
# MSE:  606.968188780575
# RMSE:  24.63672439226804
# r2_score:  -4.7525974386332965
# MSLE:  6.893643900063027
# MAPE:  7.602186316869358e+16
# ===== flank_wear results =====
# MAE:  100.79767100016277
# MSE:  21453.356004525558
# RMSE:  146.46964192120345
# r2_score:  -0.3389639257101078
# MSLE:  0.7552001203157516
# MAPE:  0.5757706472412852
# ===== overhang results =====
# MAE:  7.7090666961669925
# MSE:  87.82020069915235
# RMSE:  9.37124328459956
# r2_score:  -3.353468623857883
# MSLE:  0.40039816031416336
# MAPE:  0.8733917445598277
# ===== multi results =====
# MAE:  43.573584442138674
# MSE:  7382.714798001762
# RMSE:  60.159203199357016
# r2_score:  -2.815009996067096
# MSLE:  2.683080726897647
# MAPE:  2.5340621056231196e+16
