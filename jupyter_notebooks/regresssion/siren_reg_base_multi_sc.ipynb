# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# 2023-09-23 13:52:35.774170: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-23 13:52:37.155460: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  1
# GPUs:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-09-23 13:52:40.129778: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:52:40.178911: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:52:40.179860: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_spec = 9
in_channel_chip = 3
img_rows, img_cols = image_size, image_size
input_shape_spec = (img_rows, img_cols, in_channel_spec)
input_shape_chip = (img_rows, img_cols, in_channel_chip)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_sc"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_spec_path = f"./{exp_name}_{sub_exp_name}_spec.h5"
model_chip_path = f"./{exp_name}_{sub_exp_name}_chip.h5"

# dataset
csv_path = "../../dataset/labels_reg_sample.csv"
spec_path = "../../dataset/spec"
chip_path = "../../dataset/chip"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang                            spec_x  \
# 14   T8R3B4   6.88       40.92     14.54   ../../dataset/spec/x/T8R3B4.jpg
# 10   T6R9B3  12.94       95.63     16.65   ../../dataset/spec/x/T6R9B3.jpg
# 0    T1R2B1   7.67       34.89     48.61   ../../dataset/spec/x/T1R2B1.jpg
# 3   T2R13B4   0.00      122.59     25.55  ../../dataset/spec/x/T2R13B4.jpg
# 1    T1R7B4  13.89       85.41     50.25   ../../dataset/spec/x/T1R7B4.jpg
#
#                               spec_y                            spec_z  \
# 14   ../../dataset/spec/y/T8R3B4.jpg   ../../dataset/spec/z/T8R3B4.jpg
# 10   ../../dataset/spec/y/T6R9B3.jpg   ../../dataset/spec/z/T6R9B3.jpg
# 0    ../../dataset/spec/y/T1R2B1.jpg   ../../dataset/spec/z/T1R2B1.jpg
# 3   ../../dataset/spec/y/T2R13B4.jpg  ../../dataset/spec/z/T2R13B4.jpg
# 1    ../../dataset/spec/y/T1R7B4.jpg   ../../dataset/spec/z/T1R7B4.jpg
#
#                               chip
# 14   ../../dataset/chip/T8R3B4.jpg
# 10   ../../dataset/chip/T6R9B3.jpg
# 0    ../../dataset/chip/T1R2B1.jpg
# 3   ../../dataset/chip/T2R13B4.jpg
# 1    ../../dataset/chip/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang                            spec_x  \
# 16   T9R7B4   0.00       94.62     17.05   ../../dataset/spec/x/T9R7B4.jpg
# 18  T10R3B4   0.00       44.26      7.10  ../../dataset/spec/x/T10R3B4.jpg
# 9   T5R12B1  21.79      334.39     16.14  ../../dataset/spec/x/T5R12B1.jpg
#
#                               spec_y                            spec_z  \
# 16   ../../dataset/spec/y/T9R7B4.jpg   ../../dataset/spec/z/T9R7B4.jpg
# 18  ../../dataset/spec/y/T10R3B4.jpg  ../../dataset/spec/z/T10R3B4.jpg
# 9   ../../dataset/spec/y/T5R12B1.jpg  ../../dataset/spec/z/T5R12B1.jpg
#
#                               chip
# 16   ../../dataset/chip/T9R7B4.jpg
# 18  ../../dataset/chip/T10R3B4.jpg
# 9   ../../dataset/chip/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang                            spec_x  \
# 5   T3R10B1   5.00      128.39     35.26  ../../dataset/spec/x/T3R10B1.jpg
# 13  T7R14B3  13.67      141.91     14.62  ../../dataset/spec/x/T7R14B3.jpg
# 12   T7R8B3   7.45       77.05     19.02   ../../dataset/spec/x/T7R8B3.jpg
#
#                               spec_y                            spec_z  \
# 5   ../../dataset/spec/y/T3R10B1.jpg  ../../dataset/spec/z/T3R10B1.jpg
# 13  ../../dataset/spec/y/T7R14B3.jpg  ../../dataset/spec/z/T7R14B3.jpg
# 12   ../../dataset/spec/y/T7R8B3.jpg   ../../dataset/spec/z/T7R8B3.jpg
#
#                               chip
# 5   ../../dataset/chip/T3R10B1.jpg
# 13  ../../dataset/chip/T7R14B3.jpg
# 12   ../../dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images


def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for i in range(file_paths_x.size):
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_x)
        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_y)
        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_z)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(file_paths_x.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
# ============================== augment 1/2 ==============================
data_augmentation_spec = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_spec",
)
# Out:
# 2023-09-23 13:52:42.922012: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:52:42.923033: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:52:42.923847: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:52:43.991721: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:52:43.992367: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:52:43.993023: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:52:43.993517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1942 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:00:1b.0, compute capability: 6.1

# %%
# ============================== augment 2/2 ==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
x_train_spec = data_augmentation_spec(x_train_spec)
x_train_chip = data_augmentation_chip(x_train_chip)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_spec": x_train_spec,
            "input_1_chip": x_train_chip,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_spec": x_test_spec,
            "input_1_chip": x_test_chip,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_spec": x_val_spec,
            "input_1_chip": x_val_chip,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs2 = k.Input(input_shape_spec)
inputs3 = k.Input(input_shape_chip)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_spec': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
model_spec = k.models.load_model(model_spec_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)

model_spec.trainable = False
model_chip.trainable = False


def load_multi_mixer(model_spec, model_chip):
    inputs2 = model_spec.input
    inputs2._name = "input_spec"
    inputs3 = model_chip.input
    inputs3._name = "input_chip"

    truncated_model_spec = k.Model(
        inputs=model_spec.input, outputs=model_spec.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_spec.output,
            truncated_model_chip.output,
        ]
    )
    output = layers.Dense(num_classes, activation="linear", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs2, inputs3], outputs=output)


for layer in model_spec.layers:
    layer._name = layer.name + str("_spec")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_multi_mixer(model_spec, model_chip)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1_spec (InputLayer)      [(None, 256, 256, 9  0           []
#                                 )]
#
#  input_1_chip (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_spec (Conv2D)           (None, 16, 16, 256)  590080      ['input_1_spec[0][0]']
#
#  conv2d_chip (Conv2D)           (None, 16, 16, 256)  196864      ['input_1_chip[0][0]']
#
#  activation_spec (Activation)   (None, 16, 16, 256)  0           ['conv2d_spec[0][0]']
#
#  activation_chip (Activation)   (None, 16, 16, 256)  0           ['conv2d_chip[0][0]']
#
#  batch_normalization_spec (Batc  (None, 16, 16, 256)  1024       ['activation_spec[0][0]']
#  hNormalization)
#
#  batch_normalization_chip (Batc  (None, 16, 16, 256)  1024       ['activation_chip[0][0]']
#  hNormalization)
#
#  depthwise_conv2d_spec (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_spec[0][0]'
#  seConv2D)                                                       ]
#
#  depthwise_conv2d_chip (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_chip[0][0]'
#  seConv2D)                                                       ]
#
#  activation_1_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_spec[0][0]']
#
#  activation_1_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_chip[0][0]']
#
#  batch_normalization_1_spec (Ba  (None, 16, 16, 256)  1024       ['activation_1_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_1_chip (Ba  (None, 16, 16, 256)  1024       ['activation_1_chip[0][0]']
#  tchNormalization)
#
#  add_spec (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  add_chip (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  conv2d_1_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_spec[0][0]']
#
#  conv2d_1_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_chip[0][0]']
#
#  activation_2_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_spec[0][0]']
#
#  activation_2_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_chip[0][0]']
#
#  batch_normalization_2_spec (Ba  (None, 16, 16, 256)  1024       ['activation_2_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_2_chip (Ba  (None, 16, 16, 256)  1024       ['activation_2_chip[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_1_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  depthwise_conv2d_1_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_3_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_spec[0][0]']
#
#  activation_3_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_chip[0][0]']
#
#  batch_normalization_3_spec (Ba  (None, 16, 16, 256)  1024       ['activation_3_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_3_chip (Ba  (None, 16, 16, 256)  1024       ['activation_3_chip[0][0]']
#  tchNormalization)
#
#  add_1_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_spec[0][0
#                                                                  ]']
#
#  add_1_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_chip[0][0
#                                                                  ]']
#
#  conv2d_2_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_spec[0][0]']
#
#  conv2d_2_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_chip[0][0]']
#
#  activation_4_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_spec[0][0]']
#
#  activation_4_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_chip[0][0]']
#
#  batch_normalization_4_spec (Ba  (None, 16, 16, 256)  1024       ['activation_4_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_4_chip (Ba  (None, 16, 16, 256)  1024       ['activation_4_chip[0][0]']
#  tchNormalization)
#
#  add_4_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  add_4_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_4_spec (Depth  (None, 16, 16, 256)  6656       ['add_4_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_4_chip (Depth  (None, 16, 16, 256)  6656       ['add_4_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_2_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_spec[0][0]']
#
#  depthwise_conv2d_2_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_chip[0][0]']
#
#  activation_5_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_spec[0][0]']
#
#  batch_normalization_9_spec (Ba  (None, 16, 16, 256)  1024       ['activation_9_spec[0][0]']
#  tchNormalization)
#
#  activation_5_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_chip[0][0]']
#
#  batch_normalization_9_chip (Ba  (None, 16, 16, 256)  1024       ['activation_9_chip[0][0]']
#  tchNormalization)
#
#  batch_normalization_5_spec (Ba  (None, 16, 16, 256)  1024       ['activation_5_spec[0][0]']
#  tchNormalization)
#
#  add_5_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_spec[0][0
#                                                                  ]',
#                                                                   'add_4_spec[0][0]']
#
#  batch_normalization_5_chip (Ba  (None, 16, 16, 256)  1024       ['activation_5_chip[0][0]']
#  tchNormalization)
#
#  add_5_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_chip[0][0
#                                                                  ]',
#                                                                   'add_4_chip[0][0]']
#
#  add_2_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_spec[0][0
#                                                                  ]']
#
#  conv2d_5_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_spec[0][0]']
#
#  add_2_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_chip[0][0
#                                                                  ]']
#
#  conv2d_5_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_chip[0][0]']
#
#  conv2d_3_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_spec[0][0]']
#
#  activation_10_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_5_spec[0][0]']
#  )
#
#  conv2d_3_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_chip[0][0]']
#
#  activation_10_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_5_chip[0][0]']
#  )
#
#  activation_6_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_spec[0][0]']
#
#  batch_normalization_10_spec (B  (None, 16, 16, 256)  1024       ['activation_10_spec[0][0]']
#  atchNormalization)
#
#  activation_6_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_chip[0][0]']
#
#  batch_normalization_10_chip (B  (None, 16, 16, 256)  1024       ['activation_10_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_6_spec (Ba  (None, 16, 16, 256)  1024       ['activation_6_spec[0][0]']
#  tchNormalization)
#
#  add_6_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_spec[0][
#                                                                  0]']
#
#  batch_normalization_6_chip (Ba  (None, 16, 16, 256)  1024       ['activation_6_chip[0][0]']
#  tchNormalization)
#
#  add_6_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_chip[0][
#                                                                  0]']
#
#  add_7_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_spec[0][0
#                                                                  ]',
#                                                                   'add_6_spec[0][0]']
#
#  add_7_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_chip[0][0
#                                                                  ]',
#                                                                   'add_6_chip[0][0]']
#
#  depthwise_conv2d_5_spec (Depth  (None, 16, 16, 256)  6656       ['add_7_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_5_chip (Depth  (None, 16, 16, 256)  6656       ['add_7_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_3_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_spec[0][0]']
#  )
#
#  depthwise_conv2d_3_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_chip[0][0]']
#  )
#
#  activation_7_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_spec[0][0]']
#
#  batch_normalization_11_spec (B  (None, 16, 16, 256)  1024       ['activation_11_spec[0][0]']
#  atchNormalization)
#
#  activation_7_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_chip[0][0]']
#
#  batch_normalization_11_chip (B  (None, 16, 16, 256)  1024       ['activation_11_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_7_spec (Ba  (None, 16, 16, 256)  1024       ['activation_7_spec[0][0]']
#  tchNormalization)
#
#  add_8_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_spec[0][
#                                                                  0]',
#                                                                   'add_7_spec[0][0]']
#
#  batch_normalization_7_chip (Ba  (None, 16, 16, 256)  1024       ['activation_7_chip[0][0]']
#  tchNormalization)
#
#  add_8_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_chip[0][
#                                                                  0]',
#                                                                   'add_7_chip[0][0]']
#
#  add_3_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_spec[0][0
#                                                                  ]']
#
#  conv2d_6_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_spec[0][0]']
#
#  add_3_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_chip[0][0
#                                                                  ]']
#
#  conv2d_6_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_chip[0][0]']
#
#  conv2d_4_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_spec[0][0]']
#
#  activation_12_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_6_spec[0][0]']
#  )
#
#  conv2d_4_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_chip[0][0]']
#
#  activation_12_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_6_chip[0][0]']
#  )
#
#  activation_8_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_spec[0][0]']
#
#  batch_normalization_12_spec (B  (None, 16, 16, 256)  1024       ['activation_12_spec[0][0]']
#  atchNormalization)
#
#  activation_8_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_chip[0][0]']
#
#  batch_normalization_12_chip (B  (None, 16, 16, 256)  1024       ['activation_12_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_8_spec (Ba  (None, 16, 16, 256)  1024       ['activation_8_spec[0][0]']
#  tchNormalization)
#
#  add_9_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_spec[0][
#                                                                  0]']
#
#  batch_normalization_8_chip (Ba  (None, 16, 16, 256)  1024       ['activation_8_chip[0][0]']
#  tchNormalization)
#
#  add_9_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_chip[0][
#                                                                  0]']
#
#  add_10_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_spec[0][0
#                                                                  ]',
#                                                                   'add_9_spec[0][0]']
#
#  add_15_spec (Add)              (None, 16, 16, 256)  0           ['add_9_spec[0][0]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  add_10_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_chip[0][0
#                                                                  ]',
#                                                                   'add_9_chip[0][0]']
#
#  add_15_chip (Add)              (None, 16, 16, 256)  0           ['add_9_chip[0][0]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_6_spec (Depth  (None, 16, 16, 256)  6656       ['add_10_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_spec (Depth  (None, 16, 16, 256)  6656       ['add_15_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_6_chip (Depth  (None, 16, 16, 256)  6656       ['add_10_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_chip (Depth  (None, 16, 16, 256)  6656       ['add_15_chip[0][0]']
#  wiseConv2D)
#
#  activation_13_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_6_spec[0][0]']
#  )
#
#  activation_17_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_8_spec[0][0]']
#  )
#
#  activation_13_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_6_chip[0][0]']
#  )
#
#  activation_17_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_8_chip[0][0]']
#  )
#
#  batch_normalization_13_spec (B  (None, 16, 16, 256)  1024       ['activation_13_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_17_spec (B  (None, 16, 16, 256)  1024       ['activation_17_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_13_chip (B  (None, 16, 16, 256)  1024       ['activation_13_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_17_chip (B  (None, 16, 16, 256)  1024       ['activation_17_chip[0][0]']
#  atchNormalization)
#
#  add_11_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_13_spec[0][
#                                                                  0]',
#                                                                   'add_10_spec[0][0]']
#
#  add_16_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_17_spec[0][
#                                                                  0]',
#                                                                   'add_15_spec[0][0]']
#
#  add_11_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_13_chip[0][
#                                                                  0]',
#                                                                   'add_10_chip[0][0]']
#
#  add_16_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_17_chip[0][
#                                                                  0]',
#                                                                   'add_15_chip[0][0]']
#
#  conv2d_7_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_11_spec[0][0]']
#
#  conv2d_9_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_16_spec[0][0]']
#
#  conv2d_7_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_11_chip[0][0]']
#
#  conv2d_9_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_16_chip[0][0]']
#
#  activation_14_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_7_spec[0][0]']
#  )
#
#  activation_18_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_9_spec[0][0]']
#  )
#
#  activation_14_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_7_chip[0][0]']
#  )
#
#  activation_18_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_9_chip[0][0]']
#  )
#
#  batch_normalization_14_spec (B  (None, 16, 16, 256)  1024       ['activation_14_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_18_spec (B  (None, 16, 16, 256)  1024       ['activation_18_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_14_chip (B  (None, 16, 16, 256)  1024       ['activation_14_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_18_chip (B  (None, 16, 16, 256)  1024       ['activation_18_chip[0][0]']
#  atchNormalization)
#
#  add_12_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_6_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_14_spec[0][
#                                                                  0]']
#
#  add_17_spec (Add)              (None, 16, 16, 256)  0           ['add_6_spec[0][0]',
#                                                                   'batch_normalization_18_spec[0][
#                                                                  0]']
#
#  add_12_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_6_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_14_chip[0][
#                                                                  0]']
#
#  add_17_chip (Add)              (None, 16, 16, 256)  0           ['add_6_chip[0][0]',
#                                                                   'batch_normalization_18_chip[0][
#                                                                  0]']
#
#  add_18_spec (Add)              (None, 16, 16, 256)  0           ['add_12_spec[0][0]',
#                                                                   'add_17_spec[0][0]']
#
#  add_18_chip (Add)              (None, 16, 16, 256)  0           ['add_12_chip[0][0]',
#                                                                   'add_17_chip[0][0]']
#
#  depthwise_conv2d_7_spec (Depth  (None, 16, 16, 256)  6656       ['add_12_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_9_spec (Depth  (None, 16, 16, 256)  6656       ['add_18_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_7_chip (Depth  (None, 16, 16, 256)  6656       ['add_12_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_9_chip (Depth  (None, 16, 16, 256)  6656       ['add_18_chip[0][0]']
#  wiseConv2D)
#
#  activation_15_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_7_spec[0][0]']
#  )
#
#  activation_19_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_9_spec[0][0]']
#  )
#
#  activation_15_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_7_chip[0][0]']
#  )
#
#  activation_19_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_9_chip[0][0]']
#  )
#
#  batch_normalization_15_spec (B  (None, 16, 16, 256)  1024       ['activation_15_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_19_spec (B  (None, 16, 16, 256)  1024       ['activation_19_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_15_chip (B  (None, 16, 16, 256)  1024       ['activation_15_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_19_chip (B  (None, 16, 16, 256)  1024       ['activation_19_chip[0][0]']
#  atchNormalization)
#
#  add_13_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_15_spec[0][
#                                                                  0]',
#                                                                   'add_12_spec[0][0]']
#
#  add_19_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_19_spec[0][
#                                                                  0]',
#                                                                   'add_18_spec[0][0]']
#
#  add_13_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_15_chip[0][
#                                                                  0]',
#                                                                   'add_12_chip[0][0]']
#
#  add_19_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_19_chip[0][
#                                                                  0]',
#                                                                   'add_18_chip[0][0]']
#
#  conv2d_8_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_13_spec[0][0]']
#
#  conv2d_10_spec (Conv2D)        (None, 16, 16, 256)  65792       ['add_19_spec[0][0]']
#
#  conv2d_8_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_13_chip[0][0]']
# ...
#  )
#
#  activation_28_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_14_spec[0][0]']
#  )
#
#  activation_24_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_12_chip[0][0]']
#  )
#
#  activation_28_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_14_chip[0][0]']
#  )
#
#  batch_normalization_24_spec (B  (None, 16, 16, 256)  1024       ['activation_24_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_28_spec (B  (None, 16, 16, 256)  1024       ['activation_28_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_24_chip (B  (None, 16, 16, 256)  1024       ['activation_24_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_28_chip (B  (None, 16, 16, 256)  1024       ['activation_28_chip[0][0]']
#  atchNormalization)
#
#  add_25_spec (Add)              (None, 16, 16, 256)  0           ['add_14_spec[0][0]',
#                                                                   'batch_normalization_24_spec[0][
#                                                                  0]']
#
#  add_31_spec (Add)              (None, 16, 16, 256)  0           ['add_20_spec[0][0]',
#                                                                   'batch_normalization_28_spec[0][
#                                                                  0]']
#
#  add_25_chip (Add)              (None, 16, 16, 256)  0           ['add_14_chip[0][0]',
#                                                                   'batch_normalization_24_chip[0][
#                                                                  0]']
#
#  add_31_chip (Add)              (None, 16, 16, 256)  0           ['add_20_chip[0][0]',
#                                                                   'batch_normalization_28_chip[0][
#                                                                  0]']
#
#  add_32_spec (Add)              (None, 16, 16, 256)  0           ['add_25_spec[0][0]',
#                                                                   'add_31_spec[0][0]']
#
#  add_32_chip (Add)              (None, 16, 16, 256)  0           ['add_25_chip[0][0]',
#                                                                   'add_31_chip[0][0]']
#
#  depthwise_conv2d_14_spec (Dept  (None, 16, 16, 256)  6656       ['add_32_spec[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_14_chip (Dept  (None, 16, 16, 256)  6656       ['add_32_chip[0][0]']
#  hwiseConv2D)
#
#  activation_29_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_spec[0][0]'
#  )                                                               ]
#
#  activation_29_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_chip[0][0]'
#  )                                                               ]
#
#  batch_normalization_29_spec (B  (None, 16, 16, 256)  1024       ['activation_29_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_29_chip (B  (None, 16, 16, 256)  1024       ['activation_29_chip[0][0]']
#  atchNormalization)
#
#  add_33_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_spec[0][
#                                                                  0]',
#                                                                   'add_32_spec[0][0]']
#
#  add_33_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_chip[0][
#                                                                  0]',
#                                                                   'add_32_chip[0][0]']
#
#  conv2d_15_spec (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_spec[0][0]']
#
#  conv2d_15_chip (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_chip[0][0]']
#
#  activation_30_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_15_spec[0][0]']
#  )
#
#  activation_30_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_15_chip[0][0]']
#  )
#
#  batch_normalization_30_spec (B  (None, 16, 16, 256)  1024       ['activation_30_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_30_chip (B  (None, 16, 16, 256)  1024       ['activation_30_chip[0][0]']
#  atchNormalization)
#
#  add_34_spec (Add)              (None, 16, 16, 256)  0           ['add_23_spec[0][0]',
#                                                                   'batch_normalization_30_spec[0][
#                                                                  0]']
#
#  add_34_chip (Add)              (None, 16, 16, 256)  0           ['add_23_chip[0][0]',
#                                                                   'batch_normalization_30_chip[0][
#                                                                  0]']
#
#  depthwise_conv2d_15_spec (Dept  (None, 16, 16, 256)  6656       ['add_34_spec[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_15_chip (Dept  (None, 16, 16, 256)  6656       ['add_34_chip[0][0]']
#  hwiseConv2D)
#
#  activation_31_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_spec[0][0]'
#  )                                                               ]
#
#  activation_31_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_chip[0][0]'
#  )                                                               ]
#
#  batch_normalization_31_spec (B  (None, 16, 16, 256)  1024       ['activation_31_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_31_chip (B  (None, 16, 16, 256)  1024       ['activation_31_chip[0][0]']
#  atchNormalization)
#
#  add_35_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_spec[0][
#                                                                  0]',
#                                                                   'add_34_spec[0][0]']
#
#  add_35_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_chip[0][
#                                                                  0]',
#                                                                   'add_34_chip[0][0]']
#
#  conv2d_16_spec (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_spec[0][0]']
#
#  conv2d_16_chip (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_chip[0][0]']
#
#  activation_32_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_16_spec[0][0]']
#  )
#
#  activation_32_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_16_chip[0][0]']
#  )
#
#  batch_normalization_32_spec (B  (None, 16, 16, 256)  1024       ['activation_32_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_32_chip (B  (None, 16, 16, 256)  1024       ['activation_32_chip[0][0]']
#  atchNormalization)
#
#  add_36_spec (Add)              (None, 16, 16, 256)  0           ['add_25_spec[0][0]',
#                                                                   'batch_normalization_32_spec[0][
#                                                                  0]']
#
#  add_36_chip (Add)              (None, 16, 16, 256)  0           ['add_25_chip[0][0]',
#                                                                   'batch_normalization_32_chip[0][
#                                                                  0]']
#
#  global_average_pooling2d_spec   (None, 256)         0           ['add_36_spec[0][0]']
#  (GlobalAveragePooling2D)
#
#  global_average_pooling2d_chip   (None, 256)         0           ['add_36_chip[0][0]']
#  (GlobalAveragePooling2D)
#
#  concatenate (Concatenate)      (None, 512)          0           ['global_average_pooling2d_spec[0
#                                                                  ][0]',
#                                                                   'global_average_pooling2d_chip[0
#                                                                  ][0]']
#
#  output_mult (Dense)            (None, 3)            1539        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3,174,403
# Trainable params: 1,539
# Non-trainable params: 3,172,864
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2023-09-23 13:52:48.160087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [14,256,256,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-23 13:52:48.160536: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [14,256,256,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-23 13:52:57.242892: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2/2 [==============================] - ETA: 0s - loss: 3857.7585 - mean_squared_error: 3857.7585
# 2023-09-23 13:52:58.070840: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_2}}]]
# 2/2 [==============================] - 12s 2s/step - loss: 3857.7585 - mean_squared_error: 3857.7585 - val_loss: 4714.9077 - val_mean_squared_error: 4714.9077
# Epoch 2/100
# 2/2 [==============================] - 0s 58ms/step - loss: 3750.6980 - mean_squared_error: 3750.6980 - val_loss: 4599.4800 - val_mean_squared_error: 4599.4800
# Epoch 3/100
# 2/2 [==============================] - 0s 57ms/step - loss: 3668.4709 - mean_squared_error: 3668.4707 - val_loss: 4484.9888 - val_mean_squared_error: 4484.9888
# Epoch 4/100
# 2/2 [==============================] - 0s 60ms/step - loss: 3576.6687 - mean_squared_error: 3576.6687 - val_loss: 4373.6890 - val_mean_squared_error: 4373.6890
# Epoch 5/100
# 2/2 [==============================] - 0s 59ms/step - loss: 3490.8655 - mean_squared_error: 3490.8655 - val_loss: 4265.2905 - val_mean_squared_error: 4265.2905
# Epoch 6/100
# 2/2 [==============================] - 0s 60ms/step - loss: 3404.4402 - mean_squared_error: 3404.4402 - val_loss: 4160.2310 - val_mean_squared_error: 4160.2310
# Epoch 7/100
# 2/2 [==============================] - 0s 59ms/step - loss: 3312.8118 - mean_squared_error: 3312.8118 - val_loss: 4058.8896 - val_mean_squared_error: 4058.8896
# Epoch 8/100
# 2/2 [==============================] - 0s 53ms/step - loss: 3240.4187 - mean_squared_error: 3240.4187 - val_loss: 3959.6472 - val_mean_squared_error: 3959.6472
# Epoch 9/100
# 2/2 [==============================] - 0s 60ms/step - loss: 3159.4556 - mean_squared_error: 3159.4553 - val_loss: 3864.1648 - val_mean_squared_error: 3864.1648
# Epoch 10/100
# 2/2 [==============================] - 0s 56ms/step - loss: 3087.5725 - mean_squared_error: 3087.5725 - val_loss: 3770.7542 - val_mean_squared_error: 3770.7542
# Epoch 11/100
# 2/2 [==============================] - 0s 58ms/step - loss: 3012.6897 - mean_squared_error: 3012.6897 - val_loss: 3680.7773 - val_mean_squared_error: 3680.7773
# Epoch 12/100
# 2/2 [==============================] - 0s 60ms/step - loss: 2947.1848 - mean_squared_error: 2947.1848 - val_loss: 3593.0432 - val_mean_squared_error: 3593.0432
# Epoch 13/100
# 2/2 [==============================] - 0s 56ms/step - loss: 2879.2922 - mean_squared_error: 2879.2922 - val_loss: 3508.2539 - val_mean_squared_error: 3508.2539
# Epoch 14/100
# 2/2 [==============================] - 0s 62ms/step - loss: 2814.8367 - mean_squared_error: 2814.8367 - val_loss: 3426.0752 - val_mean_squared_error: 3426.0752
# Epoch 15/100
# 2/2 [==============================] - 0s 57ms/step - loss: 2743.7947 - mean_squared_error: 2743.7947 - val_loss: 3347.5134 - val_mean_squared_error: 3347.5134
# Epoch 16/100
# 2/2 [==============================] - 0s 56ms/step - loss: 2689.1433 - mean_squared_error: 2689.1433 - val_loss: 3270.1926 - val_mean_squared_error: 3270.1926
# Epoch 17/100
# 2/2 [==============================] - 0s 54ms/step - loss: 2631.2688 - mean_squared_error: 2631.2688 - val_loss: 3194.7903 - val_mean_squared_error: 3194.7903
# Epoch 18/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2570.2249 - mean_squared_error: 2570.2249 - val_loss: 3121.9255 - val_mean_squared_error: 3121.9255
# Epoch 19/100
# 2/2 [==============================] - 0s 60ms/step - loss: 2525.2244 - mean_squared_error: 2525.2244 - val_loss: 3050.4385 - val_mean_squared_error: 3050.4385
# Epoch 20/100
# 2/2 [==============================] - 0s 57ms/step - loss: 2468.1077 - mean_squared_error: 2468.1077 - val_loss: 2982.2825 - val_mean_squared_error: 2982.2825
# Epoch 21/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2415.3452 - mean_squared_error: 2415.3452 - val_loss: 2916.2395 - val_mean_squared_error: 2916.2395
# Epoch 22/100
# 2/2 [==============================] - 0s 58ms/step - loss: 2366.6294 - mean_squared_error: 2366.6294 - val_loss: 2851.6943 - val_mean_squared_error: 2851.6943
# Epoch 23/100
# 2/2 [==============================] - 0s 53ms/step - loss: 2315.5461 - mean_squared_error: 2315.5461 - val_loss: 2789.0762 - val_mean_squared_error: 2789.0762
# Epoch 24/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2273.4771 - mean_squared_error: 2273.4771 - val_loss: 2727.8308 - val_mean_squared_error: 2727.8308
# Epoch 25/100
# 2/2 [==============================] - 0s 54ms/step - loss: 2226.5007 - mean_squared_error: 2226.5007 - val_loss: 2668.1741 - val_mean_squared_error: 2668.1741
# Epoch 26/100
# 2/2 [==============================] - 0s 57ms/step - loss: 2183.7712 - mean_squared_error: 2183.7712 - val_loss: 2609.6750 - val_mean_squared_error: 2609.6750
# Epoch 27/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2137.2991 - mean_squared_error: 2137.2991 - val_loss: 2552.5964 - val_mean_squared_error: 2552.5964
# Epoch 28/100
# 2/2 [==============================] - 0s 59ms/step - loss: 2103.1694 - mean_squared_error: 2103.1694 - val_loss: 2496.2214 - val_mean_squared_error: 2496.2214
# Epoch 29/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2059.9182 - mean_squared_error: 2059.9182 - val_loss: 2441.9458 - val_mean_squared_error: 2441.9458
# Epoch 30/100
# 2/2 [==============================] - 0s 54ms/step - loss: 2018.6328 - mean_squared_error: 2018.6328 - val_loss: 2388.9700 - val_mean_squared_error: 2388.9700
# Epoch 31/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1984.2435 - mean_squared_error: 1984.2434 - val_loss: 2337.2568 - val_mean_squared_error: 2337.2568
# Epoch 32/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1945.9569 - mean_squared_error: 1945.9569 - val_loss: 2286.9448 - val_mean_squared_error: 2286.9448
# Epoch 33/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1907.6150 - mean_squared_error: 1907.6150 - val_loss: 2237.7002 - val_mean_squared_error: 2237.7002
# Epoch 34/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1872.6110 - mean_squared_error: 1872.6110 - val_loss: 2189.3901 - val_mean_squared_error: 2189.3901
# Epoch 35/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1840.5745 - mean_squared_error: 1840.5745 - val_loss: 2142.1677 - val_mean_squared_error: 2142.1677
# Epoch 36/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1806.0997 - mean_squared_error: 1806.0996 - val_loss: 2095.7332 - val_mean_squared_error: 2095.7332
# Epoch 37/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1775.0597 - mean_squared_error: 1775.0596 - val_loss: 2050.9822 - val_mean_squared_error: 2050.9822
# Epoch 38/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1738.6708 - mean_squared_error: 1738.6708 - val_loss: 2007.1237 - val_mean_squared_error: 2007.1237
# Epoch 39/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1713.1575 - mean_squared_error: 1713.1575 - val_loss: 1963.8217 - val_mean_squared_error: 1963.8217
# Epoch 40/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1677.6475 - mean_squared_error: 1677.6475 - val_loss: 1921.8390 - val_mean_squared_error: 1921.8390
# Epoch 41/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1650.9377 - mean_squared_error: 1650.9377 - val_loss: 1880.6454 - val_mean_squared_error: 1880.6454
# Epoch 42/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1624.4934 - mean_squared_error: 1624.4934 - val_loss: 1839.8981 - val_mean_squared_error: 1839.8981
# Epoch 43/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1591.9818 - mean_squared_error: 1591.9818 - val_loss: 1800.3744 - val_mean_squared_error: 1800.3744
# Epoch 44/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1565.4060 - mean_squared_error: 1565.4060 - val_loss: 1761.7985 - val_mean_squared_error: 1761.7985
# Epoch 45/100
# 2/2 [==============================] - 0s 55ms/step - loss: 1540.2649 - mean_squared_error: 1540.2649 - val_loss: 1724.0967 - val_mean_squared_error: 1724.0967
# Epoch 46/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1514.6915 - mean_squared_error: 1514.6915 - val_loss: 1687.7596 - val_mean_squared_error: 1687.7596
# Epoch 47/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1489.7858 - mean_squared_error: 1489.7858 - val_loss: 1652.2378 - val_mean_squared_error: 1652.2378
# Epoch 48/100
# 2/2 [==============================] - 0s 55ms/step - loss: 1462.9138 - mean_squared_error: 1462.9138 - val_loss: 1617.3286 - val_mean_squared_error: 1617.3286
# Epoch 49/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1438.8884 - mean_squared_error: 1438.8884 - val_loss: 1583.3555 - val_mean_squared_error: 1583.3555
# Epoch 50/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1418.2000 - mean_squared_error: 1418.2000 - val_loss: 1550.4103 - val_mean_squared_error: 1550.4103
# Epoch 51/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1392.8010 - mean_squared_error: 1392.8010 - val_loss: 1518.1923 - val_mean_squared_error: 1518.1923
# Epoch 52/100
# 2/2 [==============================] - 0s 55ms/step - loss: 1370.7102 - mean_squared_error: 1370.7102 - val_loss: 1486.6854 - val_mean_squared_error: 1486.6854
# Epoch 53/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1348.1218 - mean_squared_error: 1348.1218 - val_loss: 1456.3239 - val_mean_squared_error: 1456.3239
# Epoch 54/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1330.5315 - mean_squared_error: 1330.5315 - val_loss: 1426.3619 - val_mean_squared_error: 1426.3619
# Epoch 55/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1308.7600 - mean_squared_error: 1308.7600 - val_loss: 1396.5869 - val_mean_squared_error: 1396.5869
# Epoch 56/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1290.3668 - mean_squared_error: 1290.3668 - val_loss: 1368.1118 - val_mean_squared_error: 1368.1118
# Epoch 57/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1268.5983 - mean_squared_error: 1268.5983 - val_loss: 1340.2574 - val_mean_squared_error: 1340.2574
# Epoch 58/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1248.3867 - mean_squared_error: 1248.3867 - val_loss: 1313.5243 - val_mean_squared_error: 1313.5243
# Epoch 59/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1231.6974 - mean_squared_error: 1231.6974 - val_loss: 1286.8635 - val_mean_squared_error: 1286.8635
# Epoch 60/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1214.9427 - mean_squared_error: 1214.9427 - val_loss: 1260.8527 - val_mean_squared_error: 1260.8527
# Epoch 61/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1195.6895 - mean_squared_error: 1195.6895 - val_loss: 1236.0239 - val_mean_squared_error: 1236.0239
# Epoch 62/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1182.4355 - mean_squared_error: 1182.4355 - val_loss: 1211.6810 - val_mean_squared_error: 1211.6810
# Epoch 63/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1163.2736 - mean_squared_error: 1163.2736 - val_loss: 1187.7719 - val_mean_squared_error: 1187.7719
# Epoch 64/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1146.7411 - mean_squared_error: 1146.7411 - val_loss: 1164.7086 - val_mean_squared_error: 1164.7086
# Epoch 65/100
# 2/2 [==============================] - 0s 55ms/step - loss: 1135.2528 - mean_squared_error: 1135.2528 - val_loss: 1141.9701 - val_mean_squared_error: 1141.9701
# Epoch 66/100
# 2/2 [==============================] - 0s 59ms/step - loss: 1115.7633 - mean_squared_error: 1115.7633 - val_loss: 1120.3342 - val_mean_squared_error: 1120.3342
# Epoch 67/100
# 2/2 [==============================] - 0s 55ms/step - loss: 1103.7802 - mean_squared_error: 1103.7802 - val_loss: 1099.1903 - val_mean_squared_error: 1099.1903
# Epoch 68/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1091.1835 - mean_squared_error: 1091.1835 - val_loss: 1077.9760 - val_mean_squared_error: 1077.9760
# Epoch 69/100
# 2/2 [==============================] - 0s 55ms/step - loss: 1076.2167 - mean_squared_error: 1076.2167 - val_loss: 1057.8795 - val_mean_squared_error: 1057.8795
# Epoch 70/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1061.0442 - mean_squared_error: 1061.0442 - val_loss: 1037.9568 - val_mean_squared_error: 1037.9568
# Epoch 71/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1051.2769 - mean_squared_error: 1051.2769 - val_loss: 1018.4736 - val_mean_squared_error: 1018.4736
# Epoch 72/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1039.2892 - mean_squared_error: 1039.2892 - val_loss: 999.5887 - val_mean_squared_error: 999.5887
# Epoch 73/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1024.1218 - mean_squared_error: 1024.1218 - val_loss: 981.2896 - val_mean_squared_error: 981.2896
# Epoch 74/100
# 2/2 [==============================] - 0s 55ms/step - loss: 1015.7782 - mean_squared_error: 1015.7782 - val_loss: 963.0916 - val_mean_squared_error: 963.0916
# Epoch 75/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1002.5945 - mean_squared_error: 1002.5945 - val_loss: 945.5491 - val_mean_squared_error: 945.5491
# Epoch 76/100
# 2/2 [==============================] - 0s 55ms/step - loss: 992.1599 - mean_squared_error: 992.1599 - val_loss: 928.8884 - val_mean_squared_error: 928.8884
# Epoch 77/100
# 2/2 [==============================] - 0s 54ms/step - loss: 980.6534 - mean_squared_error: 980.6534 - val_loss: 912.8865 - val_mean_squared_error: 912.8865
# Epoch 78/100
# 2/2 [==============================] - 0s 59ms/step - loss: 972.5961 - mean_squared_error: 972.5961 - val_loss: 897.5139 - val_mean_squared_error: 897.5139
# Epoch 79/100
# 2/2 [==============================] - 0s 51ms/step - loss: 961.0386 - mean_squared_error: 961.0386 - val_loss: 882.2991 - val_mean_squared_error: 882.2991
# Epoch 80/100
# 2/2 [==============================] - 0s 55ms/step - loss: 950.8837 - mean_squared_error: 950.8837 - val_loss: 867.8195 - val_mean_squared_error: 867.8195
# Epoch 81/100
# 2/2 [==============================] - 0s 50ms/step - loss: 943.2606 - mean_squared_error: 943.2606 - val_loss: 854.0959 - val_mean_squared_error: 854.0959
# Epoch 82/100
# 2/2 [==============================] - 0s 54ms/step - loss: 932.7985 - mean_squared_error: 932.7985 - val_loss: 840.2145 - val_mean_squared_error: 840.2145
# Epoch 83/100
# 2/2 [==============================] - 0s 55ms/step - loss: 924.3835 - mean_squared_error: 924.3835 - val_loss: 826.8403 - val_mean_squared_error: 826.8403
# Epoch 84/100
# 2/2 [==============================] - 0s 58ms/step - loss: 914.5648 - mean_squared_error: 914.5648 - val_loss: 814.3552 - val_mean_squared_error: 814.3552
# Epoch 85/100
# 2/2 [==============================] - 0s 57ms/step - loss: 906.6183 - mean_squared_error: 906.6183 - val_loss: 801.9739 - val_mean_squared_error: 801.9739
# Epoch 86/100
# 2/2 [==============================] - 0s 53ms/step - loss: 897.9542 - mean_squared_error: 897.9542 - val_loss: 790.2723 - val_mean_squared_error: 790.2723
# Epoch 87/100
# 2/2 [==============================] - 0s 56ms/step - loss: 892.3481 - mean_squared_error: 892.3481 - val_loss: 778.6680 - val_mean_squared_error: 778.6680
# Epoch 88/100
# 2/2 [==============================] - 0s 51ms/step - loss: 883.8173 - mean_squared_error: 883.8173 - val_loss: 767.2358 - val_mean_squared_error: 767.2358
# Epoch 89/100
# 2/2 [==============================] - 0s 56ms/step - loss: 877.0660 - mean_squared_error: 877.0660 - val_loss: 756.0910 - val_mean_squared_error: 756.0910
# Epoch 90/100
# 2/2 [==============================] - 0s 51ms/step - loss: 869.3775 - mean_squared_error: 869.3775 - val_loss: 745.2515 - val_mean_squared_error: 745.2515
# Epoch 91/100
# 2/2 [==============================] - 0s 53ms/step - loss: 861.9995 - mean_squared_error: 861.9995 - val_loss: 734.2291 - val_mean_squared_error: 734.2291
# Epoch 92/100
# 2/2 [==============================] - 0s 53ms/step - loss: 855.7303 - mean_squared_error: 855.7303 - val_loss: 723.5734 - val_mean_squared_error: 723.5734
# Epoch 93/100
# 2/2 [==============================] - 0s 58ms/step - loss: 849.1940 - mean_squared_error: 849.1940 - val_loss: 713.4868 - val_mean_squared_error: 713.4868
# Epoch 94/100
# 2/2 [==============================] - 0s 56ms/step - loss: 842.1700 - mean_squared_error: 842.1700 - val_loss: 703.0523 - val_mean_squared_error: 703.0523
# Epoch 95/100
# 2/2 [==============================] - 0s 51ms/step - loss: 837.2466 - mean_squared_error: 837.2466 - val_loss: 693.5975 - val_mean_squared_error: 693.5975
# Epoch 96/100
# 2/2 [==============================] - 0s 55ms/step - loss: 831.0807 - mean_squared_error: 831.0807 - val_loss: 684.2984 - val_mean_squared_error: 684.2984
# Epoch 97/100
# 2/2 [==============================] - 0s 55ms/step - loss: 825.4689 - mean_squared_error: 825.4689 - val_loss: 674.8317 - val_mean_squared_error: 674.8317
# Epoch 98/100
# 2/2 [==============================] - 0s 58ms/step - loss: 819.9509 - mean_squared_error: 819.9509 - val_loss: 666.4660 - val_mean_squared_error: 666.4660
# Epoch 99/100
# 2/2 [==============================] - 0s 53ms/step - loss: 813.4521 - mean_squared_error: 813.4521 - val_loss: 658.1028 - val_mean_squared_error: 658.1028
# Epoch 100/100
# 2/2 [==============================] - 0s 55ms/step - loss: 808.5899 - mean_squared_error: 808.5899 - val_loss: 649.9008 - val_mean_squared_error: 649.9008
# 1/1 [==============================] - 0s 37ms/step - loss: 7207.4355 - mean_squared_error: 7207.4355
# Test error: 7207.44
# 2023-09-23 13:53:08.254792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_2}}]]

# %%
model.save(model_save_path)

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  15.349377619425455
# MSE:  298.9744523683195
# RMSE:  17.290877721166137
# r2_score:  -1.833558167794755
# MSLE:  5.912927776846342
# MAPE:  5.801326286506121e+16
# ===== flank_wear results =====
# MAE:  101.07581837972005
# MSE:  21244.43969031807
# RMSE:  145.7547244185178
# r2_score:  -0.3259248744699599
# MSLE:  0.7480646112912525
# MAPE:  0.5895718543473395
# ===== overhang results =====
# MAE:  7.252483673095703
# MSE:  78.89112043172123
# RMSE:  8.88206735122636
# r2_score:  -2.9108316169426263
# MSLE:  0.3745069497921563
# MAPE:  0.8267027991687007
# ===== multi results =====
# MAE:  41.2258932240804
# MSE:  7207.435087706038
# RMSE:  57.30922316363677
# r2_score:  -1.690104886402447
# MSLE:  2.3451664459765835
# MAPE:  1.9337754288353736e+16
