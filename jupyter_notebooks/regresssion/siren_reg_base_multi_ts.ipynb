# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"]="3"
# Out:
# 2023-09-23 13:41:13.251790: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-23 13:41:15.417068: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  1
# GPUs:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-09-23 13:41:20.114092: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:41:20.164779: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:41:20.166194: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_spec = 9
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_spec = (img_rows, img_cols, in_channel_spec)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_ts"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"./{exp_name}_{sub_exp_name}_tool.h5"
model_spec_path = f"./{exp_name}_{sub_exp_name}_spec.h5"

# dataset
csv_path = "../../dataset/labels_reg_sample.csv"
tool_path = "../../dataset/tool"
spec_path = "../../dataset/spec"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang                            tool  \
# 14   T8R3B4   6.88       40.92     14.54   ../../dataset/tool/T8R3B4.jpg
# 10   T6R9B3  12.94       95.63     16.65   ../../dataset/tool/T6R9B3.jpg
# 0    T1R2B1   7.67       34.89     48.61   ../../dataset/tool/T1R2B1.jpg
# 3   T2R13B4   0.00      122.59     25.55  ../../dataset/tool/T2R13B4.jpg
# 1    T1R7B4  13.89       85.41     50.25   ../../dataset/tool/T1R7B4.jpg
#
#                               spec_x                            spec_y  \
# 14   ../../dataset/spec/x/T8R3B4.jpg   ../../dataset/spec/y/T8R3B4.jpg
# 10   ../../dataset/spec/x/T6R9B3.jpg   ../../dataset/spec/y/T6R9B3.jpg
# 0    ../../dataset/spec/x/T1R2B1.jpg   ../../dataset/spec/y/T1R2B1.jpg
# 3   ../../dataset/spec/x/T2R13B4.jpg  ../../dataset/spec/y/T2R13B4.jpg
# 1    ../../dataset/spec/x/T1R7B4.jpg   ../../dataset/spec/y/T1R7B4.jpg
#
#                               spec_z
# 14   ../../dataset/spec/z/T8R3B4.jpg
# 10   ../../dataset/spec/z/T6R9B3.jpg
# 0    ../../dataset/spec/z/T1R2B1.jpg
# 3   ../../dataset/spec/z/T2R13B4.jpg
# 1    ../../dataset/spec/z/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang                            tool  \
# 16   T9R7B4   0.00       94.62     17.05   ../../dataset/tool/T9R7B4.jpg
# 18  T10R3B4   0.00       44.26      7.10  ../../dataset/tool/T10R3B4.jpg
# 9   T5R12B1  21.79      334.39     16.14  ../../dataset/tool/T5R12B1.jpg
#
#                               spec_x                            spec_y  \
# 16   ../../dataset/spec/x/T9R7B4.jpg   ../../dataset/spec/y/T9R7B4.jpg
# 18  ../../dataset/spec/x/T10R3B4.jpg  ../../dataset/spec/y/T10R3B4.jpg
# 9   ../../dataset/spec/x/T5R12B1.jpg  ../../dataset/spec/y/T5R12B1.jpg
#
#                               spec_z
# 16   ../../dataset/spec/z/T9R7B4.jpg
# 18  ../../dataset/spec/z/T10R3B4.jpg
# 9   ../../dataset/spec/z/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang                            tool  \
# 5   T3R10B1   5.00      128.39     35.26  ../../dataset/tool/T3R10B1.jpg
# 13  T7R14B3  13.67      141.91     14.62  ../../dataset/tool/T7R14B3.jpg
# 12   T7R8B3   7.45       77.05     19.02   ../../dataset/tool/T7R8B3.jpg
#
#                               spec_x                            spec_y  \
# 5   ../../dataset/spec/x/T3R10B1.jpg  ../../dataset/spec/y/T3R10B1.jpg
# 13  ../../dataset/spec/x/T7R14B3.jpg  ../../dataset/spec/y/T7R14B3.jpg
# 12   ../../dataset/spec/x/T7R8B3.jpg   ../../dataset/spec/y/T7R8B3.jpg
#
#                               spec_z
# 5   ../../dataset/spec/z/T3R10B1.jpg
# 13  ../../dataset/spec/z/T7R14B3.jpg
# 12   ../../dataset/spec/z/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images


def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for i in range(file_paths_x.size):
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_x)
        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_y)
        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        images.append(res_z)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(file_paths_x.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
# ============================== augment 1/2 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)
# Out:
# 2023-09-23 13:41:23.367948: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:41:23.369465: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:41:23.370745: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:41:24.451606: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:41:24.452576: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:41:24.453504: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:41:24.454395: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10377 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:00:1c.0, compute capability: 6.1

# %%
# ============================== augment 2/2 ==============================
data_augmentation_spec = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_spec",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_spec = data_augmentation_spec(x_train_spec)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_spec": x_train_spec,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_spec": x_test_spec,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_spec": x_val_spec,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs2 = k.Input(input_shape_spec)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_spec': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
model_tool = k.models.load_model(model_tool_path, compile=False)
model_spec = k.models.load_model(model_spec_path, compile=False)

model_tool.trainable = False
model_spec.trainable = False


def load_multi_mixer(model_tool, model_spec):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs2 = model_spec.input
    inputs2._name = "input_spec"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_spec = k.Model(
        inputs=model_spec.input, outputs=model_spec.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_spec.output,
        ]
    )
    output = layers.Dense(num_classes, activation="linear", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs2], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_spec.layers:
    layer._name = layer.name + str("_spec")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_multi_mixer(model_tool, model_spec)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1_tool (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_1_spec (InputLayer)      [(None, 256, 256, 9  0           []
#                                 )]
#
#  conv2d_tool (Conv2D)           (None, 16, 16, 256)  196864      ['input_1_tool[0][0]']
#
#  conv2d_spec (Conv2D)           (None, 16, 16, 256)  590080      ['input_1_spec[0][0]']
#
#  activation_tool (Activation)   (None, 16, 16, 256)  0           ['conv2d_tool[0][0]']
#
#  activation_spec (Activation)   (None, 16, 16, 256)  0           ['conv2d_spec[0][0]']
#
#  batch_normalization_tool (Batc  (None, 16, 16, 256)  1024       ['activation_tool[0][0]']
#  hNormalization)
#
#  batch_normalization_spec (Batc  (None, 16, 16, 256)  1024       ['activation_spec[0][0]']
#  hNormalization)
#
#  depthwise_conv2d_tool (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_tool[0][0]'
#  seConv2D)                                                       ]
#
#  depthwise_conv2d_spec (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_spec[0][0]'
#  seConv2D)                                                       ]
#
#  activation_1_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_tool[0][0]']
#
#  activation_1_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_spec[0][0]']
#
#  batch_normalization_1_tool (Ba  (None, 16, 16, 256)  1024       ['activation_1_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_1_spec (Ba  (None, 16, 16, 256)  1024       ['activation_1_spec[0][0]']
#  tchNormalization)
#
#  add_tool (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_spec (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  conv2d_1_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_tool[0][0]']
#
#  conv2d_1_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_spec[0][0]']
#
#  activation_2_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_tool[0][0]']
#
#  activation_2_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_spec[0][0]']
#
#  batch_normalization_2_tool (Ba  (None, 16, 16, 256)  1024       ['activation_2_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_2_spec (Ba  (None, 16, 16, 256)  1024       ['activation_2_spec[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_1_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  depthwise_conv2d_1_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_3_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_tool[0][0]']
#
#  activation_3_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_spec[0][0]']
#
#  batch_normalization_3_tool (Ba  (None, 16, 16, 256)  1024       ['activation_3_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_3_spec (Ba  (None, 16, 16, 256)  1024       ['activation_3_spec[0][0]']
#  tchNormalization)
#
#  add_1_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_tool[0][0
#                                                                  ]']
#
#  add_1_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_spec[0][0
#                                                                  ]']
#
#  conv2d_2_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_tool[0][0]']
#
#  conv2d_2_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_spec[0][0]']
#
#  activation_4_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_tool[0][0]']
#
#  activation_4_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_spec[0][0]']
#
#  batch_normalization_4_tool (Ba  (None, 16, 16, 256)  1024       ['activation_4_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_4_spec (Ba  (None, 16, 16, 256)  1024       ['activation_4_spec[0][0]']
#  tchNormalization)
#
#  add_4_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_4_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_4_tool (Depth  (None, 16, 16, 256)  6656       ['add_4_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_4_spec (Depth  (None, 16, 16, 256)  6656       ['add_4_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_2_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_tool[0][0]']
#
#  depthwise_conv2d_2_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_spec[0][0]']
#
#  activation_5_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_tool[0][0]']
#
#  batch_normalization_9_tool (Ba  (None, 16, 16, 256)  1024       ['activation_9_tool[0][0]']
#  tchNormalization)
#
#  activation_5_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_spec[0][0]']
#
#  batch_normalization_9_spec (Ba  (None, 16, 16, 256)  1024       ['activation_9_spec[0][0]']
#  tchNormalization)
#
#  batch_normalization_5_tool (Ba  (None, 16, 16, 256)  1024       ['activation_5_tool[0][0]']
#  tchNormalization)
#
#  add_5_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_tool[0][0
#                                                                  ]',
#                                                                   'add_4_tool[0][0]']
#
#  batch_normalization_5_spec (Ba  (None, 16, 16, 256)  1024       ['activation_5_spec[0][0]']
#  tchNormalization)
#
#  add_5_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_spec[0][0
#                                                                  ]',
#                                                                   'add_4_spec[0][0]']
#
#  add_2_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_tool[0][0
#                                                                  ]']
#
#  conv2d_5_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_tool[0][0]']
#
#  add_2_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_spec[0][0
#                                                                  ]']
#
#  conv2d_5_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_spec[0][0]']
#
#  conv2d_3_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_tool[0][0]']
#
#  activation_10_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_5_tool[0][0]']
#  )
#
#  conv2d_3_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_spec[0][0]']
#
#  activation_10_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_5_spec[0][0]']
#  )
#
#  activation_6_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_tool[0][0]']
#
#  batch_normalization_10_tool (B  (None, 16, 16, 256)  1024       ['activation_10_tool[0][0]']
#  atchNormalization)
#
#  activation_6_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_spec[0][0]']
#
#  batch_normalization_10_spec (B  (None, 16, 16, 256)  1024       ['activation_10_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_6_tool (Ba  (None, 16, 16, 256)  1024       ['activation_6_tool[0][0]']
#  tchNormalization)
#
#  add_6_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_tool[0][
#                                                                  0]']
#
#  batch_normalization_6_spec (Ba  (None, 16, 16, 256)  1024       ['activation_6_spec[0][0]']
#  tchNormalization)
#
#  add_6_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_spec[0][
#                                                                  0]']
#
#  add_7_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_tool[0][0
#                                                                  ]',
#                                                                   'add_6_tool[0][0]']
#
#  add_7_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_spec[0][0
#                                                                  ]',
#                                                                   'add_6_spec[0][0]']
#
#  depthwise_conv2d_5_tool (Depth  (None, 16, 16, 256)  6656       ['add_7_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_5_spec (Depth  (None, 16, 16, 256)  6656       ['add_7_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_3_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_tool[0][0]']
#  )
#
#  depthwise_conv2d_3_spec (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_spec[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_spec[0][0]']
#  )
#
#  activation_7_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_tool[0][0]']
#
#  batch_normalization_11_tool (B  (None, 16, 16, 256)  1024       ['activation_11_tool[0][0]']
#  atchNormalization)
#
#  activation_7_spec (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_spec[0][0]']
#
#  batch_normalization_11_spec (B  (None, 16, 16, 256)  1024       ['activation_11_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_7_tool (Ba  (None, 16, 16, 256)  1024       ['activation_7_tool[0][0]']
#  tchNormalization)
#
#  add_8_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_tool[0][
#                                                                  0]',
#                                                                   'add_7_tool[0][0]']
#
#  batch_normalization_7_spec (Ba  (None, 16, 16, 256)  1024       ['activation_7_spec[0][0]']
#  tchNormalization)
#
#  add_8_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_spec[0][
#                                                                  0]',
#                                                                   'add_7_spec[0][0]']
#
#  add_3_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_tool[0][0
#                                                                  ]']
#
#  conv2d_6_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_tool[0][0]']
#
#  add_3_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_spec[0][0
#                                                                  ]']
#
#  conv2d_6_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_spec[0][0]']
#
#  conv2d_4_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_tool[0][0]']
#
#  activation_12_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_6_tool[0][0]']
#  )
#
#  conv2d_4_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_spec[0][0]']
#
#  activation_12_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_6_spec[0][0]']
#  )
#
#  activation_8_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_tool[0][0]']
#
#  batch_normalization_12_tool (B  (None, 16, 16, 256)  1024       ['activation_12_tool[0][0]']
#  atchNormalization)
#
#  activation_8_spec (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_spec[0][0]']
#
#  batch_normalization_12_spec (B  (None, 16, 16, 256)  1024       ['activation_12_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_8_tool (Ba  (None, 16, 16, 256)  1024       ['activation_8_tool[0][0]']
#  tchNormalization)
#
#  add_9_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_tool[0][
#                                                                  0]']
#
#  batch_normalization_8_spec (Ba  (None, 16, 16, 256)  1024       ['activation_8_spec[0][0]']
#  tchNormalization)
#
#  add_9_spec (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_spec[0][
#                                                                  0]']
#
#  add_10_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_tool[0][0
#                                                                  ]',
#                                                                   'add_9_tool[0][0]']
#
#  add_15_tool (Add)              (None, 16, 16, 256)  0           ['add_9_tool[0][0]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_10_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_spec[0][0
#                                                                  ]',
#                                                                   'add_9_spec[0][0]']
#
#  add_15_spec (Add)              (None, 16, 16, 256)  0           ['add_9_spec[0][0]',
#                                                                   'batch_normalization_spec[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_6_tool (Depth  (None, 16, 16, 256)  6656       ['add_10_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_tool (Depth  (None, 16, 16, 256)  6656       ['add_15_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_6_spec (Depth  (None, 16, 16, 256)  6656       ['add_10_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_spec (Depth  (None, 16, 16, 256)  6656       ['add_15_spec[0][0]']
#  wiseConv2D)
#
#  activation_13_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_6_tool[0][0]']
#  )
#
#  activation_17_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_8_tool[0][0]']
#  )
#
#  activation_13_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_6_spec[0][0]']
#  )
#
#  activation_17_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_8_spec[0][0]']
#  )
#
#  batch_normalization_13_tool (B  (None, 16, 16, 256)  1024       ['activation_13_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_17_tool (B  (None, 16, 16, 256)  1024       ['activation_17_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_13_spec (B  (None, 16, 16, 256)  1024       ['activation_13_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_17_spec (B  (None, 16, 16, 256)  1024       ['activation_17_spec[0][0]']
#  atchNormalization)
#
#  add_11_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_13_tool[0][
#                                                                  0]',
#                                                                   'add_10_tool[0][0]']
#
#  add_16_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_17_tool[0][
#                                                                  0]',
#                                                                   'add_15_tool[0][0]']
#
#  add_11_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_13_spec[0][
#                                                                  0]',
#                                                                   'add_10_spec[0][0]']
#
#  add_16_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_17_spec[0][
#                                                                  0]',
#                                                                   'add_15_spec[0][0]']
#
#  conv2d_7_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_11_tool[0][0]']
#
#  conv2d_9_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_16_tool[0][0]']
#
#  conv2d_7_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_11_spec[0][0]']
#
#  conv2d_9_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_16_spec[0][0]']
#
#  activation_14_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_7_tool[0][0]']
#  )
#
#  activation_18_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_9_tool[0][0]']
#  )
#
#  activation_14_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_7_spec[0][0]']
#  )
#
#  activation_18_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_9_spec[0][0]']
#  )
#
#  batch_normalization_14_tool (B  (None, 16, 16, 256)  1024       ['activation_14_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_18_tool (B  (None, 16, 16, 256)  1024       ['activation_18_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_14_spec (B  (None, 16, 16, 256)  1024       ['activation_14_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_18_spec (B  (None, 16, 16, 256)  1024       ['activation_18_spec[0][0]']
#  atchNormalization)
#
#  add_12_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_6_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_14_tool[0][
#                                                                  0]']
#
#  add_17_tool (Add)              (None, 16, 16, 256)  0           ['add_6_tool[0][0]',
#                                                                   'batch_normalization_18_tool[0][
#                                                                  0]']
#
#  add_12_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_6_spec[0][0
#                                                                  ]',
#                                                                   'batch_normalization_14_spec[0][
#                                                                  0]']
#
#  add_17_spec (Add)              (None, 16, 16, 256)  0           ['add_6_spec[0][0]',
#                                                                   'batch_normalization_18_spec[0][
#                                                                  0]']
#
#  add_18_tool (Add)              (None, 16, 16, 256)  0           ['add_12_tool[0][0]',
#                                                                   'add_17_tool[0][0]']
#
#  add_18_spec (Add)              (None, 16, 16, 256)  0           ['add_12_spec[0][0]',
#                                                                   'add_17_spec[0][0]']
#
#  depthwise_conv2d_7_tool (Depth  (None, 16, 16, 256)  6656       ['add_12_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_9_tool (Depth  (None, 16, 16, 256)  6656       ['add_18_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_7_spec (Depth  (None, 16, 16, 256)  6656       ['add_12_spec[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_9_spec (Depth  (None, 16, 16, 256)  6656       ['add_18_spec[0][0]']
#  wiseConv2D)
#
#  activation_15_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_7_tool[0][0]']
#  )
#
#  activation_19_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_9_tool[0][0]']
#  )
#
#  activation_15_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_7_spec[0][0]']
#  )
#
#  activation_19_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_9_spec[0][0]']
#  )
#
#  batch_normalization_15_tool (B  (None, 16, 16, 256)  1024       ['activation_15_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_19_tool (B  (None, 16, 16, 256)  1024       ['activation_19_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_15_spec (B  (None, 16, 16, 256)  1024       ['activation_15_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_19_spec (B  (None, 16, 16, 256)  1024       ['activation_19_spec[0][0]']
#  atchNormalization)
#
#  add_13_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_15_tool[0][
#                                                                  0]',
#                                                                   'add_12_tool[0][0]']
#
#  add_19_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_19_tool[0][
#                                                                  0]',
#                                                                   'add_18_tool[0][0]']
#
#  add_13_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_15_spec[0][
#                                                                  0]',
#                                                                   'add_12_spec[0][0]']
#
#  add_19_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_19_spec[0][
#                                                                  0]',
#                                                                   'add_18_spec[0][0]']
#
#  conv2d_8_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_13_tool[0][0]']
#
#  conv2d_10_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_19_tool[0][0]']
#
#  conv2d_8_spec (Conv2D)         (None, 16, 16, 256)  65792       ['add_13_spec[0][0]']
# ...
#  )
#
#  activation_28_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_14_tool[0][0]']
#  )
#
#  activation_24_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_12_spec[0][0]']
#  )
#
#  activation_28_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_14_spec[0][0]']
#  )
#
#  batch_normalization_24_tool (B  (None, 16, 16, 256)  1024       ['activation_24_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_28_tool (B  (None, 16, 16, 256)  1024       ['activation_28_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_24_spec (B  (None, 16, 16, 256)  1024       ['activation_24_spec[0][0]']
#  atchNormalization)
#
#  batch_normalization_28_spec (B  (None, 16, 16, 256)  1024       ['activation_28_spec[0][0]']
#  atchNormalization)
#
#  add_25_tool (Add)              (None, 16, 16, 256)  0           ['add_14_tool[0][0]',
#                                                                   'batch_normalization_24_tool[0][
#                                                                  0]']
#
#  add_31_tool (Add)              (None, 16, 16, 256)  0           ['add_20_tool[0][0]',
#                                                                   'batch_normalization_28_tool[0][
#                                                                  0]']
#
#  add_25_spec (Add)              (None, 16, 16, 256)  0           ['add_14_spec[0][0]',
#                                                                   'batch_normalization_24_spec[0][
#                                                                  0]']
#
#  add_31_spec (Add)              (None, 16, 16, 256)  0           ['add_20_spec[0][0]',
#                                                                   'batch_normalization_28_spec[0][
#                                                                  0]']
#
#  add_32_tool (Add)              (None, 16, 16, 256)  0           ['add_25_tool[0][0]',
#                                                                   'add_31_tool[0][0]']
#
#  add_32_spec (Add)              (None, 16, 16, 256)  0           ['add_25_spec[0][0]',
#                                                                   'add_31_spec[0][0]']
#
#  depthwise_conv2d_14_tool (Dept  (None, 16, 16, 256)  6656       ['add_32_tool[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_14_spec (Dept  (None, 16, 16, 256)  6656       ['add_32_spec[0][0]']
#  hwiseConv2D)
#
#  activation_29_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_tool[0][0]'
#  )                                                               ]
#
#  activation_29_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_spec[0][0]'
#  )                                                               ]
#
#  batch_normalization_29_tool (B  (None, 16, 16, 256)  1024       ['activation_29_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_29_spec (B  (None, 16, 16, 256)  1024       ['activation_29_spec[0][0]']
#  atchNormalization)
#
#  add_33_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_tool[0][
#                                                                  0]',
#                                                                   'add_32_tool[0][0]']
#
#  add_33_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_spec[0][
#                                                                  0]',
#                                                                   'add_32_spec[0][0]']
#
#  conv2d_15_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_tool[0][0]']
#
#  conv2d_15_spec (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_spec[0][0]']
#
#  activation_30_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_15_tool[0][0]']
#  )
#
#  activation_30_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_15_spec[0][0]']
#  )
#
#  batch_normalization_30_tool (B  (None, 16, 16, 256)  1024       ['activation_30_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_30_spec (B  (None, 16, 16, 256)  1024       ['activation_30_spec[0][0]']
#  atchNormalization)
#
#  add_34_tool (Add)              (None, 16, 16, 256)  0           ['add_23_tool[0][0]',
#                                                                   'batch_normalization_30_tool[0][
#                                                                  0]']
#
#  add_34_spec (Add)              (None, 16, 16, 256)  0           ['add_23_spec[0][0]',
#                                                                   'batch_normalization_30_spec[0][
#                                                                  0]']
#
#  depthwise_conv2d_15_tool (Dept  (None, 16, 16, 256)  6656       ['add_34_tool[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_15_spec (Dept  (None, 16, 16, 256)  6656       ['add_34_spec[0][0]']
#  hwiseConv2D)
#
#  activation_31_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_tool[0][0]'
#  )                                                               ]
#
#  activation_31_spec (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_spec[0][0]'
#  )                                                               ]
#
#  batch_normalization_31_tool (B  (None, 16, 16, 256)  1024       ['activation_31_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_31_spec (B  (None, 16, 16, 256)  1024       ['activation_31_spec[0][0]']
#  atchNormalization)
#
#  add_35_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_tool[0][
#                                                                  0]',
#                                                                   'add_34_tool[0][0]']
#
#  add_35_spec (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_spec[0][
#                                                                  0]',
#                                                                   'add_34_spec[0][0]']
#
#  conv2d_16_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_tool[0][0]']
#
#  conv2d_16_spec (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_spec[0][0]']
#
#  activation_32_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_16_tool[0][0]']
#  )
#
#  activation_32_spec (Activation  (None, 16, 16, 256)  0          ['conv2d_16_spec[0][0]']
#  )
#
#  batch_normalization_32_tool (B  (None, 16, 16, 256)  1024       ['activation_32_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_32_spec (B  (None, 16, 16, 256)  1024       ['activation_32_spec[0][0]']
#  atchNormalization)
#
#  add_36_tool (Add)              (None, 16, 16, 256)  0           ['add_25_tool[0][0]',
#                                                                   'batch_normalization_32_tool[0][
#                                                                  0]']
#
#  add_36_spec (Add)              (None, 16, 16, 256)  0           ['add_25_spec[0][0]',
#                                                                   'batch_normalization_32_spec[0][
#                                                                  0]']
#
#  global_average_pooling2d_tool   (None, 256)         0           ['add_36_tool[0][0]']
#  (GlobalAveragePooling2D)
#
#  global_average_pooling2d_spec   (None, 256)         0           ['add_36_spec[0][0]']
#  (GlobalAveragePooling2D)
#
#  concatenate (Concatenate)      (None, 512)          0           ['global_average_pooling2d_tool[0
#                                                                  ][0]',
#                                                                   'global_average_pooling2d_spec[0
#                                                                  ][0]']
#
#  output_mult (Dense)            (None, 3)            1539        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3,174,403
# Trainable params: 1,539
# Non-trainable params: 3,172,864
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2023-09-23 13:41:29.243603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [14,256,256,3]
# 	 [[{{node Placeholder/_1}}]]
# 2023-09-23 13:41:29.244080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [14,3]
# 	 [[{{node Placeholder/_2}}]]
# 2023-09-23 13:41:38.308160: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2/2 [==============================] - ETA: 0s - loss: 3981.2341 - mean_squared_error: 3981.2341
# 2023-09-23 13:41:39.103640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_2}}]]
# 2/2 [==============================] - 12s 2s/step - loss: 3981.2341 - mean_squared_error: 3981.2341 - val_loss: 4916.9565 - val_mean_squared_error: 4916.9565
# Epoch 2/100
# 2/2 [==============================] - 0s 58ms/step - loss: 3865.2971 - mean_squared_error: 3865.2971 - val_loss: 4777.0649 - val_mean_squared_error: 4777.0649
# Epoch 3/100
# 2/2 [==============================] - 0s 58ms/step - loss: 3762.1128 - mean_squared_error: 3762.1128 - val_loss: 4642.1089 - val_mean_squared_error: 4642.1089
# Epoch 4/100
# 2/2 [==============================] - 0s 54ms/step - loss: 3659.4749 - mean_squared_error: 3659.4749 - val_loss: 4512.8486 - val_mean_squared_error: 4512.8486
# Epoch 5/100
# 2/2 [==============================] - 0s 55ms/step - loss: 3553.3745 - mean_squared_error: 3553.3743 - val_loss: 4388.8931 - val_mean_squared_error: 4388.8931
# Epoch 6/100
# 2/2 [==============================] - 0s 56ms/step - loss: 3454.9597 - mean_squared_error: 3454.9597 - val_loss: 4268.7524 - val_mean_squared_error: 4268.7524
# Epoch 7/100
# 2/2 [==============================] - 0s 53ms/step - loss: 3356.4336 - mean_squared_error: 3356.4336 - val_loss: 4152.1855 - val_mean_squared_error: 4152.1855
# Epoch 8/100
# 2/2 [==============================] - 0s 50ms/step - loss: 3268.1379 - mean_squared_error: 3268.1379 - val_loss: 4038.8799 - val_mean_squared_error: 4038.8799
# Epoch 9/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3186.9966 - mean_squared_error: 3186.9966 - val_loss: 3928.7002 - val_mean_squared_error: 3928.7002
# Epoch 10/100
# 2/2 [==============================] - 0s 52ms/step - loss: 3103.2317 - mean_squared_error: 3103.2317 - val_loss: 3823.0881 - val_mean_squared_error: 3823.0881
# Epoch 11/100
# 2/2 [==============================] - 0s 54ms/step - loss: 3024.3259 - mean_squared_error: 3024.3259 - val_loss: 3720.8528 - val_mean_squared_error: 3720.8528
# Epoch 12/100
# 2/2 [==============================] - 0s 56ms/step - loss: 2945.6116 - mean_squared_error: 2945.6116 - val_loss: 3622.1768 - val_mean_squared_error: 3622.1768
# Epoch 13/100
# 2/2 [==============================] - 0s 58ms/step - loss: 2872.9084 - mean_squared_error: 2872.9084 - val_loss: 3526.0898 - val_mean_squared_error: 3526.0898
# Epoch 14/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2804.5112 - mean_squared_error: 2804.5112 - val_loss: 3432.4805 - val_mean_squared_error: 3432.4805
# Epoch 15/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2727.3533 - mean_squared_error: 2727.3533 - val_loss: 3342.3984 - val_mean_squared_error: 3342.3984
# Epoch 16/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2662.4253 - mean_squared_error: 2662.4253 - val_loss: 3254.3027 - val_mean_squared_error: 3254.3027
# Epoch 17/100
# 2/2 [==============================] - 0s 54ms/step - loss: 2598.0933 - mean_squared_error: 2598.0933 - val_loss: 3168.3203 - val_mean_squared_error: 3168.3203
# Epoch 18/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2544.9426 - mean_squared_error: 2544.9426 - val_loss: 3083.9490 - val_mean_squared_error: 3083.9490
# Epoch 19/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2483.6467 - mean_squared_error: 2483.6467 - val_loss: 3002.3206 - val_mean_squared_error: 3002.3206
# Epoch 20/100
# 2/2 [==============================] - 0s 53ms/step - loss: 2419.2957 - mean_squared_error: 2419.2957 - val_loss: 2923.3682 - val_mean_squared_error: 2923.3682
# Epoch 21/100
# 2/2 [==============================] - 0s 57ms/step - loss: 2368.8176 - mean_squared_error: 2368.8179 - val_loss: 2846.1096 - val_mean_squared_error: 2846.1096
# Epoch 22/100
# 2/2 [==============================] - 0s 54ms/step - loss: 2312.0400 - mean_squared_error: 2312.0400 - val_loss: 2771.2097 - val_mean_squared_error: 2771.2097
# Epoch 23/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2257.0051 - mean_squared_error: 2257.0051 - val_loss: 2697.6775 - val_mean_squared_error: 2697.6775
# Epoch 24/100
# 2/2 [==============================] - 0s 57ms/step - loss: 2209.9612 - mean_squared_error: 2209.9612 - val_loss: 2626.0750 - val_mean_squared_error: 2626.0750
# Epoch 25/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2158.0547 - mean_squared_error: 2158.0547 - val_loss: 2556.6758 - val_mean_squared_error: 2556.6758
# Epoch 26/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2109.6941 - mean_squared_error: 2109.6941 - val_loss: 2488.8945 - val_mean_squared_error: 2488.8945
# Epoch 27/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2063.1157 - mean_squared_error: 2063.1157 - val_loss: 2422.7637 - val_mean_squared_error: 2422.7637
# Epoch 28/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2018.4209 - mean_squared_error: 2018.4209 - val_loss: 2358.2200 - val_mean_squared_error: 2358.2200
# Epoch 29/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1972.4337 - mean_squared_error: 1972.4337 - val_loss: 2295.3762 - val_mean_squared_error: 2295.3762
# Epoch 30/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1926.8329 - mean_squared_error: 1926.8329 - val_loss: 2234.8484 - val_mean_squared_error: 2234.8484
# Epoch 31/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1888.0109 - mean_squared_error: 1888.0109 - val_loss: 2175.2458 - val_mean_squared_error: 2175.2458
# Epoch 32/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1846.3119 - mean_squared_error: 1846.3119 - val_loss: 2117.5344 - val_mean_squared_error: 2117.5344
# Epoch 33/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1811.3513 - mean_squared_error: 1811.3513 - val_loss: 2061.3252 - val_mean_squared_error: 2061.3252
# Epoch 34/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1771.4336 - mean_squared_error: 1771.4336 - val_loss: 2006.6132 - val_mean_squared_error: 2006.6132
# Epoch 35/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1733.5977 - mean_squared_error: 1733.5977 - val_loss: 1952.8633 - val_mean_squared_error: 1952.8633
# Epoch 36/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1700.2334 - mean_squared_error: 1700.2334 - val_loss: 1901.1470 - val_mean_squared_error: 1901.1470
# Epoch 37/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1665.9777 - mean_squared_error: 1665.9777 - val_loss: 1850.0529 - val_mean_squared_error: 1850.0529
# Epoch 38/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1632.7338 - mean_squared_error: 1632.7338 - val_loss: 1801.5316 - val_mean_squared_error: 1801.5316
# Epoch 39/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1600.4749 - mean_squared_error: 1600.4749 - val_loss: 1754.4996 - val_mean_squared_error: 1754.4996
# Epoch 40/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1568.0033 - mean_squared_error: 1568.0033 - val_loss: 1709.0531 - val_mean_squared_error: 1709.0531
# Epoch 41/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1538.5126 - mean_squared_error: 1538.5126 - val_loss: 1664.1797 - val_mean_squared_error: 1664.1797
# Epoch 42/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1511.8420 - mean_squared_error: 1511.8420 - val_loss: 1619.6830 - val_mean_squared_error: 1619.6830
# Epoch 43/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1482.7792 - mean_squared_error: 1482.7792 - val_loss: 1577.8306 - val_mean_squared_error: 1577.8306
# Epoch 44/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1457.2976 - mean_squared_error: 1457.2976 - val_loss: 1537.1079 - val_mean_squared_error: 1537.1079
# Epoch 45/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1430.7518 - mean_squared_error: 1430.7518 - val_loss: 1497.6440 - val_mean_squared_error: 1497.6440
# Epoch 46/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1406.7272 - mean_squared_error: 1406.7272 - val_loss: 1459.1139 - val_mean_squared_error: 1459.1139
# Epoch 47/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1380.0917 - mean_squared_error: 1380.0917 - val_loss: 1421.9347 - val_mean_squared_error: 1421.9347
# Epoch 48/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1356.4156 - mean_squared_error: 1356.4156 - val_loss: 1386.0416 - val_mean_squared_error: 1386.0416
# Epoch 49/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1338.2826 - mean_squared_error: 1338.2826 - val_loss: 1350.9652 - val_mean_squared_error: 1350.9652
# Epoch 50/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1316.6151 - mean_squared_error: 1316.6151 - val_loss: 1317.1909 - val_mean_squared_error: 1317.1909
# Epoch 51/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1293.7953 - mean_squared_error: 1293.7953 - val_loss: 1284.2744 - val_mean_squared_error: 1284.2744
# Epoch 52/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1272.7235 - mean_squared_error: 1272.7235 - val_loss: 1253.0621 - val_mean_squared_error: 1253.0621
# Epoch 53/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1256.3855 - mean_squared_error: 1256.3855 - val_loss: 1222.3732 - val_mean_squared_error: 1222.3732
# Epoch 54/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1238.1320 - mean_squared_error: 1238.1320 - val_loss: 1193.9187 - val_mean_squared_error: 1193.9187
# Epoch 55/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1219.5470 - mean_squared_error: 1219.5470 - val_loss: 1166.3910 - val_mean_squared_error: 1166.3910
# Epoch 56/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1199.7900 - mean_squared_error: 1199.7900 - val_loss: 1139.2352 - val_mean_squared_error: 1139.2352
# Epoch 57/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1183.2815 - mean_squared_error: 1183.2815 - val_loss: 1113.0265 - val_mean_squared_error: 1113.0265
# Epoch 58/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1167.8241 - mean_squared_error: 1167.8241 - val_loss: 1087.4100 - val_mean_squared_error: 1087.4100
# Epoch 59/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1155.9388 - mean_squared_error: 1155.9388 - val_loss: 1062.5359 - val_mean_squared_error: 1062.5359
# Epoch 60/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1139.1628 - mean_squared_error: 1139.1628 - val_loss: 1039.2167 - val_mean_squared_error: 1039.2167
# Epoch 61/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1123.2126 - mean_squared_error: 1123.2126 - val_loss: 1016.0119 - val_mean_squared_error: 1016.0119
# Epoch 62/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1112.5681 - mean_squared_error: 1112.5681 - val_loss: 993.5342 - val_mean_squared_error: 993.5342
# Epoch 63/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1098.1654 - mean_squared_error: 1098.1654 - val_loss: 972.2773 - val_mean_squared_error: 972.2773
# Epoch 64/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1086.2982 - mean_squared_error: 1086.2982 - val_loss: 951.2625 - val_mean_squared_error: 951.2625
# Epoch 65/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1075.6986 - mean_squared_error: 1075.6986 - val_loss: 930.8848 - val_mean_squared_error: 930.8848
# Epoch 66/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1062.9727 - mean_squared_error: 1062.9727 - val_loss: 911.6137 - val_mean_squared_error: 911.6137
# Epoch 67/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1051.2080 - mean_squared_error: 1051.2080 - val_loss: 893.4219 - val_mean_squared_error: 893.4219
# Epoch 68/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1042.1807 - mean_squared_error: 1042.1807 - val_loss: 875.2241 - val_mean_squared_error: 875.2241
# Epoch 69/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1030.2985 - mean_squared_error: 1030.2985 - val_loss: 857.9223 - val_mean_squared_error: 857.9223
# Epoch 70/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1022.9464 - mean_squared_error: 1022.9464 - val_loss: 841.4581 - val_mean_squared_error: 841.4581
# Epoch 71/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1013.2384 - mean_squared_error: 1013.2384 - val_loss: 825.4797 - val_mean_squared_error: 825.4797
# Epoch 72/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1004.6624 - mean_squared_error: 1004.6624 - val_loss: 809.7852 - val_mean_squared_error: 809.7852
# Epoch 73/100
# 2/2 [==============================] - 0s 48ms/step - loss: 995.9039 - mean_squared_error: 995.9039 - val_loss: 795.8925 - val_mean_squared_error: 795.8925
# Epoch 74/100
# 2/2 [==============================] - 0s 52ms/step - loss: 987.7207 - mean_squared_error: 987.7207 - val_loss: 782.4385 - val_mean_squared_error: 782.4385
# Epoch 75/100
# 2/2 [==============================] - 0s 49ms/step - loss: 982.0684 - mean_squared_error: 982.0684 - val_loss: 768.3277 - val_mean_squared_error: 768.3277
# Epoch 76/100
# 2/2 [==============================] - 0s 49ms/step - loss: 972.8437 - mean_squared_error: 972.8437 - val_loss: 754.8804 - val_mean_squared_error: 754.8804
# Epoch 77/100
# 2/2 [==============================] - 0s 51ms/step - loss: 964.1411 - mean_squared_error: 964.1411 - val_loss: 742.9692 - val_mean_squared_error: 742.9692
# Epoch 78/100
# 2/2 [==============================] - 0s 62ms/step - loss: 958.8647 - mean_squared_error: 958.8647 - val_loss: 730.9644 - val_mean_squared_error: 730.9644
# Epoch 79/100
# 2/2 [==============================] - 0s 51ms/step - loss: 950.6970 - mean_squared_error: 950.6970 - val_loss: 720.2488 - val_mean_squared_error: 720.2488
# Epoch 80/100
# 2/2 [==============================] - 0s 52ms/step - loss: 943.8641 - mean_squared_error: 943.8641 - val_loss: 709.8318 - val_mean_squared_error: 709.8318
# Epoch 81/100
# 2/2 [==============================] - 0s 53ms/step - loss: 938.2982 - mean_squared_error: 938.2982 - val_loss: 699.5158 - val_mean_squared_error: 699.5158
# Epoch 82/100
# 2/2 [==============================] - 0s 52ms/step - loss: 934.2973 - mean_squared_error: 934.2973 - val_loss: 689.7510 - val_mean_squared_error: 689.7510
# Epoch 83/100
# 2/2 [==============================] - 0s 52ms/step - loss: 927.0972 - mean_squared_error: 927.0972 - val_loss: 680.6621 - val_mean_squared_error: 680.6621
# Epoch 84/100
# 2/2 [==============================] - 0s 51ms/step - loss: 921.2753 - mean_squared_error: 921.2753 - val_loss: 671.5058 - val_mean_squared_error: 671.5058
# Epoch 85/100
# 2/2 [==============================] - 0s 53ms/step - loss: 915.7715 - mean_squared_error: 915.7715 - val_loss: 662.3771 - val_mean_squared_error: 662.3771
# Epoch 86/100
# 2/2 [==============================] - 0s 54ms/step - loss: 911.3775 - mean_squared_error: 911.3775 - val_loss: 653.1727 - val_mean_squared_error: 653.1727
# Epoch 87/100
# 2/2 [==============================] - 0s 50ms/step - loss: 905.1911 - mean_squared_error: 905.1911 - val_loss: 644.3777 - val_mean_squared_error: 644.3777
# Epoch 88/100
# 2/2 [==============================] - 0s 50ms/step - loss: 901.0051 - mean_squared_error: 901.0051 - val_loss: 635.5515 - val_mean_squared_error: 635.5515
# Epoch 89/100
# 2/2 [==============================] - 0s 55ms/step - loss: 896.2000 - mean_squared_error: 896.2000 - val_loss: 627.4503 - val_mean_squared_error: 627.4503
# Epoch 90/100
# 2/2 [==============================] - 0s 50ms/step - loss: 891.2129 - mean_squared_error: 891.2129 - val_loss: 619.1985 - val_mean_squared_error: 619.1985
# Epoch 91/100
# 2/2 [==============================] - 0s 50ms/step - loss: 888.5569 - mean_squared_error: 888.5569 - val_loss: 611.5629 - val_mean_squared_error: 611.5629
# Epoch 92/100
# 2/2 [==============================] - 0s 51ms/step - loss: 881.8969 - mean_squared_error: 881.8969 - val_loss: 604.8768 - val_mean_squared_error: 604.8768
# Epoch 93/100
# 2/2 [==============================] - 0s 53ms/step - loss: 880.1981 - mean_squared_error: 880.1981 - val_loss: 597.7158 - val_mean_squared_error: 597.7158
# Epoch 94/100
# 2/2 [==============================] - 0s 50ms/step - loss: 876.2027 - mean_squared_error: 876.2027 - val_loss: 590.9691 - val_mean_squared_error: 590.9691
# Epoch 95/100
# 2/2 [==============================] - 0s 51ms/step - loss: 871.3485 - mean_squared_error: 871.3485 - val_loss: 585.0448 - val_mean_squared_error: 585.0448
# Epoch 96/100
# 2/2 [==============================] - 0s 56ms/step - loss: 868.1689 - mean_squared_error: 868.1689 - val_loss: 578.7798 - val_mean_squared_error: 578.7798
# Epoch 97/100
# 2/2 [==============================] - 0s 51ms/step - loss: 864.2628 - mean_squared_error: 864.2628 - val_loss: 572.2939 - val_mean_squared_error: 572.2939
# Epoch 98/100
# 2/2 [==============================] - 0s 51ms/step - loss: 860.6204 - mean_squared_error: 860.6204 - val_loss: 566.4404 - val_mean_squared_error: 566.4404
# Epoch 99/100
# 2/2 [==============================] - 0s 56ms/step - loss: 858.5739 - mean_squared_error: 858.5739 - val_loss: 561.3638 - val_mean_squared_error: 561.3638
# Epoch 100/100
# 2/2 [==============================] - 0s 52ms/step - loss: 853.4224 - mean_squared_error: 853.4224 - val_loss: 556.0923 - val_mean_squared_error: 556.0923
# 1/1 [==============================] - 0s 40ms/step - loss: 7106.2915 - mean_squared_error: 7106.2915
# Test error: 7106.29
# 2023-09-23 13:41:48.903237: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_2}}]]

# %%
model.save(model_save_path)

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  10.384298973083496
# MSE:  121.39279121832
# RMSE:  11.017839680187764
# r2_score:  -0.15051146458600506
# MSLE:  4.603831340171278
# MAPE:  3.844409048939452e+16
# ===== flank_wear results =====
# MAE:  99.25738525390625
# MSE:  21079.5240400718
# RMSE:  145.1878921951545
# r2_score:  -0.31563202768094456
# MSLE:  0.743449039608874
# MAPE:  0.5859179258560383
# ===== overhang results =====
# MAE:  8.774111735026041
# MSE:  117.95348435120007
# RMSE:  10.860639223876285
# r2_score:  -4.847251419485969
# MSLE:  0.4764354400944328
# MAPE:  0.9916393809861264
# ===== multi results =====
# MAE:  39.4719319873386
# MSE:  7106.290105213774
# RMSE:  55.68879036640618
# r2_score:  -1.7711316372509727
# MSLE:  1.9412386066248615
# MAPE:  1.2814696829798174e+16
