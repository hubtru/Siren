# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# 2023-09-23 13:44:28.183102: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-23 13:44:29.229791: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  1
# GPUs:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-09-23 13:44:31.362685: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:44:31.408439: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:44:31.409512: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_chip = 3
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_chip = (img_rows, img_cols, in_channel_chip)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_tc"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"./{exp_name}_{sub_exp_name}_tool.h5"
model_chip_path = f"./{exp_name}_{sub_exp_name}_chip.h5"

# dataset
csv_path = "../../dataset/labels_reg_sample.csv"
tool_path = "../../dataset/tool"
chip_path = "../../dataset/chip"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()
# Out:
# /home/user/.conda/envs/tf/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang                            tool  \
# 14   T8R3B4   6.88       40.92     14.54   ../../dataset/tool/T8R3B4.jpg
# 10   T6R9B3  12.94       95.63     16.65   ../../dataset/tool/T6R9B3.jpg
# 0    T1R2B1   7.67       34.89     48.61   ../../dataset/tool/T1R2B1.jpg
# 3   T2R13B4   0.00      122.59     25.55  ../../dataset/tool/T2R13B4.jpg
# 1    T1R7B4  13.89       85.41     50.25   ../../dataset/tool/T1R7B4.jpg
#
#                               chip
# 14   ../../dataset/chip/T8R3B4.jpg
# 10   ../../dataset/chip/T6R9B3.jpg
# 0    ../../dataset/chip/T1R2B1.jpg
# 3   ../../dataset/chip/T2R13B4.jpg
# 1    ../../dataset/chip/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang                            tool  \
# 16   T9R7B4   0.00       94.62     17.05   ../../dataset/tool/T9R7B4.jpg
# 18  T10R3B4   0.00       44.26      7.10  ../../dataset/tool/T10R3B4.jpg
# 9   T5R12B1  21.79      334.39     16.14  ../../dataset/tool/T5R12B1.jpg
#
#                               chip
# 16   ../../dataset/chip/T9R7B4.jpg
# 18  ../../dataset/chip/T10R3B4.jpg
# 9   ../../dataset/chip/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang                            tool  \
# 5   T3R10B1   5.00      128.39     35.26  ../../dataset/tool/T3R10B1.jpg
# 13  T7R14B3  13.67      141.91     14.62  ../../dataset/tool/T7R14B3.jpg
# 12   T7R8B3   7.45       77.05     19.02   ../../dataset/tool/T7R8B3.jpg
#
#                               chip
# 5   ../../dataset/chip/T3R10B1.jpg
# 13  ../../dataset/chip/T7R14B3.jpg
# 12   ../../dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
# ============================== augment 1/2 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)
# Out:
# 2023-09-23 13:44:34.635188: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:44:34.636153: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:44:34.637028: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:44:35.808330: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:44:35.809061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:44:35.809764: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-23 13:44:35.810277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1942 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:00:1b.0, compute capability: 6.1

# %%
# ============================== augment 2/2 ==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_chip = data_augmentation_chip(x_train_chip)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_chip": x_train_chip,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_chip": x_test_chip,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_chip": x_val_chip,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs3 = k.Input(input_shape_chip)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
model_tool = k.models.load_model(model_tool_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)

model_tool.trainable = False
model_chip.trainable = False


def load_siren(model_tool, model_chip):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs3 = model_chip.input
    inputs3._name = "input_chip"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_chip.output,
        ]
    )
    output = layers.Dense(num_classes, activation="linear", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs3], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren(model_tool, model_chip)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1_tool (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_1_chip (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_tool (Conv2D)           (None, 16, 16, 256)  196864      ['input_1_tool[0][0]']
#
#  conv2d_chip (Conv2D)           (None, 16, 16, 256)  196864      ['input_1_chip[0][0]']
#
#  activation_tool (Activation)   (None, 16, 16, 256)  0           ['conv2d_tool[0][0]']
#
#  activation_chip (Activation)   (None, 16, 16, 256)  0           ['conv2d_chip[0][0]']
#
#  batch_normalization_tool (Batc  (None, 16, 16, 256)  1024       ['activation_tool[0][0]']
#  hNormalization)
#
#  batch_normalization_chip (Batc  (None, 16, 16, 256)  1024       ['activation_chip[0][0]']
#  hNormalization)
#
#  depthwise_conv2d_tool (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_tool[0][0]'
#  seConv2D)                                                       ]
#
#  depthwise_conv2d_chip (Depthwi  (None, 16, 16, 256)  6656       ['batch_normalization_chip[0][0]'
#  seConv2D)                                                       ]
#
#  activation_1_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_tool[0][0]']
#
#  activation_1_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_chip[0][0]']
#
#  batch_normalization_1_tool (Ba  (None, 16, 16, 256)  1024       ['activation_1_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_1_chip (Ba  (None, 16, 16, 256)  1024       ['activation_1_chip[0][0]']
#  tchNormalization)
#
#  add_tool (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_chip (Add)                 (None, 16, 16, 256)  0           ['batch_normalization_1_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  conv2d_1_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_tool[0][0]']
#
#  conv2d_1_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_chip[0][0]']
#
#  activation_2_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_tool[0][0]']
#
#  activation_2_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_1_chip[0][0]']
#
#  batch_normalization_2_tool (Ba  (None, 16, 16, 256)  1024       ['activation_2_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_2_chip (Ba  (None, 16, 16, 256)  1024       ['activation_2_chip[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_1_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  depthwise_conv2d_1_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_2_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_3_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_tool[0][0]']
#
#  activation_3_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_1_chip[0][0]']
#
#  batch_normalization_3_tool (Ba  (None, 16, 16, 256)  1024       ['activation_3_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_3_chip (Ba  (None, 16, 16, 256)  1024       ['activation_3_chip[0][0]']
#  tchNormalization)
#
#  add_1_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_tool[0][0
#                                                                  ]']
#
#  add_1_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_3_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_2_chip[0][0
#                                                                  ]']
#
#  conv2d_2_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_tool[0][0]']
#
#  conv2d_2_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_1_chip[0][0]']
#
#  activation_4_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_tool[0][0]']
#
#  activation_4_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_2_chip[0][0]']
#
#  batch_normalization_4_tool (Ba  (None, 16, 16, 256)  1024       ['activation_4_tool[0][0]']
#  tchNormalization)
#
#  batch_normalization_4_chip (Ba  (None, 16, 16, 256)  1024       ['activation_4_chip[0][0]']
#  tchNormalization)
#
#  add_4_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_4_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_4_tool (Depth  (None, 16, 16, 256)  6656       ['add_4_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_4_chip (Depth  (None, 16, 16, 256)  6656       ['add_4_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_2_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_tool[0][0]']
#
#  depthwise_conv2d_2_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_4_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_9_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_4_chip[0][0]']
#
#  activation_5_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_tool[0][0]']
#
#  batch_normalization_9_tool (Ba  (None, 16, 16, 256)  1024       ['activation_9_tool[0][0]']
#  tchNormalization)
#
#  activation_5_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_2_chip[0][0]']
#
#  batch_normalization_9_chip (Ba  (None, 16, 16, 256)  1024       ['activation_9_chip[0][0]']
#  tchNormalization)
#
#  batch_normalization_5_tool (Ba  (None, 16, 16, 256)  1024       ['activation_5_tool[0][0]']
#  tchNormalization)
#
#  add_5_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_tool[0][0
#                                                                  ]',
#                                                                   'add_4_tool[0][0]']
#
#  batch_normalization_5_chip (Ba  (None, 16, 16, 256)  1024       ['activation_5_chip[0][0]']
#  tchNormalization)
#
#  add_5_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_9_chip[0][0
#                                                                  ]',
#                                                                   'add_4_chip[0][0]']
#
#  add_2_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_tool[0][0
#                                                                  ]']
#
#  conv2d_5_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_tool[0][0]']
#
#  add_2_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_5_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_4_chip[0][0
#                                                                  ]']
#
#  conv2d_5_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_5_chip[0][0]']
#
#  conv2d_3_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_tool[0][0]']
#
#  activation_10_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_5_tool[0][0]']
#  )
#
#  conv2d_3_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_2_chip[0][0]']
#
#  activation_10_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_5_chip[0][0]']
#  )
#
#  activation_6_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_tool[0][0]']
#
#  batch_normalization_10_tool (B  (None, 16, 16, 256)  1024       ['activation_10_tool[0][0]']
#  atchNormalization)
#
#  activation_6_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_3_chip[0][0]']
#
#  batch_normalization_10_chip (B  (None, 16, 16, 256)  1024       ['activation_10_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_6_tool (Ba  (None, 16, 16, 256)  1024       ['activation_6_tool[0][0]']
#  tchNormalization)
#
#  add_6_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_tool[0][
#                                                                  0]']
#
#  batch_normalization_6_chip (Ba  (None, 16, 16, 256)  1024       ['activation_6_chip[0][0]']
#  tchNormalization)
#
#  add_6_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_2_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_10_chip[0][
#                                                                  0]']
#
#  add_7_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_tool[0][0
#                                                                  ]',
#                                                                   'add_6_tool[0][0]']
#
#  add_7_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_6_chip[0][0
#                                                                  ]',
#                                                                   'add_6_chip[0][0]']
#
#  depthwise_conv2d_5_tool (Depth  (None, 16, 16, 256)  6656       ['add_7_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_5_chip (Depth  (None, 16, 16, 256)  6656       ['add_7_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_3_tool (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_tool[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_tool[0][0]']
#  )
#
#  depthwise_conv2d_3_chip (Depth  (None, 16, 16, 256)  6656       ['batch_normalization_6_chip[0][0
#  wiseConv2D)                                                     ]']
#
#  activation_11_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_5_chip[0][0]']
#  )
#
#  activation_7_tool (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_tool[0][0]']
#
#  batch_normalization_11_tool (B  (None, 16, 16, 256)  1024       ['activation_11_tool[0][0]']
#  atchNormalization)
#
#  activation_7_chip (Activation)  (None, 16, 16, 256)  0          ['depthwise_conv2d_3_chip[0][0]']
#
#  batch_normalization_11_chip (B  (None, 16, 16, 256)  1024       ['activation_11_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_7_tool (Ba  (None, 16, 16, 256)  1024       ['activation_7_tool[0][0]']
#  tchNormalization)
#
#  add_8_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_tool[0][
#                                                                  0]',
#                                                                   'add_7_tool[0][0]']
#
#  batch_normalization_7_chip (Ba  (None, 16, 16, 256)  1024       ['activation_7_chip[0][0]']
#  tchNormalization)
#
#  add_8_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_11_chip[0][
#                                                                  0]',
#                                                                   'add_7_chip[0][0]']
#
#  add_3_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_tool[0][0
#                                                                  ]']
#
#  conv2d_6_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_tool[0][0]']
#
#  add_3_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_7_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_6_chip[0][0
#                                                                  ]']
#
#  conv2d_6_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_8_chip[0][0]']
#
#  conv2d_4_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_tool[0][0]']
#
#  activation_12_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_6_tool[0][0]']
#  )
#
#  conv2d_4_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_3_chip[0][0]']
#
#  activation_12_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_6_chip[0][0]']
#  )
#
#  activation_8_tool (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_tool[0][0]']
#
#  batch_normalization_12_tool (B  (None, 16, 16, 256)  1024       ['activation_12_tool[0][0]']
#  atchNormalization)
#
#  activation_8_chip (Activation)  (None, 16, 16, 256)  0          ['conv2d_4_chip[0][0]']
#
#  batch_normalization_12_chip (B  (None, 16, 16, 256)  1024       ['activation_12_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_8_tool (Ba  (None, 16, 16, 256)  1024       ['activation_8_tool[0][0]']
#  tchNormalization)
#
#  add_9_tool (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_tool[0][
#                                                                  0]']
#
#  batch_normalization_8_chip (Ba  (None, 16, 16, 256)  1024       ['activation_8_chip[0][0]']
#  tchNormalization)
#
#  add_9_chip (Add)               (None, 16, 16, 256)  0           ['batch_normalization_4_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_12_chip[0][
#                                                                  0]']
#
#  add_10_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_tool[0][0
#                                                                  ]',
#                                                                   'add_9_tool[0][0]']
#
#  add_15_tool (Add)              (None, 16, 16, 256)  0           ['add_9_tool[0][0]',
#                                                                   'batch_normalization_tool[0][0]'
#                                                                  ]
#
#  add_10_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_8_chip[0][0
#                                                                  ]',
#                                                                   'add_9_chip[0][0]']
#
#  add_15_chip (Add)              (None, 16, 16, 256)  0           ['add_9_chip[0][0]',
#                                                                   'batch_normalization_chip[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_6_tool (Depth  (None, 16, 16, 256)  6656       ['add_10_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_tool (Depth  (None, 16, 16, 256)  6656       ['add_15_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_6_chip (Depth  (None, 16, 16, 256)  6656       ['add_10_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_8_chip (Depth  (None, 16, 16, 256)  6656       ['add_15_chip[0][0]']
#  wiseConv2D)
#
#  activation_13_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_6_tool[0][0]']
#  )
#
#  activation_17_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_8_tool[0][0]']
#  )
#
#  activation_13_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_6_chip[0][0]']
#  )
#
#  activation_17_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_8_chip[0][0]']
#  )
#
#  batch_normalization_13_tool (B  (None, 16, 16, 256)  1024       ['activation_13_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_17_tool (B  (None, 16, 16, 256)  1024       ['activation_17_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_13_chip (B  (None, 16, 16, 256)  1024       ['activation_13_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_17_chip (B  (None, 16, 16, 256)  1024       ['activation_17_chip[0][0]']
#  atchNormalization)
#
#  add_11_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_13_tool[0][
#                                                                  0]',
#                                                                   'add_10_tool[0][0]']
#
#  add_16_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_17_tool[0][
#                                                                  0]',
#                                                                   'add_15_tool[0][0]']
#
#  add_11_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_13_chip[0][
#                                                                  0]',
#                                                                   'add_10_chip[0][0]']
#
#  add_16_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_17_chip[0][
#                                                                  0]',
#                                                                   'add_15_chip[0][0]']
#
#  conv2d_7_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_11_tool[0][0]']
#
#  conv2d_9_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_16_tool[0][0]']
#
#  conv2d_7_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_11_chip[0][0]']
#
#  conv2d_9_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_16_chip[0][0]']
#
#  activation_14_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_7_tool[0][0]']
#  )
#
#  activation_18_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_9_tool[0][0]']
#  )
#
#  activation_14_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_7_chip[0][0]']
#  )
#
#  activation_18_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_9_chip[0][0]']
#  )
#
#  batch_normalization_14_tool (B  (None, 16, 16, 256)  1024       ['activation_14_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_18_tool (B  (None, 16, 16, 256)  1024       ['activation_18_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_14_chip (B  (None, 16, 16, 256)  1024       ['activation_14_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_18_chip (B  (None, 16, 16, 256)  1024       ['activation_18_chip[0][0]']
#  atchNormalization)
#
#  add_12_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_6_tool[0][0
#                                                                  ]',
#                                                                   'batch_normalization_14_tool[0][
#                                                                  0]']
#
#  add_17_tool (Add)              (None, 16, 16, 256)  0           ['add_6_tool[0][0]',
#                                                                   'batch_normalization_18_tool[0][
#                                                                  0]']
#
#  add_12_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_6_chip[0][0
#                                                                  ]',
#                                                                   'batch_normalization_14_chip[0][
#                                                                  0]']
#
#  add_17_chip (Add)              (None, 16, 16, 256)  0           ['add_6_chip[0][0]',
#                                                                   'batch_normalization_18_chip[0][
#                                                                  0]']
#
#  add_18_tool (Add)              (None, 16, 16, 256)  0           ['add_12_tool[0][0]',
#                                                                   'add_17_tool[0][0]']
#
#  add_18_chip (Add)              (None, 16, 16, 256)  0           ['add_12_chip[0][0]',
#                                                                   'add_17_chip[0][0]']
#
#  depthwise_conv2d_7_tool (Depth  (None, 16, 16, 256)  6656       ['add_12_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_9_tool (Depth  (None, 16, 16, 256)  6656       ['add_18_tool[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_7_chip (Depth  (None, 16, 16, 256)  6656       ['add_12_chip[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_9_chip (Depth  (None, 16, 16, 256)  6656       ['add_18_chip[0][0]']
#  wiseConv2D)
#
#  activation_15_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_7_tool[0][0]']
#  )
#
#  activation_19_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_9_tool[0][0]']
#  )
#
#  activation_15_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_7_chip[0][0]']
#  )
#
#  activation_19_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_9_chip[0][0]']
#  )
#
#  batch_normalization_15_tool (B  (None, 16, 16, 256)  1024       ['activation_15_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_19_tool (B  (None, 16, 16, 256)  1024       ['activation_19_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_15_chip (B  (None, 16, 16, 256)  1024       ['activation_15_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_19_chip (B  (None, 16, 16, 256)  1024       ['activation_19_chip[0][0]']
#  atchNormalization)
#
#  add_13_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_15_tool[0][
#                                                                  0]',
#                                                                   'add_12_tool[0][0]']
#
#  add_19_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_19_tool[0][
#                                                                  0]',
#                                                                   'add_18_tool[0][0]']
#
#  add_13_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_15_chip[0][
#                                                                  0]',
#                                                                   'add_12_chip[0][0]']
#
#  add_19_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_19_chip[0][
#                                                                  0]',
#                                                                   'add_18_chip[0][0]']
#
#  conv2d_8_tool (Conv2D)         (None, 16, 16, 256)  65792       ['add_13_tool[0][0]']
#
#  conv2d_10_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_19_tool[0][0]']
#
#  conv2d_8_chip (Conv2D)         (None, 16, 16, 256)  65792       ['add_13_chip[0][0]']
# ...
#  )
#
#  activation_28_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_14_tool[0][0]']
#  )
#
#  activation_24_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_12_chip[0][0]']
#  )
#
#  activation_28_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_14_chip[0][0]']
#  )
#
#  batch_normalization_24_tool (B  (None, 16, 16, 256)  1024       ['activation_24_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_28_tool (B  (None, 16, 16, 256)  1024       ['activation_28_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_24_chip (B  (None, 16, 16, 256)  1024       ['activation_24_chip[0][0]']
#  atchNormalization)
#
#  batch_normalization_28_chip (B  (None, 16, 16, 256)  1024       ['activation_28_chip[0][0]']
#  atchNormalization)
#
#  add_25_tool (Add)              (None, 16, 16, 256)  0           ['add_14_tool[0][0]',
#                                                                   'batch_normalization_24_tool[0][
#                                                                  0]']
#
#  add_31_tool (Add)              (None, 16, 16, 256)  0           ['add_20_tool[0][0]',
#                                                                   'batch_normalization_28_tool[0][
#                                                                  0]']
#
#  add_25_chip (Add)              (None, 16, 16, 256)  0           ['add_14_chip[0][0]',
#                                                                   'batch_normalization_24_chip[0][
#                                                                  0]']
#
#  add_31_chip (Add)              (None, 16, 16, 256)  0           ['add_20_chip[0][0]',
#                                                                   'batch_normalization_28_chip[0][
#                                                                  0]']
#
#  add_32_tool (Add)              (None, 16, 16, 256)  0           ['add_25_tool[0][0]',
#                                                                   'add_31_tool[0][0]']
#
#  add_32_chip (Add)              (None, 16, 16, 256)  0           ['add_25_chip[0][0]',
#                                                                   'add_31_chip[0][0]']
#
#  depthwise_conv2d_14_tool (Dept  (None, 16, 16, 256)  6656       ['add_32_tool[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_14_chip (Dept  (None, 16, 16, 256)  6656       ['add_32_chip[0][0]']
#  hwiseConv2D)
#
#  activation_29_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_tool[0][0]'
#  )                                                               ]
#
#  activation_29_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_14_chip[0][0]'
#  )                                                               ]
#
#  batch_normalization_29_tool (B  (None, 16, 16, 256)  1024       ['activation_29_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_29_chip (B  (None, 16, 16, 256)  1024       ['activation_29_chip[0][0]']
#  atchNormalization)
#
#  add_33_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_tool[0][
#                                                                  0]',
#                                                                   'add_32_tool[0][0]']
#
#  add_33_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_29_chip[0][
#                                                                  0]',
#                                                                   'add_32_chip[0][0]']
#
#  conv2d_15_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_tool[0][0]']
#
#  conv2d_15_chip (Conv2D)        (None, 16, 16, 256)  65792       ['add_33_chip[0][0]']
#
#  activation_30_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_15_tool[0][0]']
#  )
#
#  activation_30_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_15_chip[0][0]']
#  )
#
#  batch_normalization_30_tool (B  (None, 16, 16, 256)  1024       ['activation_30_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_30_chip (B  (None, 16, 16, 256)  1024       ['activation_30_chip[0][0]']
#  atchNormalization)
#
#  add_34_tool (Add)              (None, 16, 16, 256)  0           ['add_23_tool[0][0]',
#                                                                   'batch_normalization_30_tool[0][
#                                                                  0]']
#
#  add_34_chip (Add)              (None, 16, 16, 256)  0           ['add_23_chip[0][0]',
#                                                                   'batch_normalization_30_chip[0][
#                                                                  0]']
#
#  depthwise_conv2d_15_tool (Dept  (None, 16, 16, 256)  6656       ['add_34_tool[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_15_chip (Dept  (None, 16, 16, 256)  6656       ['add_34_chip[0][0]']
#  hwiseConv2D)
#
#  activation_31_tool (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_tool[0][0]'
#  )                                                               ]
#
#  activation_31_chip (Activation  (None, 16, 16, 256)  0          ['depthwise_conv2d_15_chip[0][0]'
#  )                                                               ]
#
#  batch_normalization_31_tool (B  (None, 16, 16, 256)  1024       ['activation_31_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_31_chip (B  (None, 16, 16, 256)  1024       ['activation_31_chip[0][0]']
#  atchNormalization)
#
#  add_35_tool (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_tool[0][
#                                                                  0]',
#                                                                   'add_34_tool[0][0]']
#
#  add_35_chip (Add)              (None, 16, 16, 256)  0           ['batch_normalization_31_chip[0][
#                                                                  0]',
#                                                                   'add_34_chip[0][0]']
#
#  conv2d_16_tool (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_tool[0][0]']
#
#  conv2d_16_chip (Conv2D)        (None, 16, 16, 256)  65792       ['add_35_chip[0][0]']
#
#  activation_32_tool (Activation  (None, 16, 16, 256)  0          ['conv2d_16_tool[0][0]']
#  )
#
#  activation_32_chip (Activation  (None, 16, 16, 256)  0          ['conv2d_16_chip[0][0]']
#  )
#
#  batch_normalization_32_tool (B  (None, 16, 16, 256)  1024       ['activation_32_tool[0][0]']
#  atchNormalization)
#
#  batch_normalization_32_chip (B  (None, 16, 16, 256)  1024       ['activation_32_chip[0][0]']
#  atchNormalization)
#
#  add_36_tool (Add)              (None, 16, 16, 256)  0           ['add_25_tool[0][0]',
#                                                                   'batch_normalization_32_tool[0][
#                                                                  0]']
#
#  add_36_chip (Add)              (None, 16, 16, 256)  0           ['add_25_chip[0][0]',
#                                                                   'batch_normalization_32_chip[0][
#                                                                  0]']
#
#  global_average_pooling2d_tool   (None, 256)         0           ['add_36_tool[0][0]']
#  (GlobalAveragePooling2D)
#
#  global_average_pooling2d_chip   (None, 256)         0           ['add_36_chip[0][0]']
#  (GlobalAveragePooling2D)
#
#  concatenate (Concatenate)      (None, 512)          0           ['global_average_pooling2d_tool[0
#                                                                  ][0]',
#                                                                   'global_average_pooling2d_chip[0
#                                                                  ][0]']
#
#  output_mult (Dense)            (None, 3)            1539        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 2,781,187
# Trainable params: 1,539
# Non-trainable params: 2,779,648
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2023-09-23 13:44:40.006296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype float and shape [14,256,256,3]
# 	 [[{{node Placeholder/_1}}]]
# 2023-09-23 13:44:40.006956: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype float and shape [14,256,256,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-23 13:44:49.190927: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2/2 [==============================] - ETA: 0s - loss: 3794.8438 - mean_squared_error: 3794.8438
# 2023-09-23 13:44:50.097204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_2}}]]
# 2/2 [==============================] - 12s 2s/step - loss: 3794.8438 - mean_squared_error: 3794.8438 - val_loss: 4602.7720 - val_mean_squared_error: 4602.7720
# Epoch 2/100
# 2/2 [==============================] - 0s 55ms/step - loss: 3689.7715 - mean_squared_error: 3689.7712 - val_loss: 4477.3320 - val_mean_squared_error: 4477.3320
# Epoch 3/100
# 2/2 [==============================] - 0s 53ms/step - loss: 3592.5703 - mean_squared_error: 3592.5703 - val_loss: 4355.6416 - val_mean_squared_error: 4355.6416
# Epoch 4/100
# 2/2 [==============================] - 0s 47ms/step - loss: 3505.8298 - mean_squared_error: 3505.8298 - val_loss: 4237.4507 - val_mean_squared_error: 4237.4507
# Epoch 5/100
# 2/2 [==============================] - 0s 46ms/step - loss: 3408.2317 - mean_squared_error: 3408.2317 - val_loss: 4123.6836 - val_mean_squared_error: 4123.6836
# Epoch 6/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3326.1519 - mean_squared_error: 3326.1519 - val_loss: 4013.5940 - val_mean_squared_error: 4013.5940
# Epoch 7/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3241.1958 - mean_squared_error: 3241.1958 - val_loss: 3906.9954 - val_mean_squared_error: 3906.9954
# Epoch 8/100
# 2/2 [==============================] - 0s 54ms/step - loss: 3159.3823 - mean_squared_error: 3159.3823 - val_loss: 3804.5566 - val_mean_squared_error: 3804.5566
# Epoch 9/100
# 2/2 [==============================] - 0s 51ms/step - loss: 3083.6450 - mean_squared_error: 3083.6450 - val_loss: 3704.8076 - val_mean_squared_error: 3704.8076
# Epoch 10/100
# 2/2 [==============================] - 0s 49ms/step - loss: 3007.5095 - mean_squared_error: 3007.5095 - val_loss: 3608.5801 - val_mean_squared_error: 3608.5801
# Epoch 11/100
# 2/2 [==============================] - 0s 53ms/step - loss: 2935.2268 - mean_squared_error: 2935.2268 - val_loss: 3515.5273 - val_mean_squared_error: 3515.5273
# Epoch 12/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2858.9312 - mean_squared_error: 2858.9312 - val_loss: 3426.4314 - val_mean_squared_error: 3426.4314
# Epoch 13/100
# 2/2 [==============================] - 0s 56ms/step - loss: 2797.7805 - mean_squared_error: 2797.7805 - val_loss: 3339.1292 - val_mean_squared_error: 3339.1292
# Epoch 14/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2731.9844 - mean_squared_error: 2731.9844 - val_loss: 3254.2773 - val_mean_squared_error: 3254.2773
# Epoch 15/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2668.2437 - mean_squared_error: 2668.2437 - val_loss: 3171.8772 - val_mean_squared_error: 3171.8772
# Epoch 16/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2607.9792 - mean_squared_error: 2607.9792 - val_loss: 3091.2102 - val_mean_squared_error: 3091.2102
# Epoch 17/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2546.6821 - mean_squared_error: 2546.6821 - val_loss: 3012.5344 - val_mean_squared_error: 3012.5344
# Epoch 18/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2484.1223 - mean_squared_error: 2484.1223 - val_loss: 2936.8909 - val_mean_squared_error: 2936.8909
# Epoch 19/100
# 2/2 [==============================] - 0s 53ms/step - loss: 2437.5254 - mean_squared_error: 2437.5254 - val_loss: 2861.7864 - val_mean_squared_error: 2861.7864
# Epoch 20/100
# 2/2 [==============================] - 0s 48ms/step - loss: 2378.2195 - mean_squared_error: 2378.2195 - val_loss: 2788.8691 - val_mean_squared_error: 2788.8691
# Epoch 21/100
# 2/2 [==============================] - 0s 53ms/step - loss: 2326.0076 - mean_squared_error: 2326.0076 - val_loss: 2718.3870 - val_mean_squared_error: 2718.3870
# Epoch 22/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2273.4109 - mean_squared_error: 2273.4109 - val_loss: 2648.7776 - val_mean_squared_error: 2648.7776
# Epoch 23/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2224.6042 - mean_squared_error: 2224.6042 - val_loss: 2581.1580 - val_mean_squared_error: 2581.1580
# Epoch 24/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2178.7910 - mean_squared_error: 2178.7910 - val_loss: 2514.6062 - val_mean_squared_error: 2514.6062
# Epoch 25/100
# 2/2 [==============================] - 0s 50ms/step - loss: 2126.8613 - mean_squared_error: 2126.8613 - val_loss: 2449.6909 - val_mean_squared_error: 2449.6909
# Epoch 26/100
# 2/2 [==============================] - 0s 51ms/step - loss: 2084.4739 - mean_squared_error: 2084.4739 - val_loss: 2386.7654 - val_mean_squared_error: 2386.7654
# Epoch 27/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2038.4835 - mean_squared_error: 2038.4835 - val_loss: 2325.4553 - val_mean_squared_error: 2325.4553
# Epoch 28/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1992.9381 - mean_squared_error: 1992.9381 - val_loss: 2265.5618 - val_mean_squared_error: 2265.5618
# Epoch 29/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1952.9540 - mean_squared_error: 1952.9539 - val_loss: 2207.3860 - val_mean_squared_error: 2207.3860
# Epoch 30/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1905.6044 - mean_squared_error: 1905.6044 - val_loss: 2150.8787 - val_mean_squared_error: 2150.8787
# Epoch 31/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1875.3381 - mean_squared_error: 1875.3381 - val_loss: 2094.5208 - val_mean_squared_error: 2094.5208
# Epoch 32/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1832.3990 - mean_squared_error: 1832.3990 - val_loss: 2040.5825 - val_mean_squared_error: 2040.5825
# Epoch 33/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1795.3317 - mean_squared_error: 1795.3317 - val_loss: 1987.8341 - val_mean_squared_error: 1987.8341
# Epoch 34/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1758.3807 - mean_squared_error: 1758.3807 - val_loss: 1936.0045 - val_mean_squared_error: 1936.0045
# Epoch 35/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1724.7019 - mean_squared_error: 1724.7019 - val_loss: 1886.3307 - val_mean_squared_error: 1886.3307
# Epoch 36/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1688.2142 - mean_squared_error: 1688.2142 - val_loss: 1837.7335 - val_mean_squared_error: 1837.7335
# Epoch 37/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1656.3307 - mean_squared_error: 1656.3307 - val_loss: 1790.9990 - val_mean_squared_error: 1790.9990
# Epoch 38/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1622.4503 - mean_squared_error: 1622.4503 - val_loss: 1745.0907 - val_mean_squared_error: 1745.0907
# Epoch 39/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1592.1604 - mean_squared_error: 1592.1604 - val_loss: 1700.3218 - val_mean_squared_error: 1700.3218
# Epoch 40/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1565.4551 - mean_squared_error: 1565.4551 - val_loss: 1656.9323 - val_mean_squared_error: 1656.9323
# Epoch 41/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1530.2540 - mean_squared_error: 1530.2540 - val_loss: 1615.6888 - val_mean_squared_error: 1615.6888
# Epoch 42/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1502.7014 - mean_squared_error: 1502.7014 - val_loss: 1574.9629 - val_mean_squared_error: 1574.9629
# Epoch 43/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1475.0055 - mean_squared_error: 1475.0056 - val_loss: 1535.1669 - val_mean_squared_error: 1535.1669
# Epoch 44/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1447.7430 - mean_squared_error: 1447.7430 - val_loss: 1496.5537 - val_mean_squared_error: 1496.5537
# Epoch 45/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1426.1241 - mean_squared_error: 1426.1241 - val_loss: 1458.6509 - val_mean_squared_error: 1458.6509
# Epoch 46/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1396.1515 - mean_squared_error: 1396.1515 - val_loss: 1422.1129 - val_mean_squared_error: 1422.1129
# Epoch 47/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1373.4926 - mean_squared_error: 1373.4926 - val_loss: 1386.1787 - val_mean_squared_error: 1386.1787
# Epoch 48/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1351.7014 - mean_squared_error: 1351.7014 - val_loss: 1351.8766 - val_mean_squared_error: 1351.8766
# Epoch 49/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1327.0868 - mean_squared_error: 1327.0868 - val_loss: 1318.5850 - val_mean_squared_error: 1318.5850
# Epoch 50/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1303.4387 - mean_squared_error: 1303.4387 - val_loss: 1285.9825 - val_mean_squared_error: 1285.9825
# Epoch 51/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1284.6127 - mean_squared_error: 1284.6127 - val_loss: 1254.5736 - val_mean_squared_error: 1254.5736
# Epoch 52/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1262.4016 - mean_squared_error: 1262.4016 - val_loss: 1224.3109 - val_mean_squared_error: 1224.3109
# Epoch 53/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1241.8838 - mean_squared_error: 1241.8839 - val_loss: 1194.5826 - val_mean_squared_error: 1194.5826
# Epoch 54/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1223.2130 - mean_squared_error: 1223.2130 - val_loss: 1165.8187 - val_mean_squared_error: 1165.8187
# Epoch 55/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1204.4578 - mean_squared_error: 1204.4578 - val_loss: 1138.1384 - val_mean_squared_error: 1138.1384
# Epoch 56/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1188.7694 - mean_squared_error: 1188.7694 - val_loss: 1111.6113 - val_mean_squared_error: 1111.6113
# Epoch 57/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1169.1301 - mean_squared_error: 1169.1301 - val_loss: 1085.8767 - val_mean_squared_error: 1085.8767
# Epoch 58/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1153.6799 - mean_squared_error: 1153.6799 - val_loss: 1061.5021 - val_mean_squared_error: 1061.5021
# Epoch 59/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1135.8007 - mean_squared_error: 1135.8007 - val_loss: 1037.5596 - val_mean_squared_error: 1037.5596
# Epoch 60/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1122.2410 - mean_squared_error: 1122.2410 - val_loss: 1014.3469 - val_mean_squared_error: 1014.3469
# Epoch 61/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1104.4927 - mean_squared_error: 1104.4927 - val_loss: 992.0287 - val_mean_squared_error: 992.0287
# Epoch 62/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1090.3829 - mean_squared_error: 1090.3829 - val_loss: 970.2390 - val_mean_squared_error: 970.2390
# Epoch 63/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1079.1311 - mean_squared_error: 1079.1311 - val_loss: 948.9321 - val_mean_squared_error: 948.9321
# Epoch 64/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1063.3951 - mean_squared_error: 1063.3951 - val_loss: 928.6577 - val_mean_squared_error: 928.6577
# Epoch 65/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1052.1699 - mean_squared_error: 1052.1699 - val_loss: 908.1856 - val_mean_squared_error: 908.1856
# Epoch 66/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1038.0886 - mean_squared_error: 1038.0886 - val_loss: 888.4433 - val_mean_squared_error: 888.4433
# Epoch 67/100
# 2/2 [==============================] - 0s 45ms/step - loss: 1025.8879 - mean_squared_error: 1025.8879 - val_loss: 870.0258 - val_mean_squared_error: 870.0258
# Epoch 68/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1014.1403 - mean_squared_error: 1014.1403 - val_loss: 852.0708 - val_mean_squared_error: 852.0708
# Epoch 69/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1003.7493 - mean_squared_error: 1003.7493 - val_loss: 834.1611 - val_mean_squared_error: 834.1611
# Epoch 70/100
# 2/2 [==============================] - 0s 52ms/step - loss: 992.7562 - mean_squared_error: 992.7562 - val_loss: 816.8441 - val_mean_squared_error: 816.8441
# Epoch 71/100
# 2/2 [==============================] - 0s 50ms/step - loss: 980.5216 - mean_squared_error: 980.5216 - val_loss: 799.9827 - val_mean_squared_error: 799.9827
# Epoch 72/100
# 2/2 [==============================] - 0s 51ms/step - loss: 971.6571 - mean_squared_error: 971.6571 - val_loss: 783.5690 - val_mean_squared_error: 783.5690
# Epoch 73/100
# 2/2 [==============================] - 0s 52ms/step - loss: 963.5034 - mean_squared_error: 963.5034 - val_loss: 768.0501 - val_mean_squared_error: 768.0501
# Epoch 74/100
# 2/2 [==============================] - 0s 50ms/step - loss: 952.3906 - mean_squared_error: 952.3906 - val_loss: 753.6575 - val_mean_squared_error: 753.6575
# Epoch 75/100
# 2/2 [==============================] - 0s 49ms/step - loss: 944.0107 - mean_squared_error: 944.0107 - val_loss: 739.4465 - val_mean_squared_error: 739.4465
# Epoch 76/100
# 2/2 [==============================] - 0s 48ms/step - loss: 933.7734 - mean_squared_error: 933.7734 - val_loss: 725.5522 - val_mean_squared_error: 725.5522
# Epoch 77/100
# 2/2 [==============================] - 0s 50ms/step - loss: 928.2863 - mean_squared_error: 928.2863 - val_loss: 711.9704 - val_mean_squared_error: 711.9704
# Epoch 78/100
# 2/2 [==============================] - 0s 52ms/step - loss: 918.3480 - mean_squared_error: 918.3480 - val_loss: 699.3950 - val_mean_squared_error: 699.3950
# Epoch 79/100
# 2/2 [==============================] - 0s 52ms/step - loss: 910.4037 - mean_squared_error: 910.4037 - val_loss: 687.1912 - val_mean_squared_error: 687.1912
# Epoch 80/100
# 2/2 [==============================] - 0s 52ms/step - loss: 903.7484 - mean_squared_error: 903.7484 - val_loss: 675.0636 - val_mean_squared_error: 675.0636
# Epoch 81/100
# 2/2 [==============================] - 0s 59ms/step - loss: 896.6956 - mean_squared_error: 896.6956 - val_loss: 663.4616 - val_mean_squared_error: 663.4616
# Epoch 82/100
# 2/2 [==============================] - 0s 51ms/step - loss: 889.1163 - mean_squared_error: 889.1163 - val_loss: 652.0427 - val_mean_squared_error: 652.0427
# Epoch 83/100
# 2/2 [==============================] - 0s 47ms/step - loss: 884.2095 - mean_squared_error: 884.2095 - val_loss: 641.3976 - val_mean_squared_error: 641.3976
# Epoch 84/100
# 2/2 [==============================] - 0s 52ms/step - loss: 876.2347 - mean_squared_error: 876.2347 - val_loss: 631.4193 - val_mean_squared_error: 631.4193
# Epoch 85/100
# 2/2 [==============================] - 0s 46ms/step - loss: 870.5071 - mean_squared_error: 870.5071 - val_loss: 622.1686 - val_mean_squared_error: 622.1686
# Epoch 86/100
# 2/2 [==============================] - 0s 48ms/step - loss: 865.3085 - mean_squared_error: 865.3085 - val_loss: 612.7424 - val_mean_squared_error: 612.7424
# Epoch 87/100
# 2/2 [==============================] - 0s 49ms/step - loss: 858.1735 - mean_squared_error: 858.1735 - val_loss: 603.8929 - val_mean_squared_error: 603.8929
# Epoch 88/100
# 2/2 [==============================] - 0s 50ms/step - loss: 853.8387 - mean_squared_error: 853.8387 - val_loss: 595.5943 - val_mean_squared_error: 595.5943
# Epoch 89/100
# 2/2 [==============================] - 0s 52ms/step - loss: 847.5762 - mean_squared_error: 847.5762 - val_loss: 587.2169 - val_mean_squared_error: 587.2169
# Epoch 90/100
# 2/2 [==============================] - 0s 49ms/step - loss: 843.5883 - mean_squared_error: 843.5883 - val_loss: 579.5911 - val_mean_squared_error: 579.5911
# Epoch 91/100
# 2/2 [==============================] - 0s 52ms/step - loss: 838.9159 - mean_squared_error: 838.9159 - val_loss: 572.2092 - val_mean_squared_error: 572.2092
# Epoch 92/100
# 2/2 [==============================] - 0s 46ms/step - loss: 834.0356 - mean_squared_error: 834.0356 - val_loss: 564.9037 - val_mean_squared_error: 564.9037
# Epoch 93/100
# 2/2 [==============================] - 0s 54ms/step - loss: 828.9093 - mean_squared_error: 828.9093 - val_loss: 557.8898 - val_mean_squared_error: 557.8898
# Epoch 94/100
# 2/2 [==============================] - 0s 54ms/step - loss: 824.0205 - mean_squared_error: 824.0205 - val_loss: 551.0479 - val_mean_squared_error: 551.0479
# Epoch 95/100
# 2/2 [==============================] - 0s 49ms/step - loss: 819.5485 - mean_squared_error: 819.5485 - val_loss: 544.8472 - val_mean_squared_error: 544.8472
# Epoch 96/100
# 2/2 [==============================] - 0s 47ms/step - loss: 817.4742 - mean_squared_error: 817.4742 - val_loss: 538.7043 - val_mean_squared_error: 538.7043
# Epoch 97/100
# 2/2 [==============================] - 0s 50ms/step - loss: 811.4495 - mean_squared_error: 811.4495 - val_loss: 533.2105 - val_mean_squared_error: 533.2105
# Epoch 98/100
# 2/2 [==============================] - 0s 48ms/step - loss: 808.4445 - mean_squared_error: 808.4445 - val_loss: 528.1956 - val_mean_squared_error: 528.1956
# Epoch 99/100
# 2/2 [==============================] - 0s 49ms/step - loss: 803.6450 - mean_squared_error: 803.6450 - val_loss: 522.8557 - val_mean_squared_error: 522.8557
# Epoch 100/100
# 2/2 [==============================] - 0s 53ms/step - loss: 801.7242 - mean_squared_error: 801.7242 - val_loss: 517.8405 - val_mean_squared_error: 517.8405
# 1/1 [==============================] - 0s 34ms/step - loss: 6905.9844 - mean_squared_error: 6905.9844
# Test error: 6905.98
# 2023-09-23 13:44:59.805490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,3]
# 	 [[{{node Placeholder/_2}}]]

# %%
model.save(model_save_path)

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  11.672055892944336
# MSE:  143.10819455447154
# RMSE:  11.962783729319508
# r2_score:  -0.35632121857229526
# MSLE:  4.690753410625644
# MAPE:  3.892656850390221e+16
# ===== flank_wear results =====
# MAE:  98.02207692464192
# MSE:  20518.2245848153
# RMSE:  143.24183950513657
# r2_score:  -0.2805997594451195
# MSLE:  0.7076950615008841
# MAPE:  0.5789891432648928
# ===== overhang results =====
# MAE:  6.135181821187338
# MSE:  56.618647187847074
# RMSE:  7.524536343712287
# r2_score:  -1.8067289996520208
# MSLE:  0.296371684943796
# MAPE:  0.6888805898824922
# ===== multi results =====
# MAE:  38.60977154625786
# MSE:  6905.983808852539
# RMSE:  54.24305319272279
# r2_score:  -0.8145499925564786
# MSLE:  1.898273385690108
# MAPE:  1.297552283463407e+16
