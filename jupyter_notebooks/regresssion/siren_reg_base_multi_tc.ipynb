# %%
# !pip install tensorflow_addons
# !pip install keras-tuner --upgrade

# clone siren repository, refresh folder to see the siren repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Siren/
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5
# Cloning into 'Siren'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 332 (delta 16), reused 29 (delta 12), pack-reused 297
# Receiving objects: 100% (332/332), 186.05 MiB | 26.83 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# Updating files: 100% (236/236), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_chip = 3
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_chip = (img_rows, img_cols, in_channel_chip)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 100

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_tc"
exp_name = f"siren_reg"
sub_exp_name = f"base"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_tool.h5"
model_chip_path = f"/content/Siren/models/regression/{exp_name}_{sub_exp_name}_chip.h5"

# dataset
csv_path = "/content/Siren/dataset/labels_reg_sample.csv"
tool_path = "/content/Siren/dataset/tool"
chip_path = "/content/Siren/dataset/chip"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["gaps"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["flank_wear"])
plt.title("Label Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["overhang"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                        tool  \
# 14   /content/Siren/dataset/tool/T8R3B4.jpg
# 10   /content/Siren/dataset/tool/T6R9B3.jpg
# 0    /content/Siren/dataset/tool/T1R2B1.jpg
# 3   /content/Siren/dataset/tool/T2R13B4.jpg
# 1    /content/Siren/dataset/tool/T1R7B4.jpg
#
#                                        chip
# 14   /content/Siren/dataset/chip/T8R3B4.jpg
# 10   /content/Siren/dataset/chip/T6R9B3.jpg
# 0    /content/Siren/dataset/chip/T1R2B1.jpg
# 3   /content/Siren/dataset/chip/T2R13B4.jpg
# 1    /content/Siren/dataset/chip/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                        tool  \
# 16   /content/Siren/dataset/tool/T9R7B4.jpg
# 18  /content/Siren/dataset/tool/T10R3B4.jpg
# 9   /content/Siren/dataset/tool/T5R12B1.jpg
#
#                                        chip
# 16   /content/Siren/dataset/chip/T9R7B4.jpg
# 18  /content/Siren/dataset/chip/T10R3B4.jpg
# 9   /content/Siren/dataset/chip/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                        tool  \
# 5   /content/Siren/dataset/tool/T3R10B1.jpg
# 13  /content/Siren/dataset/tool/T7R14B3.jpg
# 12   /content/Siren/dataset/tool/T7R8B3.jpg
#
#                                        chip
# 5   /content/Siren/dataset/chip/T3R10B1.jpg
# 13  /content/Siren/dataset/chip/T7R14B3.jpg
# 12   /content/Siren/dataset/chip/T7R8B3.jpg

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
pil_img = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
# ============================== augment 1/2 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)

# %%
# ============================== augment 2/2 ==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2,0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_chip = data_augmentation_chip(x_train_chip)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_chip": x_train_chip,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_chip": x_test_chip,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_chip": x_val_chip,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs3 = k.Input(input_shape_chip)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
model_tool = k.models.load_model(model_tool_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)

model_tool.trainable = False
model_chip.trainable = False


def load_siren(model_tool, model_chip):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs3 = model_chip.input
    inputs3._name = "input_chip"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_chip.output,
        ]
    )
    output = layers.Dense(num_classes, activation="linear", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs3], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")

# %%
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_siren(model_tool, model_chip)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1_tool (InputLayer)   [(None, 256, 256, 3)]        0         []
#
#  input_1_chip (InputLayer)   [(None, 256, 256, 3)]        0         []
#
#  conv2d_tool (Conv2D)        (None, 16, 16, 256)          196864    ['input_1_tool[0][0]']
#
#  conv2d_chip (Conv2D)        (None, 16, 16, 256)          196864    ['input_1_chip[0][0]']
#
#  activation_tool (Activatio  (None, 16, 16, 256)          0         ['conv2d_tool[0][0]']
#  n)
#
#  activation_chip (Activatio  (None, 16, 16, 256)          0         ['conv2d_chip[0][0]']
#  n)
#
#  batch_normalization_tool (  (None, 16, 16, 256)          1024      ['activation_tool[0][0]']
#  BatchNormalization)
#
#  batch_normalization_chip (  (None, 16, 16, 256)          1024      ['activation_chip[0][0]']
#  BatchNormalization)
#
#  depthwise_conv2d_tool (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_tool[0][
#  thwiseConv2D)                                                      0]']
#
#  depthwise_conv2d_chip (Dep  (None, 16, 16, 256)          6656      ['batch_normalization_chip[0][
#  thwiseConv2D)                                                      0]']
#
#  activation_1_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_tool[0][0]'
#  ion)                                                               ]
#
#  activation_1_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_chip[0][0]'
#  ion)                                                               ]
#
#  batch_normalization_1_tool  (None, 16, 16, 256)          1024      ['activation_1_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_1_chip  (None, 16, 16, 256)          1024      ['activation_1_chip[0][0]']
#   (BatchNormalization)
#
#  add_tool (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_chip (Add)              (None, 16, 16, 256)          0         ['batch_normalization_1_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  conv2d_1_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_tool[0][0]']
#
#  conv2d_1_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_chip[0][0]']
#
#  activation_2_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_1_tool[0][0]']
#  ion)
#
#  activation_2_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_1_chip[0][0]']
#  ion)
#
#  batch_normalization_2_tool  (None, 16, 16, 256)          1024      ['activation_2_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_2_chip  (None, 16, 16, 256)          1024      ['activation_2_chip[0][0]']
#   (BatchNormalization)
#
#  depthwise_conv2d_1_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  depthwise_conv2d_1_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_2_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_3_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_tool[0][0
#  ion)                                                               ]']
#
#  activation_3_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_1_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_3_tool  (None, 16, 16, 256)          1024      ['activation_3_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_3_chip  (None, 16, 16, 256)          1024      ['activation_3_chip[0][0]']
#   (BatchNormalization)
#
#  add_1_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_tool[0
#                                                                     ][0]']
#
#  add_1_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_3_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_2_chip[0
#                                                                     ][0]']
#
#  conv2d_2_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_tool[0][0]']
#
#  conv2d_2_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_1_chip[0][0]']
#
#  activation_4_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_2_tool[0][0]']
#  ion)
#
#  activation_4_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_2_chip[0][0]']
#  ion)
#
#  batch_normalization_4_tool  (None, 16, 16, 256)          1024      ['activation_4_tool[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_4_chip  (None, 16, 16, 256)          1024      ['activation_4_chip[0][0]']
#   (BatchNormalization)
#
#  add_4_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_4_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  depthwise_conv2d_4_tool (D  (None, 16, 16, 256)          6656      ['add_4_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_4_chip (D  (None, 16, 16, 256)          6656      ['add_4_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_2_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_tool[0][0
#  ion)                                                               ]']
#
#  depthwise_conv2d_2_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_4_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_9_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_4_chip[0][0
#  ion)                                                               ]']
#
#  activation_5_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_tool[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_tool  (None, 16, 16, 256)          1024      ['activation_9_tool[0][0]']
#   (BatchNormalization)
#
#  activation_5_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_2_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_9_chip  (None, 16, 16, 256)          1024      ['activation_9_chip[0][0]']
#   (BatchNormalization)
#
#  batch_normalization_5_tool  (None, 16, 16, 256)          1024      ['activation_5_tool[0][0]']
#   (BatchNormalization)
#
#  add_5_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_tool[0
#                                                                     ][0]',
#                                                                      'add_4_tool[0][0]']
#
#  batch_normalization_5_chip  (None, 16, 16, 256)          1024      ['activation_5_chip[0][0]']
#   (BatchNormalization)
#
#  add_5_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_9_chip[0
#                                                                     ][0]',
#                                                                      'add_4_chip[0][0]']
#
#  add_2_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_tool[0
#                                                                     ][0]']
#
#  conv2d_5_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_tool[0][0]']
#
#  add_2_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_5_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_4_chip[0
#                                                                     ][0]']
#
#  conv2d_5_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_5_chip[0][0]']
#
#  conv2d_3_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_tool[0][0]']
#
#  activation_10_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_5_tool[0][0]']
#  tion)
#
#  conv2d_3_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_2_chip[0][0]']
#
#  activation_10_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_5_chip[0][0]']
#  tion)
#
#  activation_6_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_3_tool[0][0]']
#  ion)
#
#  batch_normalization_10_too  (None, 16, 16, 256)          1024      ['activation_10_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_6_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_3_chip[0][0]']
#  ion)
#
#  batch_normalization_10_chi  (None, 16, 16, 256)          1024      ['activation_10_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_6_tool  (None, 16, 16, 256)          1024      ['activation_6_tool[0][0]']
#   (BatchNormalization)
#
#  add_6_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_tool[
#                                                                     0][0]']
#
#  batch_normalization_6_chip  (None, 16, 16, 256)          1024      ['activation_6_chip[0][0]']
#   (BatchNormalization)
#
#  add_6_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_2_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_10_chip[
#                                                                     0][0]']
#
#  add_7_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_tool[0
#                                                                     ][0]',
#                                                                      'add_6_tool[0][0]']
#
#  add_7_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_6_chip[0
#                                                                     ][0]',
#                                                                      'add_6_chip[0][0]']
#
#  depthwise_conv2d_5_tool (D  (None, 16, 16, 256)          6656      ['add_7_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_5_chip (D  (None, 16, 16, 256)          6656      ['add_7_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_3_tool (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_tool[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_tool[0][0
#  tion)                                                              ]']
#
#  depthwise_conv2d_3_chip (D  (None, 16, 16, 256)          6656      ['batch_normalization_6_chip[0
#  epthwiseConv2D)                                                    ][0]']
#
#  activation_11_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_5_chip[0][0
#  tion)                                                              ]']
#
#  activation_7_tool (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_tool[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_too  (None, 16, 16, 256)          1024      ['activation_11_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_7_chip (Activat  (None, 16, 16, 256)          0         ['depthwise_conv2d_3_chip[0][0
#  ion)                                                               ]']
#
#  batch_normalization_11_chi  (None, 16, 16, 256)          1024      ['activation_11_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_7_tool  (None, 16, 16, 256)          1024      ['activation_7_tool[0][0]']
#   (BatchNormalization)
#
#  add_8_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_tool[
#                                                                     0][0]',
#                                                                      'add_7_tool[0][0]']
#
#  batch_normalization_7_chip  (None, 16, 16, 256)          1024      ['activation_7_chip[0][0]']
#   (BatchNormalization)
#
#  add_8_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_11_chip[
#                                                                     0][0]',
#                                                                      'add_7_chip[0][0]']
#
#  add_3_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_tool[0
#                                                                     ][0]']
#
#  conv2d_6_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_tool[0][0]']
#
#  add_3_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_7_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_6_chip[0
#                                                                     ][0]']
#
#  conv2d_6_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_8_chip[0][0]']
#
#  conv2d_4_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_tool[0][0]']
#
#  activation_12_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_6_tool[0][0]']
#  tion)
#
#  conv2d_4_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_3_chip[0][0]']
#
#  activation_12_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_6_chip[0][0]']
#  tion)
#
#  activation_8_tool (Activat  (None, 16, 16, 256)          0         ['conv2d_4_tool[0][0]']
#  ion)
#
#  batch_normalization_12_too  (None, 16, 16, 256)          1024      ['activation_12_tool[0][0]']
#  l (BatchNormalization)
#
#  activation_8_chip (Activat  (None, 16, 16, 256)          0         ['conv2d_4_chip[0][0]']
#  ion)
#
#  batch_normalization_12_chi  (None, 16, 16, 256)          1024      ['activation_12_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_8_tool  (None, 16, 16, 256)          1024      ['activation_8_tool[0][0]']
#   (BatchNormalization)
#
#  add_9_tool (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_tool[
#                                                                     0][0]']
#
#  batch_normalization_8_chip  (None, 16, 16, 256)          1024      ['activation_8_chip[0][0]']
#   (BatchNormalization)
#
#  add_9_chip (Add)            (None, 16, 16, 256)          0         ['batch_normalization_4_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_12_chip[
#                                                                     0][0]']
#
#  add_10_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_8_tool[0
#                                                                     ][0]',
#                                                                      'add_9_tool[0][0]']
#
#  add_15_tool (Add)           (None, 16, 16, 256)          0         ['add_9_tool[0][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_10_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_8_chip[0
#                                                                     ][0]',
#                                                                      'add_9_chip[0][0]']
#
#  add_15_chip (Add)           (None, 16, 16, 256)          0         ['add_9_chip[0][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  depthwise_conv2d_6_tool (D  (None, 16, 16, 256)          6656      ['add_10_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_8_tool (D  (None, 16, 16, 256)          6656      ['add_15_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_6_chip (D  (None, 16, 16, 256)          6656      ['add_10_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_8_chip (D  (None, 16, 16, 256)          6656      ['add_15_chip[0][0]']
#  epthwiseConv2D)
#
#  activation_13_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_6_tool[0][0
#  tion)                                                              ]']
#
#  activation_17_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_8_tool[0][0
#  tion)                                                              ]']
#
#  activation_13_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_6_chip[0][0
#  tion)                                                              ]']
#
#  activation_17_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_8_chip[0][0
#  tion)                                                              ]']
#
#  batch_normalization_13_too  (None, 16, 16, 256)          1024      ['activation_13_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_17_too  (None, 16, 16, 256)          1024      ['activation_17_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_13_chi  (None, 16, 16, 256)          1024      ['activation_13_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_17_chi  (None, 16, 16, 256)          1024      ['activation_17_chip[0][0]']
#  p (BatchNormalization)
#
#  add_11_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_13_tool[
#                                                                     0][0]',
#                                                                      'add_10_tool[0][0]']
#
#  add_16_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_17_tool[
#                                                                     0][0]',
#                                                                      'add_15_tool[0][0]']
#
#  add_11_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_13_chip[
#                                                                     0][0]',
#                                                                      'add_10_chip[0][0]']
#
#  add_16_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_17_chip[
#                                                                     0][0]',
#                                                                      'add_15_chip[0][0]']
#
#  conv2d_7_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_11_tool[0][0]']
#
#  conv2d_9_tool (Conv2D)      (None, 16, 16, 256)          65792     ['add_16_tool[0][0]']
#
#  conv2d_7_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_11_chip[0][0]']
#
#  conv2d_9_chip (Conv2D)      (None, 16, 16, 256)          65792     ['add_16_chip[0][0]']
#
#  activation_14_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_7_tool[0][0]']
#  tion)
#
#  activation_18_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_9_tool[0][0]']
#  tion)
#
#  activation_14_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_7_chip[0][0]']
#  tion)
#
#  activation_18_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_9_chip[0][0]']
#  tion)
#
#  batch_normalization_14_too  (None, 16, 16, 256)          1024      ['activation_14_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_18_too  (None, 16, 16, 256)          1024      ['activation_18_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_14_chi  (None, 16, 16, 256)          1024      ['activation_14_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_18_chi  (None, 16, 16, 256)          1024      ['activation_18_chip[0][0]']
#  p (BatchNormalization)
#
#  add_12_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_6_tool[0
#                                                                     ][0]',
#                                                                      'batch_normalization_14_tool[
#                                                                     0][0]']
#
#  add_17_tool (Add)           (None, 16, 16, 256)          0         ['add_6_tool[0][0]',
#                                                                      'batch_normalization_18_tool[
#                                                                     0][0]']
#
#  add_12_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_6_chip[0
#                                                                     ][0]',
#                                                                      'batch_normalization_14_chip[
#                                                                     0][0]']
#
#  add_17_chip (Add)           (None, 16, 16, 256)          0         ['add_6_chip[0][0]',
#                                                                      'batch_normalization_18_chip[
#                                                                     0][0]']
#
#  add_18_tool (Add)           (None, 16, 16, 256)          0         ['add_12_tool[0][0]',
#                                                                      'add_17_tool[0][0]']
#
#  add_18_chip (Add)           (None, 16, 16, 256)          0         ['add_12_chip[0][0]',
#                                                                      'add_17_chip[0][0]']
#
#  depthwise_conv2d_7_tool (D  (None, 16, 16, 256)          6656      ['add_12_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_9_tool (D  (None, 16, 16, 256)          6656      ['add_18_tool[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_7_chip (D  (None, 16, 16, 256)          6656      ['add_12_chip[0][0]']
#  epthwiseConv2D)
#
#  depthwise_conv2d_9_chip (D  (None, 16, 16, 256)          6656      ['add_18_chip[0][0]']
#  epthwiseConv2D)
#
#  activation_15_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_7_tool[0][0
#  tion)                                                              ]']
#
#  activation_19_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_9_tool[0][0
#  tion)                                                              ]']
#
#  activation_15_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_7_chip[0][0
#  tion)                                                              ]']
#
#  activation_19_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_9_chip[0][0
#  tion)                                                              ]']
#
#  batch_normalization_15_too  (None, 16, 16, 256)          1024      ['activation_15_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_19_too  (None, 16, 16, 256)          1024      ['activation_19_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_15_chi  (None, 16, 16, 256)          1024      ['activation_15_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_19_chi  (None, 16, 16, 256)          1024      ['activation_19_chip[0][0]']
#  p (BatchNormalization)
#
#  add_13_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_15_tool[
#                                                                     0][0]',
#                                                                      'add_12_tool[0][0]']
# ...
#  activation_28_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_14_tool[0][0]']
#  tion)
#
#  activation_24_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_12_chip[0][0]']
#  tion)
#
#  activation_28_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_14_chip[0][0]']
#  tion)
#
#  batch_normalization_24_too  (None, 16, 16, 256)          1024      ['activation_24_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_28_too  (None, 16, 16, 256)          1024      ['activation_28_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_24_chi  (None, 16, 16, 256)          1024      ['activation_24_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_28_chi  (None, 16, 16, 256)          1024      ['activation_28_chip[0][0]']
#  p (BatchNormalization)
#
#  add_25_tool (Add)           (None, 16, 16, 256)          0         ['add_14_tool[0][0]',
#                                                                      'batch_normalization_24_tool[
#                                                                     0][0]']
#
#  add_31_tool (Add)           (None, 16, 16, 256)          0         ['add_20_tool[0][0]',
#                                                                      'batch_normalization_28_tool[
#                                                                     0][0]']
#
#  add_25_chip (Add)           (None, 16, 16, 256)          0         ['add_14_chip[0][0]',
#                                                                      'batch_normalization_24_chip[
#                                                                     0][0]']
#
#  add_31_chip (Add)           (None, 16, 16, 256)          0         ['add_20_chip[0][0]',
#                                                                      'batch_normalization_28_chip[
#                                                                     0][0]']
#
#  add_32_tool (Add)           (None, 16, 16, 256)          0         ['add_25_tool[0][0]',
#                                                                      'add_31_tool[0][0]']
#
#  add_32_chip (Add)           (None, 16, 16, 256)          0         ['add_25_chip[0][0]',
#                                                                      'add_31_chip[0][0]']
#
#  depthwise_conv2d_14_tool (  (None, 16, 16, 256)          6656      ['add_32_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_14_chip (  (None, 16, 16, 256)          6656      ['add_32_chip[0][0]']
#  DepthwiseConv2D)
#
#  activation_29_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_14_tool[0][
#  tion)                                                              0]']
#
#  activation_29_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_14_chip[0][
#  tion)                                                              0]']
#
#  batch_normalization_29_too  (None, 16, 16, 256)          1024      ['activation_29_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_29_chi  (None, 16, 16, 256)          1024      ['activation_29_chip[0][0]']
#  p (BatchNormalization)
#
#  add_33_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_tool[
#                                                                     0][0]',
#                                                                      'add_32_tool[0][0]']
#
#  add_33_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_29_chip[
#                                                                     0][0]',
#                                                                      'add_32_chip[0][0]']
#
#  conv2d_15_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_tool[0][0]']
#
#  conv2d_15_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_33_chip[0][0]']
#
#  activation_30_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_15_tool[0][0]']
#  tion)
#
#  activation_30_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_15_chip[0][0]']
#  tion)
#
#  batch_normalization_30_too  (None, 16, 16, 256)          1024      ['activation_30_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_30_chi  (None, 16, 16, 256)          1024      ['activation_30_chip[0][0]']
#  p (BatchNormalization)
#
#  add_34_tool (Add)           (None, 16, 16, 256)          0         ['add_23_tool[0][0]',
#                                                                      'batch_normalization_30_tool[
#                                                                     0][0]']
#
#  add_34_chip (Add)           (None, 16, 16, 256)          0         ['add_23_chip[0][0]',
#                                                                      'batch_normalization_30_chip[
#                                                                     0][0]']
#
#  depthwise_conv2d_15_tool (  (None, 16, 16, 256)          6656      ['add_34_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_15_chip (  (None, 16, 16, 256)          6656      ['add_34_chip[0][0]']
#  DepthwiseConv2D)
#
#  activation_31_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_tool[0][
#  tion)                                                              0]']
#
#  activation_31_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_15_chip[0][
#  tion)                                                              0]']
#
#  batch_normalization_31_too  (None, 16, 16, 256)          1024      ['activation_31_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_31_chi  (None, 16, 16, 256)          1024      ['activation_31_chip[0][0]']
#  p (BatchNormalization)
#
#  add_35_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_tool[
#                                                                     0][0]',
#                                                                      'add_34_tool[0][0]']
#
#  add_35_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_31_chip[
#                                                                     0][0]',
#                                                                      'add_34_chip[0][0]']
#
#  conv2d_16_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_tool[0][0]']
#
#  conv2d_16_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_35_chip[0][0]']
#
#  activation_32_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_16_tool[0][0]']
#  tion)
#
#  activation_32_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_16_chip[0][0]']
#  tion)
#
#  batch_normalization_32_too  (None, 16, 16, 256)          1024      ['activation_32_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_32_chi  (None, 16, 16, 256)          1024      ['activation_32_chip[0][0]']
#  p (BatchNormalization)
#
#  add_36_tool (Add)           (None, 16, 16, 256)          0         ['add_25_tool[0][0]',
#                                                                      'batch_normalization_32_tool[
#                                                                     0][0]']
#
#  add_36_chip (Add)           (None, 16, 16, 256)          0         ['add_25_chip[0][0]',
#                                                                      'batch_normalization_32_chip[
#                                                                     0][0]']
#
#  global_average_pooling2d_t  (None, 256)                  0         ['add_36_tool[0][0]']
#  ool (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_c  (None, 256)                  0         ['add_36_chip[0][0]']
#  hip (GlobalAveragePooling2
#  D)
#
#  concatenate (Concatenate)   (None, 512)                  0         ['global_average_pooling2d_too
#                                                                     l[0][0]',
#                                                                      'global_average_pooling2d_chi
#                                                                     p[0][0]']
#
#  output_mult (Dense)         (None, 3)                    1539      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 2781187 (10.61 MB)
# Trainable params: 1539 (6.01 KB)
# Non-trainable params: 2779648 (10.60 MB)
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 13s 2s/step - loss: 3876.9194 - mean_squared_error: 3876.9194 - val_loss: 4775.3521 - val_mean_squared_error: 4775.3521
# Epoch 2/100
# 2/2 [==============================] - 1s 405ms/step - loss: 3759.3601 - mean_squared_error: 3759.3601 - val_loss: 4643.8394 - val_mean_squared_error: 4643.8394
# Epoch 3/100
# 2/2 [==============================] - 1s 404ms/step - loss: 3659.9431 - mean_squared_error: 3659.9431 - val_loss: 4515.0073 - val_mean_squared_error: 4515.0073
# Epoch 4/100
# 2/2 [==============================] - 1s 388ms/step - loss: 3553.2283 - mean_squared_error: 3553.2283 - val_loss: 4390.3530 - val_mean_squared_error: 4390.3530
# Epoch 5/100
# 2/2 [==============================] - 1s 764ms/step - loss: 3456.6367 - mean_squared_error: 3456.6367 - val_loss: 4269.4946 - val_mean_squared_error: 4269.4946
# Epoch 6/100
# 2/2 [==============================] - 1s 442ms/step - loss: 3355.6719 - mean_squared_error: 3355.6719 - val_loss: 4153.2524 - val_mean_squared_error: 4153.2524
# Epoch 7/100
# 2/2 [==============================] - 1s 405ms/step - loss: 3270.6213 - mean_squared_error: 3270.6213 - val_loss: 4040.2500 - val_mean_squared_error: 4040.2500
# Epoch 8/100
# 2/2 [==============================] - 1s 388ms/step - loss: 3180.4409 - mean_squared_error: 3180.4409 - val_loss: 3931.5754 - val_mean_squared_error: 3931.5754
# Epoch 9/100
# 2/2 [==============================] - 1s 398ms/step - loss: 3087.6484 - mean_squared_error: 3087.6484 - val_loss: 3827.5110 - val_mean_squared_error: 3827.5110
# Epoch 10/100
# 2/2 [==============================] - 1s 405ms/step - loss: 3012.4722 - mean_squared_error: 3012.4722 - val_loss: 3725.9119 - val_mean_squared_error: 3725.9119
# Epoch 11/100
# 2/2 [==============================] - 1s 382ms/step - loss: 2935.0669 - mean_squared_error: 2935.0669 - val_loss: 3627.9651 - val_mean_squared_error: 3627.9651
# Epoch 12/100
# 2/2 [==============================] - 1s 391ms/step - loss: 2863.9011 - mean_squared_error: 2863.9011 - val_loss: 3532.5813 - val_mean_squared_error: 3532.5813
# Epoch 13/100
# 2/2 [==============================] - 1s 400ms/step - loss: 2792.1663 - mean_squared_error: 2792.1663 - val_loss: 3440.6045 - val_mean_squared_error: 3440.6045
# Epoch 14/100
# 2/2 [==============================] - 1s 531ms/step - loss: 2717.5496 - mean_squared_error: 2717.5496 - val_loss: 3352.0393 - val_mean_squared_error: 3352.0393
# Epoch 15/100
# 2/2 [==============================] - 1s 582ms/step - loss: 2647.9536 - mean_squared_error: 2647.9536 - val_loss: 3266.6375 - val_mean_squared_error: 3266.6375
# Epoch 16/100
# 2/2 [==============================] - 1s 391ms/step - loss: 2593.1121 - mean_squared_error: 2593.1121 - val_loss: 3182.8059 - val_mean_squared_error: 3182.8059
# Epoch 17/100
# 2/2 [==============================] - 1s 393ms/step - loss: 2528.3259 - mean_squared_error: 2528.3259 - val_loss: 3101.5801 - val_mean_squared_error: 3101.5801
# Epoch 18/100
# 2/2 [==============================] - 1s 397ms/step - loss: 2472.4363 - mean_squared_error: 2472.4363 - val_loss: 3023.2043 - val_mean_squared_error: 3023.2043
# Epoch 19/100
# 2/2 [==============================] - 1s 400ms/step - loss: 2409.7444 - mean_squared_error: 2409.7444 - val_loss: 2947.9641 - val_mean_squared_error: 2947.9641
# Epoch 20/100
# 2/2 [==============================] - 1s 422ms/step - loss: 2356.7385 - mean_squared_error: 2356.7385 - val_loss: 2873.8645 - val_mean_squared_error: 2873.8645
# Epoch 21/100
# 2/2 [==============================] - 1s 395ms/step - loss: 2301.3118 - mean_squared_error: 2301.3118 - val_loss: 2801.1768 - val_mean_squared_error: 2801.1768
# Epoch 22/100
# 2/2 [==============================] - 1s 405ms/step - loss: 2247.6392 - mean_squared_error: 2247.6392 - val_loss: 2730.4338 - val_mean_squared_error: 2730.4338
# Epoch 23/100
# 2/2 [==============================] - 1s 395ms/step - loss: 2198.7795 - mean_squared_error: 2198.7795 - val_loss: 2661.5642 - val_mean_squared_error: 2661.5642
# Epoch 24/100
# 2/2 [==============================] - 1s 398ms/step - loss: 2147.9167 - mean_squared_error: 2147.9167 - val_loss: 2593.8713 - val_mean_squared_error: 2593.8713
# Epoch 25/100
# 2/2 [==============================] - 1s 391ms/step - loss: 2104.9604 - mean_squared_error: 2104.9604 - val_loss: 2527.6692 - val_mean_squared_error: 2527.6692
# Epoch 26/100
# 2/2 [==============================] - 1s 402ms/step - loss: 2051.6128 - mean_squared_error: 2051.6128 - val_loss: 2463.6355 - val_mean_squared_error: 2463.6355
# Epoch 27/100
# 2/2 [==============================] - 1s 515ms/step - loss: 2011.3048 - mean_squared_error: 2011.3048 - val_loss: 2400.2463 - val_mean_squared_error: 2400.2463
# Epoch 28/100
# 2/2 [==============================] - 1s 729ms/step - loss: 1970.4158 - mean_squared_error: 1970.4158 - val_loss: 2338.8533 - val_mean_squared_error: 2338.8533
# Epoch 29/100
# 2/2 [==============================] - 1s 431ms/step - loss: 1925.5724 - mean_squared_error: 1925.5724 - val_loss: 2279.6575 - val_mean_squared_error: 2279.6575
# Epoch 30/100
# 2/2 [==============================] - 1s 395ms/step - loss: 1883.2245 - mean_squared_error: 1883.2245 - val_loss: 2221.9529 - val_mean_squared_error: 2221.9529
# Epoch 31/100
# 2/2 [==============================] - 1s 419ms/step - loss: 1848.1018 - mean_squared_error: 1848.1018 - val_loss: 2164.7781 - val_mean_squared_error: 2164.7781
# Epoch 32/100
# 2/2 [==============================] - 1s 400ms/step - loss: 1807.9602 - mean_squared_error: 1807.9602 - val_loss: 2109.5989 - val_mean_squared_error: 2109.5989
# Epoch 33/100
# 2/2 [==============================] - 1s 414ms/step - loss: 1771.3196 - mean_squared_error: 1771.3196 - val_loss: 2056.0750 - val_mean_squared_error: 2056.0750
# Epoch 34/100
# 2/2 [==============================] - 1s 417ms/step - loss: 1736.9314 - mean_squared_error: 1736.9314 - val_loss: 2003.9677 - val_mean_squared_error: 2003.9677
# Epoch 35/100
# 2/2 [==============================] - 1s 400ms/step - loss: 1702.3047 - mean_squared_error: 1702.3047 - val_loss: 1953.6107 - val_mean_squared_error: 1953.6107
# Epoch 36/100
# 2/2 [==============================] - 1s 410ms/step - loss: 1667.9275 - mean_squared_error: 1667.9275 - val_loss: 1905.1207 - val_mean_squared_error: 1905.1207
# Epoch 37/100
# 2/2 [==============================] - 1s 402ms/step - loss: 1635.9023 - mean_squared_error: 1635.9023 - val_loss: 1857.6215 - val_mean_squared_error: 1857.6215
# Epoch 38/100
# 2/2 [==============================] - 1s 410ms/step - loss: 1608.2521 - mean_squared_error: 1608.2521 - val_loss: 1811.7723 - val_mean_squared_error: 1811.7723
# Epoch 39/100
# 2/2 [==============================] - 1s 405ms/step - loss: 1579.7963 - mean_squared_error: 1579.7963 - val_loss: 1767.0033 - val_mean_squared_error: 1767.0033
# Epoch 40/100
# 2/2 [==============================] - 1s 611ms/step - loss: 1548.4049 - mean_squared_error: 1548.4049 - val_loss: 1724.1866 - val_mean_squared_error: 1724.1866
# Epoch 41/100
# 2/2 [==============================] - 1s 403ms/step - loss: 1520.3558 - mean_squared_error: 1520.3558 - val_loss: 1682.4364 - val_mean_squared_error: 1682.4364
# Epoch 42/100
# 2/2 [==============================] - 1s 401ms/step - loss: 1496.1921 - mean_squared_error: 1496.1921 - val_loss: 1641.4740 - val_mean_squared_error: 1641.4740
# Epoch 43/100
# 2/2 [==============================] - 1s 385ms/step - loss: 1468.8730 - mean_squared_error: 1468.8730 - val_loss: 1601.9985 - val_mean_squared_error: 1601.9985
# Epoch 44/100
# 2/2 [==============================] - 1s 395ms/step - loss: 1447.7697 - mean_squared_error: 1447.7697 - val_loss: 1563.0297 - val_mean_squared_error: 1563.0297
# Epoch 45/100
# 2/2 [==============================] - 1s 422ms/step - loss: 1420.0808 - mean_squared_error: 1420.0808 - val_loss: 1526.0684 - val_mean_squared_error: 1526.0684
# Epoch 46/100
# 2/2 [==============================] - 1s 398ms/step - loss: 1398.1010 - mean_squared_error: 1398.1010 - val_loss: 1490.5677 - val_mean_squared_error: 1490.5677
# Epoch 47/100
# 2/2 [==============================] - 1s 415ms/step - loss: 1377.1125 - mean_squared_error: 1377.1125 - val_loss: 1455.4325 - val_mean_squared_error: 1455.4325
# Epoch 48/100
# 2/2 [==============================] - 1s 395ms/step - loss: 1352.4366 - mean_squared_error: 1352.4366 - val_loss: 1421.2598 - val_mean_squared_error: 1421.2598
# Epoch 49/100
# 2/2 [==============================] - 1s 392ms/step - loss: 1333.6566 - mean_squared_error: 1333.6566 - val_loss: 1388.0576 - val_mean_squared_error: 1388.0576
# Epoch 50/100
# 2/2 [==============================] - 1s 405ms/step - loss: 1316.4835 - mean_squared_error: 1316.4835 - val_loss: 1355.1874 - val_mean_squared_error: 1355.1874
# Epoch 51/100
# 2/2 [==============================] - 1s 609ms/step - loss: 1294.0245 - mean_squared_error: 1294.0245 - val_loss: 1323.9388 - val_mean_squared_error: 1323.9388
# Epoch 52/100
# 2/2 [==============================] - 1s 834ms/step - loss: 1275.1409 - mean_squared_error: 1275.1409 - val_loss: 1293.7743 - val_mean_squared_error: 1293.7743
# Epoch 53/100
# 2/2 [==============================] - 1s 390ms/step - loss: 1259.6600 - mean_squared_error: 1259.6600 - val_loss: 1264.7725 - val_mean_squared_error: 1264.7725
# Epoch 54/100
# 2/2 [==============================] - 1s 382ms/step - loss: 1238.4427 - mean_squared_error: 1238.4427 - val_loss: 1236.7733 - val_mean_squared_error: 1236.7733
# Epoch 55/100
# 2/2 [==============================] - 1s 403ms/step - loss: 1222.3021 - mean_squared_error: 1222.3024 - val_loss: 1209.6188 - val_mean_squared_error: 1209.6188
# Epoch 56/100
# 2/2 [==============================] - 1s 416ms/step - loss: 1208.2260 - mean_squared_error: 1208.2260 - val_loss: 1183.2069 - val_mean_squared_error: 1183.2069
# Epoch 57/100
# 2/2 [==============================] - 1s 401ms/step - loss: 1191.2668 - mean_squared_error: 1191.2668 - val_loss: 1157.1088 - val_mean_squared_error: 1157.1088
# Epoch 58/100
# 2/2 [==============================] - 1s 650ms/step - loss: 1175.9297 - mean_squared_error: 1175.9297 - val_loss: 1132.2362 - val_mean_squared_error: 1132.2362
# Epoch 59/100
# 2/2 [==============================] - 1s 728ms/step - loss: 1163.0885 - mean_squared_error: 1163.0885 - val_loss: 1108.3154 - val_mean_squared_error: 1108.3154
# Epoch 60/100
# 2/2 [==============================] - 1s 395ms/step - loss: 1148.9923 - mean_squared_error: 1148.9924 - val_loss: 1084.9581 - val_mean_squared_error: 1084.9581
# Epoch 61/100
# 2/2 [==============================] - 1s 384ms/step - loss: 1136.4648 - mean_squared_error: 1136.4648 - val_loss: 1061.7523 - val_mean_squared_error: 1061.7523
# Epoch 62/100
# 2/2 [==============================] - 1s 647ms/step - loss: 1121.6411 - mean_squared_error: 1121.6411 - val_loss: 1039.4952 - val_mean_squared_error: 1039.4952
# Epoch 63/100
# 2/2 [==============================] - 1s 776ms/step - loss: 1109.1174 - mean_squared_error: 1109.1174 - val_loss: 1018.1611 - val_mean_squared_error: 1018.1611
# Epoch 64/100
# 2/2 [==============================] - 1s 418ms/step - loss: 1097.5764 - mean_squared_error: 1097.5764 - val_loss: 997.5498 - val_mean_squared_error: 997.5498
# Epoch 65/100
# 2/2 [==============================] - 1s 383ms/step - loss: 1088.1887 - mean_squared_error: 1088.1887 - val_loss: 977.9084 - val_mean_squared_error: 977.9084
# Epoch 66/100
# 2/2 [==============================] - 1s 415ms/step - loss: 1075.2203 - mean_squared_error: 1075.2203 - val_loss: 958.6751 - val_mean_squared_error: 958.6751
# Epoch 67/100
# 2/2 [==============================] - 1s 386ms/step - loss: 1064.8533 - mean_squared_error: 1064.8533 - val_loss: 940.0720 - val_mean_squared_error: 940.0720
# Epoch 68/100
# 2/2 [==============================] - 1s 394ms/step - loss: 1055.3234 - mean_squared_error: 1055.3234 - val_loss: 922.0583 - val_mean_squared_error: 922.0583
# Epoch 69/100
# 2/2 [==============================] - 1s 381ms/step - loss: 1046.2639 - mean_squared_error: 1046.2639 - val_loss: 905.2640 - val_mean_squared_error: 905.2640
# Epoch 70/100
# 2/2 [==============================] - 1s 407ms/step - loss: 1035.5326 - mean_squared_error: 1035.5326 - val_loss: 888.2441 - val_mean_squared_error: 888.2441
# Epoch 71/100
# 2/2 [==============================] - 1s 390ms/step - loss: 1030.2938 - mean_squared_error: 1030.2938 - val_loss: 871.7917 - val_mean_squared_error: 871.7917
# Epoch 72/100
# 2/2 [==============================] - 1s 407ms/step - loss: 1020.3300 - mean_squared_error: 1020.3300 - val_loss: 856.1935 - val_mean_squared_error: 856.1935
# Epoch 73/100
# 2/2 [==============================] - 1s 387ms/step - loss: 1009.2417 - mean_squared_error: 1009.2417 - val_loss: 841.3454 - val_mean_squared_error: 841.3454
# Epoch 74/100
# 2/2 [==============================] - 1s 765ms/step - loss: 1004.2427 - mean_squared_error: 1004.2427 - val_loss: 826.4108 - val_mean_squared_error: 826.4108
# Epoch 75/100
# 2/2 [==============================] - 1s 513ms/step - loss: 995.8069 - mean_squared_error: 995.8069 - val_loss: 811.6464 - val_mean_squared_error: 811.6464
# Epoch 76/100
# 2/2 [==============================] - 1s 405ms/step - loss: 988.1187 - mean_squared_error: 988.1187 - val_loss: 797.6833 - val_mean_squared_error: 797.6833
# Epoch 77/100
# 2/2 [==============================] - 1s 404ms/step - loss: 981.7147 - mean_squared_error: 981.7147 - val_loss: 784.2955 - val_mean_squared_error: 784.2955
# Epoch 78/100
# 2/2 [==============================] - 1s 404ms/step - loss: 976.8073 - mean_squared_error: 976.8073 - val_loss: 772.0049 - val_mean_squared_error: 772.0049
# Epoch 79/100
# 2/2 [==============================] - 1s 391ms/step - loss: 969.3925 - mean_squared_error: 969.3925 - val_loss: 760.0928 - val_mean_squared_error: 760.0928
# Epoch 80/100
# 2/2 [==============================] - 1s 867ms/step - loss: 963.6844 - mean_squared_error: 963.6844 - val_loss: 747.7418 - val_mean_squared_error: 747.7418
# Epoch 81/100
# 2/2 [==============================] - 1s 394ms/step - loss: 956.9199 - mean_squared_error: 956.9199 - val_loss: 735.6999 - val_mean_squared_error: 735.6999
# Epoch 82/100
# 2/2 [==============================] - 1s 387ms/step - loss: 950.9134 - mean_squared_error: 950.9134 - val_loss: 724.5380 - val_mean_squared_error: 724.5380
# Epoch 83/100
# 2/2 [==============================] - 1s 416ms/step - loss: 947.2040 - mean_squared_error: 947.2040 - val_loss: 713.4021 - val_mean_squared_error: 713.4021
# Epoch 84/100
# 2/2 [==============================] - 1s 413ms/step - loss: 940.8250 - mean_squared_error: 940.8250 - val_loss: 703.5672 - val_mean_squared_error: 703.5672
# Epoch 85/100
# 2/2 [==============================] - 1s 748ms/step - loss: 935.7889 - mean_squared_error: 935.7889 - val_loss: 694.4514 - val_mean_squared_error: 694.4514
# Epoch 86/100
# 2/2 [==============================] - 1s 561ms/step - loss: 930.7137 - mean_squared_error: 930.7137 - val_loss: 685.5537 - val_mean_squared_error: 685.5537
# Epoch 87/100
# 2/2 [==============================] - 1s 392ms/step - loss: 928.1353 - mean_squared_error: 928.1353 - val_loss: 677.0076 - val_mean_squared_error: 677.0076
# Epoch 88/100
# 2/2 [==============================] - 1s 405ms/step - loss: 922.1590 - mean_squared_error: 922.1590 - val_loss: 668.1911 - val_mean_squared_error: 668.1911
# Epoch 89/100
# 2/2 [==============================] - 1s 407ms/step - loss: 918.1265 - mean_squared_error: 918.1265 - val_loss: 659.7023 - val_mean_squared_error: 659.7023
# Epoch 90/100
# 2/2 [==============================] - 1s 417ms/step - loss: 915.1844 - mean_squared_error: 915.1844 - val_loss: 652.1702 - val_mean_squared_error: 652.1702
# Epoch 91/100
# 2/2 [==============================] - 1s 409ms/step - loss: 909.9463 - mean_squared_error: 909.9463 - val_loss: 644.1989 - val_mean_squared_error: 644.1989
# Epoch 92/100
# 2/2 [==============================] - 1s 409ms/step - loss: 907.8376 - mean_squared_error: 907.8376 - val_loss: 636.7742 - val_mean_squared_error: 636.7742
# Epoch 93/100
# 2/2 [==============================] - 1s 400ms/step - loss: 902.3389 - mean_squared_error: 902.3389 - val_loss: 629.6817 - val_mean_squared_error: 629.6817
# Epoch 94/100
# 2/2 [==============================] - 1s 399ms/step - loss: 898.9902 - mean_squared_error: 898.9902 - val_loss: 622.8334 - val_mean_squared_error: 622.8334
# Epoch 95/100
# 2/2 [==============================] - 1s 564ms/step - loss: 897.0092 - mean_squared_error: 897.0092 - val_loss: 616.3785 - val_mean_squared_error: 616.3785
# Epoch 96/100
# 2/2 [==============================] - 1s 715ms/step - loss: 893.9476 - mean_squared_error: 893.9476 - val_loss: 609.7012 - val_mean_squared_error: 609.7012
# Epoch 97/100
# 2/2 [==============================] - 1s 404ms/step - loss: 889.9082 - mean_squared_error: 889.9082 - val_loss: 602.9794 - val_mean_squared_error: 602.9794
# Epoch 98/100
# 2/2 [==============================] - 1s 411ms/step - loss: 887.0675 - mean_squared_error: 887.0675 - val_loss: 596.6309 - val_mean_squared_error: 596.6309
# Epoch 99/100
# 2/2 [==============================] - 1s 405ms/step - loss: 883.5991 - mean_squared_error: 883.5991 - val_loss: 591.0876 - val_mean_squared_error: 591.0876
# Epoch 100/100
# 2/2 [==============================] - 1s 406ms/step - loss: 880.9360 - mean_squared_error: 880.9360 - val_loss: 585.6343 - val_mean_squared_error: 585.6343
# 1/1 [==============================] - 0s 136ms/step - loss: 6902.0151 - mean_squared_error: 6902.0151
# Test error: 6902.02

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  12.882802022298177
# MSE:  201.83780731523396
# RMSE:  14.206963338983948
# r2_score:  -0.912936583568998
# MSLE:  5.555733217519911
# MAPE:  5.0841131337209176e+16
# ===== flank_wear results =====
# MAE:  100.42209370930989
# MSE:  20454.260762126774
# RMSE:  143.01839309028324
# r2_score:  -0.2766075984465146
# MSLE:  0.7180707705854537
# MAPE:  0.6205054000585758
# ===== overhang results =====
# MAE:  5.49625213623047
# MSE:  49.94443870215418
# RMSE:  7.067137942771047
# r2_score:  -1.4758716684203637
# MSLE:  0.2703574453329243
# MAPE:  0.6286610587609353
# ===== multi results =====
# MAE:  39.60038262261285
# MSE:  6902.014336048054
# RMSE:  54.76416479067941
# r2_score:  -0.8884719501452921
# MSLE:  2.1813871444794293
# MAPE:  1.6947043779069726e+16
